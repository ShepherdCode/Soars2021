# %% [markdown]
# # ORF recognition by CNN
#
# In 105, we used Conv1D layers with filter width=3 with dropout to reduce overfitting. The simulated RNA lengths were 1000.
#
# Here, try really short simulated RNA.
#
#
#
# RNA_LENS=71, CDS_LEN=63 and was cut in half with layers with filters 8 and 30 epochs with 5 folds.

# %%
import time 
t = time.time()
time.strftime('%Y-%m-%d %H:%M:%S %Z', time.localtime(t))
# Out:
# '2021-06-14 14:27:49 UTC'

# %%
PC_SEQUENCES=2000   # how many protein-coding sequences
NC_SEQUENCES=2000   # how many non-coding sequences
PC_TESTS=1000
NC_TESTS=1000
RNA_LEN=91            # how long is each sequence
CDS_LEN=73
ALPHABET=4          # how many different letters are possible
INPUT_SHAPE_2D = (RNA_LEN,ALPHABET,1) # Conv2D needs 3D inputs
INPUT_SHAPE = (RNA_LEN,ALPHABET) # Conv1D needs 2D inputs
FILTERS = 16   # how many different patterns the model looks for
NEURONS = 8
DROP_RATE = 0.2
WIDTH = 3   # how wide each pattern is, in bases
STRIDE_2D = (1,1)  # For Conv2D how far in each direction
STRIDE = 1 # For Conv1D, how far between pattern matches, in bases
EPOCHS=30  # how many times to train on all the data
SPLITS=5  # SPLITS=3 means train on 2/3 and validate on 1/3 
FOLDS=5  # train the model this many times (range 1 to SPLITS)

# %%
import sys
try:
    from google.colab import drive
    IN_COLAB = True
    print("On Google CoLab, mount cloud-local file, get our code from GitHub.")
    PATH='/content/drive/'
    #drive.mount(PATH,force_remount=True)  # hardly ever need this
    #drive.mount(PATH)    # Google will require login credentials
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/RNA_gen.py')
    with open('RNA_gen.py', 'w') as f:
        f.write(r.text)  
    from RNA_gen import *
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/RNA_describe.py')
    with open('RNA_describe.py', 'w') as f:
        f.write(r.text)  
    from RNA_describe import ORF_counter
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/RNA_prep.py')
    with open('RNA_prep.py', 'w') as f:
        f.write(r.text)  
    from RNA_prep import *
except:
    print("CoLab not working. On my PC, use relative paths.")
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"
    sys.path.append("..") # append parent dir in order to use sibling dirs
    from SimTools.RNA_gen import *
    from SimTools.RNA_describe import ORF_counter
    from SimTools.RNA_prep import *

MODELPATH="BestModel"  # saved on cloud instance and lost after logout
#MODELPATH=DATAPATH+MODELPATH  # saved on Google Drive but requires login

if not assert_imported_RNA_gen():
    print("ERROR: Cannot use RNA_gen.")
if not assert_imported_RNA_prep():
    print("ERROR: Cannot use RNA_prep.")
# Out:
# On Google CoLab, mount cloud-local file, get our code from GitHub.

# %%
from os import listdir
import csv
from zipfile import ZipFile

import numpy as np
import pandas as pd
from scipy import stats  # mode

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

from keras.models import Sequential
from keras.layers import Dense,Embedding,Dropout
from keras.layers import Conv1D,Conv2D
from keras.layers import Flatten,MaxPooling1D,MaxPooling2D
from keras.losses import BinaryCrossentropy
# tf.keras.losses.BinaryCrossentropy

import matplotlib.pyplot as plt
from matplotlib import colors
mycmap = colors.ListedColormap(['red','blue'])  # list color for label 0 then 1
np.set_printoptions(precision=2)

# %%
# Use code from our SimTools library.
def make_generators(seq_len):
    pcgen = Collection_Generator()  
    pcgen.get_len_oracle().set_mean(seq_len)
    tora = Transcript_Oracle()
    tora.set_cds_len_mean(CDS_LEN)  # CDS=ORF+STOP. 
    pcgen.set_seq_oracle(tora)
    ncgen = Collection_Generator()  
    ncgen.get_len_oracle().set_mean(seq_len)
    return pcgen,ncgen

pc_sim,nc_sim = make_generators(RNA_LEN)
pc_train = pc_sim.get_sequences(PC_SEQUENCES)
nc_train = nc_sim.get_sequences(NC_SEQUENCES)
print("Train on",len(pc_train),"PC seqs")
print("Train on",len(nc_train),"NC seqs")
# Out:
# Train on 2000 PC seqs
# Train on 2000 NC seqs

# %%
# Describe the sequences
def describe_sequences(list_of_seq):
    oc = ORF_counter()
    num_seq = len(list_of_seq)
    rna_lens = np.zeros(num_seq)
    orf_lens = np.zeros(num_seq)
    for i in range(0,num_seq):
        rna_len = len(list_of_seq[i])
        rna_lens[i] = rna_len
        oc.set_sequence(list_of_seq[i])
        orf_len = oc.get_max_orf_len()
        orf_lens[i] = orf_len
    print ("Average RNA length:",rna_lens.mean())
    print ("Average ORF length:",orf_lens.mean())
    
print("PC train")
describe_sequences(pc_train)
print("NC train")
describe_sequences(nc_train)
# Out:
# PC train
# Average RNA length: 91.0
# Average ORF length: 68.748
# NC train
# Average RNA length: 91.0
# Average ORF length: 12.609

# %%
# Use code from our SimTools library.
X,y = prepare_inputs_len_x_alphabet(pc_train,nc_train,ALPHABET) # shuffles
print("Data ready.")
# Out:
# Data ready.

# %%
def make_DNN():
    print("make_DNN")
    print("input shape:",INPUT_SHAPE)
    dnn = Sequential()
    #dnn.add(Embedding(input_dim=INPUT_SHAPE,output_dim=INPUT_SHAPE)) 
    dnn.add(Conv1D(filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,padding="same",
            input_shape=INPUT_SHAPE))
    #dnn.add(Conv1D(filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,padding="same"))
    dnn.add(MaxPooling1D())
    dnn.add(Flatten())
    dnn.add(Dense(NEURONS,activation="sigmoid",dtype=np.float32))   
    dnn.add(Dropout(DROP_RATE))
    dnn.add(Dense(1,activation="sigmoid",dtype=np.float32))   
    dnn.compile(optimizer='adam',
                loss=BinaryCrossentropy(from_logits=False),
                metrics=['accuracy'])   # add to default metrics=loss
    dnn.build(input_shape=INPUT_SHAPE)
    #ln_rate = tf.keras.optimizers.Adam(learning_rate = LN_RATE)
    #bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    #model.compile(loss=bc, optimizer=ln_rate, metrics=["accuracy"])
    return dnn
model = make_DNN()
print(model.summary())
# Out:
# make_DNN
# input shape: (91, 4)
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_4 (Conv1D)            (None, 91, 16)            208
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 45, 16)            0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 720)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 8)                 5768
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 5,985
# Trainable params: 5,985
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from keras.callbacks import ModelCheckpoint
def do_cross_validation(X,y):
    cv_scores = []
    fold=0
    mycallbacks = [ModelCheckpoint(
        filepath=MODELPATH, save_best_only=True, 
        monitor='val_accuracy', mode='max')]   
    splitter = KFold(n_splits=SPLITS)  # this does not shuffle
    for train_index,valid_index in splitter.split(X):
        if fold < FOLDS:
            fold += 1
            X_train=X[train_index] # inputs for training
            y_train=y[train_index] # labels for training
            X_valid=X[valid_index] # inputs for validation
            y_valid=y[valid_index] # labels for validation
            print("MODEL")
            # Call constructor on each CV. Else, continually improves the same model.
            model = model = make_DNN()
            print("FIT")  # model.fit() implements learning
            start_time=time.time()
            history=model.fit(X_train, y_train, 
                    epochs=EPOCHS, 
                    verbose=1,  # ascii art while learning
                    callbacks=mycallbacks,   # called at end of each epoch
                    validation_data=(X_valid,y_valid))
            end_time=time.time()
            elapsed_time=(end_time-start_time)                        
            print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
            # print(history.history.keys())  # all these keys will be shown in figure
            pd.DataFrame(history.history).plot(figsize=(8,5))
            plt.grid(True)
            plt.gca().set_ylim(0,1) # any losses > 1 will be off the scale
            plt.show()

# %%
do_cross_validation(X,y)
# Out:
# MODEL
# make_DNN
# input shape: (91, 4)
# FIT
# Epoch 1/30
# 100/100 [==============================] - 1s 5ms/step - loss: 0.7126 - accuracy: 0.5051 - val_loss: 0.6845 - val_accuracy: 0.5113
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 2/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6769 - accuracy: 0.5722 - val_loss: 0.6595 - val_accuracy: 0.6438
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 3/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6509 - accuracy: 0.6203 - val_loss: 0.6338 - val_accuracy: 0.6762
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 4/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6321 - accuracy: 0.6508 - val_loss: 0.6126 - val_accuracy: 0.6938
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 5/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6128 - accuracy: 0.6701 - val_loss: 0.5999 - val_accuracy: 0.6950
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 6/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5945 - accuracy: 0.6775 - val_loss: 0.5866 - val_accuracy: 0.7025
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 7/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5756 - accuracy: 0.7078 - val_loss: 0.5726 - val_accuracy: 0.7100
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 8/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5571 - accuracy: 0.7263 - val_loss: 0.5664 - val_accuracy: 0.7125
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 9/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5462 - accuracy: 0.7370 - val_loss: 0.5580 - val_accuracy: 0.7163
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 10/30
# 100/100 [==============================] - 0s 2ms/step - loss: 0.5232 - accuracy: 0.7561 - val_loss: 0.5526 - val_accuracy: 0.7262
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 11/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5209 - accuracy: 0.7565 - val_loss: 0.5478 - val_accuracy: 0.7275
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 12/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4974 - accuracy: 0.7608 - val_loss: 0.5551 - val_accuracy: 0.7125
# Epoch 13/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5029 - accuracy: 0.7620 - val_loss: 0.5433 - val_accuracy: 0.7412
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 14/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5013 - accuracy: 0.7564 - val_loss: 0.5540 - val_accuracy: 0.7237
# Epoch 15/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4788 - accuracy: 0.7914 - val_loss: 0.5406 - val_accuracy: 0.7400
# Epoch 16/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4714 - accuracy: 0.7795 - val_loss: 0.5400 - val_accuracy: 0.7337
# Epoch 17/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4596 - accuracy: 0.7893 - val_loss: 0.5380 - val_accuracy: 0.7425
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 18/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4581 - accuracy: 0.7932 - val_loss: 0.5404 - val_accuracy: 0.7325
# Epoch 19/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4512 - accuracy: 0.7940 - val_loss: 0.5384 - val_accuracy: 0.7337
# Epoch 20/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4346 - accuracy: 0.7960 - val_loss: 0.5394 - val_accuracy: 0.7387
# Epoch 21/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4420 - accuracy: 0.7985 - val_loss: 0.5372 - val_accuracy: 0.7375
# Epoch 22/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4268 - accuracy: 0.8164 - val_loss: 0.5399 - val_accuracy: 0.7412
# Epoch 23/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4131 - accuracy: 0.8209 - val_loss: 0.5403 - val_accuracy: 0.7325
# Epoch 24/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4121 - accuracy: 0.8147 - val_loss: 0.5397 - val_accuracy: 0.7350
# Epoch 25/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3925 - accuracy: 0.8403 - val_loss: 0.5432 - val_accuracy: 0.7375
# Epoch 26/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4018 - accuracy: 0.8268 - val_loss: 0.5433 - val_accuracy: 0.7375
# Epoch 27/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3953 - accuracy: 0.8340 - val_loss: 0.5432 - val_accuracy: 0.7350
# Epoch 28/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3963 - accuracy: 0.8337 - val_loss: 0.5477 - val_accuracy: 0.7325
# Epoch 29/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3782 - accuracy: 0.8400 - val_loss: 0.5486 - val_accuracy: 0.7387
# Epoch 30/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3548 - accuracy: 0.8547 - val_loss: 0.5519 - val_accuracy: 0.7275
# Fold 1, 30 epochs, 19 sec
# MODEL
# make_DNN
# input shape: (91, 4)
# FIT
# Epoch 1/30
# 100/100 [==============================] - 1s 5ms/step - loss: 0.7329 - accuracy: 0.5225 - val_loss: 0.6910 - val_accuracy: 0.5100
# Epoch 2/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6857 - accuracy: 0.5425 - val_loss: 0.6792 - val_accuracy: 0.6075
# Epoch 3/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6732 - accuracy: 0.5927 - val_loss: 0.6642 - val_accuracy: 0.6200
# Epoch 4/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6566 - accuracy: 0.6268 - val_loss: 0.6478 - val_accuracy: 0.6237
# Epoch 5/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6389 - accuracy: 0.6351 - val_loss: 0.6338 - val_accuracy: 0.6413
# Epoch 6/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6117 - accuracy: 0.6618 - val_loss: 0.6159 - val_accuracy: 0.6538
# Epoch 7/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5971 - accuracy: 0.6860 - val_loss: 0.6053 - val_accuracy: 0.6712
# Epoch 8/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5761 - accuracy: 0.7076 - val_loss: 0.5909 - val_accuracy: 0.6875
# Epoch 9/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5710 - accuracy: 0.7043 - val_loss: 0.5839 - val_accuracy: 0.6787
# Epoch 10/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5493 - accuracy: 0.7366 - val_loss: 0.5690 - val_accuracy: 0.7050
# Epoch 11/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5318 - accuracy: 0.7448 - val_loss: 0.5613 - val_accuracy: 0.7113
# Epoch 12/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5134 - accuracy: 0.7645 - val_loss: 0.5572 - val_accuracy: 0.7125
# Epoch 13/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5048 - accuracy: 0.7855 - val_loss: 0.5512 - val_accuracy: 0.7175
# Epoch 14/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4960 - accuracy: 0.7738 - val_loss: 0.5443 - val_accuracy: 0.7138
# Epoch 15/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4899 - accuracy: 0.7821 - val_loss: 0.5404 - val_accuracy: 0.7138
# Epoch 16/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4777 - accuracy: 0.7801 - val_loss: 0.5387 - val_accuracy: 0.7188
# Epoch 17/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4807 - accuracy: 0.7797 - val_loss: 0.5358 - val_accuracy: 0.7188
# Epoch 18/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4538 - accuracy: 0.8021 - val_loss: 0.5331 - val_accuracy: 0.7250
# Epoch 19/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4575 - accuracy: 0.7961 - val_loss: 0.5335 - val_accuracy: 0.7250
# Epoch 20/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4321 - accuracy: 0.8131 - val_loss: 0.5300 - val_accuracy: 0.7325
# Epoch 21/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4353 - accuracy: 0.8080 - val_loss: 0.5335 - val_accuracy: 0.7300
# Epoch 22/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4282 - accuracy: 0.8138 - val_loss: 0.5290 - val_accuracy: 0.7375
# Epoch 23/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4380 - accuracy: 0.8069 - val_loss: 0.5315 - val_accuracy: 0.7337
# Epoch 24/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4132 - accuracy: 0.8264 - val_loss: 0.5295 - val_accuracy: 0.7400
# Epoch 25/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3928 - accuracy: 0.8354 - val_loss: 0.5305 - val_accuracy: 0.7362
# Epoch 26/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3880 - accuracy: 0.8385 - val_loss: 0.5362 - val_accuracy: 0.7287
# Epoch 27/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3891 - accuracy: 0.8438 - val_loss: 0.5329 - val_accuracy: 0.7325
# Epoch 28/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3873 - accuracy: 0.8458 - val_loss: 0.5362 - val_accuracy: 0.7325
# Epoch 29/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3742 - accuracy: 0.8534 - val_loss: 0.5349 - val_accuracy: 0.7437
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 30/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3670 - accuracy: 0.8578 - val_loss: 0.5356 - val_accuracy: 0.7375
# Fold 2, 30 epochs, 10 sec
# MODEL
# make_DNN
# input shape: (91, 4)
# FIT
# Epoch 1/30
# 100/100 [==============================] - 1s 5ms/step - loss: 0.7192 - accuracy: 0.4937 - val_loss: 0.6885 - val_accuracy: 0.5337
# Epoch 2/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6846 - accuracy: 0.5472 - val_loss: 0.6811 - val_accuracy: 0.5725
# Epoch 3/30
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6759 - accuracy: 0.5729 - val_loss: 0.6642 - val_accuracy: 0.6087
# Epoch 4/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6526 - accuracy: 0.6299 - val_loss: 0.6435 - val_accuracy: 0.6313
# Epoch 5/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6250 - accuracy: 0.6669 - val_loss: 0.6278 - val_accuracy: 0.6475
# Epoch 6/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6091 - accuracy: 0.6855 - val_loss: 0.6189 - val_accuracy: 0.6637
# Epoch 7/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5796 - accuracy: 0.7132 - val_loss: 0.6006 - val_accuracy: 0.6812
# Epoch 8/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5701 - accuracy: 0.7203 - val_loss: 0.5881 - val_accuracy: 0.6963
# Epoch 9/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5432 - accuracy: 0.7281 - val_loss: 0.5746 - val_accuracy: 0.7013
# Epoch 10/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5288 - accuracy: 0.7401 - val_loss: 0.5652 - val_accuracy: 0.7188
# Epoch 11/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5085 - accuracy: 0.7587 - val_loss: 0.5555 - val_accuracy: 0.7250
# Epoch 12/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4953 - accuracy: 0.7708 - val_loss: 0.5483 - val_accuracy: 0.7275
# Epoch 13/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4870 - accuracy: 0.7781 - val_loss: 0.5438 - val_accuracy: 0.7275
# Epoch 14/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4843 - accuracy: 0.7797 - val_loss: 0.5390 - val_accuracy: 0.7300
# Epoch 15/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4785 - accuracy: 0.7797 - val_loss: 0.5358 - val_accuracy: 0.7337
# Epoch 16/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4658 - accuracy: 0.7927 - val_loss: 0.5305 - val_accuracy: 0.7362
# Epoch 17/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4307 - accuracy: 0.8120 - val_loss: 0.5267 - val_accuracy: 0.7325
# Epoch 18/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4398 - accuracy: 0.8024 - val_loss: 0.5261 - val_accuracy: 0.7350
# Epoch 19/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4192 - accuracy: 0.8250 - val_loss: 0.5279 - val_accuracy: 0.7400
# Epoch 20/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4249 - accuracy: 0.8092 - val_loss: 0.5173 - val_accuracy: 0.7437
# Epoch 21/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4260 - accuracy: 0.8128 - val_loss: 0.5181 - val_accuracy: 0.7513
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 22/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3961 - accuracy: 0.8281 - val_loss: 0.5175 - val_accuracy: 0.7437
# Epoch 23/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3832 - accuracy: 0.8399 - val_loss: 0.5214 - val_accuracy: 0.7425
# Epoch 24/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3928 - accuracy: 0.8331 - val_loss: 0.5167 - val_accuracy: 0.7462
# Epoch 25/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3696 - accuracy: 0.8471 - val_loss: 0.5175 - val_accuracy: 0.7412
# Epoch 26/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3720 - accuracy: 0.8468 - val_loss: 0.5297 - val_accuracy: 0.7250
# Epoch 27/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3811 - accuracy: 0.8315 - val_loss: 0.5283 - val_accuracy: 0.7300
# Epoch 28/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3307 - accuracy: 0.8662 - val_loss: 0.5204 - val_accuracy: 0.7525
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 29/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3489 - accuracy: 0.8578 - val_loss: 0.5185 - val_accuracy: 0.7437
# Epoch 30/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3271 - accuracy: 0.8707 - val_loss: 0.5237 - val_accuracy: 0.7375
# Fold 3, 30 epochs, 11 sec
# MODEL
# make_DNN
# input shape: (91, 4)
# FIT
# Epoch 1/30
# 100/100 [==============================] - 1s 5ms/step - loss: 0.6942 - accuracy: 0.5255 - val_loss: 0.6795 - val_accuracy: 0.5925
# Epoch 2/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6753 - accuracy: 0.5721 - val_loss: 0.6612 - val_accuracy: 0.6375
# Epoch 3/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6485 - accuracy: 0.6410 - val_loss: 0.6407 - val_accuracy: 0.6712
# Epoch 4/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6203 - accuracy: 0.6676 - val_loss: 0.6235 - val_accuracy: 0.6787
# Epoch 5/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5995 - accuracy: 0.7017 - val_loss: 0.6054 - val_accuracy: 0.6850
# Epoch 6/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5807 - accuracy: 0.7073 - val_loss: 0.5893 - val_accuracy: 0.6925
# Epoch 7/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5528 - accuracy: 0.7268 - val_loss: 0.5812 - val_accuracy: 0.7075
# Epoch 8/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5215 - accuracy: 0.7571 - val_loss: 0.5733 - val_accuracy: 0.7163
# Epoch 9/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5080 - accuracy: 0.7663 - val_loss: 0.5579 - val_accuracy: 0.7188
# Epoch 10/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5026 - accuracy: 0.7709 - val_loss: 0.5500 - val_accuracy: 0.7325
# Epoch 11/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4865 - accuracy: 0.7833 - val_loss: 0.5448 - val_accuracy: 0.7425
# Epoch 12/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4793 - accuracy: 0.7813 - val_loss: 0.5406 - val_accuracy: 0.7375
# Epoch 13/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4592 - accuracy: 0.7888 - val_loss: 0.5371 - val_accuracy: 0.7412
# Epoch 14/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4540 - accuracy: 0.7990 - val_loss: 0.5402 - val_accuracy: 0.7462
# Epoch 15/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4483 - accuracy: 0.7991 - val_loss: 0.5382 - val_accuracy: 0.7425
# Epoch 16/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4353 - accuracy: 0.7986 - val_loss: 0.5329 - val_accuracy: 0.7487
# Epoch 17/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4203 - accuracy: 0.8219 - val_loss: 0.5376 - val_accuracy: 0.7450
# Epoch 18/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4095 - accuracy: 0.8265 - val_loss: 0.5365 - val_accuracy: 0.7412
# Epoch 19/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4079 - accuracy: 0.8259 - val_loss: 0.5324 - val_accuracy: 0.7513
# Epoch 20/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4109 - accuracy: 0.8158 - val_loss: 0.5308 - val_accuracy: 0.7475
# Epoch 21/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4203 - accuracy: 0.8185 - val_loss: 0.5355 - val_accuracy: 0.7487
# Epoch 22/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3865 - accuracy: 0.8414 - val_loss: 0.5366 - val_accuracy: 0.7462
# Epoch 23/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3869 - accuracy: 0.8424 - val_loss: 0.5391 - val_accuracy: 0.7425
# Epoch 24/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3991 - accuracy: 0.8258 - val_loss: 0.5457 - val_accuracy: 0.7437
# Epoch 25/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3780 - accuracy: 0.8432 - val_loss: 0.5358 - val_accuracy: 0.7500
# Epoch 26/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3777 - accuracy: 0.8373 - val_loss: 0.5406 - val_accuracy: 0.7500
# Epoch 27/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3728 - accuracy: 0.8365 - val_loss: 0.5418 - val_accuracy: 0.7563
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 28/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3538 - accuracy: 0.8527 - val_loss: 0.5429 - val_accuracy: 0.7525
# Epoch 29/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3368 - accuracy: 0.8705 - val_loss: 0.5510 - val_accuracy: 0.7500
# Epoch 30/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3406 - accuracy: 0.8641 - val_loss: 0.5527 - val_accuracy: 0.7500
# Fold 4, 30 epochs, 10 sec
# MODEL
# make_DNN
# input shape: (91, 4)
# FIT
# Epoch 1/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.7026 - accuracy: 0.4988 - val_loss: 0.6908 - val_accuracy: 0.4900
# Epoch 2/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6838 - accuracy: 0.5583 - val_loss: 0.6683 - val_accuracy: 0.6200
# Epoch 3/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6521 - accuracy: 0.6388 - val_loss: 0.6466 - val_accuracy: 0.6425
# Epoch 4/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6225 - accuracy: 0.6757 - val_loss: 0.6253 - val_accuracy: 0.6675
# Epoch 5/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5882 - accuracy: 0.7210 - val_loss: 0.6089 - val_accuracy: 0.6787
# Epoch 6/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5622 - accuracy: 0.7283 - val_loss: 0.5954 - val_accuracy: 0.6837
# Epoch 7/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5389 - accuracy: 0.7425 - val_loss: 0.5844 - val_accuracy: 0.6900
# Epoch 8/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5146 - accuracy: 0.7679 - val_loss: 0.5799 - val_accuracy: 0.7038
# Epoch 9/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5134 - accuracy: 0.7542 - val_loss: 0.5688 - val_accuracy: 0.7063
# Epoch 10/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4907 - accuracy: 0.7763 - val_loss: 0.5641 - val_accuracy: 0.7063
# Epoch 11/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4755 - accuracy: 0.7799 - val_loss: 0.5590 - val_accuracy: 0.7175
# Epoch 12/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4560 - accuracy: 0.7977 - val_loss: 0.5543 - val_accuracy: 0.7150
# Epoch 13/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4576 - accuracy: 0.8027 - val_loss: 0.5545 - val_accuracy: 0.7125
# Epoch 14/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4454 - accuracy: 0.8049 - val_loss: 0.5657 - val_accuracy: 0.7050
# Epoch 15/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4314 - accuracy: 0.8121 - val_loss: 0.5539 - val_accuracy: 0.7300
# Epoch 16/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4211 - accuracy: 0.8100 - val_loss: 0.5486 - val_accuracy: 0.7237
# Epoch 17/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4074 - accuracy: 0.8275 - val_loss: 0.5667 - val_accuracy: 0.7038
# Epoch 18/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4112 - accuracy: 0.8201 - val_loss: 0.5520 - val_accuracy: 0.7250
# Epoch 19/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3997 - accuracy: 0.8267 - val_loss: 0.5555 - val_accuracy: 0.7300
# Epoch 20/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4073 - accuracy: 0.8243 - val_loss: 0.5581 - val_accuracy: 0.7300
# Epoch 21/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3968 - accuracy: 0.8285 - val_loss: 0.5622 - val_accuracy: 0.7287
# Epoch 22/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3798 - accuracy: 0.8302 - val_loss: 0.5597 - val_accuracy: 0.7325
# Epoch 23/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3746 - accuracy: 0.8334 - val_loss: 0.5669 - val_accuracy: 0.7337
# Epoch 24/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3488 - accuracy: 0.8589 - val_loss: 0.5687 - val_accuracy: 0.7337
# Epoch 25/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3489 - accuracy: 0.8580 - val_loss: 0.5702 - val_accuracy: 0.7225
# Epoch 26/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3579 - accuracy: 0.8405 - val_loss: 0.5779 - val_accuracy: 0.7225
# Epoch 27/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3456 - accuracy: 0.8569 - val_loss: 0.5821 - val_accuracy: 0.7275
# Epoch 28/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3539 - accuracy: 0.8448 - val_loss: 0.5841 - val_accuracy: 0.7262
# Epoch 29/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3404 - accuracy: 0.8526 - val_loss: 0.5889 - val_accuracy: 0.7237
# Epoch 30/30
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3434 - accuracy: 0.8535 - val_loss: 0.5906 - val_accuracy: 0.7275
# Fold 5, 30 epochs, 9 sec

# %%
from keras.models import load_model
pc_sim.set_reproducible(True)
nc_sim.set_reproducible(True)
pc_test = pc_sim.get_sequences(PC_TESTS)
nc_test = nc_sim.get_sequences(NC_TESTS)
X,y = prepare_inputs_len_x_alphabet(pc_test,nc_test,ALPHABET)
best_model=load_model(MODELPATH)
scores = best_model.evaluate(X, y, verbose=0)
print("The best model parameters were saved during cross-validation.")
print("Best was defined as maximum validation accuracy at end of any epoch.")
print("Now re-load the best model and test it on previously unseen data.")
print("Test on",len(pc_test),"PC seqs")
print("Test on",len(nc_test),"NC seqs")
print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))
# Out:
# The best model parameters were saved during cross-validation.
# Best was defined as maximum validation accuracy at end of any epoch.
# Now re-load the best model and test it on previously unseen data.
# Test on 1000 PC seqs
# Test on 1000 NC seqs
# accuracy: 72.95%

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
ns_probs = [0 for _ in range(len(y))]
bm_probs = best_model.predict(X)
ns_auc = roc_auc_score(y, ns_probs)
bm_auc = roc_auc_score(y, bm_probs)
ns_fpr, ns_tpr, _ = roc_curve(y, ns_probs)
bm_fpr, bm_tpr, _ = roc_curve(y, bm_probs)
plt.plot(ns_fpr, ns_tpr, linestyle='--', label='Guess, auc=%.4f'%ns_auc)
plt.plot(bm_fpr, bm_tpr, marker='.', label='Model, auc=%.4f'%bm_auc)
plt.title('ROC')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()
print("%s: %.2f%%" %('AUC',bm_auc*100.0))
# Out:
# AUC: 80.39%

# %%
t = time.time()
time.strftime('%Y-%m-%d %H:%M:%S %Z', time.localtime(t))
# Out:
# '2021-06-14 14:28:55 UTC'

# %% [markdown]
# ## Conclusion
# The CNN is very capable of learning ORF/nonORF from simulated short RNA.
