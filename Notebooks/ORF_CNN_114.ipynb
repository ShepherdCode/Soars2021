# %% [markdown]
# # ORF recognition by CNN
#
# Compare to 111. Use longer sequence, longer ORF, more training.

# %%
import time 
t = time.time()
time.strftime('%Y-%m-%d %H:%M:%S %Z', time.localtime(t))
# Out:
# '2021-06-11 12:20:47 EDT'

# %%
PC_SEQUENCES=4000   # how many protein-coding sequences
NC_SEQUENCES=4000   # how many non-coding sequences
PC_TESTS=1000
NC_TESTS=1000
RNA_LEN=36            # how long is each sequence
CDS_LEN=30            # include bases in start, residues, stop
ALPHABET=4          # how many different letters are possible
INPUT_SHAPE_2D = (RNA_LEN,ALPHABET,1) # Conv2D needs 3D inputs
INPUT_SHAPE = (RNA_LEN,ALPHABET) # Conv1D needs 2D inputs
FILTERS = 16   # how many different patterns the model looks for
NEURONS = 16
DROP_RATE = 0.2
WIDTH = 3   # how wide each pattern is, in bases
STRIDE_2D = (1,1)  # For Conv2D how far in each direction
STRIDE = 1 # For Conv1D, how far between pattern matches, in bases
EPOCHS=40  # how many times to train on all the data
SPLITS=5  # SPLITS=3 means train on 2/3 and validate on 1/3 
FOLDS=5  # train the model this many times (range 1 to SPLITS)

# %%
import sys
try:
    from google.colab import drive
    IN_COLAB = True
    print("On Google CoLab, mount cloud-local file, get our code from GitHub.")
    PATH='/content/drive/'
    #drive.mount(PATH,force_remount=True)  # hardly ever need this
    #drive.mount(PATH)    # Google will require login credentials
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/RNA_gen.py')
    with open('RNA_gen.py', 'w') as f:
        f.write(r.text)  
    from RNA_gen import *
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/RNA_describe.py')
    with open('RNA_describe.py', 'w') as f:
        f.write(r.text)  
    from RNA_describe import ORF_counter
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/RNA_prep.py')
    with open('RNA_prep.py', 'w') as f:
        f.write(r.text)  
    from RNA_prep import *
except:
    print("CoLab not working. On my PC, use relative paths.")
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"
    sys.path.append("..") # append parent dir in order to use sibling dirs
    from SimTools.RNA_gen import *
    from SimTools.RNA_describe import ORF_counter
    from SimTools.RNA_prep import *

MODELPATH="BestModel"  # saved on cloud instance and lost after logout
#MODELPATH=DATAPATH+MODELPATH  # saved on Google Drive but requires login

if not assert_imported_RNA_gen():
    print("ERROR: Cannot use RNA_gen.")
if not assert_imported_RNA_prep():
    print("ERROR: Cannot use RNA_prep.")
# Out:
# CoLab not working. On my PC, use relative paths.

# %%
from os import listdir
import csv
from zipfile import ZipFile

import numpy as np
import pandas as pd
from scipy import stats  # mode

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

from keras.models import Sequential
from keras.layers import Dense,Embedding,Dropout
from keras.layers import Conv1D,Conv2D
from keras.layers import Flatten,MaxPooling1D,MaxPooling2D
from keras.losses import BinaryCrossentropy
# tf.keras.losses.BinaryCrossentropy

import matplotlib.pyplot as plt
from matplotlib import colors
mycmap = colors.ListedColormap(['red','blue'])  # list color for label 0 then 1
np.set_printoptions(precision=2)

# %%
import random
def partition_random_sequences(goal_per_class):
    between_bases = CDS_LEN - 6
    utr5_bases = (RNA_LEN - CDS_LEN) // 2
    utr3_bases = RNA_LEN - utr5_bases - CDS_LEN
    pc_seqs=[]
    nc_seqs=[]
    oc = ORF_counter()
    trials = 0
    pc_cnt = 0
    nc_cnt = 0
    bases=['A','C','G','T']
    while pc_cnt<goal_per_class or nc_cnt<goal_per_class:
        trials += 1
        one_seq  = "".join(random.choices(bases,k=utr5_bases)) 
        one_seq += 'ATG'                               
        one_seq += "".join(random.choices(bases,k=between_bases)) 
        one_seq += random.choice(['TAA','TAG','TGA'])  
        one_seq += "".join(random.choices(bases,k=utr3_bases))  
        oc.set_sequence(one_seq)
        cds_len = oc.get_max_cds_len() + 3
        if cds_len >= CDS_LEN and pc_cnt<goal_per_class:
            pc_cnt += 1
            pc_seqs.append(one_seq)
        elif cds_len < CDS_LEN and nc_cnt<goal_per_class:
            nc_cnt += 1
            nc_seqs.append(one_seq)
    print ("It took %d trials to reach %d per class."%(trials,goal_per_class))
    return pc_seqs,nc_seqs
pc_all,nc_all=partition_random_sequences(10)  # just testing
pc_all,nc_all=partition_random_sequences(PC_SEQUENCES+PC_TESTS)
print("Use",len(pc_all),"PC seqs")
print("Use",len(nc_all),"NC seqs")
# Out:
# It took 31 trials to reach 10 per class.
# It took 17594 trials to reach 5000 per class.
# Use 5000 PC seqs
# Use 5000 NC seqs

# %%
# Describe the sequences
def describe_sequences(list_of_seq):
    oc = ORF_counter()
    num_seq = len(list_of_seq)
    rna_lens = np.zeros(num_seq)
    orf_lens = np.zeros(num_seq)
    for i in range(0,num_seq):
        rna_len = len(list_of_seq[i])
        rna_lens[i] = rna_len
        oc.set_sequence(list_of_seq[i])
        orf_len = oc.get_max_orf_len()
        orf_lens[i] = orf_len
    print ("Average RNA length:",rna_lens.mean())
    print ("Average ORF length:",orf_lens.mean())
    
print("Simulated sequences prior to adjustment:")
print("PC seqs")
describe_sequences(pc_all)
print("NC seqs")
describe_sequences(nc_all)
# Out:
# Simulated sequences prior to adjustment:
# PC seqs
# Average RNA length: 36.0
# Average ORF length: 26.8812
# NC seqs
# Average RNA length: 36.0
# Average ORF length: 11.604

# %%
pc_train=pc_all[:PC_SEQUENCES]
nc_train=nc_all[:NC_SEQUENCES]
pc_test=pc_all[PC_SEQUENCES:]
nc_test=nc_all[NC_SEQUENCES:]

# %%
# Use code from our SimTools library.
X,y = prepare_inputs_len_x_alphabet(pc_train,nc_train,ALPHABET) # shuffles
print("Data ready.")
# Out:
# Data ready.

# %%
def make_DNN():
    print("make_DNN")
    print("input shape:",INPUT_SHAPE)
    dnn = Sequential()
    #dnn.add(Embedding(input_dim=INPUT_SHAPE,output_dim=INPUT_SHAPE)) 
    dnn.add(Conv1D(filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,padding="same",
            input_shape=INPUT_SHAPE))
    dnn.add(Conv1D(filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,padding="same"))
    dnn.add(MaxPooling1D())
    #dnn.add(Conv1D(filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,padding="same"))
    #dnn.add(Conv1D(filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,padding="same"))
    #dnn.add(MaxPooling1D())
    dnn.add(Flatten())
    dnn.add(Dense(NEURONS,activation="sigmoid",dtype=np.float32))   
    dnn.add(Dropout(DROP_RATE))
    dnn.add(Dense(1,activation="sigmoid",dtype=np.float32))   
    dnn.compile(optimizer='adam',
                loss=BinaryCrossentropy(from_logits=False),
                metrics=['accuracy'])   # add to default metrics=loss
    dnn.build(input_shape=INPUT_SHAPE)
    #ln_rate = tf.keras.optimizers.Adam(learning_rate = LN_RATE)
    #bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    #model.compile(loss=bc, optimizer=ln_rate, metrics=["accuracy"])
    return dnn
model = make_DNN()
print(model.summary())
# Out:
# make_DNN
# input shape: (36, 4)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 36, 16)            208
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 36, 16)            784
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 18, 16)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 288)               0
# _________________________________________________________________
# dense (Dense)                (None, 16)                4624
# _________________________________________________________________
# dropout (Dropout)            (None, 16)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 5,633
# Trainable params: 5,633
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from keras.callbacks import ModelCheckpoint
def do_cross_validation(X,y):
    cv_scores = []
    fold=0
    mycallbacks = [ModelCheckpoint(
        filepath=MODELPATH, save_best_only=True, 
        monitor='val_accuracy', mode='max')]   
    splitter = KFold(n_splits=SPLITS)  # this does not shuffle
    for train_index,valid_index in splitter.split(X):
        if fold < FOLDS:
            fold += 1
            X_train=X[train_index] # inputs for training
            y_train=y[train_index] # labels for training
            X_valid=X[valid_index] # inputs for validation
            y_valid=y[valid_index] # labels for validation
            print("MODEL")
            # Call constructor on each CV. Else, continually improves the same model.
            model = model = make_DNN()
            print("FIT")  # model.fit() implements learning
            start_time=time.time()
            history=model.fit(X_train, y_train, 
                    epochs=EPOCHS, 
                    verbose=1,  # ascii art while learning
                    callbacks=mycallbacks,   # called at end of each epoch
                    validation_data=(X_valid,y_valid))
            end_time=time.time()
            elapsed_time=(end_time-start_time)                        
            print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
            # print(history.history.keys())  # all these keys will be shown in figure
            pd.DataFrame(history.history).plot(figsize=(8,5))
            plt.grid(True)
            plt.gca().set_ylim(0,1) # any losses > 1 will be off the scale
            plt.show()

# %%
do_cross_validation(X,y)
# Out:
# MODEL
# make_DNN
# input shape: (36, 4)
# FIT
# Epoch 1/40
# 200/200 [==============================] - 3s 11ms/step - loss: 0.6859 - accuracy: 0.5549 - val_loss: 0.5649 - val_accuracy: 0.7300
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 2/40
# 200/200 [==============================] - 1s 5ms/step - loss: 0.5515 - accuracy: 0.7299 - val_loss: 0.4701 - val_accuracy: 0.7731
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 3/40
# 200/200 [==============================] - 1s 5ms/step - loss: 0.4784 - accuracy: 0.7743 - val_loss: 0.4424 - val_accuracy: 0.7850
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 4/40
# 200/200 [==============================] - 1s 5ms/step - loss: 0.4520 - accuracy: 0.7910 - val_loss: 0.4263 - val_accuracy: 0.7969
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 5/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4189 - accuracy: 0.8122 - val_loss: 0.3857 - val_accuracy: 0.8256
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 6/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3962 - accuracy: 0.8157 - val_loss: 0.3550 - val_accuracy: 0.8381
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 7/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3602 - accuracy: 0.8428 - val_loss: 0.3257 - val_accuracy: 0.8594
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 8/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3320 - accuracy: 0.8624 - val_loss: 0.2989 - val_accuracy: 0.8756
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 9/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3088 - accuracy: 0.8610 - val_loss: 0.2805 - val_accuracy: 0.8788
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 10/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2872 - accuracy: 0.8850 - val_loss: 0.2644 - val_accuracy: 0.8913
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 11/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2741 - accuracy: 0.8842 - val_loss: 0.2625 - val_accuracy: 0.8956
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 12/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2491 - accuracy: 0.8997 - val_loss: 0.2384 - val_accuracy: 0.9062
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 13/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2374 - accuracy: 0.9045 - val_loss: 0.2242 - val_accuracy: 0.9100
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 14/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2134 - accuracy: 0.9174 - val_loss: 0.2091 - val_accuracy: 0.9094
# Epoch 15/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2108 - accuracy: 0.9195 - val_loss: 0.1972 - val_accuracy: 0.9156
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 16/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1964 - accuracy: 0.9220 - val_loss: 0.1895 - val_accuracy: 0.9231
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 17/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1763 - accuracy: 0.9349 - val_loss: 0.1858 - val_accuracy: 0.9275
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 18/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1734 - accuracy: 0.9345 - val_loss: 0.1745 - val_accuracy: 0.9306
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 19/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1582 - accuracy: 0.9429 - val_loss: 0.1719 - val_accuracy: 0.9306
# Epoch 20/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1494 - accuracy: 0.9431 - val_loss: 0.1682 - val_accuracy: 0.9306
# Epoch 21/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1519 - accuracy: 0.9452 - val_loss: 0.1691 - val_accuracy: 0.9250
# Epoch 22/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1452 - accuracy: 0.9447 - val_loss: 0.1577 - val_accuracy: 0.9337
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 23/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1312 - accuracy: 0.9563 - val_loss: 0.1570 - val_accuracy: 0.9400
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 24/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1219 - accuracy: 0.9577 - val_loss: 0.1583 - val_accuracy: 0.9325
# Epoch 25/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1238 - accuracy: 0.9551 - val_loss: 0.1496 - val_accuracy: 0.9375
# Epoch 26/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1117 - accuracy: 0.9594 - val_loss: 0.1587 - val_accuracy: 0.9331
# Epoch 27/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1072 - accuracy: 0.9627 - val_loss: 0.1468 - val_accuracy: 0.9425
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 28/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0978 - accuracy: 0.9689 - val_loss: 0.1427 - val_accuracy: 0.9425
# Epoch 29/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0961 - accuracy: 0.9683 - val_loss: 0.1488 - val_accuracy: 0.9419
# Epoch 30/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0884 - accuracy: 0.9686 - val_loss: 0.1309 - val_accuracy: 0.9425
# Epoch 31/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0913 - accuracy: 0.9680 - val_loss: 0.1287 - val_accuracy: 0.9469
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 32/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0842 - accuracy: 0.9700 - val_loss: 0.1225 - val_accuracy: 0.9475
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 33/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0787 - accuracy: 0.9763 - val_loss: 0.1271 - val_accuracy: 0.9500
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 34/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0760 - accuracy: 0.9731 - val_loss: 0.1236 - val_accuracy: 0.9519
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 35/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0692 - accuracy: 0.9790 - val_loss: 0.1181 - val_accuracy: 0.9575
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 36/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0665 - accuracy: 0.9780 - val_loss: 0.1176 - val_accuracy: 0.9525
# Epoch 37/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0655 - accuracy: 0.9803 - val_loss: 0.1141 - val_accuracy: 0.9538
# Epoch 38/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0698 - accuracy: 0.9765 - val_loss: 0.1164 - val_accuracy: 0.9550
# Epoch 39/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0571 - accuracy: 0.9817 - val_loss: 0.1221 - val_accuracy: 0.9569
# Epoch 40/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0583 - accuracy: 0.9818 - val_loss: 0.1125 - val_accuracy: 0.9563
# Fold 1, 40 epochs, 61 sec
# MODEL
# make_DNN
# input shape: (36, 4)
# FIT
# Epoch 1/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6800 - accuracy: 0.5745 - val_loss: 0.5876 - val_accuracy: 0.6825
# Epoch 2/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5462 - accuracy: 0.7319 - val_loss: 0.4882 - val_accuracy: 0.7600
# Epoch 3/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4731 - accuracy: 0.7787 - val_loss: 0.4788 - val_accuracy: 0.7619
# Epoch 4/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4531 - accuracy: 0.7880 - val_loss: 0.4389 - val_accuracy: 0.7931
# Epoch 5/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4167 - accuracy: 0.8143 - val_loss: 0.4108 - val_accuracy: 0.8075
# Epoch 6/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4000 - accuracy: 0.8191 - val_loss: 0.3839 - val_accuracy: 0.8269
# Epoch 7/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3723 - accuracy: 0.8431 - val_loss: 0.3610 - val_accuracy: 0.8456
# Epoch 8/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3398 - accuracy: 0.8574 - val_loss: 0.3306 - val_accuracy: 0.8606
# Epoch 9/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3088 - accuracy: 0.8685 - val_loss: 0.3247 - val_accuracy: 0.8456
# Epoch 10/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2976 - accuracy: 0.8802 - val_loss: 0.2856 - val_accuracy: 0.8806
# Epoch 11/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2699 - accuracy: 0.8881 - val_loss: 0.2814 - val_accuracy: 0.8813
# Epoch 12/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2644 - accuracy: 0.8879 - val_loss: 0.2626 - val_accuracy: 0.8931
# Epoch 13/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2409 - accuracy: 0.9048 - val_loss: 0.2512 - val_accuracy: 0.8944
# Epoch 14/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2242 - accuracy: 0.9106 - val_loss: 0.2396 - val_accuracy: 0.9031
# Epoch 15/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2056 - accuracy: 0.9163 - val_loss: 0.2275 - val_accuracy: 0.9069
# Epoch 16/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1989 - accuracy: 0.9182 - val_loss: 0.2202 - val_accuracy: 0.9031
# Epoch 17/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1981 - accuracy: 0.9220 - val_loss: 0.2197 - val_accuracy: 0.9094
# Epoch 18/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1740 - accuracy: 0.9365 - val_loss: 0.2103 - val_accuracy: 0.9094
# Epoch 19/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1750 - accuracy: 0.9369 - val_loss: 0.1989 - val_accuracy: 0.9150
# Epoch 20/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1586 - accuracy: 0.9399 - val_loss: 0.2022 - val_accuracy: 0.9156
# Epoch 21/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1588 - accuracy: 0.9444 - val_loss: 0.1888 - val_accuracy: 0.9269
# Epoch 22/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1501 - accuracy: 0.9464 - val_loss: 0.1799 - val_accuracy: 0.9325
# Epoch 23/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1345 - accuracy: 0.9450 - val_loss: 0.1780 - val_accuracy: 0.9231
# Epoch 24/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1334 - accuracy: 0.9524 - val_loss: 0.1761 - val_accuracy: 0.9294
# Epoch 25/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1274 - accuracy: 0.9543 - val_loss: 0.1767 - val_accuracy: 0.9319
# Epoch 26/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1194 - accuracy: 0.9592 - val_loss: 0.1653 - val_accuracy: 0.9300
# Epoch 27/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1060 - accuracy: 0.9611 - val_loss: 0.1615 - val_accuracy: 0.9356
# Epoch 28/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1097 - accuracy: 0.9613 - val_loss: 0.1671 - val_accuracy: 0.9319
# Epoch 29/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1062 - accuracy: 0.9582 - val_loss: 0.1642 - val_accuracy: 0.9362
# Epoch 30/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0927 - accuracy: 0.9642 - val_loss: 0.1546 - val_accuracy: 0.9394
# Epoch 31/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0925 - accuracy: 0.9668 - val_loss: 0.1489 - val_accuracy: 0.9463
# Epoch 32/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0895 - accuracy: 0.9693 - val_loss: 0.1463 - val_accuracy: 0.9425
# Epoch 33/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0885 - accuracy: 0.9657 - val_loss: 0.1564 - val_accuracy: 0.9400
# Epoch 34/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0869 - accuracy: 0.9706 - val_loss: 0.1494 - val_accuracy: 0.9331
# Epoch 35/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0844 - accuracy: 0.9690 - val_loss: 0.1602 - val_accuracy: 0.9300
# Epoch 36/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0791 - accuracy: 0.9727 - val_loss: 0.1473 - val_accuracy: 0.9419
# Epoch 37/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0761 - accuracy: 0.9701 - val_loss: 0.1427 - val_accuracy: 0.9406
# Epoch 38/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0693 - accuracy: 0.9739 - val_loss: 0.1649 - val_accuracy: 0.9400
# Epoch 39/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0751 - accuracy: 0.9705 - val_loss: 0.1393 - val_accuracy: 0.9463
# Epoch 40/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0703 - accuracy: 0.9770 - val_loss: 0.1446 - val_accuracy: 0.9431
# Fold 2, 40 epochs, 30 sec
# MODEL
# make_DNN
# input shape: (36, 4)
# FIT
# Epoch 1/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.7079 - accuracy: 0.5428 - val_loss: 0.5630 - val_accuracy: 0.7331
# Epoch 2/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5317 - accuracy: 0.7460 - val_loss: 0.4852 - val_accuracy: 0.7681
# Epoch 3/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4758 - accuracy: 0.7710 - val_loss: 0.4656 - val_accuracy: 0.7738
# Epoch 4/40
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4440 - accuracy: 0.7916 - val_loss: 0.4494 - val_accuracy: 0.7800
# Epoch 5/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4282 - accuracy: 0.7988 - val_loss: 0.4349 - val_accuracy: 0.7856
# Epoch 6/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3947 - accuracy: 0.8234 - val_loss: 0.4202 - val_accuracy: 0.8125
# Epoch 7/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3997 - accuracy: 0.8238 - val_loss: 0.3962 - val_accuracy: 0.8206
# Epoch 8/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3761 - accuracy: 0.8339 - val_loss: 0.3783 - val_accuracy: 0.8269
# Epoch 9/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3495 - accuracy: 0.8514 - val_loss: 0.3631 - val_accuracy: 0.8356
# Epoch 10/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3292 - accuracy: 0.8606 - val_loss: 0.3680 - val_accuracy: 0.8256
# Epoch 11/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3224 - accuracy: 0.8658 - val_loss: 0.3268 - val_accuracy: 0.8550
# Epoch 12/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2949 - accuracy: 0.8800 - val_loss: 0.3116 - val_accuracy: 0.8669
# Epoch 13/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2748 - accuracy: 0.8867 - val_loss: 0.2971 - val_accuracy: 0.8750
# Epoch 14/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2658 - accuracy: 0.8956 - val_loss: 0.2896 - val_accuracy: 0.8775
# Epoch 15/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2554 - accuracy: 0.9037 - val_loss: 0.2785 - val_accuracy: 0.8806
# Epoch 16/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2386 - accuracy: 0.9035 - val_loss: 0.2605 - val_accuracy: 0.8931
# Epoch 17/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2190 - accuracy: 0.9208 - val_loss: 0.2500 - val_accuracy: 0.9038
# Epoch 18/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2127 - accuracy: 0.9229 - val_loss: 0.2360 - val_accuracy: 0.9069
# Epoch 19/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2077 - accuracy: 0.9201 - val_loss: 0.2305 - val_accuracy: 0.9137
# Epoch 20/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1818 - accuracy: 0.9335 - val_loss: 0.2240 - val_accuracy: 0.9100
# Epoch 21/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1855 - accuracy: 0.9319 - val_loss: 0.2130 - val_accuracy: 0.9175
# Epoch 22/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1795 - accuracy: 0.9322 - val_loss: 0.2058 - val_accuracy: 0.9169
# Epoch 23/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1566 - accuracy: 0.9472 - val_loss: 0.2004 - val_accuracy: 0.9175
# Epoch 24/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1560 - accuracy: 0.9439 - val_loss: 0.1977 - val_accuracy: 0.9237
# Epoch 25/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1549 - accuracy: 0.9426 - val_loss: 0.1880 - val_accuracy: 0.9275
# Epoch 26/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1369 - accuracy: 0.9534 - val_loss: 0.1759 - val_accuracy: 0.9300
# Epoch 27/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1361 - accuracy: 0.9534 - val_loss: 0.1822 - val_accuracy: 0.9319
# Epoch 28/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1248 - accuracy: 0.9556 - val_loss: 0.1706 - val_accuracy: 0.9388
# Epoch 29/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1290 - accuracy: 0.9562 - val_loss: 0.1616 - val_accuracy: 0.9319
# Epoch 30/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1249 - accuracy: 0.9545 - val_loss: 0.1672 - val_accuracy: 0.9325
# Epoch 31/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1165 - accuracy: 0.9589 - val_loss: 0.1612 - val_accuracy: 0.9413
# Epoch 32/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1098 - accuracy: 0.9622 - val_loss: 0.1526 - val_accuracy: 0.9419
# Epoch 33/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0992 - accuracy: 0.9651 - val_loss: 0.1480 - val_accuracy: 0.9406
# Epoch 34/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1088 - accuracy: 0.9605 - val_loss: 0.1526 - val_accuracy: 0.9406
# Epoch 35/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0974 - accuracy: 0.9690 - val_loss: 0.1466 - val_accuracy: 0.9431
# Epoch 36/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0817 - accuracy: 0.9757 - val_loss: 0.1480 - val_accuracy: 0.9431
# Epoch 37/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0877 - accuracy: 0.9716 - val_loss: 0.1437 - val_accuracy: 0.9444
# Epoch 38/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0818 - accuracy: 0.9690 - val_loss: 0.1395 - val_accuracy: 0.9475
# Epoch 39/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0823 - accuracy: 0.9726 - val_loss: 0.1397 - val_accuracy: 0.9481
# Epoch 40/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0732 - accuracy: 0.9790 - val_loss: 0.1612 - val_accuracy: 0.9344
# Fold 3, 40 epochs, 30 sec
# MODEL
# make_DNN
# input shape: (36, 4)
# FIT
# Epoch 1/40
# 200/200 [==============================] - 1s 5ms/step - loss: 0.6878 - accuracy: 0.5481 - val_loss: 0.5935 - val_accuracy: 0.7287
# Epoch 2/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5582 - accuracy: 0.7344 - val_loss: 0.4907 - val_accuracy: 0.7663
# Epoch 3/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4748 - accuracy: 0.7780 - val_loss: 0.4673 - val_accuracy: 0.7844
# Epoch 4/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4668 - accuracy: 0.7840 - val_loss: 0.4448 - val_accuracy: 0.7944
# Epoch 5/40
# 200/200 [==============================] - 1s 3ms/step - loss: 0.4366 - accuracy: 0.8088 - val_loss: 0.4141 - val_accuracy: 0.8106
# Epoch 6/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3926 - accuracy: 0.8286 - val_loss: 0.3901 - val_accuracy: 0.8225
# Epoch 7/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3675 - accuracy: 0.8430 - val_loss: 0.3532 - val_accuracy: 0.8444
# Epoch 8/40
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3192 - accuracy: 0.8689 - val_loss: 0.3343 - val_accuracy: 0.8544
# Epoch 9/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3001 - accuracy: 0.8767 - val_loss: 0.3139 - val_accuracy: 0.8631
# Epoch 10/40
# 200/200 [==============================] - 1s 3ms/step - loss: 0.2906 - accuracy: 0.8871 - val_loss: 0.2941 - val_accuracy: 0.8681
# Epoch 11/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2572 - accuracy: 0.8976 - val_loss: 0.2832 - val_accuracy: 0.8687
# Epoch 12/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2360 - accuracy: 0.9069 - val_loss: 0.2630 - val_accuracy: 0.8806
# Epoch 13/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2168 - accuracy: 0.9132 - val_loss: 0.2641 - val_accuracy: 0.8906
# Epoch 14/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2169 - accuracy: 0.9165 - val_loss: 0.2465 - val_accuracy: 0.8975
# Epoch 15/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1965 - accuracy: 0.9255 - val_loss: 0.2293 - val_accuracy: 0.9038
# Epoch 16/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1836 - accuracy: 0.9347 - val_loss: 0.2195 - val_accuracy: 0.9112
# Epoch 17/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1749 - accuracy: 0.9344 - val_loss: 0.2126 - val_accuracy: 0.9100
# Epoch 18/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1675 - accuracy: 0.9381 - val_loss: 0.2108 - val_accuracy: 0.9119
# Epoch 19/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1529 - accuracy: 0.9402 - val_loss: 0.1992 - val_accuracy: 0.9162
# Epoch 20/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1551 - accuracy: 0.9393 - val_loss: 0.1959 - val_accuracy: 0.9169
# Epoch 21/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1462 - accuracy: 0.9457 - val_loss: 0.1831 - val_accuracy: 0.9269
# Epoch 22/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1391 - accuracy: 0.9535 - val_loss: 0.1798 - val_accuracy: 0.9237
# Epoch 23/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1239 - accuracy: 0.9550 - val_loss: 0.1740 - val_accuracy: 0.9269
# Epoch 24/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1156 - accuracy: 0.9567 - val_loss: 0.1735 - val_accuracy: 0.9294
# Epoch 25/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1189 - accuracy: 0.9578 - val_loss: 0.1833 - val_accuracy: 0.9262
# Epoch 26/40
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1106 - accuracy: 0.9584 - val_loss: 0.1655 - val_accuracy: 0.9312
# Epoch 27/40
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1104 - accuracy: 0.9603 - val_loss: 0.1643 - val_accuracy: 0.9306
# Epoch 28/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1028 - accuracy: 0.9635 - val_loss: 0.1540 - val_accuracy: 0.9344
# Epoch 29/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0950 - accuracy: 0.9670 - val_loss: 0.1457 - val_accuracy: 0.9450
# Epoch 30/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0856 - accuracy: 0.9685 - val_loss: 0.1561 - val_accuracy: 0.9344
# Epoch 31/40
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0901 - accuracy: 0.9703 - val_loss: 0.1412 - val_accuracy: 0.9463
# Epoch 32/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0840 - accuracy: 0.9720 - val_loss: 0.1442 - val_accuracy: 0.9438
# Epoch 33/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0840 - accuracy: 0.9711 - val_loss: 0.1429 - val_accuracy: 0.9419
# Epoch 34/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0738 - accuracy: 0.9765 - val_loss: 0.1487 - val_accuracy: 0.9438
# Epoch 35/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0706 - accuracy: 0.9769 - val_loss: 0.1480 - val_accuracy: 0.9425
# Epoch 36/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0681 - accuracy: 0.9756 - val_loss: 0.1377 - val_accuracy: 0.9413
# Epoch 37/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0635 - accuracy: 0.9793 - val_loss: 0.1473 - val_accuracy: 0.9394
# Epoch 38/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0651 - accuracy: 0.9773 - val_loss: 0.1355 - val_accuracy: 0.9425
# Epoch 39/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0694 - accuracy: 0.9750 - val_loss: 0.1320 - val_accuracy: 0.9494
# Epoch 40/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0612 - accuracy: 0.9825 - val_loss: 0.1249 - val_accuracy: 0.9500
# Fold 4, 40 epochs, 29 sec
# MODEL
# make_DNN
# input shape: (36, 4)
# FIT
# Epoch 1/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6855 - accuracy: 0.5500 - val_loss: 0.5592 - val_accuracy: 0.7481
# Epoch 2/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5366 - accuracy: 0.7420 - val_loss: 0.4740 - val_accuracy: 0.7663
# Epoch 3/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4677 - accuracy: 0.7828 - val_loss: 0.4466 - val_accuracy: 0.7919
# Epoch 4/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4518 - accuracy: 0.7848 - val_loss: 0.4204 - val_accuracy: 0.8087
# Epoch 5/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4123 - accuracy: 0.8067 - val_loss: 0.4013 - val_accuracy: 0.8244
# Epoch 6/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3919 - accuracy: 0.8286 - val_loss: 0.3748 - val_accuracy: 0.8381
# Epoch 7/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3554 - accuracy: 0.8471 - val_loss: 0.3489 - val_accuracy: 0.8581
# Epoch 8/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3346 - accuracy: 0.8580 - val_loss: 0.3252 - val_accuracy: 0.8656
# Epoch 9/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3024 - accuracy: 0.8780 - val_loss: 0.3092 - val_accuracy: 0.8763
# Epoch 10/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2844 - accuracy: 0.8883 - val_loss: 0.2890 - val_accuracy: 0.8813
# Epoch 11/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2615 - accuracy: 0.8947 - val_loss: 0.2715 - val_accuracy: 0.8931
# Epoch 12/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2390 - accuracy: 0.9070 - val_loss: 0.2595 - val_accuracy: 0.8931
# Epoch 13/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2249 - accuracy: 0.9143 - val_loss: 0.2502 - val_accuracy: 0.9031
# Epoch 14/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2127 - accuracy: 0.9186 - val_loss: 0.2361 - val_accuracy: 0.9025
# Epoch 15/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2033 - accuracy: 0.9223 - val_loss: 0.2308 - val_accuracy: 0.9050
# Epoch 16/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1847 - accuracy: 0.9300 - val_loss: 0.2117 - val_accuracy: 0.9162
# Epoch 17/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1703 - accuracy: 0.9382 - val_loss: 0.2123 - val_accuracy: 0.9112
# Epoch 18/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1563 - accuracy: 0.9420 - val_loss: 0.1993 - val_accuracy: 0.9175
# Epoch 19/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1490 - accuracy: 0.9471 - val_loss: 0.1832 - val_accuracy: 0.9287
# Epoch 20/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1352 - accuracy: 0.9518 - val_loss: 0.1748 - val_accuracy: 0.9269
# Epoch 21/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1286 - accuracy: 0.9546 - val_loss: 0.1713 - val_accuracy: 0.9337
# Epoch 22/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1241 - accuracy: 0.9549 - val_loss: 0.1607 - val_accuracy: 0.9325
# Epoch 23/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1144 - accuracy: 0.9604 - val_loss: 0.1579 - val_accuracy: 0.9344
# Epoch 24/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1060 - accuracy: 0.9633 - val_loss: 0.1557 - val_accuracy: 0.9381
# Epoch 25/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1012 - accuracy: 0.9661 - val_loss: 0.1482 - val_accuracy: 0.9394
# Epoch 26/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0904 - accuracy: 0.9685 - val_loss: 0.1402 - val_accuracy: 0.9444
# Epoch 27/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0901 - accuracy: 0.9699 - val_loss: 0.1372 - val_accuracy: 0.9506
# Epoch 28/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0852 - accuracy: 0.9707 - val_loss: 0.1407 - val_accuracy: 0.9406
# Epoch 29/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0748 - accuracy: 0.9773 - val_loss: 0.1428 - val_accuracy: 0.9413
# Epoch 30/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0833 - accuracy: 0.9714 - val_loss: 0.1364 - val_accuracy: 0.9469
# Epoch 31/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0727 - accuracy: 0.9764 - val_loss: 0.1328 - val_accuracy: 0.9494
# Epoch 32/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0684 - accuracy: 0.9787 - val_loss: 0.1271 - val_accuracy: 0.9506
# Epoch 33/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0666 - accuracy: 0.9782 - val_loss: 0.1306 - val_accuracy: 0.9463
# Epoch 34/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0615 - accuracy: 0.9829 - val_loss: 0.1220 - val_accuracy: 0.9519
# Epoch 35/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0527 - accuracy: 0.9847 - val_loss: 0.1246 - val_accuracy: 0.9481
# Epoch 36/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0601 - accuracy: 0.9792 - val_loss: 0.1343 - val_accuracy: 0.9463
# Epoch 37/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0523 - accuracy: 0.9840 - val_loss: 0.1087 - val_accuracy: 0.9594
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 38/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0482 - accuracy: 0.9867 - val_loss: 0.1093 - val_accuracy: 0.9569
# Epoch 39/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0450 - accuracy: 0.9856 - val_loss: 0.1054 - val_accuracy: 0.9569
# Epoch 40/40
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0479 - accuracy: 0.9831 - val_loss: 0.1066 - val_accuracy: 0.9569
# Fold 5, 40 epochs, 30 sec

# %%
from keras.models import load_model
X,y = prepare_inputs_len_x_alphabet(pc_test,nc_test,ALPHABET)
best_model=load_model(MODELPATH)
scores = best_model.evaluate(X, y, verbose=0)
print("The best model parameters were saved during cross-validation.")
print("Best was defined as maximum validation accuracy at end of any epoch.")
print("Now re-load the best model and test it on previously unseen data.")
print("Test on",len(pc_test),"PC seqs")
print("Test on",len(nc_test),"NC seqs")
print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))
# Out:
# The best model parameters were saved during cross-validation.
# Best was defined as maximum validation accuracy at end of any epoch.
# Now re-load the best model and test it on previously unseen data.
# Test on 1000 PC seqs
# Test on 1000 NC seqs
# accuracy: 95.75%

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
ns_probs = [0 for _ in range(len(y))]
bm_probs = best_model.predict(X)
ns_auc = roc_auc_score(y, ns_probs)
bm_auc = roc_auc_score(y, bm_probs)
ns_fpr, ns_tpr, _ = roc_curve(y, ns_probs)
bm_fpr, bm_tpr, _ = roc_curve(y, bm_probs)
plt.plot(ns_fpr, ns_tpr, linestyle='--', label='Guess, auc=%.4f'%ns_auc)
plt.plot(bm_fpr, bm_tpr, marker='.', label='Model, auc=%.4f'%bm_auc)
plt.title('ROC')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()
print("%s: %.2f%%" %('AUC',bm_auc*100.0))
# Out:
# AUC: 99.15%

# %%
t = time.time()
time.strftime('%Y-%m-%d %H:%M:%S %Z', time.localtime(t))
# Out:
# '2021-06-11 12:24:08 EDT'
