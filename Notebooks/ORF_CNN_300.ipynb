# %% [markdown]
# # ORF recognition by CNN
#
# In 105, we used Conv1D layers with filter width=3 with dropout to reduce overfitting. The simulated RNA lengths were 1000.
#
# Here, try really short simulated RNA.
#
#
# Added 4 layers.

# %%
import time 
t = time.time()
time.strftime('%Y-%m-%d %H:%M:%S %Z', time.localtime(t))
# Out:
# '2021-06-17 16:08:40 UTC'

# %%
PC_SEQUENCES=2000   # how many protein-coding sequences
NC_SEQUENCES=2000   # how many non-coding sequences
PC_TESTS=2000
NC_TESTS=1000
RNA_LEN=91            # how long is each sequence
CDS_LEN=73
ALPHABET=4          # how many different letters are possible
INPUT_SHAPE_2D = (RNA_LEN,ALPHABET,1) # Conv2D needs 3D inputs
INPUT_SHAPE = (RNA_LEN,ALPHABET) # Conv1D needs 2D inputs
FILTERS = 16   # how many different patterns the model looks for
NEURONS = 14
DROP_RATE = 0.2
WIDTH = 3   # how wide each pattern is, in bases
STRIDE_2D = (1,1)  # For Conv2D how far in each direction
STRIDE = 1 # For Conv1D, how far between pattern matches, in bases
EPOCHS=30  # how many times to train on all the data
SPLITS=5  # SPLITS=3 means train on 2/3 and validate on 1/3 
FOLDS=5  # train the model this many times (range 1 to SPLITS)

# %%
import sys
try:
    from google.colab import drive
    IN_COLAB = True
    print("On Google CoLab, mount cloud-local file, get our code from GitHub.")
    PATH='/content/drive/'
    #drive.mount(PATH,force_remount=True)  # hardly ever need this
    #drive.mount(PATH)    # Google will require login credentials
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/RNA_gen.py')
    with open('RNA_gen.py', 'w') as f:
        f.write(r.text)  
    from RNA_gen import *
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/RNA_describe.py')
    with open('RNA_describe.py', 'w') as f:
        f.write(r.text)  
    from RNA_describe import ORF_counter
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/RNA_prep.py')
    with open('RNA_prep.py', 'w') as f:
        f.write(r.text)  
    from RNA_prep import *
except:
    print("CoLab not working. On my PC, use relative paths.")
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"
    sys.path.append("..") # append parent dir in order to use sibling dirs
    from SimTools.RNA_gen import *
    from SimTools.RNA_describe import ORF_counter
    from SimTools.RNA_prep import *

MODELPATH="BestModel"  # saved on cloud instance and lost after logout
#MODELPATH=DATAPATH+MODELPATH  # saved on Google Drive but requires login

if not assert_imported_RNA_gen():
    print("ERROR: Cannot use RNA_gen.")
if not assert_imported_RNA_prep():
    print("ERROR: Cannot use RNA_prep.")
# Out:
# On Google CoLab, mount cloud-local file, get our code from GitHub.

# %%
from os import listdir
import csv
from zipfile import ZipFile

import numpy as np
import pandas as pd
from scipy import stats  # mode

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

from keras.models import Sequential
from keras.layers import Dense,Embedding,Dropout
from keras.layers import Conv1D,Conv2D
from keras.layers import Flatten,MaxPooling1D,MaxPooling2D
from keras.losses import BinaryCrossentropy
# tf.keras.losses.BinaryCrossentropy

import matplotlib.pyplot as plt
from matplotlib import colors
mycmap = colors.ListedColormap(['red','blue'])  # list color for label 0 then 1
np.set_printoptions(precision=2)

# %%
# Use code from our SimTools library.
def make_generators(seq_len):
    pcgen = Collection_Generator()  
    pcgen.get_len_oracle().set_mean(seq_len)
    tora = Transcript_Oracle()
    tora.set_cds_len_mean(CDS_LEN)  # CDS=ORF+STOP. 
    pcgen.set_seq_oracle(tora)
    ncgen = Collection_Generator()  
    ncgen.get_len_oracle().set_mean(seq_len)
    return pcgen,ncgen

pc_sim,nc_sim = make_generators(RNA_LEN)
pc_train = pc_sim.get_sequences(PC_SEQUENCES)
nc_train = nc_sim.get_sequences(NC_SEQUENCES)
print("Train on",len(pc_train),"PC seqs")
print("Train on",len(nc_train),"NC seqs")
# Out:
# Train on 2000 PC seqs
# Train on 2000 NC seqs

# %%
# Describe the sequences
def describe_sequences(list_of_seq):
    oc = ORF_counter()
    num_seq = len(list_of_seq)
    rna_lens = np.zeros(num_seq)
    orf_lens = np.zeros(num_seq)
    for i in range(0,num_seq):
        rna_len = len(list_of_seq[i])
        rna_lens[i] = rna_len
        oc.set_sequence(list_of_seq[i])
        orf_len = oc.get_max_orf_len()
        orf_lens[i] = orf_len
    print ("Average RNA length:",rna_lens.mean())
    print ("Average ORF length:",orf_lens.mean())
    
print("PC train")
describe_sequences(pc_train)
print("NC train")
describe_sequences(nc_train)
# Out:
# PC train
# Average RNA length: 91.0
# Average ORF length: 68.9955
# NC train
# Average RNA length: 91.0
# Average ORF length: 12.7065

# %%
# Use code from our SimTools library.
X,y = prepare_inputs_len_x_alphabet(pc_train,nc_train,ALPHABET) # shuffles
print("Data ready.")
# Out:
# Data ready.

# %%
def make_DNN():
    print("make_DNN")
    print("input shape:",INPUT_SHAPE)
    dnn = Sequential()
    #dnn.add(Embedding(input_dim=INPUT_SHAPE,output_dim=INPUT_SHAPE)) 
    dnn.add(Conv1D(filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,padding="same",
            input_shape=INPUT_SHAPE))
    dnn.add(Conv1D(filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,padding="same"))
    dnn.add(MaxPooling1D())
    dnn.add(Conv1D(filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,padding="same"))
    dnn.add(MaxPooling1D())
    dnn.add(Conv1D(filters=FILTERS, kernel_size=WIDTH,strides=STRIDE,padding="same"))
    dnn.add(MaxPooling1D())
    dnn.add(Conv1D(filters=FILTERS, kernel_size=WIDTH,strides=STRIDE, padding="same"))
    dnn.add(MaxPooling1D())
    dnn.add(Flatten())
    dnn.add(Dense(NEURONS,activation="sigmoid",dtype=np.float32))   
    dnn.add(Dropout(DROP_RATE))
    dnn.add(Dense(1,activation="sigmoid",dtype=np.float32))   
    dnn.compile(optimizer='adam',
                loss=BinaryCrossentropy(from_logits=False),
                metrics=['accuracy'])   # add to default metrics=loss
    dnn.build(input_shape=INPUT_SHAPE)
    #ln_rate = tf.keras.optimizers.Adam(learning_rate = LN_RATE)
    #bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    #model.compile(loss=bc, optimizer=ln_rate, metrics=["accuracy"])
    return dnn
model = make_DNN()
print(model.summary())
# Out:
# make_DNN
# input shape: (91, 4)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 91, 16)            208
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 91, 16)            784
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 45, 16)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 45, 16)            784
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 22, 16)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 22, 16)            784
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 11, 16)            0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 11, 16)            784
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 5, 16)             0
# _________________________________________________________________
# flatten (Flatten)            (None, 80)                0
# _________________________________________________________________
# dense (Dense)                (None, 14)                1134
# _________________________________________________________________
# dropout (Dropout)            (None, 14)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 15
# =================================================================
# Total params: 4,493
# Trainable params: 4,493
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from keras.callbacks import ModelCheckpoint
def do_cross_validation(X,y):
    cv_scores = []
    fold=0
    mycallbacks = [ModelCheckpoint(
        filepath=MODELPATH, save_best_only=True, 
        monitor='val_accuracy', mode='max')]   
    splitter = KFold(n_splits=SPLITS)  # this does not shuffle
    for train_index,valid_index in splitter.split(X):
        if fold < FOLDS:
            fold += 1
            X_train=X[train_index] # inputs for training
            y_train=y[train_index] # labels for training
            X_valid=X[valid_index] # inputs for validation
            y_valid=y[valid_index] # labels for validation
            print("MODEL")
            # Call constructor on each CV. Else, continually improves the same model.
            model = model = make_DNN()
            print("FIT")  # model.fit() implements learning
            start_time=time.time()
            history=model.fit(X_train, y_train, 
                    epochs=EPOCHS, 
                    verbose=1,  # ascii art while learning
                    callbacks=mycallbacks,   # called at end of each epoch
                    validation_data=(X_valid,y_valid))
            end_time=time.time()
            elapsed_time=(end_time-start_time)                        
            print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
            # print(history.history.keys())  # all these keys will be shown in figure
            pd.DataFrame(history.history).plot(figsize=(8,5))
            plt.grid(True)
            plt.gca().set_ylim(0,1) # any losses > 1 will be off the scale
            plt.show()

# %%
do_cross_validation(X,y)
# Out:
# MODEL
# make_DNN
# input shape: (91, 4)
# FIT
# Epoch 1/30
# 100/100 [==============================] - 16s 15ms/step - loss: 0.6996 - accuracy: 0.5087 - val_loss: 0.6893 - val_accuracy: 0.5838
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 2/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.6896 - accuracy: 0.5396 - val_loss: 0.6758 - val_accuracy: 0.6263
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 3/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.6507 - accuracy: 0.6447 - val_loss: 0.5781 - val_accuracy: 0.7300
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 4/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.5357 - accuracy: 0.7340 - val_loss: 0.5106 - val_accuracy: 0.7613
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 5/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.4565 - accuracy: 0.7962 - val_loss: 0.4742 - val_accuracy: 0.7862
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 6/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.4038 - accuracy: 0.8302 - val_loss: 0.4553 - val_accuracy: 0.7962
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 7/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.3812 - accuracy: 0.8466 - val_loss: 0.4391 - val_accuracy: 0.8050
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 8/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.3711 - accuracy: 0.8512 - val_loss: 0.4309 - val_accuracy: 0.8025
# Epoch 9/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.3248 - accuracy: 0.8695 - val_loss: 0.4252 - val_accuracy: 0.7937
# Epoch 10/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.3069 - accuracy: 0.8805 - val_loss: 0.4857 - val_accuracy: 0.7650
# Epoch 11/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.3113 - accuracy: 0.8759 - val_loss: 0.4987 - val_accuracy: 0.7700
# Epoch 12/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2891 - accuracy: 0.8891 - val_loss: 0.4465 - val_accuracy: 0.7887
# Epoch 13/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2887 - accuracy: 0.8884 - val_loss: 0.4455 - val_accuracy: 0.8012
# Epoch 14/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2659 - accuracy: 0.8976 - val_loss: 0.4778 - val_accuracy: 0.7862
# Epoch 15/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2505 - accuracy: 0.9121 - val_loss: 0.4800 - val_accuracy: 0.7763
# Epoch 16/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2285 - accuracy: 0.9211 - val_loss: 0.4764 - val_accuracy: 0.7912
# Epoch 17/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2202 - accuracy: 0.9203 - val_loss: 0.4768 - val_accuracy: 0.7925
# Epoch 18/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2240 - accuracy: 0.9196 - val_loss: 0.5097 - val_accuracy: 0.7862
# Epoch 19/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2055 - accuracy: 0.9271 - val_loss: 0.5096 - val_accuracy: 0.7912
# Epoch 20/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.1934 - accuracy: 0.9303 - val_loss: 0.5084 - val_accuracy: 0.7950
# Epoch 21/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.1824 - accuracy: 0.9383 - val_loss: 0.6238 - val_accuracy: 0.7650
# Epoch 22/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.1695 - accuracy: 0.9438 - val_loss: 0.5308 - val_accuracy: 0.7875
# Epoch 23/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.1433 - accuracy: 0.9525 - val_loss: 0.5455 - val_accuracy: 0.7850
# Epoch 24/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.1421 - accuracy: 0.9647 - val_loss: 0.6114 - val_accuracy: 0.7812
# Epoch 25/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.1384 - accuracy: 0.9595 - val_loss: 0.7027 - val_accuracy: 0.7725
# Epoch 26/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1450 - accuracy: 0.9533 - val_loss: 0.5918 - val_accuracy: 0.7875
# Epoch 27/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.1409 - accuracy: 0.9605 - val_loss: 0.6115 - val_accuracy: 0.7887
# Epoch 28/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.1241 - accuracy: 0.9644 - val_loss: 0.6459 - val_accuracy: 0.7900
# Epoch 29/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.1073 - accuracy: 0.9705 - val_loss: 0.6909 - val_accuracy: 0.7788
# Epoch 30/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.1108 - accuracy: 0.9676 - val_loss: 0.6999 - val_accuracy: 0.7850
# Fold 1, 30 epochs, 52 sec
# MODEL
# make_DNN
# input shape: (91, 4)
# FIT
# Epoch 1/30
# 100/100 [==============================] - 3s 13ms/step - loss: 0.7026 - accuracy: 0.5132 - val_loss: 0.6853 - val_accuracy: 0.5813
# Epoch 2/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.6829 - accuracy: 0.5568 - val_loss: 0.6597 - val_accuracy: 0.6037
# Epoch 3/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.6320 - accuracy: 0.6447 - val_loss: 0.5694 - val_accuracy: 0.7175
# Epoch 4/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.5327 - accuracy: 0.7476 - val_loss: 0.5033 - val_accuracy: 0.7850
# Epoch 5/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.4816 - accuracy: 0.7801 - val_loss: 0.4621 - val_accuracy: 0.7850
# Epoch 6/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.4325 - accuracy: 0.8128 - val_loss: 0.4395 - val_accuracy: 0.8325
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 7/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.4017 - accuracy: 0.8279 - val_loss: 0.4298 - val_accuracy: 0.8300
# Epoch 8/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.3699 - accuracy: 0.8535 - val_loss: 0.4151 - val_accuracy: 0.8313
# Epoch 9/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.3507 - accuracy: 0.8600 - val_loss: 0.4195 - val_accuracy: 0.8188
# Epoch 10/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.3361 - accuracy: 0.8680 - val_loss: 0.4151 - val_accuracy: 0.8175
# Epoch 11/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.3247 - accuracy: 0.8767 - val_loss: 0.4179 - val_accuracy: 0.8213
# Epoch 12/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.3019 - accuracy: 0.8825 - val_loss: 0.4177 - val_accuracy: 0.8250
# Epoch 13/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.3024 - accuracy: 0.8849 - val_loss: 0.4165 - val_accuracy: 0.8313
# Epoch 14/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2663 - accuracy: 0.8998 - val_loss: 0.4118 - val_accuracy: 0.8338
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 15/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2640 - accuracy: 0.9024 - val_loss: 0.4180 - val_accuracy: 0.8163
# Epoch 16/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2397 - accuracy: 0.9144 - val_loss: 0.4524 - val_accuracy: 0.8175
# Epoch 17/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2372 - accuracy: 0.9133 - val_loss: 0.4385 - val_accuracy: 0.8163
# Epoch 18/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2223 - accuracy: 0.9143 - val_loss: 0.4509 - val_accuracy: 0.8213
# Epoch 19/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2138 - accuracy: 0.9252 - val_loss: 0.4595 - val_accuracy: 0.8300
# Epoch 20/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2034 - accuracy: 0.9208 - val_loss: 0.4784 - val_accuracy: 0.8112
# Epoch 21/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1952 - accuracy: 0.9364 - val_loss: 0.4798 - val_accuracy: 0.8263
# Epoch 22/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2006 - accuracy: 0.9289 - val_loss: 0.4774 - val_accuracy: 0.8338
# Epoch 23/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1946 - accuracy: 0.9341 - val_loss: 0.4862 - val_accuracy: 0.8313
# Epoch 24/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1938 - accuracy: 0.9284 - val_loss: 0.4963 - val_accuracy: 0.8300
# Epoch 25/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.1710 - accuracy: 0.9453 - val_loss: 0.5217 - val_accuracy: 0.8138
# Epoch 26/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1417 - accuracy: 0.9550 - val_loss: 0.5380 - val_accuracy: 0.8175
# Epoch 27/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1533 - accuracy: 0.9505 - val_loss: 0.5636 - val_accuracy: 0.8062
# Epoch 28/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.1442 - accuracy: 0.9510 - val_loss: 0.5453 - val_accuracy: 0.8250
# Epoch 29/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1547 - accuracy: 0.9527 - val_loss: 0.5542 - val_accuracy: 0.8200
# Epoch 30/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1275 - accuracy: 0.9614 - val_loss: 0.5763 - val_accuracy: 0.8112
# Fold 2, 30 epochs, 42 sec
# MODEL
# make_DNN
# input shape: (91, 4)
# FIT
# Epoch 1/30
# 100/100 [==============================] - 3s 17ms/step - loss: 0.7013 - accuracy: 0.5151 - val_loss: 0.6899 - val_accuracy: 0.5487
# Epoch 2/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.6825 - accuracy: 0.5577 - val_loss: 0.6723 - val_accuracy: 0.5925
# Epoch 3/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.6425 - accuracy: 0.6310 - val_loss: 0.6179 - val_accuracy: 0.6350
# Epoch 4/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.5824 - accuracy: 0.6963 - val_loss: 0.5604 - val_accuracy: 0.7113
# Epoch 5/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.5085 - accuracy: 0.7674 - val_loss: 0.5467 - val_accuracy: 0.7113
# Epoch 6/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.4576 - accuracy: 0.7966 - val_loss: 0.4902 - val_accuracy: 0.7625
# Epoch 7/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.4133 - accuracy: 0.8295 - val_loss: 0.4607 - val_accuracy: 0.7925
# Epoch 8/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.3806 - accuracy: 0.8492 - val_loss: 0.4600 - val_accuracy: 0.7825
# Epoch 9/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.3755 - accuracy: 0.8488 - val_loss: 0.4468 - val_accuracy: 0.8125
# Epoch 10/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.3535 - accuracy: 0.8580 - val_loss: 0.4361 - val_accuracy: 0.8125
# Epoch 11/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.3249 - accuracy: 0.8697 - val_loss: 0.4435 - val_accuracy: 0.8075
# Epoch 12/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.3118 - accuracy: 0.8789 - val_loss: 0.4594 - val_accuracy: 0.7987
# Epoch 13/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.3165 - accuracy: 0.8701 - val_loss: 0.4409 - val_accuracy: 0.8188
# Epoch 14/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2746 - accuracy: 0.8972 - val_loss: 0.4536 - val_accuracy: 0.8087
# Epoch 15/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2615 - accuracy: 0.9086 - val_loss: 0.4948 - val_accuracy: 0.7837
# Epoch 16/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2494 - accuracy: 0.9085 - val_loss: 0.4967 - val_accuracy: 0.7837
# Epoch 17/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2350 - accuracy: 0.9135 - val_loss: 0.4937 - val_accuracy: 0.7925
# Epoch 18/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2189 - accuracy: 0.9302 - val_loss: 0.5095 - val_accuracy: 0.7900
# Epoch 19/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2161 - accuracy: 0.9335 - val_loss: 0.5269 - val_accuracy: 0.7975
# Epoch 20/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2001 - accuracy: 0.9356 - val_loss: 0.5292 - val_accuracy: 0.7975
# Epoch 21/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1594 - accuracy: 0.9500 - val_loss: 0.5675 - val_accuracy: 0.7925
# Epoch 22/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1584 - accuracy: 0.9466 - val_loss: 0.5893 - val_accuracy: 0.7937
# Epoch 23/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1679 - accuracy: 0.9512 - val_loss: 0.6054 - val_accuracy: 0.7912
# Epoch 24/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1471 - accuracy: 0.9613 - val_loss: 0.6234 - val_accuracy: 0.7925
# Epoch 25/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1440 - accuracy: 0.9631 - val_loss: 0.6867 - val_accuracy: 0.7725
# Epoch 26/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1374 - accuracy: 0.9638 - val_loss: 0.6766 - val_accuracy: 0.7800
# Epoch 27/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1200 - accuracy: 0.9655 - val_loss: 0.6973 - val_accuracy: 0.7875
# Epoch 28/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1068 - accuracy: 0.9784 - val_loss: 0.7405 - val_accuracy: 0.7800
# Epoch 29/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1025 - accuracy: 0.9760 - val_loss: 0.7524 - val_accuracy: 0.7775
# Epoch 30/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0942 - accuracy: 0.9761 - val_loss: 0.7596 - val_accuracy: 0.7812
# Fold 3, 30 epochs, 42 sec
# MODEL
# make_DNN
# input shape: (91, 4)
# FIT
# Epoch 1/30
# 100/100 [==============================] - 3s 13ms/step - loss: 0.7255 - accuracy: 0.4965 - val_loss: 0.6966 - val_accuracy: 0.4938
# Epoch 2/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.6962 - accuracy: 0.5053 - val_loss: 0.6829 - val_accuracy: 0.5775
# Epoch 3/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.6782 - accuracy: 0.5719 - val_loss: 0.6634 - val_accuracy: 0.5975
# Epoch 4/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.6398 - accuracy: 0.6331 - val_loss: 0.6280 - val_accuracy: 0.6400
# Epoch 5/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.5987 - accuracy: 0.6831 - val_loss: 0.5683 - val_accuracy: 0.7212
# Epoch 6/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.5333 - accuracy: 0.7441 - val_loss: 0.5429 - val_accuracy: 0.7412
# Epoch 7/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.5031 - accuracy: 0.7658 - val_loss: 0.5182 - val_accuracy: 0.7525
# Epoch 8/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.4377 - accuracy: 0.8194 - val_loss: 0.4961 - val_accuracy: 0.7713
# Epoch 9/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.4197 - accuracy: 0.8202 - val_loss: 0.4706 - val_accuracy: 0.7887
# Epoch 10/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.3786 - accuracy: 0.8547 - val_loss: 0.4591 - val_accuracy: 0.7912
# Epoch 11/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.3572 - accuracy: 0.8649 - val_loss: 0.4547 - val_accuracy: 0.8050
# Epoch 12/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.3457 - accuracy: 0.8675 - val_loss: 0.4526 - val_accuracy: 0.8025
# Epoch 13/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2990 - accuracy: 0.8953 - val_loss: 0.4688 - val_accuracy: 0.8012
# Epoch 14/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2676 - accuracy: 0.9080 - val_loss: 0.4612 - val_accuracy: 0.7962
# Epoch 15/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2810 - accuracy: 0.9028 - val_loss: 0.4769 - val_accuracy: 0.8075
# Epoch 16/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2306 - accuracy: 0.9233 - val_loss: 0.4822 - val_accuracy: 0.8062
# Epoch 17/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2348 - accuracy: 0.9236 - val_loss: 0.4958 - val_accuracy: 0.8000
# Epoch 18/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2135 - accuracy: 0.9309 - val_loss: 0.5194 - val_accuracy: 0.7937
# Epoch 19/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2016 - accuracy: 0.9380 - val_loss: 0.5383 - val_accuracy: 0.7825
# Epoch 20/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1984 - accuracy: 0.9377 - val_loss: 0.5728 - val_accuracy: 0.7825
# Epoch 21/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1697 - accuracy: 0.9477 - val_loss: 0.5909 - val_accuracy: 0.7837
# Epoch 22/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1751 - accuracy: 0.9512 - val_loss: 0.6063 - val_accuracy: 0.7800
# Epoch 23/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1490 - accuracy: 0.9648 - val_loss: 0.6391 - val_accuracy: 0.7750
# Epoch 24/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1360 - accuracy: 0.9622 - val_loss: 0.6575 - val_accuracy: 0.7700
# Epoch 25/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1275 - accuracy: 0.9704 - val_loss: 0.6472 - val_accuracy: 0.7887
# Epoch 26/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1200 - accuracy: 0.9741 - val_loss: 0.6996 - val_accuracy: 0.7738
# Epoch 27/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1224 - accuracy: 0.9723 - val_loss: 0.7102 - val_accuracy: 0.7738
# Epoch 28/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1127 - accuracy: 0.9705 - val_loss: 0.7700 - val_accuracy: 0.7513
# Epoch 29/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1027 - accuracy: 0.9764 - val_loss: 0.7564 - val_accuracy: 0.7625
# Epoch 30/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1261 - accuracy: 0.9677 - val_loss: 0.7728 - val_accuracy: 0.7638
# Fold 4, 30 epochs, 28 sec
# MODEL
# make_DNN
# input shape: (91, 4)
# FIT
# Epoch 1/30
# 100/100 [==============================] - 3s 13ms/step - loss: 0.7106 - accuracy: 0.5054 - val_loss: 0.6913 - val_accuracy: 0.4925
# Epoch 2/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.6842 - accuracy: 0.5543 - val_loss: 0.6524 - val_accuracy: 0.6250
# Epoch 3/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.6398 - accuracy: 0.6417 - val_loss: 0.6105 - val_accuracy: 0.6862
# Epoch 4/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.5945 - accuracy: 0.6944 - val_loss: 0.5397 - val_accuracy: 0.7412
# Epoch 5/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.5177 - accuracy: 0.7639 - val_loss: 0.4662 - val_accuracy: 0.7825
# Epoch 6/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.4403 - accuracy: 0.8024 - val_loss: 0.4105 - val_accuracy: 0.8250
# Epoch 7/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.3941 - accuracy: 0.8488 - val_loss: 0.4022 - val_accuracy: 0.8338
# Epoch 8/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.3803 - accuracy: 0.8439 - val_loss: 0.3908 - val_accuracy: 0.8338
# Epoch 9/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.3532 - accuracy: 0.8608 - val_loss: 0.3918 - val_accuracy: 0.8238
# Epoch 10/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.3461 - accuracy: 0.8750 - val_loss: 0.3934 - val_accuracy: 0.8263
# Epoch 11/30
# 100/100 [==============================] - 1s 10ms/step - loss: 0.3211 - accuracy: 0.8804 - val_loss: 0.3979 - val_accuracy: 0.8275
# Epoch 12/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.3013 - accuracy: 0.8888 - val_loss: 0.3911 - val_accuracy: 0.8325
# Epoch 13/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.3141 - accuracy: 0.8809 - val_loss: 0.4223 - val_accuracy: 0.8163
# Epoch 14/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2914 - accuracy: 0.8920 - val_loss: 0.4147 - val_accuracy: 0.8238
# Epoch 15/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2588 - accuracy: 0.9095 - val_loss: 0.4454 - val_accuracy: 0.8037
# Epoch 16/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2466 - accuracy: 0.9117 - val_loss: 0.4270 - val_accuracy: 0.8238
# Epoch 17/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2432 - accuracy: 0.9178 - val_loss: 0.4483 - val_accuracy: 0.8175
# Epoch 18/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2237 - accuracy: 0.9307 - val_loss: 0.4501 - val_accuracy: 0.8238
# Epoch 19/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2373 - accuracy: 0.9261 - val_loss: 0.4642 - val_accuracy: 0.8138
# Epoch 20/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2055 - accuracy: 0.9361 - val_loss: 0.4712 - val_accuracy: 0.8150
# Epoch 21/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2049 - accuracy: 0.9385 - val_loss: 0.4958 - val_accuracy: 0.8225
# Epoch 22/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1877 - accuracy: 0.9460 - val_loss: 0.5096 - val_accuracy: 0.8112
# Epoch 23/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1755 - accuracy: 0.9490 - val_loss: 0.5854 - val_accuracy: 0.7987
# Epoch 24/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1791 - accuracy: 0.9495 - val_loss: 0.5044 - val_accuracy: 0.8112
# Epoch 25/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.1803 - accuracy: 0.9479 - val_loss: 0.5423 - val_accuracy: 0.7912
# Epoch 26/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1508 - accuracy: 0.9608 - val_loss: 0.5464 - val_accuracy: 0.8125
# Epoch 27/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1394 - accuracy: 0.9622 - val_loss: 0.5420 - val_accuracy: 0.8062
# Epoch 28/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1532 - accuracy: 0.9616 - val_loss: 0.5575 - val_accuracy: 0.8000
# Epoch 29/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1423 - accuracy: 0.9584 - val_loss: 0.6441 - val_accuracy: 0.7875
# Epoch 30/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1171 - accuracy: 0.9724 - val_loss: 0.6171 - val_accuracy: 0.8037
# Fold 5, 30 epochs, 28 sec

# %%
from keras.models import load_model
pc_sim.set_reproducible(True)
nc_sim.set_reproducible(True)
pc_test = pc_sim.get_sequences(PC_TESTS)
nc_test = nc_sim.get_sequences(NC_TESTS)
X,y = prepare_inputs_len_x_alphabet(pc_test,nc_test,ALPHABET)
best_model=load_model(MODELPATH)
scores = best_model.evaluate(X, y, verbose=0)
print("The best model parameters were saved during cross-validation.")
print("Best was defined as maximum validation accuracy at end of any epoch.")
print("Now re-load the best model and test it on previously unseen data.")
print("Test on",len(pc_test),"PC seqs")
print("Test on",len(nc_test),"NC seqs")
print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))
# Out:
# The best model parameters were saved during cross-validation.
# Best was defined as maximum validation accuracy at end of any epoch.
# Now re-load the best model and test it on previously unseen data.
# Test on 2000 PC seqs
# Test on 1000 NC seqs
# accuracy: 86.83%

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
ns_probs = [0 for _ in range(len(y))]
bm_probs = best_model.predict(X)
ns_auc = roc_auc_score(y, ns_probs)
bm_auc = roc_auc_score(y, bm_probs)
ns_fpr, ns_tpr, _ = roc_curve(y, ns_probs)
bm_fpr, bm_tpr, _ = roc_curve(y, bm_probs)
plt.plot(ns_fpr, ns_tpr, linestyle='--', label='Guess, auc=%.4f'%ns_auc)
plt.plot(bm_fpr, bm_tpr, marker='.', label='Model, auc=%.4f'%bm_auc)
plt.title('ROC')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()
print("%s: %.2f%%" %('AUC',bm_auc*100.0))
# Out:
# AUC: 89.01%

# %%
t = time.time()
time.strftime('%Y-%m-%d %H:%M:%S %Z', time.localtime(t))
# Out:
# '2021-06-17 16:12:02 UTC'

# %% [markdown]
# ## Conclusion
# The CNN is very capable of learning ORF/nonORF from simulated short RNA.
