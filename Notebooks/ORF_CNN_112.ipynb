# %% [markdown]
# # ORF recognition by CNN
#
# Compare to 111. Use a larger ORF here. We get overfitting here.

# %%
import time 
t = time.time()
time.strftime('%Y-%m-%d %H:%M:%S %Z', time.localtime(t))
# Out:
# '2021-06-11 12:05:18 EDT'

# %%
PC_SEQUENCES=2000   # how many protein-coding sequences
NC_SEQUENCES=2000   # how many non-coding sequences
PC_TESTS=1000
NC_TESTS=1000
RNA_LEN=36            # how long is each sequence
CDS_LEN=30            # include bases in start, residues, stop
ALPHABET=4          # how many different letters are possible
INPUT_SHAPE_2D = (RNA_LEN,ALPHABET,1) # Conv2D needs 3D inputs
INPUT_SHAPE = (RNA_LEN,ALPHABET) # Conv1D needs 2D inputs
FILTERS = 16   # how many different patterns the model looks for
NEURONS = 16
DROP_RATE = 0.2
WIDTH = 3   # how wide each pattern is, in bases
STRIDE_2D = (1,1)  # For Conv2D how far in each direction
STRIDE = 1 # For Conv1D, how far between pattern matches, in bases
EPOCHS=25  # how many times to train on all the data
SPLITS=5  # SPLITS=3 means train on 2/3 and validate on 1/3 
FOLDS=5  # train the model this many times (range 1 to SPLITS)

# %%
import sys
try:
    from google.colab import drive
    IN_COLAB = True
    print("On Google CoLab, mount cloud-local file, get our code from GitHub.")
    PATH='/content/drive/'
    #drive.mount(PATH,force_remount=True)  # hardly ever need this
    #drive.mount(PATH)    # Google will require login credentials
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/RNA_gen.py')
    with open('RNA_gen.py', 'w') as f:
        f.write(r.text)  
    from RNA_gen import *
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/RNA_describe.py')
    with open('RNA_describe.py', 'w') as f:
        f.write(r.text)  
    from RNA_describe import ORF_counter
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/RNA_prep.py')
    with open('RNA_prep.py', 'w') as f:
        f.write(r.text)  
    from RNA_prep import *
except:
    print("CoLab not working. On my PC, use relative paths.")
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"
    sys.path.append("..") # append parent dir in order to use sibling dirs
    from SimTools.RNA_gen import *
    from SimTools.RNA_describe import ORF_counter
    from SimTools.RNA_prep import *

MODELPATH="BestModel"  # saved on cloud instance and lost after logout
#MODELPATH=DATAPATH+MODELPATH  # saved on Google Drive but requires login

if not assert_imported_RNA_gen():
    print("ERROR: Cannot use RNA_gen.")
if not assert_imported_RNA_prep():
    print("ERROR: Cannot use RNA_prep.")
# Out:
# CoLab not working. On my PC, use relative paths.

# %%
from os import listdir
import csv
from zipfile import ZipFile

import numpy as np
import pandas as pd
from scipy import stats  # mode

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

from keras.models import Sequential
from keras.layers import Dense,Embedding,Dropout
from keras.layers import Conv1D,Conv2D
from keras.layers import Flatten,MaxPooling1D,MaxPooling2D
from keras.losses import BinaryCrossentropy
# tf.keras.losses.BinaryCrossentropy

import matplotlib.pyplot as plt
from matplotlib import colors
mycmap = colors.ListedColormap(['red','blue'])  # list color for label 0 then 1
np.set_printoptions(precision=2)

# %%
import random
def partition_random_sequences(goal_per_class):
    between_bases = CDS_LEN - 6
    utr5_bases = (RNA_LEN - CDS_LEN) // 2
    utr3_bases = RNA_LEN - utr5_bases - CDS_LEN
    pc_seqs=[]
    nc_seqs=[]
    oc = ORF_counter()
    trials = 0
    pc_cnt = 0
    nc_cnt = 0
    bases=['A','C','G','T']
    while pc_cnt<goal_per_class or nc_cnt<goal_per_class:
        trials += 1
        one_seq  = "".join(random.choices(bases,k=utr5_bases)) 
        one_seq += 'ATG'                               
        one_seq += "".join(random.choices(bases,k=between_bases)) 
        one_seq += random.choice(['TAA','TAG','TGA'])  
        one_seq += "".join(random.choices(bases,k=utr3_bases))  
        oc.set_sequence(one_seq)
        cds_len = oc.get_max_cds_len() + 3
        if cds_len >= CDS_LEN and pc_cnt<goal_per_class:
            pc_cnt += 1
            pc_seqs.append(one_seq)
        elif cds_len < CDS_LEN and nc_cnt<goal_per_class:
            nc_cnt += 1
            nc_seqs.append(one_seq)
    print ("It took %d trials to reach %d per class."%(trials,goal_per_class))
    return pc_seqs,nc_seqs
pc_all,nc_all=partition_random_sequences(10)  # just testing
pc_all,nc_all=partition_random_sequences(PC_SEQUENCES+PC_TESTS)
print("Use",len(pc_all),"PC seqs")
print("Use",len(nc_all),"NC seqs")
# Out:
# It took 69 trials to reach 10 per class.
# It took 10377 trials to reach 3000 per class.
# Use 3000 PC seqs
# Use 3000 NC seqs

# %%
# Describe the sequences
def describe_sequences(list_of_seq):
    oc = ORF_counter()
    num_seq = len(list_of_seq)
    rna_lens = np.zeros(num_seq)
    orf_lens = np.zeros(num_seq)
    for i in range(0,num_seq):
        rna_len = len(list_of_seq[i])
        rna_lens[i] = rna_len
        oc.set_sequence(list_of_seq[i])
        orf_len = oc.get_max_orf_len()
        orf_lens[i] = orf_len
    print ("Average RNA length:",rna_lens.mean())
    print ("Average ORF length:",orf_lens.mean())
    
print("Simulated sequences prior to adjustment:")
print("PC seqs")
describe_sequences(pc_all)
print("NC seqs")
describe_sequences(nc_all)
# Out:
# Simulated sequences prior to adjustment:
# PC seqs
# Average RNA length: 36.0
# Average ORF length: 26.912
# NC seqs
# Average RNA length: 36.0
# Average ORF length: 11.746

# %%
pc_train=pc_all[:PC_SEQUENCES]
nc_train=nc_all[:NC_SEQUENCES]
pc_test=pc_all[PC_SEQUENCES:]
nc_test=nc_all[NC_SEQUENCES:]

# %%
# Use code from our SimTools library.
X,y = prepare_inputs_len_x_alphabet(pc_train,nc_train,ALPHABET) # shuffles
print("Data ready.")
# Out:
# Data ready.

# %%
def make_DNN():
    print("make_DNN")
    print("input shape:",INPUT_SHAPE)
    dnn = Sequential()
    #dnn.add(Embedding(input_dim=INPUT_SHAPE,output_dim=INPUT_SHAPE)) 
    dnn.add(Conv1D(filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,padding="same",
            input_shape=INPUT_SHAPE))
    dnn.add(Conv1D(filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,padding="same"))
    dnn.add(MaxPooling1D())
    #dnn.add(Conv1D(filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,padding="same"))
    #dnn.add(Conv1D(filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,padding="same"))
    #dnn.add(MaxPooling1D())
    dnn.add(Flatten())
    dnn.add(Dense(NEURONS,activation="sigmoid",dtype=np.float32))   
    dnn.add(Dropout(DROP_RATE))
    dnn.add(Dense(1,activation="sigmoid",dtype=np.float32))   
    dnn.compile(optimizer='adam',
                loss=BinaryCrossentropy(from_logits=False),
                metrics=['accuracy'])   # add to default metrics=loss
    dnn.build(input_shape=INPUT_SHAPE)
    #ln_rate = tf.keras.optimizers.Adam(learning_rate = LN_RATE)
    #bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    #model.compile(loss=bc, optimizer=ln_rate, metrics=["accuracy"])
    return dnn
model = make_DNN()
print(model.summary())
# Out:
# make_DNN
# input shape: (36, 4)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 36, 16)            208
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 36, 16)            784
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 18, 16)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 288)               0
# _________________________________________________________________
# dense (Dense)                (None, 16)                4624
# _________________________________________________________________
# dropout (Dropout)            (None, 16)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 5,633
# Trainable params: 5,633
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from keras.callbacks import ModelCheckpoint
def do_cross_validation(X,y):
    cv_scores = []
    fold=0
    mycallbacks = [ModelCheckpoint(
        filepath=MODELPATH, save_best_only=True, 
        monitor='val_accuracy', mode='max')]   
    splitter = KFold(n_splits=SPLITS)  # this does not shuffle
    for train_index,valid_index in splitter.split(X):
        if fold < FOLDS:
            fold += 1
            X_train=X[train_index] # inputs for training
            y_train=y[train_index] # labels for training
            X_valid=X[valid_index] # inputs for validation
            y_valid=y[valid_index] # labels for validation
            print("MODEL")
            # Call constructor on each CV. Else, continually improves the same model.
            model = model = make_DNN()
            print("FIT")  # model.fit() implements learning
            start_time=time.time()
            history=model.fit(X_train, y_train, 
                    epochs=EPOCHS, 
                    verbose=1,  # ascii art while learning
                    callbacks=mycallbacks,   # called at end of each epoch
                    validation_data=(X_valid,y_valid))
            end_time=time.time()
            elapsed_time=(end_time-start_time)                        
            print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
            # print(history.history.keys())  # all these keys will be shown in figure
            pd.DataFrame(history.history).plot(figsize=(8,5))
            plt.grid(True)
            plt.gca().set_ylim(0,1) # any losses > 1 will be off the scale
            plt.show()

# %%
do_cross_validation(X,y)
# Out:
# MODEL
# make_DNN
# input shape: (36, 4)
# FIT
# Epoch 1/25
# 100/100 [==============================] - 3s 18ms/step - loss: 0.7103 - accuracy: 0.5203 - val_loss: 0.6535 - val_accuracy: 0.6662
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 2/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.6379 - accuracy: 0.6444 - val_loss: 0.5719 - val_accuracy: 0.7100
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 3/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5397 - accuracy: 0.7422 - val_loss: 0.4974 - val_accuracy: 0.7663
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 4/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4807 - accuracy: 0.7704 - val_loss: 0.4798 - val_accuracy: 0.7775
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 5/25
# 100/100 [==============================] - 1s 5ms/step - loss: 0.4629 - accuracy: 0.7738 - val_loss: 0.4621 - val_accuracy: 0.7850
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 6/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.4417 - accuracy: 0.7963 - val_loss: 0.4489 - val_accuracy: 0.7937
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 7/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4273 - accuracy: 0.8003 - val_loss: 0.4383 - val_accuracy: 0.8000
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 8/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.4168 - accuracy: 0.8083 - val_loss: 0.4319 - val_accuracy: 0.8138
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 9/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3750 - accuracy: 0.8366 - val_loss: 0.4218 - val_accuracy: 0.8175
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 10/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3713 - accuracy: 0.8421 - val_loss: 0.4225 - val_accuracy: 0.8175
# Epoch 11/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3732 - accuracy: 0.8413 - val_loss: 0.4181 - val_accuracy: 0.8112
# Epoch 12/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3579 - accuracy: 0.8409 - val_loss: 0.3937 - val_accuracy: 0.8288
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 13/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3361 - accuracy: 0.8582 - val_loss: 0.3841 - val_accuracy: 0.8325
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 14/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3207 - accuracy: 0.8612 - val_loss: 0.3828 - val_accuracy: 0.8325
# Epoch 15/25
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3164 - accuracy: 0.8629 - val_loss: 0.3698 - val_accuracy: 0.8438
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 16/25
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2970 - accuracy: 0.8764 - val_loss: 0.3627 - val_accuracy: 0.8238
# Epoch 17/25
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2790 - accuracy: 0.8910 - val_loss: 0.3628 - val_accuracy: 0.8325
# Epoch 18/25
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2863 - accuracy: 0.8757 - val_loss: 0.3560 - val_accuracy: 0.8375
# Epoch 19/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2702 - accuracy: 0.8926 - val_loss: 0.3475 - val_accuracy: 0.8363
# Epoch 20/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2700 - accuracy: 0.8894 - val_loss: 0.3359 - val_accuracy: 0.8413
# Epoch 21/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2491 - accuracy: 0.9027 - val_loss: 0.3344 - val_accuracy: 0.8462
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 22/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2267 - accuracy: 0.9139 - val_loss: 0.3286 - val_accuracy: 0.8450
# Epoch 23/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2446 - accuracy: 0.9004 - val_loss: 0.3320 - val_accuracy: 0.8500
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 24/25
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2195 - accuracy: 0.9156 - val_loss: 0.3161 - val_accuracy: 0.8550
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 25/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2101 - accuracy: 0.9216 - val_loss: 0.3200 - val_accuracy: 0.8612
# INFO:tensorflow:Assets written to: BestModel/assets
# Fold 1, 25 epochs, 32 sec
# MODEL
# make_DNN
# input shape: (36, 4)
# FIT
# Epoch 1/25
# 100/100 [==============================] - 1s 5ms/step - loss: 0.7520 - accuracy: 0.5145 - val_loss: 0.6631 - val_accuracy: 0.6250
# Epoch 2/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6605 - accuracy: 0.6159 - val_loss: 0.6243 - val_accuracy: 0.6650
# Epoch 3/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5930 - accuracy: 0.6948 - val_loss: 0.5240 - val_accuracy: 0.7663
# Epoch 4/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5229 - accuracy: 0.7555 - val_loss: 0.4912 - val_accuracy: 0.7700
# Epoch 5/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4945 - accuracy: 0.7593 - val_loss: 0.4785 - val_accuracy: 0.7700
# Epoch 6/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4606 - accuracy: 0.7976 - val_loss: 0.4590 - val_accuracy: 0.7825
# Epoch 7/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.4611 - accuracy: 0.7992 - val_loss: 0.4522 - val_accuracy: 0.7812
# Epoch 8/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4379 - accuracy: 0.8041 - val_loss: 0.4415 - val_accuracy: 0.7875
# Epoch 9/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4270 - accuracy: 0.8074 - val_loss: 0.4308 - val_accuracy: 0.7900
# Epoch 10/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4018 - accuracy: 0.8280 - val_loss: 0.4186 - val_accuracy: 0.8050
# Epoch 11/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3929 - accuracy: 0.8320 - val_loss: 0.4052 - val_accuracy: 0.8087
# Epoch 12/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3834 - accuracy: 0.8324 - val_loss: 0.4079 - val_accuracy: 0.7937
# Epoch 13/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3606 - accuracy: 0.8519 - val_loss: 0.3900 - val_accuracy: 0.8062
# Epoch 14/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3537 - accuracy: 0.8545 - val_loss: 0.3754 - val_accuracy: 0.8200
# Epoch 15/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3334 - accuracy: 0.8611 - val_loss: 0.3641 - val_accuracy: 0.8388
# Epoch 16/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.3266 - accuracy: 0.8750 - val_loss: 0.3588 - val_accuracy: 0.8475
# Epoch 17/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2945 - accuracy: 0.8830 - val_loss: 0.3505 - val_accuracy: 0.8512
# Epoch 18/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2875 - accuracy: 0.8906 - val_loss: 0.3417 - val_accuracy: 0.8525
# Epoch 19/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2734 - accuracy: 0.8974 - val_loss: 0.3386 - val_accuracy: 0.8537
# Epoch 20/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2757 - accuracy: 0.8953 - val_loss: 0.3350 - val_accuracy: 0.8525
# Epoch 21/25
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2502 - accuracy: 0.9109 - val_loss: 0.3292 - val_accuracy: 0.8512
# Epoch 22/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2566 - accuracy: 0.9142 - val_loss: 0.3211 - val_accuracy: 0.8550
# Epoch 23/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2491 - accuracy: 0.9076 - val_loss: 0.3185 - val_accuracy: 0.8637
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 24/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2350 - accuracy: 0.9061 - val_loss: 0.3075 - val_accuracy: 0.8675
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 25/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2012 - accuracy: 0.9363 - val_loss: 0.2980 - val_accuracy: 0.8662
# Fold 2, 25 epochs, 11 sec
# MODEL
# make_DNN
# input shape: (36, 4)
# FIT
# Epoch 1/25
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6957 - accuracy: 0.5257 - val_loss: 0.6199 - val_accuracy: 0.7325
# Epoch 2/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6107 - accuracy: 0.6768 - val_loss: 0.5094 - val_accuracy: 0.7650
# Epoch 3/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5052 - accuracy: 0.7649 - val_loss: 0.4557 - val_accuracy: 0.8000
# Epoch 4/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.4891 - accuracy: 0.7703 - val_loss: 0.4344 - val_accuracy: 0.8050
# Epoch 5/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.4652 - accuracy: 0.7844 - val_loss: 0.4241 - val_accuracy: 0.8112
# Epoch 6/25
# 100/100 [==============================] - 1s 5ms/step - loss: 0.4266 - accuracy: 0.8126 - val_loss: 0.4168 - val_accuracy: 0.8188
# Epoch 7/25
# 100/100 [==============================] - 1s 5ms/step - loss: 0.4333 - accuracy: 0.8009 - val_loss: 0.4068 - val_accuracy: 0.8138
# Epoch 8/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3997 - accuracy: 0.8228 - val_loss: 0.3957 - val_accuracy: 0.8325
# Epoch 9/25
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3669 - accuracy: 0.8395 - val_loss: 0.3888 - val_accuracy: 0.8350
# Epoch 10/25
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3679 - accuracy: 0.8448 - val_loss: 0.3729 - val_accuracy: 0.8425
# Epoch 11/25
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3488 - accuracy: 0.8570 - val_loss: 0.3673 - val_accuracy: 0.8462
# Epoch 12/25
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3439 - accuracy: 0.8623 - val_loss: 0.3529 - val_accuracy: 0.8550
# Epoch 13/25
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3290 - accuracy: 0.8646 - val_loss: 0.3447 - val_accuracy: 0.8575
# Epoch 14/25
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3185 - accuracy: 0.8711 - val_loss: 0.3387 - val_accuracy: 0.8625
# Epoch 15/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3060 - accuracy: 0.8775 - val_loss: 0.3285 - val_accuracy: 0.8625
# Epoch 16/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2658 - accuracy: 0.9104 - val_loss: 0.3311 - val_accuracy: 0.8550
# Epoch 17/25
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2876 - accuracy: 0.8870 - val_loss: 0.3139 - val_accuracy: 0.8737
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 18/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2624 - accuracy: 0.8963 - val_loss: 0.3069 - val_accuracy: 0.8750
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 19/25
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2683 - accuracy: 0.8909 - val_loss: 0.3057 - val_accuracy: 0.8737
# Epoch 20/25
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2482 - accuracy: 0.8990 - val_loss: 0.2948 - val_accuracy: 0.8813
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 21/25
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2389 - accuracy: 0.8961 - val_loss: 0.2885 - val_accuracy: 0.8763
# Epoch 22/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2160 - accuracy: 0.9223 - val_loss: 0.2993 - val_accuracy: 0.8700
# Epoch 23/25
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2308 - accuracy: 0.9104 - val_loss: 0.2803 - val_accuracy: 0.8788
# Epoch 24/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2193 - accuracy: 0.9104 - val_loss: 0.2753 - val_accuracy: 0.8825
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 25/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2104 - accuracy: 0.9119 - val_loss: 0.2680 - val_accuracy: 0.8900
# INFO:tensorflow:Assets written to: BestModel/assets
# Fold 3, 25 epochs, 19 sec
# MODEL
# make_DNN
# input shape: (36, 4)
# FIT
# Epoch 1/25
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6996 - accuracy: 0.5180 - val_loss: 0.6707 - val_accuracy: 0.5675
# Epoch 2/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.6460 - accuracy: 0.6301 - val_loss: 0.5821 - val_accuracy: 0.7075
# Epoch 3/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.5401 - accuracy: 0.7190 - val_loss: 0.5030 - val_accuracy: 0.7588
# Epoch 4/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.4853 - accuracy: 0.7745 - val_loss: 0.4766 - val_accuracy: 0.7638
# Epoch 5/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.4518 - accuracy: 0.7919 - val_loss: 0.4631 - val_accuracy: 0.7750
# Epoch 6/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.4300 - accuracy: 0.7967 - val_loss: 0.4548 - val_accuracy: 0.7800
# Epoch 7/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.4230 - accuracy: 0.8018 - val_loss: 0.4504 - val_accuracy: 0.7800
# Epoch 8/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3960 - accuracy: 0.8288 - val_loss: 0.4409 - val_accuracy: 0.7975
# Epoch 9/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3842 - accuracy: 0.8285 - val_loss: 0.4372 - val_accuracy: 0.8012
# Epoch 10/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3721 - accuracy: 0.8355 - val_loss: 0.4226 - val_accuracy: 0.8050
# Epoch 11/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3579 - accuracy: 0.8454 - val_loss: 0.4169 - val_accuracy: 0.8062
# Epoch 12/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3331 - accuracy: 0.8613 - val_loss: 0.4056 - val_accuracy: 0.8188
# Epoch 13/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3483 - accuracy: 0.8517 - val_loss: 0.4001 - val_accuracy: 0.8188
# Epoch 14/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3237 - accuracy: 0.8631 - val_loss: 0.3990 - val_accuracy: 0.8250
# Epoch 15/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3075 - accuracy: 0.8800 - val_loss: 0.3844 - val_accuracy: 0.8288
# Epoch 16/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3016 - accuracy: 0.8763 - val_loss: 0.3781 - val_accuracy: 0.8375
# Epoch 17/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3137 - accuracy: 0.8713 - val_loss: 0.3675 - val_accuracy: 0.8400
# Epoch 18/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2723 - accuracy: 0.8881 - val_loss: 0.3703 - val_accuracy: 0.8438
# Epoch 19/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2738 - accuracy: 0.8825 - val_loss: 0.3589 - val_accuracy: 0.8425
# Epoch 20/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2664 - accuracy: 0.8987 - val_loss: 0.3502 - val_accuracy: 0.8512
# Epoch 21/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2444 - accuracy: 0.9069 - val_loss: 0.3482 - val_accuracy: 0.8487
# Epoch 22/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2289 - accuracy: 0.9082 - val_loss: 0.3431 - val_accuracy: 0.8500
# Epoch 23/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2236 - accuracy: 0.9109 - val_loss: 0.3376 - val_accuracy: 0.8562
# Epoch 24/25
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2221 - accuracy: 0.9143 - val_loss: 0.3293 - val_accuracy: 0.8650
# Epoch 25/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2132 - accuracy: 0.9154 - val_loss: 0.3281 - val_accuracy: 0.8612
# Fold 4, 25 epochs, 12 sec
# MODEL
# make_DNN
# input shape: (36, 4)
# FIT
# Epoch 1/25
# 100/100 [==============================] - 1s 6ms/step - loss: 0.7008 - accuracy: 0.5156 - val_loss: 0.6699 - val_accuracy: 0.5675
# Epoch 2/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6463 - accuracy: 0.6415 - val_loss: 0.5745 - val_accuracy: 0.7325
# Epoch 3/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5640 - accuracy: 0.7251 - val_loss: 0.4911 - val_accuracy: 0.7862
# Epoch 4/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.4905 - accuracy: 0.7781 - val_loss: 0.4600 - val_accuracy: 0.7788
# Epoch 5/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.4531 - accuracy: 0.7960 - val_loss: 0.4521 - val_accuracy: 0.7688
# Epoch 6/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.4377 - accuracy: 0.7994 - val_loss: 0.4331 - val_accuracy: 0.8112
# Epoch 7/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.4277 - accuracy: 0.8117 - val_loss: 0.4225 - val_accuracy: 0.7875
# Epoch 8/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.4141 - accuracy: 0.8215 - val_loss: 0.4092 - val_accuracy: 0.8138
# Epoch 9/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3754 - accuracy: 0.8432 - val_loss: 0.4025 - val_accuracy: 0.8188
# Epoch 10/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3776 - accuracy: 0.8404 - val_loss: 0.3889 - val_accuracy: 0.8275
# Epoch 11/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3660 - accuracy: 0.8445 - val_loss: 0.3720 - val_accuracy: 0.8388
# Epoch 12/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3470 - accuracy: 0.8541 - val_loss: 0.3559 - val_accuracy: 0.8400
# Epoch 13/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3269 - accuracy: 0.8650 - val_loss: 0.3489 - val_accuracy: 0.8400
# Epoch 14/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3187 - accuracy: 0.8644 - val_loss: 0.3419 - val_accuracy: 0.8487
# Epoch 15/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.3260 - accuracy: 0.8598 - val_loss: 0.3287 - val_accuracy: 0.8537
# Epoch 16/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2905 - accuracy: 0.8818 - val_loss: 0.3300 - val_accuracy: 0.8512
# Epoch 17/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2825 - accuracy: 0.8881 - val_loss: 0.3130 - val_accuracy: 0.8562
# Epoch 18/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2671 - accuracy: 0.8898 - val_loss: 0.3106 - val_accuracy: 0.8600
# Epoch 19/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2656 - accuracy: 0.8959 - val_loss: 0.3002 - val_accuracy: 0.8650
# Epoch 20/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2486 - accuracy: 0.8981 - val_loss: 0.2882 - val_accuracy: 0.8763
# Epoch 21/25
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2412 - accuracy: 0.9038 - val_loss: 0.2996 - val_accuracy: 0.8687
# Epoch 22/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2436 - accuracy: 0.8991 - val_loss: 0.2806 - val_accuracy: 0.8788
# Epoch 23/25
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2153 - accuracy: 0.9132 - val_loss: 0.2944 - val_accuracy: 0.8687
# Epoch 24/25
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2184 - accuracy: 0.9147 - val_loss: 0.2825 - val_accuracy: 0.8750
# Epoch 25/25
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2055 - accuracy: 0.9163 - val_loss: 0.2648 - val_accuracy: 0.8938
# INFO:tensorflow:Assets written to: BestModel/assets
# Fold 5, 25 epochs, 13 sec

# %%
from keras.models import load_model
X,y = prepare_inputs_len_x_alphabet(pc_test,nc_test,ALPHABET)
best_model=load_model(MODELPATH)
scores = best_model.evaluate(X, y, verbose=0)
print("The best model parameters were saved during cross-validation.")
print("Best was defined as maximum validation accuracy at end of any epoch.")
print("Now re-load the best model and test it on previously unseen data.")
print("Test on",len(pc_test),"PC seqs")
print("Test on",len(nc_test),"NC seqs")
print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))
# Out:
# The best model parameters were saved during cross-validation.
# Best was defined as maximum validation accuracy at end of any epoch.
# Now re-load the best model and test it on previously unseen data.
# Test on 1000 PC seqs
# Test on 1000 NC seqs
# accuracy: 87.60%

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
ns_probs = [0 for _ in range(len(y))]
bm_probs = best_model.predict(X)
ns_auc = roc_auc_score(y, ns_probs)
bm_auc = roc_auc_score(y, bm_probs)
ns_fpr, ns_tpr, _ = roc_curve(y, ns_probs)
bm_fpr, bm_tpr, _ = roc_curve(y, bm_probs)
plt.plot(ns_fpr, ns_tpr, linestyle='--', label='Guess, auc=%.4f'%ns_auc)
plt.plot(bm_fpr, bm_tpr, marker='.', label='Model, auc=%.4f'%bm_auc)
plt.title('ROC')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()
print("%s: %.2f%%" %('AUC',bm_auc*100.0))
# Out:
# AUC: 94.97%

# %%
t = time.time()
time.strftime('%Y-%m-%d %H:%M:%S %Z', time.localtime(t))
# Out:
# '2021-06-11 12:07:06 EDT'
