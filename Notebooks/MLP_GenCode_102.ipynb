# %% [markdown]
# # MLP GenCode
# Wen et al 2019 used DNN to distinguish GenCode mRNA/lncRNA.
# Based on K-mer frequencies, K={1,2,3}, they reported 99% accuracy.
# Their CNN used 2 Conv2D layers of 32 filters of width 3x3, max pool 2x2, 25% drop, dense 128.
# Can we reproduce that with MLP layers instead of CNN?
# Extract features as list of K-mer frequencies for K={1,2,3}.

# %%
import time
def show_time():
    t = time.time()
    print(time.strftime('%Y-%m-%d %H:%M:%S %Z', time.localtime(t)))
show_time()
# Out:
# 2021-07-10 17:37:30 UTC

# %%
PC_TRAINS=20000
NC_TRAINS=20000
PC_TESTS=5000
NC_TESTS=5000   # Wen et al 2019 used 8000 and 2000 of each class
PC_LENS=(200,4000)
NC_LENS=(200,4000)    # Wen et al 2019 used 250-3500 for lncRNA only
MAX_K = 3
INPUT_SHAPE=(None,84)  # 4^3 + 4^2 + 4^1
NEURONS=128
EPOCHS=25
SPLITS=5
FOLDS=5   # make this 5 for serious testing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

from keras.models import Sequential
from keras.layers import Dense,Embedding,Dropout
from keras.layers import Flatten,TimeDistributed
from keras.losses import BinaryCrossentropy
from keras.callbacks import ModelCheckpoint

# %%
import sys
IN_COLAB = False
try:
    from google.colab import drive
    IN_COLAB = True
except:
    pass
if IN_COLAB:
    print("On Google CoLab, mount cloud-local file, get our code from GitHub.")
    PATH='/content/drive/'
    #drive.mount(PATH,force_remount=True)  # hardly ever need this
    drive.mount(PATH)    # Google will require login credentials
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/GenCodeTools.py')
    with open('GenCodeTools.py', 'w') as f:
        f.write(r.text)  
    from GenCodeTools import GenCodeLoader
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/KmerTools.py')
    with open('KmerTools.py', 'w') as f:
        f.write(r.text)  
    from KmerTools import KmerTools
else:
        print("CoLab not working. On my PC, use relative paths.")
        DATAPATH='data/'  # must end in "/"
        sys.path.append("..") # append parent dir in order to use sibling dirs
        from SimTools.GenCodeTools import GenCodeLoader
        from SimTools.KmerTools import KmerTools
MODELPATH="BestModel"  # saved on cloud instance and lost after logout
#MODELPATH=DATAPATH+MODELPATH  # saved on Google Drive but requires login
# Out:
# On Google CoLab, mount cloud-local file, get our code from GitHub.
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ## Data Load
# Restrict mRNA to those transcripts with a recognized ORF.

# %%
PC_FILENAME='gencode.v38.pc_transcripts.fa.gz'
NC_FILENAME='gencode.v38.lncRNA_transcripts.fa.gz'
PC_FULLPATH=DATAPATH+PC_FILENAME
NC_FULLPATH=DATAPATH+NC_FILENAME

# %%
# Full GenCode ver 38 human is 106143 pc + 48752 nc and loads in 7 sec.
# Expect fewer transcripts if special filtering is used.
loader=GenCodeLoader()
loader.set_label(1)
loader.set_check_utr(True)
pcdf=loader.load_file(PC_FULLPATH)
print("PC seqs loaded:",len(pcdf))
loader.set_label(0)
loader.set_check_utr(False)
ncdf=loader.load_file(NC_FULLPATH)
print("NC seqs loaded:",len(ncdf))
show_time()
# Out:
# PC seqs loaded: 70825
# NC seqs loaded: 48752
# 2021-07-10 17:37:36 UTC

# %% [markdown]
# ## Data Prep

# %%
def dataframe_length_filter(df,low_high):
    (low,high)=low_high
    # The pandas query language is strange, 
    # but this is MUCH faster than loop & drop.
    return df[ (df['seqlen']>=low) & (df['seqlen']<=high) ]
def dataframe_shuffle(df):
    # The ignore_index option is new in Pandas 1.3. 
    # The default (False) replicates the old behavior: shuffle the index too.
    # The new option seems more logical th
    # After shuffling, df.iloc[0] has index == 0.
    # return df.sample(frac=1,ignore_index=True)
    return df.sample(frac=1)  # Use this till CoLab upgrades Pandas
def dataframe_extract_sequence(df):
    return df['sequence'].tolist()

pc_all = dataframe_extract_sequence(
    dataframe_shuffle(
    dataframe_length_filter(pcdf,PC_LENS)))
nc_all = dataframe_extract_sequence(
    dataframe_shuffle(
    dataframe_length_filter(ncdf,NC_LENS)))

show_time()
print("PC seqs pass filter:",len(pc_all))
print("NC seqs pass filter:",len(nc_all))
# Garbage collection to reduce RAM footprint
pcdf=None
ncdf=None
# Out:
# 2021-07-10 17:37:36 UTC
# PC seqs pass filter: 55381
# NC seqs pass filter: 46919

# %%
# Any portion of a shuffled list is a random selection
pc_train=pc_all[:PC_TRAINS] 
nc_train=nc_all[:NC_TRAINS]
pc_test=pc_all[PC_TRAINS:PC_TESTS] 
nc_test=nc_all[NC_TRAINS:PC_TESTS]
# Garbage collection
pc_all=None
nc_all=None

# %%
def prepare_x_and_y(seqs1,seqs0):
    len1=len(seqs1)
    len0=len(seqs0)
    labels1=np.ones(len1,dtype=np.int8)
    labels0=np.zeros(len0,dtype=np.int8)
    all_labels = np.concatenate((labels1,labels0))
    seqs1 = np.asarray(seqs1)
    seqs0 = np.asarray(seqs0)
    all_seqs = np.concatenate((seqs1,seqs0),axis=0)
    # return all_seqs,all_labels  # test unshuffled
    tandem=(all_seqs,all_labels)
    X,y = shuffle(tandem) # sklearn.utils.shuffle
    return X,y
Xseq,y=prepare_x_and_y(pc_train,nc_train)
#print(pc_train[0])
#print(Xseq[0],y[0])
show_time()
# Out:
# 2021-07-10 17:37:37 UTC

# %%
def seqs_to_kmer_freqs(seqs,max_K):
    tool = KmerTools()  # from SimTools
    empty = tool.make_dict_upto_K(max_K)
    collection = []
    for seq in seqs:
        counts = empty
        counts = tool.update_count_one_K(counts,max_K,seq,True)
        counts = tool.harvest_counts_from_K(counts,max_K)
        fdict = tool.count_to_frequency(counts,max_K)
        freqs = list(fdict.values())
        collection.append(freqs)
    return np.asarray(collection)
Xfrq=seqs_to_kmer_freqs(Xseq,MAX_K)
show_time()
print("X shape",np.shape(Xfrq))
print(type(Xfrq),"of",type(Xfrq[0]),"of",type(Xfrq[0][0]))
print("y shape",np.shape(y))
# Out:
# 2021-07-10 17:38:04 UTC
# X shape (40000, 84)
# <class 'numpy.ndarray'> of <class 'numpy.ndarray'> of <class 'numpy.float64'>
# y shape (40000,)

# %% [markdown]
# ## Neural network

# %%
def make_DNN():
    dt=np.float32
    print("make_DNN")
    print("input shape:",INPUT_SHAPE)
    dnn = Sequential()
    dnn.add(Dense(NEURONS,activation="sigmoid",dtype=dt))
    dnn.add(Dense(NEURONS,activation="sigmoid",dtype=dt)) 
    #dnn.add(Dropout(DROP_RATE))
    dnn.add(Dense(1,activation="sigmoid",dtype=dt))   
    dnn.compile(optimizer='adam',
                loss=BinaryCrossentropy(from_logits=False),
                metrics=['accuracy'])   # add to default metrics=loss
    dnn.build(input_shape=INPUT_SHAPE) 
    return dnn
model = make_DNN()
print(model.summary())
# Out:
# make_DNN
# input shape: (None, 84)
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 128)               10880
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 27,521
# Trainable params: 27,521
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def do_cross_validation(X,y):
    cv_scores = []
    fold=0
    mycallbacks = [ModelCheckpoint(
        filepath=MODELPATH, save_best_only=True, 
        monitor='val_accuracy', mode='max')]   
    splitter = KFold(n_splits=SPLITS)  # this does not shuffle
    for train_index,valid_index in splitter.split(X):
        if fold < FOLDS:
            fold += 1
            X_train=X[train_index] # inputs for training
            y_train=y[train_index] # labels for training
            X_valid=X[valid_index] # inputs for validation
            y_valid=y[valid_index] # labels for validation
            print("MODEL")
            # Call constructor on each CV. Else, continually improves the same model.
            model = model = make_DNN()
            print("FIT")  # model.fit() implements learning
            start_time=time.time()
            history=model.fit(X_train, y_train, 
                    epochs=EPOCHS, 
                    verbose=1,  # ascii art while learning
                    callbacks=mycallbacks,   # called at end of each epoch
                    validation_data=(X_valid,y_valid))
            end_time=time.time()
            elapsed_time=(end_time-start_time)                        
            print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
            # print(history.history.keys())  # all these keys will be shown in figure
            pd.DataFrame(history.history).plot(figsize=(8,5))
            plt.grid(True)
            plt.gca().set_ylim(0,1) # any losses > 1 will be off the scale
            plt.show()

# %%
do_cross_validation(Xfrq,y)
# Out:
# MODEL
# make_DNN
# input shape: (None, 84)
# FIT
# Epoch 1/25
# 1000/1000 [==============================] - 3s 2ms/step - loss: 0.6690 - accuracy: 0.6167 - val_loss: 0.8625 - val_accuracy: 0.0000e+00
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 2/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6646 - accuracy: 0.6242 - val_loss: 1.0107 - val_accuracy: 0.0000e+00
# Epoch 3/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6623 - accuracy: 0.6221 - val_loss: 0.8864 - val_accuracy: 0.0000e+00
# Epoch 4/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6511 - accuracy: 0.6292 - val_loss: 0.8379 - val_accuracy: 0.0025
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 5/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6313 - accuracy: 0.6313 - val_loss: 0.9674 - val_accuracy: 0.0031
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 6/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.5493 - accuracy: 0.7059 - val_loss: 0.6484 - val_accuracy: 0.7968
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 7/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.4335 - accuracy: 0.8601 - val_loss: 0.6297 - val_accuracy: 0.7160
# Epoch 8/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.3338 - accuracy: 0.9236 - val_loss: 0.4785 - val_accuracy: 0.9895
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 9/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2762 - accuracy: 0.9293 - val_loss: 0.3178 - val_accuracy: 0.9951
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 10/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.2410 - accuracy: 0.9329 - val_loss: 0.3084 - val_accuracy: 0.9936
# Epoch 11/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2174 - accuracy: 0.9370 - val_loss: 0.2039 - val_accuracy: 0.9956
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 12/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1972 - accuracy: 0.9395 - val_loss: 0.4646 - val_accuracy: 0.8799
# Epoch 13/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1861 - accuracy: 0.9408 - val_loss: 0.3566 - val_accuracy: 0.9697
# Epoch 14/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1730 - accuracy: 0.9451 - val_loss: 0.4877 - val_accuracy: 0.8060
# Epoch 15/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1647 - accuracy: 0.9488 - val_loss: 0.3837 - val_accuracy: 0.9259
# Epoch 16/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1556 - accuracy: 0.9491 - val_loss: 0.2602 - val_accuracy: 0.9886
# Epoch 17/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1521 - accuracy: 0.9505 - val_loss: 0.4626 - val_accuracy: 0.8064
# Epoch 18/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1417 - accuracy: 0.9555 - val_loss: 0.1782 - val_accuracy: 0.9923
# Epoch 19/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1396 - accuracy: 0.9547 - val_loss: 0.2879 - val_accuracy: 0.9659
# Epoch 20/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1373 - accuracy: 0.9551 - val_loss: 0.2962 - val_accuracy: 0.9565
# Epoch 21/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1344 - accuracy: 0.9570 - val_loss: 0.4301 - val_accuracy: 0.8186
# Epoch 22/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1281 - accuracy: 0.9584 - val_loss: 0.4321 - val_accuracy: 0.8106
# Epoch 23/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1224 - accuracy: 0.9606 - val_loss: 0.1772 - val_accuracy: 0.9893
# Epoch 24/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1263 - accuracy: 0.9601 - val_loss: 0.3962 - val_accuracy: 0.8411
# Epoch 25/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1186 - accuracy: 0.9611 - val_loss: 0.2728 - val_accuracy: 0.9498
# Fold 1, 25 epochs, 82 sec
# MODEL
# make_DNN
# input shape: (None, 84)
# FIT
# Epoch 1/25
# 1000/1000 [==============================] - 3s 2ms/step - loss: 0.6678 - accuracy: 0.6183 - val_loss: 0.9321 - val_accuracy: 0.0000e+00
# Epoch 2/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6629 - accuracy: 0.6242 - val_loss: 0.9033 - val_accuracy: 0.0000e+00
# Epoch 3/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6626 - accuracy: 0.6236 - val_loss: 1.0007 - val_accuracy: 0.0000e+00
# Epoch 4/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6549 - accuracy: 0.6270 - val_loss: 0.8958 - val_accuracy: 0.0000e+00
# Epoch 5/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6376 - accuracy: 0.6305 - val_loss: 0.9736 - val_accuracy: 0.0000e+00
# Epoch 6/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.5755 - accuracy: 0.6820 - val_loss: 0.6139 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 7/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.4672 - accuracy: 0.8047 - val_loss: 0.6591 - val_accuracy: 1.0000
# Epoch 8/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.3701 - accuracy: 0.9028 - val_loss: 0.3119 - val_accuracy: 1.0000
# Epoch 9/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.3160 - accuracy: 0.9025 - val_loss: 0.3408 - val_accuracy: 1.0000
# Epoch 10/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2713 - accuracy: 0.9171 - val_loss: 0.1910 - val_accuracy: 1.0000
# Epoch 11/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2489 - accuracy: 0.9216 - val_loss: 0.2613 - val_accuracy: 1.0000
# Epoch 12/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2336 - accuracy: 0.9215 - val_loss: 0.2711 - val_accuracy: 1.0000
# Epoch 13/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2174 - accuracy: 0.9298 - val_loss: 0.1071 - val_accuracy: 1.0000
# Epoch 14/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2123 - accuracy: 0.9276 - val_loss: 0.1987 - val_accuracy: 1.0000
# Epoch 15/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2082 - accuracy: 0.9265 - val_loss: 0.2124 - val_accuracy: 1.0000
# Epoch 16/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2012 - accuracy: 0.9274 - val_loss: 0.0684 - val_accuracy: 1.0000
# Epoch 17/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1905 - accuracy: 0.9316 - val_loss: 0.1204 - val_accuracy: 1.0000
# Epoch 18/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2004 - accuracy: 0.9265 - val_loss: 0.0485 - val_accuracy: 1.0000
# Epoch 19/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1841 - accuracy: 0.9333 - val_loss: 0.1613 - val_accuracy: 1.0000
# Epoch 20/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1806 - accuracy: 0.9340 - val_loss: 0.1419 - val_accuracy: 1.0000
# Epoch 21/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1756 - accuracy: 0.9372 - val_loss: 0.1726 - val_accuracy: 1.0000
# Epoch 22/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1772 - accuracy: 0.9351 - val_loss: 0.0355 - val_accuracy: 1.0000
# Epoch 23/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1847 - accuracy: 0.9300 - val_loss: 0.0804 - val_accuracy: 1.0000
# Epoch 24/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1652 - accuracy: 0.9396 - val_loss: 0.0306 - val_accuracy: 1.0000
# Epoch 25/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1718 - accuracy: 0.9372 - val_loss: 0.1169 - val_accuracy: 1.0000
# Fold 2, 25 epochs, 82 sec
# MODEL
# make_DNN
# input shape: (None, 84)
# FIT
# Epoch 1/25
# 1000/1000 [==============================] - 3s 2ms/step - loss: 0.6980 - accuracy: 0.5023 - val_loss: 0.6934 - val_accuracy: 0.5000
# Epoch 2/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6949 - accuracy: 0.5044 - val_loss: 0.6923 - val_accuracy: 0.5000
# Epoch 3/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6886 - accuracy: 0.5472 - val_loss: 0.6919 - val_accuracy: 0.5000
# Epoch 4/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6632 - accuracy: 0.6582 - val_loss: 0.6712 - val_accuracy: 0.5000
# Epoch 5/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.5470 - accuracy: 0.8358 - val_loss: 0.6622 - val_accuracy: 0.5000
# Epoch 6/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.3397 - accuracy: 0.9603 - val_loss: 0.6045 - val_accuracy: 0.6012
# Epoch 7/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1904 - accuracy: 0.9778 - val_loss: 1.0143 - val_accuracy: 0.5000
# Epoch 8/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.1176 - accuracy: 0.9873 - val_loss: 0.8402 - val_accuracy: 0.5001
# Epoch 9/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0801 - accuracy: 0.9935 - val_loss: 0.8131 - val_accuracy: 0.5620
# Epoch 10/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0578 - accuracy: 0.9967 - val_loss: 0.9544 - val_accuracy: 0.5381
# Epoch 11/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0435 - accuracy: 0.9971 - val_loss: 0.9186 - val_accuracy: 0.5798
# Epoch 12/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0327 - accuracy: 0.9979 - val_loss: 1.1201 - val_accuracy: 0.5493
# Epoch 13/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0252 - accuracy: 0.9988 - val_loss: 1.4038 - val_accuracy: 0.5061
# Epoch 14/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0202 - accuracy: 0.9990 - val_loss: 0.9455 - val_accuracy: 0.6359
# Epoch 15/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0163 - accuracy: 0.9989 - val_loss: 0.5771 - val_accuracy: 0.7384
# Epoch 16/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0172 - accuracy: 0.9980 - val_loss: 2.1086 - val_accuracy: 0.5000
# Epoch 17/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0150 - accuracy: 0.9979 - val_loss: 1.0970 - val_accuracy: 0.6357
# Epoch 18/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0112 - accuracy: 0.9991 - val_loss: 1.6988 - val_accuracy: 0.5315
# Epoch 19/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0109 - accuracy: 0.9991 - val_loss: 2.8587 - val_accuracy: 0.5000
# Epoch 20/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0113 - accuracy: 0.9981 - val_loss: 2.5984 - val_accuracy: 0.5000
# Epoch 21/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0086 - accuracy: 0.9988 - val_loss: 0.8827 - val_accuracy: 0.6999
# Epoch 22/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0094 - accuracy: 0.9986 - val_loss: 1.4728 - val_accuracy: 0.6037
# Epoch 23/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0078 - accuracy: 0.9991 - val_loss: 1.4433 - val_accuracy: 0.6143
# Epoch 24/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0068 - accuracy: 0.9992 - val_loss: 1.0764 - val_accuracy: 0.6801
# Epoch 25/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0081 - accuracy: 0.9987 - val_loss: 0.7239 - val_accuracy: 0.7419
# Fold 3, 25 epochs, 82 sec
# MODEL
# make_DNN
# input shape: (None, 84)
# FIT
# Epoch 1/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.6673 - accuracy: 0.6248 - val_loss: 1.0572 - val_accuracy: 0.0000e+00
# Epoch 2/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.6622 - accuracy: 0.6266 - val_loss: 1.0491 - val_accuracy: 0.0000e+00
# Epoch 3/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6622 - accuracy: 0.6219 - val_loss: 1.0614 - val_accuracy: 0.0000e+00
# Epoch 4/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6522 - accuracy: 0.6234 - val_loss: 0.8200 - val_accuracy: 0.0000e+00
# Epoch 5/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.6140 - accuracy: 0.6519 - val_loss: 0.8791 - val_accuracy: 0.0000e+00
# Epoch 6/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.4958 - accuracy: 0.8326 - val_loss: 0.5256 - val_accuracy: 0.8518
# Epoch 7/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.3769 - accuracy: 0.8790 - val_loss: 0.4960 - val_accuracy: 0.7931
# Epoch 8/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.3183 - accuracy: 0.8798 - val_loss: 0.2863 - val_accuracy: 1.0000
# Epoch 9/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.2872 - accuracy: 0.8833 - val_loss: 0.2319 - val_accuracy: 1.0000
# Epoch 10/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.2716 - accuracy: 0.8872 - val_loss: 0.2559 - val_accuracy: 0.9751
# Epoch 11/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.2612 - accuracy: 0.8917 - val_loss: 0.1500 - val_accuracy: 1.0000
# Epoch 12/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2549 - accuracy: 0.8960 - val_loss: 0.0671 - val_accuracy: 1.0000
# Epoch 13/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2558 - accuracy: 0.8973 - val_loss: 0.2388 - val_accuracy: 0.9365
# Epoch 14/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2421 - accuracy: 0.9041 - val_loss: 0.0795 - val_accuracy: 1.0000
# Epoch 15/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.2394 - accuracy: 0.9085 - val_loss: 0.0710 - val_accuracy: 1.0000
# Epoch 16/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2265 - accuracy: 0.9146 - val_loss: 0.0674 - val_accuracy: 1.0000
# Epoch 17/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.2227 - accuracy: 0.9161 - val_loss: 0.1086 - val_accuracy: 1.0000
# Epoch 18/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.2227 - accuracy: 0.9172 - val_loss: 0.0379 - val_accuracy: 1.0000
# Epoch 19/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.2169 - accuracy: 0.9194 - val_loss: 0.0569 - val_accuracy: 1.0000
# Epoch 20/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.2220 - accuracy: 0.9193 - val_loss: 0.0220 - val_accuracy: 1.0000
# Epoch 21/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.2139 - accuracy: 0.9241 - val_loss: 0.0188 - val_accuracy: 1.0000
# Epoch 22/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2036 - accuracy: 0.9267 - val_loss: 0.0122 - val_accuracy: 1.0000
# Epoch 23/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2040 - accuracy: 0.9264 - val_loss: 0.0230 - val_accuracy: 1.0000
# Epoch 24/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2018 - accuracy: 0.9291 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 25/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1982 - accuracy: 0.9293 - val_loss: 0.0024 - val_accuracy: 1.0000
# Fold 4, 25 epochs, 61 sec
# MODEL
# make_DNN
# input shape: (None, 84)
# FIT
# Epoch 1/25
# 1000/1000 [==============================] - 3s 2ms/step - loss: 0.6664 - accuracy: 0.6198 - val_loss: 0.9363 - val_accuracy: 0.0000e+00
# Epoch 2/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.6633 - accuracy: 0.6265 - val_loss: 1.0443 - val_accuracy: 0.0000e+00
# Epoch 3/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.6650 - accuracy: 0.6219 - val_loss: 0.9973 - val_accuracy: 0.0000e+00
# Epoch 4/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6638 - accuracy: 0.6225 - val_loss: 1.0523 - val_accuracy: 0.0000e+00
# Epoch 5/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.6613 - accuracy: 0.6251 - val_loss: 0.8905 - val_accuracy: 0.0000e+00
# Epoch 6/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6583 - accuracy: 0.6296 - val_loss: 0.9818 - val_accuracy: 0.0000e+00
# Epoch 7/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6565 - accuracy: 0.6258 - val_loss: 0.8157 - val_accuracy: 0.0000e+00
# Epoch 8/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6476 - accuracy: 0.6219 - val_loss: 0.9069 - val_accuracy: 0.0000e+00
# Epoch 9/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.6152 - accuracy: 0.6508 - val_loss: 0.4940 - val_accuracy: 1.0000
# Epoch 10/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.5617 - accuracy: 0.7387 - val_loss: 0.3401 - val_accuracy: 1.0000
# Epoch 11/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.4847 - accuracy: 0.8334 - val_loss: 0.1466 - val_accuracy: 1.0000
# Epoch 12/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.4150 - accuracy: 0.8668 - val_loss: 0.0422 - val_accuracy: 1.0000
# Epoch 13/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.3490 - accuracy: 0.8917 - val_loss: 0.0467 - val_accuracy: 1.0000
# Epoch 14/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.3097 - accuracy: 0.8994 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 15/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2803 - accuracy: 0.9082 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 16/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2605 - accuracy: 0.9148 - val_loss: 9.6239e-04 - val_accuracy: 1.0000
# Epoch 17/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2419 - accuracy: 0.9187 - val_loss: 2.3370e-04 - val_accuracy: 1.0000
# Epoch 18/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2251 - accuracy: 0.9249 - val_loss: 1.0075e-04 - val_accuracy: 1.0000
# Epoch 19/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2195 - accuracy: 0.9254 - val_loss: 6.3437e-05 - val_accuracy: 1.0000
# Epoch 20/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.2127 - accuracy: 0.9292 - val_loss: 7.3314e-05 - val_accuracy: 1.0000
# Epoch 21/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.2048 - accuracy: 0.9307 - val_loss: 2.6394e-05 - val_accuracy: 1.0000
# Epoch 22/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1905 - accuracy: 0.9343 - val_loss: 1.3595e-05 - val_accuracy: 1.0000
# Epoch 23/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1981 - accuracy: 0.9312 - val_loss: 1.6128e-06 - val_accuracy: 1.0000
# Epoch 24/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1972 - accuracy: 0.9333 - val_loss: 7.6645e-06 - val_accuracy: 1.0000
# Epoch 25/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1874 - accuracy: 0.9356 - val_loss: 3.2201e-06 - val_accuracy: 1.0000
# Fold 5, 25 epochs, 60 sec

# %%
# TO DO: run trained model on (pc_test,nc_test)
# and draw the AUC.
# Borrow code from other notebooks.
