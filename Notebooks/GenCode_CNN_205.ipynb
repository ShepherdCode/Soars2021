# %% [markdown]
# # PC/NC classification by CNN
#
# The convolutional neural network (CNN) was invented for image processing.
# We can use Conv1D layers for processing string sequences.
# How well does CNN work on human RNA as a binary classifier of protein-coding/non-coding?
#
#
#
#
# Assume user downloaded files from GenCode 38 [FTP](http://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_human/release_38/)
# to a subdirectory called data.

# %%
import time 
def show_time():
    t = time.time()
    s = time.strftime('%Y-%m-%d %H:%M:%S %Z', time.localtime(t))
    print(s)
show_time()
# Out:
# 2021-06-04 15:18:17 UTC

# %%
PC_FILENAME='gencode.v38.pc_transcripts.fa.gz'
NC_FILENAME='gencode.v38.lncRNA_transcripts.fa.gz'

# %%
PC_SEQUENCES=20000   # how many protein-coding sequences
NC_SEQUENCES=20000   # how many non-coding sequences
PC_TESTS=1000
NC_TESTS=1000
BASES=1000            # how long is each sequence
ALPHABET=4          # how many different letters are possible
INPUT_SHAPE_2D = (BASES,ALPHABET,1) # Conv2D needs 3D inputs
INPUT_SHAPE = (BASES,ALPHABET) # Conv1D needs 2D inputs
FILTERS = 92   # how many different patterns the model looks for
NEURONS = 16
DROP_RATE = 0.2
WIDTH = 3   # how wide each pattern is, in bases
STRIDE_2D = (1,1)  # For Conv2D how far in each direction
STRIDE = 1 # For Conv1D, how far between pattern matches, in bases
EPOCHS=50  # how many times to train on all the data
SPLITS=5  # SPLITS=3 means train on 2/3 and validate on 1/3 
FOLDS=5  # train the model this many times (range 1 to SPLITS)

# %%
import sys
import csv

try:
    from google.colab import drive
    IN_COLAB = True
    print("On Google CoLab, mount cloud-local file, get our code from GitHub.")
    PATH='/content/drive/'
    #drive.mount(PATH,force_remount=True)  # hardly ever need this
    drive.mount(PATH)    # Google will require login credentials
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/RNA_gen.py')
    with open('RNA_gen.py', 'w') as f:
        f.write(r.text)  
    from RNA_gen import *
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/RNA_describe.py')
    with open('RNA_describe.py', 'w') as f:
        f.write(r.text)  
    from RNA_describe import *
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/RNA_prep.py')
    with open('RNA_prep.py', 'w') as f:
        f.write(r.text)  
    from RNA_prep import *
except:
    print("CoLab not working. On my PC, use relative paths.")
    IN_COLAB = False
    DATAPATH='../data/'  # must end in "/"
    sys.path.append("..") # append parent dir in order to use sibling dirs
    from SimTools.RNA_gen import *
    from SimTools.RNA_describe import *
    from SimTools.RNA_prep import *

MODELPATH="BestModel"  # saved on cloud instance and lost after logout
#MODELPATH=DATAPATH+MODELPATH  # saved on Google Drive but requires login

if not assert_imported_RNA_gen():
    print("ERROR: Cannot use RNA_gen.")
if not assert_imported_RNA_prep():
    print("ERROR: Cannot use RNA_prep.")
# Out:
# On Google CoLab, mount cloud-local file, get our code from GitHub.
# Mounted at /content/drive/

# %%
from os import listdir
#from zipfile import ZipFile
import gzip

import numpy as np
import pandas as pd
from scipy import stats  # mode

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

from keras.models import Sequential
from keras.layers import Dense,Embedding,Dropout
from keras.layers import Conv1D,Conv2D
from keras.layers import Flatten,MaxPooling1D,MaxPooling2D
from keras.losses import BinaryCrossentropy
# tf.keras.losses.BinaryCrossentropy

import matplotlib.pyplot as plt
from matplotlib import colors
mycmap = colors.ListedColormap(['red','blue'])  # list color for label 0 then 1
np.set_printoptions(precision=2)

# %%
def load_gencode(filename,label):
    DEFLINE='>'
    DELIM='|'
    EMPTY=''
    labels=[]  # usually 1 for protein-coding or 0 for non-coding
    seqs=[]    # usually string of ACGT
    lens=[]    # sequence length
    ids=[]     # GenCode transcript ID, always starts ENST
    one_seq = EMPTY
    one_id = None
    # Use gzip 'r' mode to open file in read-only mode.
    # Use gzip 't' mode to read each line of text as type string.
    with gzip.open (filename,'rt') as infile:
        for line in infile:
            if line[0]==DEFLINE:
                # Save the previous sequence if one exists.
                if not one_seq == EMPTY:
                    labels.append(label)
                    seqs.append(one_seq)
                    lens.append(len(one_seq))
                    ids.append(one_id)
                # Get ready to read the next sequence. 
                # Parse a GenCode defline that is formatted like this:
                # >transcript_ID|gene_ID|other_fields other_info|other_info
                one_id = line[1:].split(DELIM)[0]
                one_seq = EMPTY
            else:
                # Continue loading sequence lines till next defline.
                additional = line.rstrip()
                one_seq = one_seq + additional
        # Don't forget to save the last sequence after end-of-file.
        if not one_seq == EMPTY:
            labels.append(label)
            seqs.append(one_seq)
            lens.append(len(one_seq))
            ids.append(one_id)

    df1=pd.DataFrame(ids,columns=['tid'])
    df2=pd.DataFrame(labels,columns=['class'])
    df3=pd.DataFrame(seqs,columns=['sequence'])
    df4=pd.DataFrame(lens,columns=['seqlen'])
    df=pd.concat((df1,df2,df3,df4),axis=1)
    return df

# %%
PC_FULLPATH=DATAPATH+PC_FILENAME
NC_FULLPATH=DATAPATH+NC_FILENAME
pcdf=load_gencode(PC_FULLPATH,1)
print("PC seqs loaded:",len(pcdf))
ncdf=load_gencode(NC_FULLPATH,0)
print("NC seqs loaded:",len(ncdf))
# Out:
# PC seqs loaded: 106143
# NC seqs loaded: 48752

# %%
def uniform_length(seqs,hardlen,too_big):
    newseqs=[]
    pad='T'*hardlen
    too_small=200 ## by definition of long non-coding RNA
    for seq in seqs:
        size=len(seq)
        if (size>too_small and size<too_big):
            big=seq+pad
            little=big[:hardlen]
            newseqs.append(little)
    return newseqs

# %%
from sklearn.model_selection import train_test_split
pc_all = pcdf['sequence']
nc_all = ncdf['sequence']
# The split function also shuffles
pc_train,pc_test=train_test_split(pc_all,test_size=0.10,random_state=1234)
nc_train,nc_test=train_test_split(nc_all,test_size=0.10,random_state=1234)

# %%
# Use code from our SimTools library.
UNIFORM_LENGTH=1000
MAXIMUM_LENGTH=2000
pc_seqs=uniform_length(pc_train,UNIFORM_LENGTH,MAXIMUM_LENGTH-500)
print("PC seqs ready:",len(pc_seqs))
nc_seqs=uniform_length(nc_train,UNIFORM_LENGTH,MAXIMUM_LENGTH+2000)
print("NC seqs ready:",len(nc_seqs))
X,y = prepare_inputs_len_x_alphabet(pc_seqs,nc_seqs,ALPHABET) # shuffles
print("Data ready")
# Out:
# PC seqs ready: 44652
# NC seqs ready: 42211
# Data ready

# %%
def make_DNN():
    print("make_DNN")
    print("input shape:",INPUT_SHAPE)
    dnn = Sequential()
    #dnn.add(Embedding(input_dim=INPUT_SHAPE,output_dim=INPUT_SHAPE)) 
    dnn.add(Conv1D(filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,padding="same",
            input_shape=INPUT_SHAPE))
    dnn.add(Conv1D(filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,padding="same"))
    dnn.add(MaxPooling1D())
    dnn.add(Conv1D(filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,padding="same"))
    dnn.add(Conv1D(filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,padding="same"))
    dnn.add(MaxPooling1D())
    dnn.add(Flatten())
    dnn.add(Dense(NEURONS,activation="sigmoid",dtype=np.float32))   
    dnn.add(Dropout(DROP_RATE))
    dnn.add(Dense(1,activation="sigmoid",dtype=np.float32))   
    dnn.compile(optimizer='adam',
                loss=BinaryCrossentropy(from_logits=False),
                metrics=['accuracy'])   # add to default metrics=loss
    dnn.build(input_shape=INPUT_SHAPE)
    #ln_rate = tf.keras.optimizers.Adam(learning_rate = LN_RATE)
    #bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    #model.compile(loss=bc, optimizer=ln_rate, metrics=["accuracy"])
    return dnn
model = make_DNN()
print(model.summary())
# Out:
# make_DNN
# input shape: (1000, 4)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 1000, 92)          1196
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 1000, 92)          25484
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 500, 92)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 500, 92)           25484
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 500, 92)           25484
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 250, 92)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 23000)             0
# _________________________________________________________________
# dense (Dense)                (None, 16)                368016
# _________________________________________________________________
# dropout (Dropout)            (None, 16)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 445,681
# Trainable params: 445,681
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from keras.callbacks import ModelCheckpoint

def do_cross_validation(X,y):
    cv_scores = []
    fold=0
    mycallbacks = [ModelCheckpoint(
        filepath=MODELPATH, save_best_only=True, 
        monitor='val_accuracy', mode='max')]   
    splitter = KFold(n_splits=SPLITS)  # this does not shuffle
    for train_index,valid_index in splitter.split(X):
        if fold < FOLDS:
            fold += 1
            X_train=X[train_index] # inputs for training
            y_train=y[train_index] # labels for training
            X_valid=X[valid_index] # inputs for validation
            y_valid=y[valid_index] # labels for validation
            print("MODEL")
            # Call constructor on each CV. Else, continually improves the same model.
            model = model = make_DNN()
            print("FIT")  # model.fit() implements learning
            start_time=time.time()
            history=model.fit(X_train, y_train, 
                    epochs=EPOCHS, 
                    verbose=1,  # ascii art while learning
                    callbacks=mycallbacks,   # called at end of each epoch
                    validation_data=(X_valid,y_valid))
            end_time=time.time()
            elapsed_time=(end_time-start_time)                        
            print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
            # print(history.history.keys())  # all these keys will be shown in figure
            pd.DataFrame(history.history).plot(figsize=(8,5))
            plt.grid(True)
            plt.gca().set_ylim(0,1) # any losses > 1 will be off the scale
            plt.show()

# %%
show_time()
do_cross_validation(X,y)
show_time()
# Out:
# 2021-06-04 15:19:08 UTC
# MODEL
# make_DNN
# input shape: (1000, 4)
# FIT
# Epoch 1/50
# 2172/2172 [==============================] - 72s 13ms/step - loss: 0.6854 - accuracy: 0.5719 - val_loss: 0.6926 - val_accuracy: 0.5198
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 2/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6941 - accuracy: 0.5074 - val_loss: 0.6924 - val_accuracy: 0.5197
# Epoch 3/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6932 - accuracy: 0.5124 - val_loss: 0.6935 - val_accuracy: 0.4803
# Epoch 4/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5117 - val_loss: 0.6924 - val_accuracy: 0.5197
# Epoch 5/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6932 - accuracy: 0.5031 - val_loss: 0.6926 - val_accuracy: 0.5197
# Epoch 6/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5090 - val_loss: 0.6924 - val_accuracy: 0.5197
# Epoch 7/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5093 - val_loss: 0.6934 - val_accuracy: 0.4804
# Epoch 8/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5081 - val_loss: 0.6924 - val_accuracy: 0.5197
# Epoch 9/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6932 - accuracy: 0.5062 - val_loss: 0.6926 - val_accuracy: 0.5197
# Epoch 10/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6932 - accuracy: 0.5050 - val_loss: 0.6924 - val_accuracy: 0.5197
# Epoch 11/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6932 - accuracy: 0.5071 - val_loss: 0.6926 - val_accuracy: 0.5197
# Epoch 12/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5099 - val_loss: 0.6924 - val_accuracy: 0.5197
# Epoch 13/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6932 - accuracy: 0.5060 - val_loss: 0.6929 - val_accuracy: 0.5197
# Epoch 14/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5115 - val_loss: 0.6924 - val_accuracy: 0.5197
# Epoch 15/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6932 - accuracy: 0.5065 - val_loss: 0.6926 - val_accuracy: 0.5197
# Epoch 16/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5109 - val_loss: 0.6939 - val_accuracy: 0.4803
# Epoch 17/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6932 - accuracy: 0.5066 - val_loss: 0.6924 - val_accuracy: 0.5197
# Epoch 18/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6932 - accuracy: 0.5062 - val_loss: 0.6924 - val_accuracy: 0.5197
# Epoch 19/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6928 - accuracy: 0.5147 - val_loss: 0.6926 - val_accuracy: 0.5197
# Epoch 20/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5117 - val_loss: 0.6924 - val_accuracy: 0.5197
# Epoch 21/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6934 - accuracy: 0.5046 - val_loss: 0.6924 - val_accuracy: 0.5197
# Epoch 22/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5098 - val_loss: 0.6924 - val_accuracy: 0.5197
# Epoch 23/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5104 - val_loss: 0.6926 - val_accuracy: 0.5197
# Epoch 24/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5148 - val_loss: 0.6926 - val_accuracy: 0.5197
# Epoch 25/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5098 - val_loss: 0.6924 - val_accuracy: 0.5197
# Epoch 26/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6929 - accuracy: 0.5134 - val_loss: 0.6925 - val_accuracy: 0.5197
# Epoch 27/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5097 - val_loss: 0.6926 - val_accuracy: 0.5197
# Epoch 28/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6929 - accuracy: 0.5131 - val_loss: 0.6929 - val_accuracy: 0.5197
# Epoch 29/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5120 - val_loss: 0.6924 - val_accuracy: 0.5197
# Epoch 30/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5093 - val_loss: 0.6942 - val_accuracy: 0.4803
# Epoch 31/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5073 - val_loss: 0.6931 - val_accuracy: 0.5197
# Epoch 32/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5115 - val_loss: 0.6937 - val_accuracy: 0.4803
# Epoch 33/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5074 - val_loss: 0.6924 - val_accuracy: 0.5197
# Epoch 34/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5089 - val_loss: 0.6924 - val_accuracy: 0.5197
# Epoch 35/50
# 2172/2172 [==============================] - 30s 14ms/step - loss: 0.6931 - accuracy: 0.5089 - val_loss: 0.6924 - val_accuracy: 0.5197
# Epoch 36/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6927 - accuracy: 0.5149 - val_loss: 0.6932 - val_accuracy: 0.4803
# Epoch 37/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6933 - accuracy: 0.5039 - val_loss: 0.6924 - val_accuracy: 0.5197
# Epoch 38/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5076 - val_loss: 0.6936 - val_accuracy: 0.4803
# Epoch 39/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6932 - accuracy: 0.5062 - val_loss: 0.6930 - val_accuracy: 0.5197
# Epoch 40/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6928 - accuracy: 0.5141 - val_loss: 0.6925 - val_accuracy: 0.5197
# Epoch 41/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5109 - val_loss: 0.6931 - val_accuracy: 0.5197
# Epoch 42/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6932 - accuracy: 0.5086 - val_loss: 0.6924 - val_accuracy: 0.5197
# Epoch 43/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6932 - accuracy: 0.5080 - val_loss: 0.6924 - val_accuracy: 0.5197
# Epoch 44/50
# 2172/2172 [==============================] - 31s 14ms/step - loss: 0.6929 - accuracy: 0.5110 - val_loss: 0.6925 - val_accuracy: 0.5197
# Epoch 45/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5102 - val_loss: 0.6943 - val_accuracy: 0.4803
# Epoch 46/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6932 - accuracy: 0.5066 - val_loss: 0.6928 - val_accuracy: 0.5197
# Epoch 47/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5082 - val_loss: 0.6933 - val_accuracy: 0.4803
# Epoch 48/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6928 - accuracy: 0.5126 - val_loss: 0.6925 - val_accuracy: 0.5197
# Epoch 49/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6929 - accuracy: 0.5123 - val_loss: 0.6924 - val_accuracy: 0.5197
# Epoch 50/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6932 - accuracy: 0.5071 - val_loss: 0.6927 - val_accuracy: 0.5197
# Fold 1, 50 epochs, 1476 sec
# MODEL
# make_DNN
# input shape: (1000, 4)
# FIT
# Epoch 1/50
# 2172/2172 [==============================] - 30s 13ms/step - loss: 0.6347 - accuracy: 0.6429 - val_loss: 0.7016 - val_accuracy: 0.5143
# Epoch 2/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6896 - accuracy: 0.5373 - val_loss: 0.6937 - val_accuracy: 0.5119
# Epoch 3/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6941 - accuracy: 0.5093 - val_loss: 0.6929 - val_accuracy: 0.5119
# Epoch 4/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6928 - accuracy: 0.5145 - val_loss: 0.6930 - val_accuracy: 0.5119
# Epoch 5/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6928 - accuracy: 0.5154 - val_loss: 0.6930 - val_accuracy: 0.5119
# Epoch 6/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6929 - accuracy: 0.5127 - val_loss: 0.6931 - val_accuracy: 0.5119
# Epoch 7/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5106 - val_loss: 0.6929 - val_accuracy: 0.5119
# Epoch 8/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5073 - val_loss: 0.6930 - val_accuracy: 0.5119
# Epoch 9/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6927 - accuracy: 0.5163 - val_loss: 0.6933 - val_accuracy: 0.4881
# Epoch 10/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5062 - val_loss: 0.6929 - val_accuracy: 0.5119
# Epoch 11/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6932 - accuracy: 0.5086 - val_loss: 0.6929 - val_accuracy: 0.5119
# Epoch 12/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5083 - val_loss: 0.6930 - val_accuracy: 0.5119
# Epoch 13/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5107 - val_loss: 0.6929 - val_accuracy: 0.5119
# Epoch 14/50
# 2172/2172 [==============================] - 31s 14ms/step - loss: 0.6930 - accuracy: 0.5096 - val_loss: 0.6930 - val_accuracy: 0.5119
# Epoch 15/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6929 - accuracy: 0.5125 - val_loss: 0.6929 - val_accuracy: 0.5119
# Epoch 16/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6932 - accuracy: 0.5072 - val_loss: 0.6932 - val_accuracy: 0.5119
# Epoch 17/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5144 - val_loss: 0.6933 - val_accuracy: 0.5119
# Epoch 18/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6929 - accuracy: 0.5133 - val_loss: 0.6929 - val_accuracy: 0.5119
# Epoch 19/50
# 2172/2172 [==============================] - 31s 14ms/step - loss: 0.6929 - accuracy: 0.5151 - val_loss: 0.6930 - val_accuracy: 0.5119
# Epoch 20/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5109 - val_loss: 0.6938 - val_accuracy: 0.5119
# Epoch 21/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5099 - val_loss: 0.6932 - val_accuracy: 0.5119
# Epoch 22/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5080 - val_loss: 0.6931 - val_accuracy: 0.5119
# Epoch 23/50
# 2172/2172 [==============================] - 30s 14ms/step - loss: 0.6933 - accuracy: 0.5085 - val_loss: 0.6931 - val_accuracy: 0.5119
# Epoch 24/50
# 2172/2172 [==============================] - 31s 14ms/step - loss: 0.6927 - accuracy: 0.5165 - val_loss: 0.6932 - val_accuracy: 0.4881
# Epoch 25/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5080 - val_loss: 0.6931 - val_accuracy: 0.5119
# Epoch 26/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6928 - accuracy: 0.5132 - val_loss: 0.6934 - val_accuracy: 0.5119
# Epoch 27/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6929 - accuracy: 0.5111 - val_loss: 0.6932 - val_accuracy: 0.4881
# Epoch 28/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5133 - val_loss: 0.6935 - val_accuracy: 0.5119
# Epoch 29/50
# 2172/2172 [==============================] - 31s 14ms/step - loss: 0.6931 - accuracy: 0.5114 - val_loss: 0.6929 - val_accuracy: 0.5119
# Epoch 30/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5095 - val_loss: 0.6929 - val_accuracy: 0.5119
# Epoch 31/50
# 2172/2172 [==============================] - 31s 14ms/step - loss: 0.6929 - accuracy: 0.5135 - val_loss: 0.6929 - val_accuracy: 0.5119
# Epoch 32/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6931 - val_accuracy: 0.5119
# Epoch 33/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6929 - accuracy: 0.5142 - val_loss: 0.6929 - val_accuracy: 0.5119
# Epoch 34/50
# 2172/2172 [==============================] - 31s 14ms/step - loss: 0.6929 - accuracy: 0.5131 - val_loss: 0.6929 - val_accuracy: 0.5119
# Epoch 35/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6929 - accuracy: 0.5139 - val_loss: 0.6929 - val_accuracy: 0.5119
# Epoch 36/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6929 - accuracy: 0.5173 - val_loss: 0.6929 - val_accuracy: 0.5119
# Epoch 37/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5106 - val_loss: 0.6933 - val_accuracy: 0.5119
# Epoch 38/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6932 - accuracy: 0.5115 - val_loss: 0.6933 - val_accuracy: 0.5119
# Epoch 39/50
# 2172/2172 [==============================] - 31s 14ms/step - loss: 0.6930 - accuracy: 0.5159 - val_loss: 0.6929 - val_accuracy: 0.5119
# Epoch 40/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6932 - accuracy: 0.5112 - val_loss: 0.6929 - val_accuracy: 0.5119
# Epoch 41/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6929 - accuracy: 0.5163 - val_loss: 0.6931 - val_accuracy: 0.5119
# Epoch 42/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5111 - val_loss: 0.6929 - val_accuracy: 0.5119
# Epoch 43/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5114 - val_loss: 0.6929 - val_accuracy: 0.5119
# Epoch 44/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6929 - accuracy: 0.5133 - val_loss: 0.6930 - val_accuracy: 0.5119
# Epoch 45/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6929 - accuracy: 0.5115 - val_loss: 0.6930 - val_accuracy: 0.5119
# Epoch 46/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6930 - accuracy: 0.5113 - val_loss: 0.6935 - val_accuracy: 0.5119
# Epoch 47/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6933 - accuracy: 0.5083 - val_loss: 0.6931 - val_accuracy: 0.5119
# Epoch 48/50
# 2172/2172 [==============================] - 31s 14ms/step - loss: 0.6931 - accuracy: 0.5080 - val_loss: 0.6930 - val_accuracy: 0.5119
# Epoch 49/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6932 - accuracy: 0.5063 - val_loss: 0.6929 - val_accuracy: 0.5119
# Epoch 50/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6931 - accuracy: 0.5072 - val_loss: 0.6929 - val_accuracy: 0.5119
# Fold 2, 50 epochs, 1463 sec
# MODEL
# make_DNN
# input shape: (1000, 4)
# FIT
# Epoch 1/50
# 2172/2172 [==============================] - 30s 13ms/step - loss: 0.6527 - accuracy: 0.6166 - val_loss: 0.6932 - val_accuracy: 0.5054
# Epoch 2/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6947 - accuracy: 0.5084 - val_loss: 0.6933 - val_accuracy: 0.5054
# Epoch 3/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6932 - accuracy: 0.5107 - val_loss: 0.6939 - val_accuracy: 0.5054
# Epoch 4/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5110 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 5/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6929 - accuracy: 0.5143 - val_loss: 0.6932 - val_accuracy: 0.5054
# Epoch 6/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6931 - accuracy: 0.5105 - val_loss: 0.6931 - val_accuracy: 0.5054
# Epoch 7/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6928 - accuracy: 0.5160 - val_loss: 0.6931 - val_accuracy: 0.5054
# Epoch 8/50
# 2172/2172 [==============================] - 31s 14ms/step - loss: 0.6927 - accuracy: 0.5176 - val_loss: 0.6941 - val_accuracy: 0.4946
# Epoch 9/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5109 - val_loss: 0.6945 - val_accuracy: 0.5054
# Epoch 10/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6928 - accuracy: 0.5131 - val_loss: 0.6934 - val_accuracy: 0.5054
# Epoch 11/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6929 - accuracy: 0.5135 - val_loss: 0.6932 - val_accuracy: 0.5054
# Epoch 12/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6929 - accuracy: 0.5135 - val_loss: 0.6947 - val_accuracy: 0.5054
# Epoch 13/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6930 - accuracy: 0.5112 - val_loss: 0.6931 - val_accuracy: 0.5054
# Epoch 14/50
# 2172/2172 [==============================] - 31s 14ms/step - loss: 0.6929 - accuracy: 0.5131 - val_loss: 0.6943 - val_accuracy: 0.5054
# Epoch 15/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6927 - accuracy: 0.5151 - val_loss: 0.6940 - val_accuracy: 0.5054
# Epoch 16/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5119 - val_loss: 0.6936 - val_accuracy: 0.5054
# Epoch 17/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5132 - val_loss: 0.6938 - val_accuracy: 0.5054
# Epoch 18/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5126 - val_loss: 0.6955 - val_accuracy: 0.5054
# Epoch 19/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5141 - val_loss: 0.6931 - val_accuracy: 0.5054
# Epoch 20/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5121 - val_loss: 0.6932 - val_accuracy: 0.5054
# Epoch 21/50
# 2172/2172 [==============================] - 31s 14ms/step - loss: 0.6930 - accuracy: 0.5132 - val_loss: 0.6931 - val_accuracy: 0.5054
# Epoch 22/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6928 - accuracy: 0.5129 - val_loss: 0.6932 - val_accuracy: 0.5054
# Epoch 23/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5129 - val_loss: 0.6932 - val_accuracy: 0.5054
# Epoch 24/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5122 - val_loss: 0.6932 - val_accuracy: 0.4946
# Epoch 25/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6926 - accuracy: 0.5138 - val_loss: 0.6933 - val_accuracy: 0.5054
# Epoch 26/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6929 - accuracy: 0.5142 - val_loss: 0.6934 - val_accuracy: 0.5054
# Epoch 27/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6928 - accuracy: 0.5152 - val_loss: 0.6931 - val_accuracy: 0.5054
# Epoch 28/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6930 - accuracy: 0.5134 - val_loss: 0.6935 - val_accuracy: 0.5054
# Epoch 29/50
# 2172/2172 [==============================] - 31s 14ms/step - loss: 0.6929 - accuracy: 0.5140 - val_loss: 0.6942 - val_accuracy: 0.5054
# Epoch 30/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6929 - accuracy: 0.5149 - val_loss: 0.6932 - val_accuracy: 0.5054
# Epoch 31/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6929 - accuracy: 0.5139 - val_loss: 0.6931 - val_accuracy: 0.5054
# Epoch 32/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6928 - accuracy: 0.5153 - val_loss: 0.6931 - val_accuracy: 0.5054
# Epoch 33/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6928 - accuracy: 0.5157 - val_loss: 0.6937 - val_accuracy: 0.5054
# Epoch 34/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6927 - accuracy: 0.5173 - val_loss: 0.6931 - val_accuracy: 0.5054
# Epoch 35/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6928 - accuracy: 0.5147 - val_loss: 0.6931 - val_accuracy: 0.5054
# Epoch 36/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6928 - accuracy: 0.5149 - val_loss: 0.6934 - val_accuracy: 0.5054
# Epoch 37/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6928 - accuracy: 0.5163 - val_loss: 0.6939 - val_accuracy: 0.5054
# Epoch 38/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6929 - accuracy: 0.5151 - val_loss: 0.6932 - val_accuracy: 0.5054
# Epoch 39/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6929 - accuracy: 0.5137 - val_loss: 0.6931 - val_accuracy: 0.5054
# Epoch 40/50
# 2172/2172 [==============================] - 31s 14ms/step - loss: 0.6929 - accuracy: 0.5144 - val_loss: 0.6936 - val_accuracy: 0.5054
# Epoch 41/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6930 - accuracy: 0.5149 - val_loss: 0.6940 - val_accuracy: 0.5054
# Epoch 42/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6929 - accuracy: 0.5114 - val_loss: 0.6935 - val_accuracy: 0.5054
# Epoch 43/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6928 - accuracy: 0.5155 - val_loss: 0.6935 - val_accuracy: 0.5054
# Epoch 44/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6928 - accuracy: 0.5157 - val_loss: 0.6940 - val_accuracy: 0.5054
# Epoch 45/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6927 - accuracy: 0.5174 - val_loss: 0.6931 - val_accuracy: 0.5052
# Epoch 46/50
# 2172/2172 [==============================] - 31s 14ms/step - loss: 0.6928 - accuracy: 0.5142 - val_loss: 0.6935 - val_accuracy: 0.5054
# Epoch 47/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6929 - accuracy: 0.5148 - val_loss: 0.6932 - val_accuracy: 0.5054
# Epoch 48/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6929 - accuracy: 0.5156 - val_loss: 0.6931 - val_accuracy: 0.5054
# Epoch 49/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6927 - accuracy: 0.5169 - val_loss: 0.6931 - val_accuracy: 0.5054
# Epoch 50/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6927 - accuracy: 0.5168 - val_loss: 0.6931 - val_accuracy: 0.5054
# Fold 3, 50 epochs, 1443 sec
# MODEL
# make_DNN
# input shape: (1000, 4)
# FIT
# Epoch 1/50
# 2172/2172 [==============================] - 30s 13ms/step - loss: 0.6265 - accuracy: 0.6560 - val_loss: 0.6923 - val_accuracy: 0.5203
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 2/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.7002 - accuracy: 0.4993 - val_loss: 0.6930 - val_accuracy: 0.5203
# Epoch 3/50
# 2172/2172 [==============================] - 31s 14ms/step - loss: 0.6935 - accuracy: 0.5031 - val_loss: 0.6925 - val_accuracy: 0.5203
# Epoch 4/50
# 2172/2172 [==============================] - 31s 14ms/step - loss: 0.6931 - accuracy: 0.5083 - val_loss: 0.6924 - val_accuracy: 0.5203
# Epoch 5/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5116 - val_loss: 0.6930 - val_accuracy: 0.5203
# Epoch 6/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6933 - accuracy: 0.5052 - val_loss: 0.6935 - val_accuracy: 0.4797
# Epoch 7/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6933 - accuracy: 0.5059 - val_loss: 0.6924 - val_accuracy: 0.5203
# Epoch 8/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6933 - accuracy: 0.5087 - val_loss: 0.6923 - val_accuracy: 0.5203
# Epoch 9/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5115 - val_loss: 0.6924 - val_accuracy: 0.5203
# Epoch 10/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6932 - accuracy: 0.5064 - val_loss: 0.6923 - val_accuracy: 0.5203
# Epoch 11/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5122 - val_loss: 0.6926 - val_accuracy: 0.5203
# Epoch 12/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5102 - val_loss: 0.6926 - val_accuracy: 0.5203
# Epoch 13/50
# 2172/2172 [==============================] - 31s 14ms/step - loss: 0.6934 - accuracy: 0.5015 - val_loss: 0.6925 - val_accuracy: 0.5203
# Epoch 14/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6932 - accuracy: 0.5087 - val_loss: 0.6925 - val_accuracy: 0.5203
# Epoch 15/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6933 - accuracy: 0.5038 - val_loss: 0.6929 - val_accuracy: 0.5203
# Epoch 16/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6933 - accuracy: 0.5056 - val_loss: 0.6937 - val_accuracy: 0.4797
# Epoch 17/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5106 - val_loss: 0.6924 - val_accuracy: 0.5203
# Epoch 18/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6928 - accuracy: 0.5137 - val_loss: 0.6924 - val_accuracy: 0.5203
# Epoch 19/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6934 - accuracy: 0.5078 - val_loss: 0.6923 - val_accuracy: 0.5203
# Epoch 20/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6930 - accuracy: 0.5115 - val_loss: 0.6924 - val_accuracy: 0.5203
# Epoch 21/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5107 - val_loss: 0.6928 - val_accuracy: 0.5203
# Epoch 22/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6932 - accuracy: 0.5068 - val_loss: 0.6924 - val_accuracy: 0.5203
# Epoch 23/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6932 - accuracy: 0.5097 - val_loss: 0.6926 - val_accuracy: 0.5203
# Epoch 24/50
# 2172/2172 [==============================] - 31s 14ms/step - loss: 0.6931 - accuracy: 0.5100 - val_loss: 0.6929 - val_accuracy: 0.5203
# Epoch 25/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5090 - val_loss: 0.6926 - val_accuracy: 0.5203
# Epoch 26/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5072 - val_loss: 0.6928 - val_accuracy: 0.5203
# Epoch 27/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5099 - val_loss: 0.6926 - val_accuracy: 0.5203
# Epoch 28/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5094 - val_loss: 0.6923 - val_accuracy: 0.5203
# Epoch 29/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5120 - val_loss: 0.6927 - val_accuracy: 0.5203
# Epoch 30/50
# 2172/2172 [==============================] - 31s 14ms/step - loss: 0.6930 - accuracy: 0.5109 - val_loss: 0.6924 - val_accuracy: 0.5203
# Epoch 31/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6930 - accuracy: 0.5097 - val_loss: 0.6944 - val_accuracy: 0.4797
# Epoch 32/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6932 - accuracy: 0.5093 - val_loss: 0.6924 - val_accuracy: 0.5203
# Epoch 33/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6927 - accuracy: 0.5149 - val_loss: 0.6923 - val_accuracy: 0.5203
# Epoch 34/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5126 - val_loss: 0.6923 - val_accuracy: 0.5203
# Epoch 35/50
# 2172/2172 [==============================] - 31s 14ms/step - loss: 0.6932 - accuracy: 0.5097 - val_loss: 0.6923 - val_accuracy: 0.5203
# Epoch 36/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5096 - val_loss: 0.6924 - val_accuracy: 0.5203
# Epoch 37/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6932 - accuracy: 0.5084 - val_loss: 0.6923 - val_accuracy: 0.5203
# Epoch 38/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6927 - accuracy: 0.5142 - val_loss: 0.6928 - val_accuracy: 0.5203
# Epoch 39/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5060 - val_loss: 0.6923 - val_accuracy: 0.5203
# Epoch 40/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6932 - accuracy: 0.5099 - val_loss: 0.6926 - val_accuracy: 0.5203
# Epoch 41/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5088 - val_loss: 0.6924 - val_accuracy: 0.5203
# Epoch 42/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6932 - accuracy: 0.5101 - val_loss: 0.6925 - val_accuracy: 0.5203
# Epoch 43/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5096 - val_loss: 0.6924 - val_accuracy: 0.5203
# Epoch 44/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5085 - val_loss: 0.6924 - val_accuracy: 0.5203
# Epoch 45/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5117 - val_loss: 0.6937 - val_accuracy: 0.4797
# Epoch 46/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5092 - val_loss: 0.6928 - val_accuracy: 0.5203
# Epoch 47/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6932 - accuracy: 0.5084 - val_loss: 0.6936 - val_accuracy: 0.4797
# Epoch 48/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5116 - val_loss: 0.6925 - val_accuracy: 0.5203
# Epoch 49/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5098 - val_loss: 0.6943 - val_accuracy: 0.4797
# Epoch 50/50
# 2172/2172 [==============================] - 31s 14ms/step - loss: 0.6933 - accuracy: 0.5046 - val_loss: 0.6923 - val_accuracy: 0.5203
# Fold 4, 50 epochs, 1436 sec
# MODEL
# make_DNN
# input shape: (1000, 4)
# FIT
# Epoch 1/50
# 2172/2172 [==============================] - 30s 13ms/step - loss: 0.6600 - accuracy: 0.6057 - val_loss: 0.6928 - val_accuracy: 0.5135
# Epoch 2/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6932 - accuracy: 0.5094 - val_loss: 0.6707 - val_accuracy: 0.6346
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 3/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6934 - accuracy: 0.5152 - val_loss: 0.6930 - val_accuracy: 0.5131
# Epoch 4/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6932 - accuracy: 0.5088 - val_loss: 0.6930 - val_accuracy: 0.5131
# Epoch 5/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6928 - accuracy: 0.5142 - val_loss: 0.6933 - val_accuracy: 0.5131
# Epoch 6/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6929 - accuracy: 0.5140 - val_loss: 0.6928 - val_accuracy: 0.5131
# Epoch 7/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6927 - accuracy: 0.5167 - val_loss: 0.6932 - val_accuracy: 0.4869
# Epoch 8/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6929 - accuracy: 0.5103 - val_loss: 0.6929 - val_accuracy: 0.5131
# Epoch 9/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6929 - val_accuracy: 0.5131
# Epoch 10/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6926 - accuracy: 0.5136 - val_loss: 0.6932 - val_accuracy: 0.5131
# Epoch 11/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6931 - accuracy: 0.5100 - val_loss: 0.6928 - val_accuracy: 0.5131
# Epoch 12/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6929 - accuracy: 0.5125 - val_loss: 0.6929 - val_accuracy: 0.5131
# Epoch 13/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6929 - accuracy: 0.5100 - val_loss: 0.6928 - val_accuracy: 0.5131
# Epoch 14/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6930 - accuracy: 0.5118 - val_loss: 0.6929 - val_accuracy: 0.5131
# Epoch 15/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5090 - val_loss: 0.6928 - val_accuracy: 0.5131
# Epoch 16/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6929 - accuracy: 0.5127 - val_loss: 0.6929 - val_accuracy: 0.5131
# Epoch 17/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6929 - accuracy: 0.5144 - val_loss: 0.6928 - val_accuracy: 0.5131
# Epoch 18/50
# 2172/2172 [==============================] - 31s 14ms/step - loss: 0.6927 - accuracy: 0.5158 - val_loss: 0.6928 - val_accuracy: 0.5131
# Epoch 19/50
# 2172/2172 [==============================] - 31s 14ms/step - loss: 0.6927 - accuracy: 0.5155 - val_loss: 0.6928 - val_accuracy: 0.5131
# Epoch 20/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6928 - accuracy: 0.5151 - val_loss: 0.6931 - val_accuracy: 0.5131
# Epoch 21/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6928 - accuracy: 0.5133 - val_loss: 0.6929 - val_accuracy: 0.5131
# Epoch 22/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5112 - val_loss: 0.6929 - val_accuracy: 0.5131
# Epoch 23/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6929 - accuracy: 0.5136 - val_loss: 0.6928 - val_accuracy: 0.5131
# Epoch 24/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6929 - accuracy: 0.5138 - val_loss: 0.6930 - val_accuracy: 0.5131
# Epoch 25/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5112 - val_loss: 0.6929 - val_accuracy: 0.5131
# Epoch 26/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5118 - val_loss: 0.6929 - val_accuracy: 0.5131
# Epoch 27/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6932 - accuracy: 0.5019 - val_loss: 0.6929 - val_accuracy: 0.5131
# Epoch 28/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6929 - accuracy: 0.5128 - val_loss: 0.6928 - val_accuracy: 0.5131
# Epoch 29/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6929 - accuracy: 0.5140 - val_loss: 0.6929 - val_accuracy: 0.5131
# Epoch 30/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6927 - accuracy: 0.5164 - val_loss: 0.6928 - val_accuracy: 0.5131
# Epoch 31/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6928 - accuracy: 0.5143 - val_loss: 0.6930 - val_accuracy: 0.5131
# Epoch 32/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6929 - accuracy: 0.5125 - val_loss: 0.6930 - val_accuracy: 0.5131
# Epoch 33/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6929 - accuracy: 0.5135 - val_loss: 0.6931 - val_accuracy: 0.5131
# Epoch 34/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6928 - accuracy: 0.5149 - val_loss: 0.6928 - val_accuracy: 0.5131
# Epoch 35/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6929 - accuracy: 0.5131 - val_loss: 0.6929 - val_accuracy: 0.5131
# Epoch 36/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6929 - accuracy: 0.5149 - val_loss: 0.6929 - val_accuracy: 0.5131
# Epoch 37/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6927 - accuracy: 0.5160 - val_loss: 0.6928 - val_accuracy: 0.5131
# Epoch 38/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6927 - accuracy: 0.5159 - val_loss: 0.6929 - val_accuracy: 0.5131
# Epoch 39/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6929 - accuracy: 0.5142 - val_loss: 0.6928 - val_accuracy: 0.5131
# Epoch 40/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6930 - accuracy: 0.5103 - val_loss: 0.6928 - val_accuracy: 0.5131
# Epoch 41/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6928 - accuracy: 0.5117 - val_loss: 0.6928 - val_accuracy: 0.5131
# Epoch 42/50
# 2172/2172 [==============================] - 31s 14ms/step - loss: 0.6928 - accuracy: 0.5136 - val_loss: 0.6928 - val_accuracy: 0.5131
# Epoch 43/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6930 - accuracy: 0.5105 - val_loss: 0.6931 - val_accuracy: 0.5131
# Epoch 44/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6928 - accuracy: 0.5100 - val_loss: 0.6928 - val_accuracy: 0.5131
# Epoch 45/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6930 - accuracy: 0.5124 - val_loss: 0.6930 - val_accuracy: 0.5131
# Epoch 46/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6929 - accuracy: 0.5128 - val_loss: 0.6928 - val_accuracy: 0.5131
# Epoch 47/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6927 - accuracy: 0.5141 - val_loss: 0.6928 - val_accuracy: 0.5131
# Epoch 48/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6929 - accuracy: 0.5105 - val_loss: 0.6928 - val_accuracy: 0.5131
# Epoch 49/50
# 2172/2172 [==============================] - 29s 13ms/step - loss: 0.6931 - accuracy: 0.5103 - val_loss: 0.6928 - val_accuracy: 0.5131
# Epoch 50/50
# 2172/2172 [==============================] - 28s 13ms/step - loss: 0.6927 - accuracy: 0.5152 - val_loss: 0.6929 - val_accuracy: 0.5131
# Fold 5, 50 epochs, 1462 sec
# 2021-06-04 17:20:32 UTC
