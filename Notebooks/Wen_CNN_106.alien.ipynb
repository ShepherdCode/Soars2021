# %% [markdown]
# # Wen CNN
#
# First run on Alien.

# %%
import time
def show_time():
    t = time.time()
    print(time.strftime('%Y-%m-%d %H:%M:%S %Z', time.localtime(t)))
show_time()
# Out:
# 2021-08-12 05:42:34 EDT

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D
from keras.layers import Dense,Embedding,Dropout
from keras.layers import Flatten,TimeDistributed
from keras.losses import BinaryCrossentropy
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
# Out:
# 2021-08-12 05:42:34.952261: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %%
import sys
IN_COLAB = False
try:
    from google.colab import drive
    IN_COLAB = True
except:
    pass
if IN_COLAB:
    print("On Google CoLab, mount cloud-local file, get our code from GitHub.")
    PATH='/content/drive/'
    #drive.mount(PATH,force_remount=True)  # hardly ever need this
    drive.mount(PATH)    # Google will require login credentials
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/RNA_describe.py')
    with open('RNA_describe.py', 'w') as f:
        f.write(r.text)  
    from RNA_describe import ORF_counter
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/GenCodeTools.py')
    with open('GenCodeTools.py', 'w') as f:
        f.write(r.text)  
    from GenCodeTools import GenCodeLoader
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/KmerTools.py')
    with open('KmerTools.py', 'w') as f:
        f.write(r.text)  
    from KmerTools import KmerTools
else:
        print("CoLab not working. On my PC, use relative paths.")
        DATAPATH='data/'  # must end in "/"
        sys.path.append("..") # append parent dir in order to use sibling dirs
        from SimTools.RNA_describe import ORF_counter
        from SimTools.GenCodeTools import GenCodeLoader
        from SimTools.KmerTools import KmerTools
BESTMODELPATH=DATAPATH+"BestModel-Wen"  # saved on cloud instance and lost after logout
LASTMODELPATH=DATAPATH+"LastModel-Wen"  # saved on Google Drive but requires login
# Out:
# CoLab not working. On my PC, use relative paths.

# %% [markdown]
# ## Data Load

# %%
PC_TRAINS=8000
NC_TRAINS=8000
PC_TESTS=2000
NC_TESTS=2000   
PC_LENS=(200,4000)
NC_LENS=(200,4000)   # Wen used 3500 for hyperparameter, 3000 for train
PC_FILENAME='gencode.v38.pc_transcripts.fa.gz'
NC_FILENAME='gencode.v38.lncRNA_transcripts.fa.gz'
PC_FULLPATH=DATAPATH+PC_FILENAME
NC_FULLPATH=DATAPATH+NC_FILENAME
MAX_K = 3 
# With K={1,2,3}, num K-mers is 4^3 + 4^2 + 4^1 = 84.
# Wen specified 17x20 which is impossible.
# The factors of 84 are 1, 2, 3, 4, 6, 7, 12, 14, 21, 28, 42 and 84.
FRQ_CNT=84
ROWS=7
COLS=FRQ_CNT//ROWS
SHAPE2D = (ROWS,COLS,1)
EPOCHS=100 # 1000 # 200
SPLITS=5
FOLDS=5   # make this 5 for serious testing
show_time()
# Out:
# 2021-08-12 05:42:35 EDT

# %%
loader=GenCodeLoader()
loader.set_label(1)
loader.set_check_utr(True)
pcdf=loader.load_file(PC_FULLPATH)
print("PC seqs loaded:",len(pcdf))
loader.set_label(0)
loader.set_check_utr(False)
ncdf=loader.load_file(NC_FULLPATH)
print("NC seqs loaded:",len(ncdf))
show_time()
# Out:
# PC seqs loaded: 70825
# NC seqs loaded: 48752
# 2021-08-12 05:42:37 EDT

# %%
def dataframe_length_filter(df,low_high):
    (low,high)=low_high
    # The pandas query language is strange, 
    # but this is MUCH faster than loop & drop.
    return df[ (df['seqlen']>=low) & (df['seqlen']<=high) ]
def dataframe_extract_sequence(df):
    return df['sequence'].tolist()

pc_all = dataframe_extract_sequence(
    dataframe_length_filter(pcdf,PC_LENS))
nc_all = dataframe_extract_sequence(
    dataframe_length_filter(ncdf,NC_LENS))

show_time()
print("PC seqs pass filter:",len(pc_all))
print("NC seqs pass filter:",len(nc_all))
# Garbage collection to reduce RAM footprint
pcdf=None
ncdf=None
# Out:
# 2021-08-12 05:42:37 EDT
# PC seqs pass filter: 55381
# NC seqs pass filter: 46919

# %% [markdown]
# ## Data Prep

# %%
pc_train=pc_all[:PC_TRAINS] 
nc_train=nc_all[:NC_TRAINS]
print("PC train, NC train:",len(pc_train),len(nc_train))
pc_test=pc_all[PC_TRAINS:PC_TRAINS+PC_TESTS] 
nc_test=nc_all[NC_TRAINS:NC_TRAINS+PC_TESTS]
print("PC test, NC test:",len(pc_test),len(nc_test))
# Garbage collection
pc_all=None
nc_all=None
# Out:
# PC train, NC train: 8000 8000
# PC test, NC test: 2000 2000

# %%
def prepare_x_and_y(seqs1,seqs0):
    len1=len(seqs1)
    len0=len(seqs0)
    total=len1+len0
    L1=np.ones(len1,dtype=np.int8)
    L0=np.zeros(len0,dtype=np.int8)
    S1 = np.asarray(seqs1)
    S0 = np.asarray(seqs0)
    all_labels = np.concatenate((L1,L0))
    all_seqs = np.concatenate((S1,S0))  
    # interleave (uses less RAM than shuffle)
    for i in range(0,len0):
        all_labels[i*2] = L0[i]
        all_seqs[i*2] = S0[i]
        all_labels[i*2+1] = L1[i]
        all_seqs[i*2+1] = S1[i]
    return all_seqs,all_labels  # use this to test unshuffled
    X,y = shuffle(all_seqs,all_labels) # sklearn.utils.shuffle 
    return X,y
Xseq,y=prepare_x_and_y(pc_train,nc_train)
#print(Xseq[:3])
#print(y[:3])
show_time()
# Out:
# 2021-08-12 05:42:37 EDT

# %%
def seqs_to_kmer_freqs(seqs,max_K):
    tool = KmerTools()  # from SimTools
    collection = []
    for seq in seqs:
        counts = tool.make_dict_upto_K(max_K)
        # Last param should be True when using Harvester.
        counts = tool.update_count_one_K(counts,max_K,seq,True)
        # Given counts for K=3, Harvester fills in counts for K=1,2.
        counts = tool.harvest_counts_from_K(counts,max_K)
        fdict = tool.count_to_frequency(counts,max_K)
        freqs = list(fdict.values())
        collection.append(freqs)
    return np.asarray(collection)
Xfrq=seqs_to_kmer_freqs(Xseq,MAX_K)
# Garbage collection
Xseq = None
show_time()
# Out:
# 2021-08-12 05:42:42 EDT

# %%
def reshape(frequency_matrix):
    seq_cnt,frq_cnt=Xfrq.shape 
    # CNN inputs require a last dimension = numbers per pixel.
    # For RGB images it is 3.
    # For our frequency matrix it is 1.
    new_matrix = frequency_matrix.reshape(seq_cnt,ROWS,COLS,1)
    return new_matrix

print("Xfrq")
print("Xfrq type",type(Xfrq))
print("Xfrq shape",Xfrq.shape)
Xfrq2D = reshape(Xfrq)
print("Xfrq2D shape",Xfrq2D.shape)
# Out:
# Xfrq
# Xfrq type <class 'numpy.ndarray'>
# Xfrq shape (16000, 84)
# Xfrq2D shape (16000, 7, 12, 1)

# %% [markdown]
# ## Build and train a neural network

# %%
def make_DNN(shape):
    dt=np.float32
    print("make_DNN")
    print("input shape:",shape)
    WIDTH=(3,3)
    STRIDE=(1,1)
    dnn = Sequential()
    dnn.add(Conv2D(filters=32,kernel_size=WIDTH,strides=STRIDE,activation="relu",padding="same",
            input_shape=shape))
    dnn.add(Conv2D(filters=64,kernel_size=WIDTH,strides=STRIDE,activation="relu",padding="same"))
    dnn.add(MaxPooling2D())
    dnn.add(Flatten())
    dnn.add(Dropout(0.25))
    dnn.add(Dense(128,activation="sigmoid",dtype=dt)) 
    dnn.add(Dropout(0.50))
    dnn.add(Dense(1,activation="sigmoid",dtype=dt))   
    dnn.compile(optimizer='adam',    # adadelta doesn't work as well
                loss=BinaryCrossentropy(from_logits=False),
                metrics=['accuracy'])   # add to default metrics=loss
    dnn.build(input_shape=shape) 
    return dnn
model = make_DNN(SHAPE2D)
print(model.summary())
# Out:
# make_DNN
# input shape: (7, 12, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 7, 12, 32)         320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 7, 12, 64)         18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 3, 6, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1152)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1152)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               147584
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 166,529
# Trainable params: 166,529
# Non-trainable params: 0
# _________________________________________________________________
# None
# 2021-08-12 05:42:42.602803: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-08-12 05:42:42.653475: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-12 05:42:42.655549: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:02:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.75GiB deviceMemoryBandwidth: 573.69GiB/s
# 2021-08-12 05:42:42.655605: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-08-12 05:42:42.659686: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2021-08-12 05:42:42.659731: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2021-08-12 05:42:42.661524: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2021-08-12 05:42:42.661735: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2021-08-12 05:42:42.662142: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2021-08-12 05:42:42.662669: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2021-08-12 05:42:42.662794: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2021-08-12 05:42:42.662801: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2021-08-12 05:42:42.663205: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-08-12 05:42:42.664117: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-08-12 05:42:42.664124: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]

# %%
def do_cross_validation(X,y,shape):
    cv_scores = []
    fold=0
    mycallbacks = [ModelCheckpoint(
        filepath=BESTMODELPATH, save_best_only=True, 
        monitor='val_accuracy', mode='max')]   
    # When shuffle=True, the valid indices are a random subset.
    splitter = KFold(n_splits=SPLITS,shuffle=True) 
    model = None
    for train_index,valid_index in splitter.split(X):
        if fold < FOLDS:
            fold += 1
            X_train=X[train_index] # inputs for training
            y_train=y[train_index] # labels for training
            X_valid=X[valid_index] # inputs for validation
            y_valid=y[valid_index] # labels for validation
            print("MODEL")
            # Call constructor on each CV. Else, continually improves the same model.
            model = model = make_DNN(shape)
            print("FIT")  # model.fit() implements learning
            start_time=time.time()
            history=model.fit(X_train, y_train, 
                    epochs=EPOCHS, 
                    verbose=1,  # ascii art while learning
                    callbacks=mycallbacks,   # called at end of each epoch
                    validation_data=(X_valid,y_valid))
            end_time=time.time()
            elapsed_time=(end_time-start_time)                        
            print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
            # print(history.history.keys())  # all these keys will be shown in figure
            pd.DataFrame(history.history).plot(figsize=(8,5))
            plt.grid(True)
            plt.gca().set_ylim(0,1) # any losses > 1 will be off the scale
            plt.show()
    return model  # parameters at end of training

# %%
show_time()
last_model = do_cross_validation(Xfrq2D,y,SHAPE2D)
last_model.save(LASTMODELPATH)
# Out:
# 2021-08-12 05:42:42 EDT
# MODEL
# make_DNN
# input shape: (7, 12, 1)
# FIT
# Epoch 1/100
# 2021-08-12 05:42:42.873819: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021
100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.1936 - accuracy: 0.9230 - val_loss: 0.3158 - val_accuracy: 0.8872
# Epoch 96/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.1994 - accuracy: 0.9172 - val_loss: 0.3017 - val_accuracy: 0.8869
# Epoch 97/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.1919 - accuracy: 0.9219 - val_loss: 0.3055 - val_accuracy: 0.8866
# Epoch 98/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.1889 - accuracy: 0.9203 - val_loss: 0.3250 - val_accuracy: 0.8791
# Epoch 99/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.1855 - accuracy: 0.9272 - val_loss: 0.3044 - val_accuracy: 0.8838
# Epoch 100/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.1819 - accuracy: 0.9234 - val_loss: 0.2956 - val_accuracy: 0.8866
# Fold 1, 100 epochs, 173 sec
# MODEL
# make_DNN
# input shape: (7, 12, 1)
# FIT
# Epoch 1/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.7225 - accuracy: 0.5346 - val_loss: 0.6386 - val_accuracy: 0.6316
# Epoch 2/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.6291 - accuracy: 0.6494 - val_loss: 0.5844 - val_accuracy: 0.6787
# Epoch 3/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.5707 - accuracy: 0.7099 - val_loss: 0.5237 - val_accuracy: 0.7516
# Epoch 4/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.5190 - accuracy: 0.7465 - val_loss: 0.4937 - val_accuracy: 0.7653
# Epoch 5/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.4762 - accuracy: 0.7767 - val_loss: 0.4307 - val_accuracy: 0.8128
# Epoch 6/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.4417 - accuracy: 0.7983 - val_loss: 0.4133 - val_accuracy: 0.8150
# Epoch 7/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.4186 - accuracy: 0.8104 - val_loss: 0.3987 - val_accuracy: 0.8313
# Epoch 8/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.4124 - accuracy: 0.8133 - val_loss: 0.3822 - val_accuracy: 0.8375
# Epoch 9/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3908 - accuracy: 0.8296 - val_loss: 0.3900 - val_accuracy: 0.8303
# Epoch 10/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3848 - accuracy: 0.8306 - val_loss: 0.3730 - val_accuracy: 0.8378
# Epoch 11/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3730 - accuracy: 0.8362 - val_loss: 0.3626 - val_accuracy: 0.8397
# Epoch 12/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3704 - accuracy: 0.8364 - val_loss: 0.3772 - val_accuracy: 0.8363
# Epoch 13/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3709 - accuracy: 0.8407 - val_loss: 0.3579 - val_accuracy: 0.8453
# Epoch 14/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3652 - accuracy: 0.8410 - val_loss: 0.3515 - val_accuracy: 0.8525
# Epoch 15/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3605 - accuracy: 0.8430 - val_loss: 0.3472 - val_accuracy: 0.8531
# Epoch 16/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3500 - accuracy: 0.8477 - val_loss: 0.3441 - val_accuracy: 0.8519
# Epoch 17/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3502 - accuracy: 0.8434 - val_loss: 0.3504 - val_accuracy: 0.8512
# Epoch 18/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3383 - accuracy: 0.8542 - val_loss: 0.3410 - val_accuracy: 0.8562
# Epoch 19/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3404 - accuracy: 0.8514 - val_loss: 0.3347 - val_accuracy: 0.8572
# Epoch 20/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3387 - accuracy: 0.8512 - val_loss: 0.3424 - val_accuracy: 0.8522
# Epoch 21/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3308 - accuracy: 0.8602 - val_loss: 0.3296 - val_accuracy: 0.8634
# Epoch 22/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3234 - accuracy: 0.8643 - val_loss: 0.3276 - val_accuracy: 0.8619
# Epoch 23/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3297 - accuracy: 0.8555 - val_loss: 0.3285 - val_accuracy: 0.8625
# Epoch 24/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3242 - accuracy: 0.8571 - val_loss: 0.3229 - val_accuracy: 0.8619
# Epoch 25/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3322 - accuracy: 0.8544 - val_loss: 0.3324 - val_accuracy: 0.8584
# Epoch 26/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.
100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3370 - accuracy: 0.8589 - val_loss: 0.3338 - val_accuracy: 0.8569
# Epoch 20/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3448 - accuracy: 0.8536 - val_loss: 0.3127 - val_accuracy: 0.8666
# Epoch 21/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3436 - accuracy: 0.8557 - val_loss: 0.3111 - val_accuracy: 0.8675
# Epoch 22/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3388 - accuracy: 0.8518 - val_loss: 0.3172 - val_accuracy: 0.8631
# Epoch 23/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3306 - accuracy: 0.8536 - val_loss: 0.3209 - val_accuracy: 0.8587
# Epoch 24/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3248 - accuracy: 0.8574 - val_loss: 0.3057 - val_accuracy: 0.8716
# Epoch 25/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3239 - accuracy: 0.8601 - val_loss: 0.3036 - val_accuracy: 0.8722
# Epoch 26/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3240 - accuracy: 0.8600 - val_loss: 0.3080 - val_accuracy: 0.8709
# Epoch 27/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3338 - accuracy: 0.8577 - val_loss: 0.3334 - val_accuracy: 0.8509
# Epoch 28/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3291 - accuracy: 0.8557 - val_loss: 0.3018 - val_accuracy: 0.8681
# Epoch 29/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3142 - accuracy: 0.8649 - val_loss: 0.3026 - val_accuracy: 0.8706
# Epoch 30/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3131 - accuracy: 0.8679 - val_loss: 0.2993 - val_accuracy: 0.8756
# Epoch 31/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3173 - accuracy: 0.8631 - val_loss: 0.2991 - val_accuracy: 0.8703
# Epoch 32/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3055 - accuracy: 0.8712 - val_loss: 0.3040 - val_accuracy: 0.8700
# Epoch 33/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3108 - accuracy: 0.8647 - val_loss: 0.2980 - val_accuracy: 0.8712
# Epoch 34/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3151 - accuracy: 0.8647 - val_loss: 0.2942 - val_accuracy: 0.8737
# Epoch 35/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3094 - accuracy: 0.8626 - val_loss: 0.2987 - val_accuracy: 0.8750
# Epoch 36/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3045 - accuracy: 0.8681 - val_loss: 0.2941 - val_accuracy: 0.8706
# Epoch 37/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3097 - accuracy: 0.8676 - val_loss: 0.2935 - val_accuracy: 0.8750
# Epoch 38/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3090 - accuracy: 0.8650 - val_loss: 0.2908 - val_accuracy: 0.8741
# Epoch 39/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3028 - accuracy: 0.8687 - val_loss: 0.2988 - val_accuracy: 0.8725
# Epoch 40/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2925 - accuracy: 0.8742 - val_loss: 0.2993 - val_accuracy: 0.8716
# Epoch 41/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3011 - accuracy: 0.8745 - val_loss: 0.2844 - val_accuracy: 0.8788
# Epoch 42/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2968 - accuracy: 0.8660 - val_loss: 0.2868 - val_accuracy: 0.8775
# Epoch 43/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2851 - accuracy: 0.8823 - val_loss: 0.2966 - val_accuracy: 0.8769
# Epoch 44/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2911 - accuracy: 0.8754 - val_loss: 0.3137 - val_accuracy: 0.8675
# Epoch 45/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2889 - accuracy: 0.8727 - val_loss: 0.2931 - val_accuracy: 0.8788
# Epoch 46/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2895 - accuracy: 0.8763 - val_loss: 0.2787 - val_accuracy: 0.8809
# Epoch 47/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2844 - accuracy: 0.8786 - val_loss: 0.2804 - val_accuracy: 0.8803
# Epoch 48/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2880 - accuracy: 0.8838 - val_loss: 0.2862 - val_accuracy: 0.8788
# Epoch 49/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2825 - accuracy: 0.8800 - val_loss: 0.2761 - val_accuracy: 0.8822
# Epoch 50/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2851 - accuracy: 0.8809 - val_loss: 0.2830 - val_accuracy: 0.8775
# Epoch 51/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2724 - accuracy: 0.8850 - val_loss: 0.2846 - val_accuracy: 0.8769
# Epoch 52/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2760 - accuracy: 0.8838 - val_loss: 0.2792 - val_accuracy: 0.8803
# Epoch 53/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2819 - accuracy: 0.8804 - val_loss: 0.2810 - val_accuracy: 0.8800
# Epoch 54/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2623 - accuracy: 0.8903 - val_loss: 0.2775 - val_accuracy: 0.8797
# Epoch 55/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2686 - accuracy: 0.8860 - val_loss: 0.2792 - val_accuracy: 0.8838
# Epoch 56/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2717 - accuracy: 0.8861 - val_loss: 0.2745 - val_accuracy: 0.8838
# Epoch 57/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2847 - accuracy: 0.8749 - val_loss: 0.2775 - val_accuracy: 0.8813
# Epoch 58/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2722 - accuracy: 0.8864 - val_loss: 0.2777 - val_accuracy: 0.8838
# Epoch 59/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2769 - accuracy: 0.8830 - val_loss: 0.2744 - val_accuracy: 0.8816
# Epoch 60/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2779 - accuracy: 0.8837 - val_loss: 0.2792 - val_accuracy: 0.8809
# Epoch 61/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2715 - accuracy: 0.8881 - val_loss: 0.2771 - val_accuracy: 0.8850
# Epoch 62/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2528 - accuracy: 0.8951 - val_loss: 0.2702 - val_accuracy: 0.8853
# Epoch 63/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2683 - accuracy: 0.8854 - val_loss: 0.2711 - val_accuracy: 0.8816
# Epoch 64/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2662 - accuracy: 0.8893 - val_loss: 0.2748 - val_accuracy: 0.8841
# Epoch 65/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2512 - accuracy: 0.8944 - val_loss: 0.2653 - val_accuracy: 0.8859
# Epoch 66/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2536 - accuracy: 0.8895 - val_loss: 0.2751 - val_accuracy: 0.8841
# Epoch 67/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2575 - accuracy: 0.8943 - val_loss: 0.2677 - val_accuracy: 0.8859
# Epoch 68/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2468 - accuracy: 0.8993 - val_loss: 0.2713 - val_accuracy: 0.8856
# Epoch 69/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2482 - accuracy: 0.8948 - val_loss: 0.2675 - val_accuracy: 0.8866
# Epoch 70/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2497 - accuracy: 0.8966 - val_loss: 0.2685 - val_accuracy: 0.8872
# Epoch 71/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2529 - accuracy: 0.8965 - val_loss: 0.2725 - val_accuracy: 0.8863
# Epoch 72/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2371 - accuracy: 0.9005 - val_loss: 0.2678 - val_accuracy: 0.8881
# Epoch 73/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2522 - accuracy: 0.8932 - val_loss: 0.2692 - val_accuracy: 0.8853
# Epoch 74/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2530 - accuracy: 0.8966 - val_loss: 0.2632 - val_accuracy: 0.8919
# Epoch 75/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2426 - accuracy: 0.8963 - val_loss: 0.2649 - val_accuracy: 0.8938
# Epoch 76/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2401 - accuracy: 0.8964 - val_loss: 0.2663 - val_accuracy: 0.8928
# Epoch 77/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2332 - accuracy: 0.9057 - val_loss: 0.2861 - val_accuracy: 0.8803
# Epoch 78/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2405 - accuracy: 0.8989 - val_loss: 0.2654 - val_accuracy: 0.8909
# Epoch 79/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2389 - accuracy: 0.9018 - val_loss: 0.2600 - val_accuracy: 0.8916
# Epoch 80/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2334 - accuracy: 0.9030 - val_loss: 0.2682 - val_accuracy: 0.8900
# Epoch 81/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2402 - accuracy: 0.9003 - val_loss: 0.2650 - val_accuracy: 0.8913
# Epoch 82/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2339 - accuracy: 0.8972 - val_loss: 0.2721 - val_accuracy: 0.8906
# Epoch 83/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2285 - accuracy: 0.9037 - val_loss: 0.2639 - val_accuracy: 0.8934
# Epoch 84/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2291 - accuracy: 0.9053 - val_loss: 0.2655 - val_accuracy: 0.8944
# Epoch 85/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2250 - accuracy: 0.9096 - val_loss: 0.2803 - val_accuracy: 0.8816
# Epoch 86/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2225 - accuracy: 0.9073 - val_loss: 0.2586 - val_accuracy: 0.8966
# Epoch 87/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2154 - accuracy: 0.9090 - val_loss: 0.2588 - val_accuracy: 0.8963
# Epoch 88/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2178 - accuracy: 0.9103 - val_loss: 0.2604 - val_accuracy: 0.8925
# Epoch 89/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2222 - accuracy: 0.9093 - val_loss: 0.2563 - val_accuracy: 0.8975
# Epoch 90/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2147 - accuracy: 0.9086 - val_loss: 0.2525 - val_accuracy: 0.8994
# INFO:tensorflow:Assets written to: data/BestModel-Wen/assets
# Epoch 91/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2059 - accuracy: 0.9155 - val_loss: 0.2556 - val_accuracy: 0.8950
# Epoch 92/100
# 400/400 [==============================] - ETA: 0s - loss: 0.2118 - accuracy: 0.91 - 2s 4ms/step - loss: 0.2118 - accuracy: 0.9129 - val_loss: 0.2633 - val_accuracy: 0.8938
# Epoch 93/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2097 - accuracy: 0.9128 - val_loss: 0.2567 - val_accuracy: 0.8966
# Epoch 94/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2096 - accuracy: 0.9114 - val_loss: 0.2492 - val_accuracy: 0.9003
# INFO:tensorflow:Assets written to: data/BestModel-Wen/assets
# Epoch 95/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2129 - accuracy: 0.9084 - val_loss: 0.2542 - val_accuracy: 0.8969
# Epoch 96/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2106 - accuracy: 0.9138 - val_loss: 0.2595 - val_accuracy: 0.8991
# Epoch 97/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2139 - accuracy: 0.9133 - val_loss: 0.2732 - val_accuracy: 0.8869
# Epoch 98/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2032 - accuracy: 0.9136 - val_loss: 0.2543 - val_accuracy: 0.9028
# INFO:tensorflow:Assets written to: data/BestModel-Wen/assets
# Epoch 99/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2021 - accuracy: 0.9162 - val_loss: 0.2567 - val_accuracy: 0.9006
# Epoch 100/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2058 - accuracy: 0.9141 - val_loss: 0.2523 - val_accuracy: 0.8928
# Fold 3, 100 epochs, 156 sec
# MODEL
# make_DNN
# input shape: (7, 12, 1)
# FIT
# Epoch 1/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.7247 - accuracy: 0.5263 - val_loss: 0.6240 - val_accuracy: 0.6516
# Epoch 2/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.6199 - accuracy: 0.6567 - val_loss: 0.5789 - val_accuracy: 0.7103
# Epoch 3/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.5679 - accuracy: 0.7191 - val_loss: 0.5290 - val_accuracy: 0.7569
# Epoch 4/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.5321 - accuracy: 0.7388 - val_loss: 0.5082 - val_accuracy: 0.7419
# Epoch 5/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.4738 - accuracy: 0.7771 - val_loss: 0.4162 - val_accuracy: 0.8247
# Epoch 6/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.4391 - accuracy: 0.8012 - val_loss: 0.3922 - val_accuracy: 0.8331
# Epoch 7/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.4201 - accuracy: 0.8132 - val_loss: 0.3924 - val_accuracy: 0.8225
# Epoch 8/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.4011 - accuracy: 0.8176 - val_loss: 0.3926 - val_accuracy: 0.8119
# Epoch 9/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3900 - accuracy: 0.8271 - val_loss: 0.3624 - val_accuracy: 0.8478
# Epoch 10/100
# ...
# Epoch 93/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2121 - accuracy: 0.9114 - val_loss: 0.2705 - val_accuracy: 0.8963
# Epoch 94/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.1987 - accuracy: 0.9192 - val_loss: 0.2736 - val_accuracy: 0.8925
# Epoch 95/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2100 - accuracy: 0.9146 - val_loss: 0.2769 - val_accuracy: 0.8891
# Epoch 96/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2086 - accuracy: 0.9144 - val_loss: 0.2788 - val_accuracy: 0.8934
# Epoch 97/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2007 - accuracy: 0.9145 - val_loss: 0.2741 - val_accuracy: 0.8925
# Epoch 98/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.1988 - accuracy: 0.9174 - val_loss: 0.2783 - val_accuracy: 0.8878
# Epoch 99/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2021 - accuracy: 0.9161 - val_loss: 0.2781 - val_accuracy: 0.8928
# Epoch 100/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2038 - accuracy: 0.9160 - val_loss: 0.2690 - val_accuracy: 0.8938
# Fold 4, 100 epochs, 157 sec
# MODEL
# make_DNN
# input shape: (7, 12, 1)
# FIT
# Epoch 1/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.7150 - accuracy: 0.5387 - val_loss: 0.6158 - val_accuracy: 0.6528
# Epoch 2/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.6147 - accuracy: 0.6660 - val_loss: 0.5603 - val_accuracy: 0.7309
# Epoch 3/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.5721 - accuracy: 0.7157 - val_loss: 0.5161 - val_accuracy: 0.7550
# Epoch 4/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.5235 - accuracy: 0.7411 - val_loss: 0.4553 - val_accuracy: 0.7906
# Epoch 5/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.4894 - accuracy: 0.7670 - val_loss: 0.4196 - val_accuracy: 0.8259
# Epoch 6/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.4475 - accuracy: 0.7946 - val_loss: 0.3986 - val_accuracy: 0.8253
# Epoch 7/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.4390 - accuracy: 0.7980 - val_loss: 0.3685 - val_accuracy: 0.8556
# Epoch 8/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.4114 - accuracy: 0.8111 - val_loss: 0.3527 - val_accuracy: 0.8569
# Epoch 9/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.4012 - accuracy: 0.8255 - val_loss: 0.3423 - val_accuracy: 0.8581
# Epoch 10/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3904 - accuracy: 0.8232 - val_loss: 0.3348 - val_accuracy: 0.8634
# Epoch 11/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3838 - accuracy: 0.8320 - val_loss: 0.3346 - val_accuracy: 0.8569
# Epoch 12/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3668 - accuracy: 0.8387 - val_loss: 0.3267 - val_accuracy: 0.8725
# Epoch 13/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3659 - accuracy: 0.8376 - val_loss: 0.3232 - val_accuracy: 0.8653
# Epoch 14/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3676 - accuracy: 0.8397 - val_loss: 0.3207 - val_accuracy: 0.8700
# Epoch 15/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3593 - accuracy: 0.8406 - val_loss: 0.3092 - val_accuracy: 0.8775
# Epoch 16/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3510 - accuracy: 0.8463 - val_loss: 0.3146 - val_accuracy: 0.8687
# Epoch 17/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3445 - accuracy: 0.8506 - val_loss: 0.3189 - val_accuracy: 0.8725
# Epoch 18/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3396 - accuracy: 0.8555 - val_loss: 0.3050 - val_accuracy: 0.8741
# Epoch 19/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3514 - accuracy: 0.8452 - val_loss: 0.3034 - val_accuracy: 0.8741
# Epoch 20/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3258 - accuracy: 0.8587 - val_loss: 0.3057 - val_accuracy: 0.8791
# Epoch 21/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3334 - accuracy: 0.8520 - val_loss: 0.3004 - val_accuracy: 0.8788
# Epoch 22/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3360 - accuracy: 0.8512 - val_loss: 0.2992 - val_accuracy: 0.8794
# Epoch 23/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3406 - accuracy: 0.8552 - val_loss: 0.2922 - val_accuracy: 0.8769
# Epoch 24/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3264 - accuracy: 0.8588 - val_loss: 0.3148 - val_accuracy: 0.8687
# Epoch 25/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3182 - accuracy: 0.8624 - val_loss: 0.2867 - val_accuracy: 0.8819
# Epoch 26/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3235 - accuracy: 0.8550 - val_loss: 0.2933 - val_accuracy: 0.8766
# Epoch 27/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3309 - accuracy: 0.8578 - val_loss: 0.2815 - val_accuracy: 0.8838
# Epoch 28/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3193 - accuracy: 0.8650 - val_loss: 0.2800 - val_accuracy: 0.8847
# Epoch 29/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3141 - accuracy: 0.8639 - val_loss: 0.2831 - val_accuracy: 0.8816
# Epoch 30/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3125 - accuracy: 0.8607 - val_loss: 0.2875 - val_accuracy: 0.8778
# Epoch 31/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3120 - accuracy: 0.8649 - val_loss: 0.2800 - val_accuracy: 0.8834
# Epoch 32/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3139 - accuracy: 0.8649 - val_loss: 0.2802 - val_accuracy: 0.8850
# Epoch 33/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3039 - accuracy: 0.8653 - val_loss: 0.2823 - val_accuracy: 0.8819
# Epoch 34/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3017 - accuracy: 0.8734 - val_loss: 0.2829 - val_accuracy: 0.8847
# Epoch 35/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3052 - accuracy: 0.8681 - val_loss: 0.2789 - val_accuracy: 0.8859
# Epoch 36/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2912 - accuracy: 0.8777 - val_loss: 0.2730 - val_accuracy: 0.8875
# Epoch 37/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2968 - accuracy: 0.8753 - val_loss: 0.2984 - val_accuracy: 0.8737
# Epoch 38/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2939 - accuracy: 0.8727 - val_loss: 0.2738 - val_accuracy: 0.8847
# Epoch 39/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2980 - accuracy: 0.8684 - val_loss: 0.2853 - val_accuracy: 0.8781
# Epoch 40/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.3032 - accuracy: 0.8683 - val_loss: 0.2762 - val_accuracy: 0.8847
# Epoch 41/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2796 - accuracy: 0.8823 - val_loss: 0.2692 - val_accuracy: 0.8909
# Epoch 42/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2908 - accuracy: 0.8749 - val_loss: 0.2757 - val_accuracy: 0.8816
# Epoch 43/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2932 - accuracy: 0.8722 - val_loss: 0.2734 - val_accuracy: 0.8834
# Epoch 44/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2762 - accuracy: 0.8790 - val_loss: 0.2681 - val_accuracy: 0.8897
# Epoch 45/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2981 - accuracy: 0.8700 - val_loss: 0.2644 - val_accuracy: 0.8906
# Epoch 46/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2873 - accuracy: 0.8748 - val_loss: 0.2894 - val_accuracy: 0.8753
# Epoch 47/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2795 - accuracy: 0.8772 - val_loss: 0.2670 - val_accuracy: 0.8891
# Epoch 48/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2873 - accuracy: 0.8748 - val_loss: 0.2595 - val_accuracy: 0.8919
# Epoch 49/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2720 - accuracy: 0.8857 - val_loss: 0.2650 - val_accuracy: 0.8925
# Epoch 50/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2721 - accuracy: 0.8850 - val_loss: 0.2658 - val_accuracy: 0.8863
# Epoch 51/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2680 - accuracy: 0.8854 - val_loss: 0.2604 - val_accuracy: 0.8916
# Epoch 52/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2720 - accuracy: 0.8837 - val_loss: 0.2640 - val_accuracy: 0.8878
# Epoch 53/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2694 - accuracy: 0.8868 - val_loss: 0.2596 - val_accuracy: 0.8931
# Epoch 54/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2693 - accuracy: 0.8906 - val_loss: 0.2627 - val_accuracy: 0.8878
# Epoch 55/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2747 - accuracy: 0.8816 - val_loss: 0.2616 - val_accuracy: 0.8906
# Epoch 56/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2654 - accuracy: 0.8863 - val_loss: 0.2673 - val_accuracy: 0.8878
# Epoch 57/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2607 - accuracy: 0.8883 - val_loss: 0.2623 - val_accuracy: 0.8891
# Epoch 58/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2537 - accuracy: 0.8957 - val_loss: 0.2612 - val_accuracy: 0.8956
# Epoch 59/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2540 - accuracy: 0.8954 - val_loss: 0.2598 - val_accuracy: 0.8925
# Epoch 60/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2611 - accuracy: 0.8878 - val_loss: 0.2568 - val_accuracy: 0.8938
# Epoch 61/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2616 - accuracy: 0.8863 - val_loss: 0.2608 - val_accuracy: 0.8875
# Epoch 62/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2553 - accuracy: 0.8948 - val_loss: 0.2589 - val_accuracy: 0.8922
# Epoch 63/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2488 - accuracy: 0.8956 - val_loss: 0.2588 - val_accuracy: 0.8928
# Epoch 64/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2564 - accuracy: 0.8901 - val_loss: 0.2529 - val_accuracy: 0.8950
# Epoch 65/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2509 - accuracy: 0.8972 - val_loss: 0.2599 - val_accuracy: 0.8919
# Epoch 66/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2448 - accuracy: 0.8957 - val_loss: 0.2579 - val_accuracy: 0.8944
# Epoch 67/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2443 - accuracy: 0.8979 - val_loss: 0.2639 - val_accuracy: 0.8928
# Epoch 68/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2393 - accuracy: 0.8987 - val_loss: 0.2524 - val_accuracy: 0.8966
# Epoch 69/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2415 - accuracy: 0.8978 - val_loss: 0.2512 - val_accuracy: 0.8972
# Epoch 70/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2388 - accuracy: 0.8980 - val_loss: 0.2485 - val_accuracy: 0.8953
# Epoch 71/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2384 - accuracy: 0.9013 - val_loss: 0.2490 - val_accuracy: 0.8969
# Epoch 72/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2329 - accuracy: 0.9022 - val_loss: 0.2534 - val_accuracy: 0.9013
# Epoch 73/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2309 - accuracy: 0.8978 - val_loss: 0.2503 - val_accuracy: 0.8991
# Epoch 74/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2325 - accuracy: 0.9030 - val_loss: 0.2474 - val_accuracy: 0.8966
# Epoch 75/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2330 - accuracy: 0.9007 - val_loss: 0.2521 - val_accuracy: 0.8984
# Epoch 76/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2299 - accuracy: 0.9036 - val_loss: 0.2543 - val_accuracy: 0.9003
# Epoch 77/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2255 - accuracy: 0.9046 - val_loss: 0.2490 - val_accuracy: 0.8972
# Epoch 78/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2200 - accuracy: 0.9058 - val_loss: 0.2482 - val_accuracy: 0.9000
# Epoch 79/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2224 - accuracy: 0.9060 - val_loss: 0.2495 - val_accuracy: 0.8981
# Epoch 80/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2169 - accuracy: 0.9114 - val_loss: 0.2482 - val_accuracy: 0.9000
# Epoch 81/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2198 - accuracy: 0.9054 - val_loss: 0.2575 - val_accuracy: 0.8944
# Epoch 82/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2091 - accuracy: 0.9111 - val_loss: 0.2518 - val_accuracy: 0.8963
# Epoch 83/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2137 - accuracy: 0.9092 - val_loss: 0.2465 - val_accuracy: 0.9013
# Epoch 84/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2116 - accuracy: 0.9131 - val_loss: 0.2582 - val_accuracy: 0.9003
# Epoch 85/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2132 - accuracy: 0.9096 - val_loss: 0.2485 - val_accuracy: 0.9025
# Epoch 86/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2036 - accuracy: 0.9134 - val_loss: 0.2457 - val_accuracy: 0.9025
# Epoch 87/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2063 - accuracy: 0.9162 - val_loss: 0.2485 - val_accuracy: 0.9034
# INFO:tensorflow:Assets written to: data/BestModel-Wen/assets
# Epoch 88/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2142 - accuracy: 0.9115 - val_loss: 0.2430 - val_accuracy: 0.9066
# INFO:tensorflow:Assets written to: data/BestModel-Wen/assets
# Epoch 89/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2029 - accuracy: 0.9139 - val_loss: 0.2453 - val_accuracy: 0.8997
# Epoch 90/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.1982 - accuracy: 0.9201 - val_loss: 0.2501 - val_accuracy: 0.9000
# Epoch 91/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.1906 - accuracy: 0.9198 - val_loss: 0.2506 - val_accuracy: 0.9031
# Epoch 92/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.1921 - accuracy: 0.9222 - val_loss: 0.2476 - val_accuracy: 0.9072
# INFO:tensorflow:Assets written to: data/BestModel-Wen/assets
# Epoch 93/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.1882 - accuracy: 0.9230 - val_loss: 0.2581 - val_accuracy: 0.8953
# Epoch 94/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2004 - accuracy: 0.9159 - val_loss: 0.2476 - val_accuracy: 0.9000
# Epoch 95/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.1895 - accuracy: 0.9214 - val_loss: 0.2531 - val_accuracy: 0.9041
# Epoch 96/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.1939 - accuracy: 0.9210 - val_loss: 0.2483 - val_accuracy: 0.9066
# Epoch 97/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.1864 - accuracy: 0.9217 - val_loss: 0.2440 - val_accuracy: 0.9038
# Epoch 98/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.1913 - accuracy: 0.9168 - val_loss: 0.2496 - val_accuracy: 0.9059
# Epoch 99/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.1879 - accuracy: 0.9205 - val_loss: 0.2544 - val_accuracy: 0.9069
# Epoch 100/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.1774 - accuracy: 0.9278 - val_loss: 0.2411 - val_accuracy: 0.9078
# INFO:tensorflow:Assets written to: data/BestModel-Wen/assets
# Fold 5, 100 epochs, 160 sec
# INFO:tensorflow:Assets written to: data/LastModel-Wen/assets

# %% [markdown]
# ## Test the neural network

# %%
def show_test_AUC(model,X,y):
    ns_probs = [0 for _ in range(len(y))]
    bm_probs = model.predict(X)
    ns_auc = roc_auc_score(y, ns_probs)
    bm_auc = roc_auc_score(y, bm_probs)
    ns_fpr, ns_tpr, _ = roc_curve(y, ns_probs)
    bm_fpr, bm_tpr, _ = roc_curve(y, bm_probs)
    plt.plot(ns_fpr, ns_tpr, linestyle='--', label='Guess, auc=%.4f'%ns_auc)
    plt.plot(bm_fpr, bm_tpr, marker='.', label='Model, auc=%.4f'%bm_auc)
    plt.title('ROC')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()
    plt.show()
    print("%s: %.2f%%" %('AUC',bm_auc*100.0))
def show_test_accuracy(model,X,y):
    scores = model.evaluate(X, y, verbose=0)
    print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))

# %%
print("Accuracy on test data.")
print("Prepare...")
show_time()
Xseq,y=prepare_x_and_y(pc_test,nc_test)
print("Extract K-mer features...")
show_time()
Xfrq=seqs_to_kmer_freqs(Xseq,MAX_K)
Xfrq2D = reshape(Xfrq)
print("Plot...")
show_time()
show_test_AUC(last_model,Xfrq2D,y)
show_test_accuracy(last_model,Xfrq2D,y)
show_time()
# Out:
# Accuracy on test data.
# Prepare...
# 2021-08-12 05:56:11 EDT
# Extract K-mer features...
# 2021-08-12 05:56:11 EDT
# Plot...
# 2021-08-12 05:56:12 EDT
# AUC: 93.77%
# accuracy: 87.12%
# 2021-08-12 05:56:12 EDT
