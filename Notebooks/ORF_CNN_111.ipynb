# %% [markdown]
# # ORF recognition by CNN
#
# Use CNN with 2 Conv1D layers. Use START + random sequence + STOP. Partition the random sequences by whether they do or do not contain a long ORF. For the short RNA used here, the non-coding examples are rarer in that they do contain a STOP near the middle. Can the CNN spot the difference? Yes.

# %%
import time 
t = time.time()
time.strftime('%Y-%m-%d %H:%M:%S %Z', time.localtime(t))
# Out:
# '2021-06-11 12:02:49 EDT'

# %%
PC_SEQUENCES=2000   # how many protein-coding sequences
NC_SEQUENCES=2000   # how many non-coding sequences
PC_TESTS=1000
NC_TESTS=1000
RNA_LEN=24            # how long is each sequence
CDS_LEN=18            # include bases in start, residues, stop
ALPHABET=4          # how many different letters are possible
INPUT_SHAPE_2D = (RNA_LEN,ALPHABET,1) # Conv2D needs 3D inputs
INPUT_SHAPE = (RNA_LEN,ALPHABET) # Conv1D needs 2D inputs
FILTERS = 16   # how many different patterns the model looks for
NEURONS = 16
DROP_RATE = 0.2
WIDTH = 3   # how wide each pattern is, in bases
STRIDE_2D = (1,1)  # For Conv2D how far in each direction
STRIDE = 1 # For Conv1D, how far between pattern matches, in bases
EPOCHS=25  # how many times to train on all the data
SPLITS=5  # SPLITS=3 means train on 2/3 and validate on 1/3 
FOLDS=5  # train the model this many times (range 1 to SPLITS)

# %%
import sys
try:
    from google.colab import drive
    IN_COLAB = True
    print("On Google CoLab, mount cloud-local file, get our code from GitHub.")
    PATH='/content/drive/'
    #drive.mount(PATH,force_remount=True)  # hardly ever need this
    #drive.mount(PATH)    # Google will require login credentials
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/RNA_gen.py')
    with open('RNA_gen.py', 'w') as f:
        f.write(r.text)  
    from RNA_gen import *
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/RNA_describe.py')
    with open('RNA_describe.py', 'w') as f:
        f.write(r.text)  
    from RNA_describe import ORF_counter
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/RNA_prep.py')
    with open('RNA_prep.py', 'w') as f:
        f.write(r.text)  
    from RNA_prep import *
except:
    print("CoLab not working. On my PC, use relative paths.")
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"
    sys.path.append("..") # append parent dir in order to use sibling dirs
    from SimTools.RNA_gen import *
    from SimTools.RNA_describe import ORF_counter
    from SimTools.RNA_prep import *

MODELPATH="BestModel"  # saved on cloud instance and lost after logout
#MODELPATH=DATAPATH+MODELPATH  # saved on Google Drive but requires login

if not assert_imported_RNA_gen():
    print("ERROR: Cannot use RNA_gen.")
if not assert_imported_RNA_prep():
    print("ERROR: Cannot use RNA_prep.")
# Out:
# CoLab not working. On my PC, use relative paths.

# %%
from os import listdir
import csv
from zipfile import ZipFile

import numpy as np
import pandas as pd
from scipy import stats  # mode

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

from keras.models import Sequential
from keras.layers import Dense,Embedding,Dropout
from keras.layers import Conv1D,Conv2D
from keras.layers import Flatten,MaxPooling1D,MaxPooling2D
from keras.losses import BinaryCrossentropy
# tf.keras.losses.BinaryCrossentropy

import matplotlib.pyplot as plt
from matplotlib import colors
mycmap = colors.ListedColormap(['red','blue'])  # list color for label 0 then 1
np.set_printoptions(precision=2)

# %%
import random
def partition_random_sequences(goal_per_class):
    between_bases = CDS_LEN - 6
    utr5_bases = (RNA_LEN - CDS_LEN) // 2
    utr3_bases = RNA_LEN - utr5_bases - CDS_LEN
    pc_seqs=[]
    nc_seqs=[]
    oc = ORF_counter()
    trials = 0
    pc_cnt = 0
    nc_cnt = 0
    bases=['A','C','G','T']
    while pc_cnt<goal_per_class or nc_cnt<goal_per_class:
        trials += 1
        one_seq  = "".join(random.choices(bases,k=utr5_bases)) 
        one_seq += 'ATG'                               
        one_seq += "".join(random.choices(bases,k=between_bases)) 
        one_seq += random.choice(['TAA','TAG','TGA'])  
        one_seq += "".join(random.choices(bases,k=utr3_bases))  
        oc.set_sequence(one_seq)
        cds_len = oc.get_max_cds_len() + 3
        if cds_len >= CDS_LEN and pc_cnt<goal_per_class:
            pc_cnt += 1
            pc_seqs.append(one_seq)
        elif cds_len < CDS_LEN and nc_cnt<goal_per_class:
            nc_cnt += 1
            nc_seqs.append(one_seq)
    print ("It took %d trials to reach %d per class."%(trials,goal_per_class))
    return pc_seqs,nc_seqs
pc_all,nc_all=partition_random_sequences(10)  # just testing
pc_all,nc_all=partition_random_sequences(PC_SEQUENCES+PC_TESTS)
print("Use",len(pc_all),"PC seqs")
print("Use",len(nc_all),"NC seqs")
# Out:
# It took 100 trials to reach 10 per class.
# It took 22701 trials to reach 3000 per class.
# Use 3000 PC seqs
# Use 3000 NC seqs

# %%
# Describe the sequences
def describe_sequences(list_of_seq):
    oc = ORF_counter()
    num_seq = len(list_of_seq)
    rna_lens = np.zeros(num_seq)
    orf_lens = np.zeros(num_seq)
    for i in range(0,num_seq):
        rna_len = len(list_of_seq[i])
        rna_lens[i] = rna_len
        oc.set_sequence(list_of_seq[i])
        orf_len = oc.get_max_orf_len()
        orf_lens[i] = orf_len
    print ("Average RNA length:",rna_lens.mean())
    print ("Average ORF length:",orf_lens.mean())
    
print("Simulated sequences prior to adjustment:")
print("PC seqs")
describe_sequences(pc_all)
print("NC seqs")
describe_sequences(nc_all)
# Out:
# Simulated sequences prior to adjustment:
# PC seqs
# Average RNA length: 24.0
# Average ORF length: 14.905
# NC seqs
# Average RNA length: 24.0
# Average ORF length: 5.884

# %%
pc_train=pc_all[:PC_SEQUENCES]
nc_train=nc_all[:NC_SEQUENCES]
pc_test=pc_all[PC_SEQUENCES:]
nc_test=nc_all[NC_SEQUENCES:]

# %%
# Use code from our SimTools library.
X,y = prepare_inputs_len_x_alphabet(pc_train,nc_train,ALPHABET) # shuffles
print("Data ready.")
# Out:
# Data ready.

# %%
def make_DNN():
    print("make_DNN")
    print("input shape:",INPUT_SHAPE)
    dnn = Sequential()
    #dnn.add(Embedding(input_dim=INPUT_SHAPE,output_dim=INPUT_SHAPE)) 
    dnn.add(Conv1D(filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,padding="same",
            input_shape=INPUT_SHAPE))
    dnn.add(Conv1D(filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,padding="same"))
    dnn.add(MaxPooling1D())
    #dnn.add(Conv1D(filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,padding="same"))
    #dnn.add(Conv1D(filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,padding="same"))
    #dnn.add(MaxPooling1D())
    dnn.add(Flatten())
    dnn.add(Dense(NEURONS,activation="sigmoid",dtype=np.float32))   
    dnn.add(Dropout(DROP_RATE))
    dnn.add(Dense(1,activation="sigmoid",dtype=np.float32))   
    dnn.compile(optimizer='adam',
                loss=BinaryCrossentropy(from_logits=False),
                metrics=['accuracy'])   # add to default metrics=loss
    dnn.build(input_shape=INPUT_SHAPE)
    #ln_rate = tf.keras.optimizers.Adam(learning_rate = LN_RATE)
    #bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    #model.compile(loss=bc, optimizer=ln_rate, metrics=["accuracy"])
    return dnn
model = make_DNN()
print(model.summary())
# Out:
# make_DNN
# input shape: (24, 4)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 24, 16)            208
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 24, 16)            784
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 12, 16)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 192)               0
# _________________________________________________________________
# dense (Dense)                (None, 16)                3088
# _________________________________________________________________
# dropout (Dropout)            (None, 16)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 4,097
# Trainable params: 4,097
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from keras.callbacks import ModelCheckpoint
def do_cross_validation(X,y):
    cv_scores = []
    fold=0
    mycallbacks = [ModelCheckpoint(
        filepath=MODELPATH, save_best_only=True, 
        monitor='val_accuracy', mode='max')]   
    splitter = KFold(n_splits=SPLITS)  # this does not shuffle
    for train_index,valid_index in splitter.split(X):
        if fold < FOLDS:
            fold += 1
            X_train=X[train_index] # inputs for training
            y_train=y[train_index] # labels for training
            X_valid=X[valid_index] # inputs for validation
            y_valid=y[valid_index] # labels for validation
            print("MODEL")
            # Call constructor on each CV. Else, continually improves the same model.
            model = model = make_DNN()
            print("FIT")  # model.fit() implements learning
            start_time=time.time()
            history=model.fit(X_train, y_train, 
                    epochs=EPOCHS, 
                    verbose=1,  # ascii art while learning
                    callbacks=mycallbacks,   # called at end of each epoch
                    validation_data=(X_valid,y_valid))
            end_time=time.time()
            elapsed_time=(end_time-start_time)                        
            print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
            # print(history.history.keys())  # all these keys will be shown in figure
            pd.DataFrame(history.history).plot(figsize=(8,5))
            plt.grid(True)
            plt.gca().set_ylim(0,1) # any losses > 1 will be off the scale
            plt.show()

# %%
do_cross_validation(X,y)
# Out:
# MODEL
# make_DNN
# input shape: (24, 4)
# FIT
# Epoch 1/25
# 100/100 [==============================] - 2s 13ms/step - loss: 0.6886 - accuracy: 0.5607 - val_loss: 0.6209 - val_accuracy: 0.6700
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 2/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.5939 - accuracy: 0.7061 - val_loss: 0.4650 - val_accuracy: 0.8138
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 3/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.4476 - accuracy: 0.8074 - val_loss: 0.3728 - val_accuracy: 0.8413
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 4/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3656 - accuracy: 0.8516 - val_loss: 0.3261 - val_accuracy: 0.8637
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 5/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3163 - accuracy: 0.8726 - val_loss: 0.2869 - val_accuracy: 0.8875
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 6/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2771 - accuracy: 0.8979 - val_loss: 0.2554 - val_accuracy: 0.9075
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 7/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2319 - accuracy: 0.9229 - val_loss: 0.2281 - val_accuracy: 0.9200
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 8/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2258 - accuracy: 0.9258 - val_loss: 0.1972 - val_accuracy: 0.9337
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 9/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.1933 - accuracy: 0.9395 - val_loss: 0.1857 - val_accuracy: 0.9300
# Epoch 10/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.1754 - accuracy: 0.9472 - val_loss: 0.1734 - val_accuracy: 0.9312
# Epoch 11/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.1712 - accuracy: 0.9477 - val_loss: 0.1536 - val_accuracy: 0.9438
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 12/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.1464 - accuracy: 0.9569 - val_loss: 0.1454 - val_accuracy: 0.9463
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 13/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.1412 - accuracy: 0.9558 - val_loss: 0.1394 - val_accuracy: 0.9500
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 14/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.1377 - accuracy: 0.9571 - val_loss: 0.1291 - val_accuracy: 0.9513
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 15/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.1235 - accuracy: 0.9678 - val_loss: 0.1210 - val_accuracy: 0.9563
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 16/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.1048 - accuracy: 0.9734 - val_loss: 0.1167 - val_accuracy: 0.9625
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 17/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.
25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0721 - accuracy: 0.9813 - val_loss: 0.0805 - val_accuracy: 0.9725
# Epoch 24/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0674 - accuracy: 0.9823 - val_loss: 0.0804 - val_accuracy: 0.9737
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 25/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0656 - accuracy: 0.9823 - val_loss: 0.0792 - val_accuracy: 0.9700
# Fold 2, 25 epochs, 14 sec
# MODEL
# make_DNN
# input shape: (24, 4)
# FIT
# Epoch 1/25
# 100/100 [==============================] - 2s 8ms/step - loss: 0.6978 - accuracy: 0.5275 - val_loss: 0.5879 - val_accuracy: 0.7937
# Epoch 2/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.5538 - accuracy: 0.7541 - val_loss: 0.4254 - val_accuracy: 0.8475
# Epoch 3/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.4268 - accuracy: 0.8248 - val_loss: 0.3628 - val_accuracy: 0.8675
# Epoch 4/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3607 - accuracy: 0.8543 - val_loss: 0.3322 - val_accuracy: 0.8625
# Epoch 5/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.3081 - accuracy: 0.8901 - val_loss: 0.2880 - val_accuracy: 0.9013
# Epoch 6/25
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2858 - accuracy: 0.8927 - val_loss: 0.2522 - val_accuracy: 0.9225
# Epoch 7/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2440 - accuracy: 0.9207 - val_loss: 0.2280 - val_accuracy: 0.9250
# Epoch 8/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.2191 - accuracy: 0.9262 - val_loss: 0.2095 - val_accuracy: 0.9250
# Epoch 9/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.1964 - accuracy: 0.9418 - val_loss: 0.1833 - val_accuracy: 0.9438
# Epoch 10/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1729 - accuracy: 0.9485 - val_loss: 0.1684 - val_accuracy: 0.9500
# Epoch 11/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1539 - accuracy: 0.9546 - val_loss: 0.1584 - val_accuracy: 0.9500
# Epoch 12/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1359 - accuracy: 0.9654 - val_loss: 0.1498 - val_accuracy: 0.9563
# Epoch 13/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1346 - accuracy: 0.9599 - val_loss: 0.1344 - val_accuracy: 0.9625
# Epoch 14/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1146 - accuracy: 0.9652 - val_loss: 0.1299 - val_accuracy: 0.9600
# Epoch 15/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1177 - accuracy: 0.9686 - val_loss: 0.1230 - val_accuracy: 0.9638
# Epoch 16/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1057 - accuracy: 0.9698 - val_loss: 0.1175 - val_accuracy: 0.9625
# Epoch 17/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0953 - accuracy: 0.9718 - val_loss: 0.1095 - val_accuracy: 0.9675
# Epoch 18/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0855 - accuracy: 0.9740 - val_loss: 0.1053 - val_accuracy: 0.9663
# Epoch 19/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0793 - accuracy: 0.9787 - val_loss: 0.1017 - val_accuracy: 0.9675
# Epoch 20/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0770 - accuracy: 0.9740 - val_loss: 0.0982 - val_accuracy: 0.9650
# Epoch 21/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0680 - accuracy: 0.9807 - val_loss: 0.0958 - val_accuracy: 0.9675
# Epoch 22/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0603 - accuracy: 0.9818 - val_loss: 0.0835 - val_accuracy: 0.9725
# Epoch 23/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0590 - accuracy: 0.9857 - val_loss: 0.0854 - val_accuracy: 0.9700
# Epoch 24/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0493 - accuracy: 0.9864 - val_loss: 0.0830 - val_accuracy: 0.9700
# Epoch 25/25
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0499 - accuracy: 0.9890 - val_loss: 0.0761 - val_accuracy: 0.9750
# INFO:tensorflow:Assets written to: BestModel/assets
# Fold 3, 25 epochs, 13 sec
# MODEL
# make_DNN
# input shape: (24, 4)
# FIT
# Epoch 1/25
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6791 - accuracy: 0.5513 - val_loss: 0.5680 - val_accuracy: 0.7563
# Epoch 2/25
# 100/100 [==============================] - 1s 5ms/step - loss: 0.5295 - accuracy: 0.7635 - val_loss: 0.4242 - val_accuracy: 0.8100
# Epoch 3/25
# 100/100 [==============================] - 1s 6ms/step - loss: 0.
25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.2188 - accuracy: 0.9332 - val_loss: 0.1988 - val_accuracy: 0.9375
# Epoch 9/25
# 100/100 [==============================] - 1s 5ms/step - loss: 0.1957 - accuracy: 0.9357 - val_loss: 0.1795 - val_accuracy: 0.9463
# Epoch 10/25
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1731 - accuracy: 0.9462 - val_loss: 0.1566 - val_accuracy: 0.9538
# Epoch 11/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.1574 - accuracy: 0.9549 - val_loss: 0.1735 - val_accuracy: 0.9262
# Epoch 12/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.1363 - accuracy: 0.9611 - val_loss: 0.1364 - val_accuracy: 0.9600
# Epoch 13/25
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1330 - accuracy: 0.9608 - val_loss: 0.1270 - val_accuracy: 0.9575
# Epoch 14/25
# 100/100 [==============================] - 0s 5ms/step - loss: 0.1113 - accuracy: 0.9668 - val_loss: 0.1152 - val_accuracy: 0.9625
# Epoch 15/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1057 - accuracy: 0.9703 - val_loss: 0.1087 - val_accuracy: 0.9638
# Epoch 16/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1092 - accuracy: 0.9684 - val_loss: 0.1000 - val_accuracy: 0.9688
# Epoch 17/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0916 - accuracy: 0.9748 - val_loss: 0.0938 - val_accuracy: 0.9712
# Epoch 18/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0907 - accuracy: 0.9716 - val_loss: 0.0860 - val_accuracy: 0.9737
# Epoch 19/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0742 - accuracy: 0.9799 - val_loss: 0.0831 - val_accuracy: 0.9675
# Epoch 20/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0749 - accuracy: 0.9748 - val_loss: 0.0765 - val_accuracy: 0.9775
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 21/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0713 - accuracy: 0.9787 - val_loss: 0.0743 - val_accuracy: 0.9775
# Epoch 22/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0604 - accuracy: 0.9811 - val_loss: 0.0686 - val_accuracy: 0.9800
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 23/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0569 - accuracy: 0.9848 - val_loss: 0.0643 - val_accuracy: 0.9800
# Epoch 24/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0599 - accuracy: 0.9821 - val_loss: 0.0613 - val_accuracy: 0.9812
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 25/25
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0535 - accuracy: 0.9885 - val_loss: 0.0601 - val_accuracy: 0.9837
# INFO:tensorflow:Assets written to: BestModel/assets
# Fold 5, 25 epochs, 17 sec

# %%
from keras.models import load_model
X,y = prepare_inputs_len_x_alphabet(pc_test,nc_test,ALPHABET)
best_model=load_model(MODELPATH)
scores = best_model.evaluate(X, y, verbose=0)
print("The best model parameters were saved during cross-validation.")
print("Best was defined as maximum validation accuracy at end of any epoch.")
print("Now re-load the best model and test it on previously unseen data.")
print("Test on",len(pc_test),"PC seqs")
print("Test on",len(nc_test),"NC seqs")
print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))
# Out:
# The best model parameters were saved during cross-validation.
# Best was defined as maximum validation accuracy at end of any epoch.
# Now re-load the best model and test it on previously unseen data.
# Test on 1000 PC seqs
# Test on 1000 NC seqs
# accuracy: 98.50%

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
ns_probs = [0 for _ in range(len(y))]
bm_probs = best_model.predict(X)
ns_auc = roc_auc_score(y, ns_probs)
bm_auc = roc_auc_score(y, bm_probs)
ns_fpr, ns_tpr, _ = roc_curve(y, ns_probs)
bm_fpr, bm_tpr, _ = roc_curve(y, bm_probs)
plt.plot(ns_fpr, ns_tpr, linestyle='--', label='Guess, auc=%.4f'%ns_auc)
plt.plot(bm_fpr, bm_tpr, marker='.', label='Model, auc=%.4f'%bm_auc)
plt.title('ROC')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()
print("%s: %.2f%%" %('AUC',bm_auc*100.0))
# Out:
# AUC: 99.93%

# %%
t = time.time()
time.strftime('%Y-%m-%d %H:%M:%S %Z', time.localtime(t))
# Out:
# '2021-06-11 12:04:38 EDT'
