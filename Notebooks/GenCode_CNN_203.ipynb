# %% [markdown]
# # PC/NC classification by CNN
#
# The convolutional neural network (CNN) was invented for image processing.
# We can use Conv1D layers for processing string sequences.
# How well does CNN work on human RNA as a binary classifier of protein-coding/non-coding?
#
#
#
#
# Trying filter width 5-got worse
#
# Assume user downloaded files from GenCode 38 [FTP](http://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_human/release_38/)
# to a subdirectory called data.

# %%
import time 
def show_time():
    t = time.time()
    s = time.strftime('%Y-%m-%d %H:%M:%S %Z', time.localtime(t))
    print(s)
show_time()
# Out:
# 2021-06-01 20:12:25 UTC

# %%
PC_FILENAME='gencode.v38.pc_transcripts.fa.gz'
NC_FILENAME='gencode.v38.lncRNA_transcripts.fa.gz'

# %%
PC_SEQUENCES=20000   # how many protein-coding sequences
NC_SEQUENCES=20000   # how many non-coding sequences
PC_TESTS=1000
NC_TESTS=1000
BASES=1000            # how long is each sequence
ALPHABET=4          # how many different letters are possible
INPUT_SHAPE_2D = (BASES,ALPHABET,1) # Conv2D needs 3D inputs
INPUT_SHAPE = (BASES,ALPHABET) # Conv1D needs 2D inputs
FILTERS = 32   # how many different patterns the model looks for
NEURONS = 16
DROP_RATE = 0.2
WIDTH = 5   # how wide each pattern is, in bases
STRIDE_2D = (1,1)  # For Conv2D how far in each direction
STRIDE = 1 # For Conv1D, how far between pattern matches, in bases
EPOCHS=10  # how many times to train on all the data
SPLITS=5  # SPLITS=3 means train on 2/3 and validate on 1/3 
FOLDS=5  # train the model this many times (range 1 to SPLITS)

# %%
import sys
import csv

try:
    from google.colab import drive
    IN_COLAB = True
    print("On Google CoLab, mount cloud-local file, get our code from GitHub.")
    PATH='/content/drive/'
    #drive.mount(PATH,force_remount=True)  # hardly ever need this
    drive.mount(PATH)    # Google will require login credentials
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/RNA_gen.py')
    with open('RNA_gen.py', 'w') as f:
        f.write(r.text)  
    from RNA_gen import *
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/RNA_describe.py')
    with open('RNA_describe.py', 'w') as f:
        f.write(r.text)  
    from RNA_describe import *
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/RNA_prep.py')
    with open('RNA_prep.py', 'w') as f:
        f.write(r.text)  
    from RNA_prep import *
except:
    print("CoLab not working. On my PC, use relative paths.")
    IN_COLAB = False
    DATAPATH='../data/'  # must end in "/"
    sys.path.append("..") # append parent dir in order to use sibling dirs
    from SimTools.RNA_gen import *
    from SimTools.RNA_describe import *
    from SimTools.RNA_prep import *

MODELPATH="BestModel"  # saved on cloud instance and lost after logout
#MODELPATH=DATAPATH+MODELPATH  # saved on Google Drive but requires login

if not assert_imported_RNA_gen():
    print("ERROR: Cannot use RNA_gen.")
if not assert_imported_RNA_prep():
    print("ERROR: Cannot use RNA_prep.")
# Out:
# On Google CoLab, mount cloud-local file, get our code from GitHub.
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
from os import listdir
#from zipfile import ZipFile
import gzip

import numpy as np
import pandas as pd
from scipy import stats  # mode

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

from keras.models import Sequential
from keras.layers import Dense,Embedding,Dropout
from keras.layers import Conv1D,Conv2D
from keras.layers import Flatten,MaxPooling1D,MaxPooling2D
from keras.losses import BinaryCrossentropy
# tf.keras.losses.BinaryCrossentropy

import matplotlib.pyplot as plt
from matplotlib import colors
mycmap = colors.ListedColormap(['red','blue'])  # list color for label 0 then 1
np.set_printoptions(precision=2)

# %%
def load_gencode(filename,label):
    DEFLINE='>'
    DELIM='|'
    EMPTY=''
    labels=[]  # usually 1 for protein-coding or 0 for non-coding
    seqs=[]    # usually string of ACGT
    lens=[]    # sequence length
    ids=[]     # GenCode transcript ID, always starts ENST
    one_seq = EMPTY
    one_id = None
    # Use gzip 'r' mode to open file in read-only mode.
    # Use gzip 't' mode to read each line of text as type string.
    with gzip.open (filename,'rt') as infile:
        for line in infile:
            if line[0]==DEFLINE:
                # Save the previous sequence if one exists.
                if not one_seq == EMPTY:
                    labels.append(label)
                    seqs.append(one_seq)
                    lens.append(len(one_seq))
                    ids.append(one_id)
                # Get ready to read the next sequence. 
                # Parse a GenCode defline that is formatted like this:
                # >transcript_ID|gene_ID|other_fields other_info|other_info
                one_id = line[1:].split(DELIM)[0]
                one_seq = EMPTY
            else:
                # Continue loading sequence lines till next defline.
                additional = line.rstrip()
                one_seq = one_seq + additional
        # Don't forget to save the last sequence after end-of-file.
        if not one_seq == EMPTY:
            labels.append(label)
            seqs.append(one_seq)
            lens.append(len(one_seq))
            ids.append(one_id)

    df1=pd.DataFrame(ids,columns=['tid'])
    df2=pd.DataFrame(labels,columns=['class'])
    df3=pd.DataFrame(seqs,columns=['sequence'])
    df4=pd.DataFrame(lens,columns=['seqlen'])
    df=pd.concat((df1,df2,df3,df4),axis=1)
    return df

# %%
PC_FULLPATH=DATAPATH+PC_FILENAME
NC_FULLPATH=DATAPATH+NC_FILENAME
pcdf=load_gencode(PC_FULLPATH,1)
print("PC seqs loaded:",len(pcdf))
ncdf=load_gencode(NC_FULLPATH,0)
print("NC seqs loaded:",len(ncdf))
# Out:
# PC seqs loaded: 106143
# NC seqs loaded: 48752

# %%
def uniform_length(seqs,hardlen,too_big):
    newseqs=[]
    pad='T'*hardlen
    too_small=200 ## by definition of long non-coding RNA
    for seq in seqs:
        size=len(seq)
        if (size>too_small and size<too_big):
            big=seq+pad
            little=big[:hardlen]
            newseqs.append(little)
    return newseqs

# %%
from sklearn.model_selection import train_test_split
pc_all = pcdf['sequence']
nc_all = ncdf['sequence']
# The split function also shuffles
pc_train,pc_test=train_test_split(pc_all,test_size=0.10,random_state=1234)
nc_train,nc_test=train_test_split(nc_all,test_size=0.10,random_state=1234)

# %%
# Use code from our SimTools library.
UNIFORM_LENGTH=1000
MAXIMUM_LENGTH=2000
pc_seqs=uniform_length(pc_train,UNIFORM_LENGTH,MAXIMUM_LENGTH-500)
print("PC seqs ready:",len(pc_seqs))
nc_seqs=uniform_length(nc_train,UNIFORM_LENGTH,MAXIMUM_LENGTH+2000)
print("NC seqs ready:",len(nc_seqs))
X,y = prepare_inputs_len_x_alphabet(pc_seqs,nc_seqs,ALPHABET) # shuffles
print("Data ready")
# Out:
# PC seqs ready: 44652
# NC seqs ready: 42211
# Data ready

# %%
def make_DNN():
    print("make_DNN")
    print("input shape:",INPUT_SHAPE)
    dnn = Sequential()
    #dnn.add(Embedding(input_dim=INPUT_SHAPE,output_dim=INPUT_SHAPE)) 
    dnn.add(Conv1D(filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,padding="same",
            input_shape=INPUT_SHAPE))
    dnn.add(Conv1D(filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,padding="same"))
    dnn.add(MaxPooling1D())
    dnn.add(Conv1D(filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,padding="same"))
    dnn.add(Conv1D(filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,padding="same"))
    dnn.add(MaxPooling1D())
    dnn.add(Flatten())
    dnn.add(Dense(NEURONS,activation="sigmoid",dtype=np.float32))   
    dnn.add(Dropout(DROP_RATE))
    dnn.add(Dense(1,activation="sigmoid",dtype=np.float32))   
    dnn.compile(optimizer='adam',
                loss=BinaryCrossentropy(from_logits=False),
                metrics=['accuracy'])   # add to default metrics=loss
    dnn.build(input_shape=INPUT_SHAPE)
    #ln_rate = tf.keras.optimizers.Adam(learning_rate = LN_RATE)
    #bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    #model.compile(loss=bc, optimizer=ln_rate, metrics=["accuracy"])
    return dnn
model = make_DNN()
print(model.summary())
# Out:
# make_DNN
# input shape: (1000, 4)
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_24 (Conv1D)           (None, 1000, 32)          672
# _________________________________________________________________
# conv1d_25 (Conv1D)           (None, 1000, 32)          5152
# _________________________________________________________________
# max_pooling1d_12 (MaxPooling (None, 500, 32)           0
# _________________________________________________________________
# conv1d_26 (Conv1D)           (None, 500, 32)           5152
# _________________________________________________________________
# conv1d_27 (Conv1D)           (None, 500, 32)           5152
# _________________________________________________________________
# max_pooling1d_13 (MaxPooling (None, 250, 32)           0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 8000)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 16)                128016
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 144,161
# Trainable params: 144,161
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from keras.callbacks import ModelCheckpoint

def do_cross_validation(X,y):
    cv_scores = []
    fold=0
    mycallbacks = [ModelCheckpoint(
        filepath=MODELPATH, save_best_only=True, 
        monitor='val_accuracy', mode='max')]   
    splitter = KFold(n_splits=SPLITS)  # this does not shuffle
    for train_index,valid_index in splitter.split(X):
        if fold < FOLDS:
            fold += 1
            X_train=X[train_index] # inputs for training
            y_train=y[train_index] # labels for training
            X_valid=X[valid_index] # inputs for validation
            y_valid=y[valid_index] # labels for validation
            print("MODEL")
            # Call constructor on each CV. Else, continually improves the same model.
            model = model = make_DNN()
            print("FIT")  # model.fit() implements learning
            start_time=time.time()
            history=model.fit(X_train, y_train, 
                    epochs=EPOCHS, 
                    verbose=1,  # ascii art while learning
                    callbacks=mycallbacks,   # called at end of each epoch
                    validation_data=(X_valid,y_valid))
            end_time=time.time()
            elapsed_time=(end_time-start_time)                        
            print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
            # print(history.history.keys())  # all these keys will be shown in figure
            pd.DataFrame(history.history).plot(figsize=(8,5))
            plt.grid(True)
            plt.gca().set_ylim(0,1) # any losses > 1 will be off the scale
            plt.show()

# %%
show_time()
do_cross_validation(X,y)
show_time()
# Out:
# 2021-06-01 20:12:48 UTC
# MODEL
# make_DNN
# input shape: (1000, 4)
# FIT
# Epoch 1/10
# 2172/2172 [==============================] - 11s 5ms/step - loss: 0.5554 - accuracy: 0.7148 - val_loss: 0.3967 - val_accuracy: 0.8288
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 2/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.3925 - accuracy: 0.8285 - val_loss: 0.4837 - val_accuracy: 0.7794
# Epoch 3/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.3601 - accuracy: 0.8459 - val_loss: 0.3549 - val_accuracy: 0.8467
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 4/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.3552 - accuracy: 0.8485 - val_loss: 0.3930 - val_accuracy: 0.8206
# Epoch 5/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.3593 - accuracy: 0.8452 - val_loss: 0.3924 - val_accuracy: 0.8293
# Epoch 6/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.3886 - accuracy: 0.8288 - val_loss: 0.4004 - val_accuracy: 0.8117
# Epoch 7/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.3944 - accuracy: 0.8268 - val_loss: 0.4028 - val_accuracy: 0.8202
# Epoch 8/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.4055 - accuracy: 0.8180 - val_loss: 0.4063 - val_accuracy: 0.8130
# Epoch 9/10
# 2172/2172 [==============================] - 10s 4ms/step - loss: 0.4241 - accuracy: 0.8085 - val_loss: 0.4296 - val_accuracy: 0.7997
# Epoch 10/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.4611 - accuracy: 0.7768 - val_loss: 0.4109 - val_accuracy: 0.8114
# Fold 1, 10 epochs, 103 sec
# MODEL
# make_DNN
# input shape: (1000, 4)
# FIT
# Epoch 1/10
# 2172/2172 [==============================] - 12s 5ms/step - loss: 0.5783 - accuracy: 0.6966 - val_loss: 0.4152 - val_accuracy: 0.8126
# Epoch 2/10
# 2172/2172 [==============================] - 10s 4ms/step - loss: 0.4270 - accuracy: 0.8065 - val_loss: 0.3954 - val_accuracy: 0.8276
# Epoch 3/10
# 2172/2172 [==============================] - 10s 4ms/step - loss: 0.3970 - accuracy: 0.8270 - val_loss: 0.4224 - val_accuracy: 0.8086
# Epoch 4/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.3859 - accuracy: 0.8320 - val_loss: 0.3708 - val_accuracy: 0.8399
# Epoch 5/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.3905 - accuracy: 0.8280 - val_loss: 0.3985 - val_accuracy: 0.8210
# Epoch 6/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.3886 - accuracy: 0.8305 - val_loss: 0.3741 - val_accuracy: 0.8414
# Epoch 7/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.3979 - accuracy: 0.8242 - val_loss: 0.4901 - val_accuracy: 0.7735
# Epoch 8/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.4003 - accuracy: 0.8241 - val_loss: 0.3782 - val_accuracy: 0.8372
# Epoch 9/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.4204 - accuracy: 0.8111 - val_loss: 0.4269 - val_accuracy: 0.8059
# Epoch 10/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.4153 - accuracy: 0.8152 - val_loss: 0.4113 - val_accuracy: 0.8135
# Fold 2, 10 epochs, 142 sec
# MODEL
# make_DNN
# input shape: (1000, 4)
# FIT
# Epoch 1/10
# 2172/2172 [==============================] - 11s 5ms/step - loss: 0.5676 - accuracy: 0.7031 - val_loss: 0.4915 - val_accuracy: 0.7561
# Epoch 2/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.4432 - accuracy: 0.7972 - val_loss: 0.4102 - val_accuracy: 0.8212
# Epoch 3/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.4124 - accuracy: 0.8180 - val_loss: 0.4930 - val_accuracy: 0.7653
# Epoch 4/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.4111 - accuracy: 0.8142 - val_loss: 0.4923 - val_accuracy: 0.7622
# Epoch 5/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.4143 - accuracy: 0.8160 - val_loss: 0.3825 - val_accuracy: 0.8326
# Epoch 6/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.4149 - accuracy: 0.8160 - val_loss: 0.4362 - val_accuracy: 0.8042
# Epoch 7/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.4552 - accuracy: 0.7889 - val_loss: 0.4534 - val_accuracy: 0.7918
# Epoch 8/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.4526 - accuracy: 0.7921 - val_loss: 0.4087 - val_accuracy: 0.8163
# Epoch 9/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.4628 - accuracy: 0.7831 - val_loss: 0.4572 - val_accuracy: 0.7853
# Epoch 10/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.4710 - accuracy: 0.7757 - val_loss: 0.4794 - val_accuracy: 0.7739
# Fold 3, 10 epochs, 100 sec
# MODEL
# make_DNN
# input shape: (1000, 4)
# FIT
# Epoch 1/10
# 2172/2172 [==============================] - 12s 5ms/step - loss: 0.5859 - accuracy: 0.6885 - val_loss: 0.4310 - val_accuracy: 0.8064
# Epoch 2/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.4451 - accuracy: 0.7959 - val_loss: 0.3965 - val_accuracy: 0.8250
# Epoch 3/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.4083 - accuracy: 0.8189 - val_loss: 0.3754 - val_accuracy: 0.8370
# Epoch 4/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.3950 - accuracy: 0.8255 - val_loss: 0.4018 - val_accuracy: 0.8173
# Epoch 5/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.3920 - accuracy: 0.8263 - val_loss: 0.4087 - val_accuracy: 0.8192
# Epoch 6/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.3952 - accuracy: 0.8252 - val_loss: 0.3877 - val_accuracy: 0.8275
# Epoch 7/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.4156 - accuracy: 0.8109 - val_loss: 0.4146 - val_accuracy: 0.8057
# Epoch 8/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.4469 - accuracy: 0.7884 - val_loss: 0.5200 - val_accuracy: 0.7526
# Epoch 9/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.4426 - accuracy: 0.7964 - val_loss: 0.4238 - val_accuracy: 0.8114
# Epoch 10/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.4678 - accuracy: 0.7768 - val_loss: 0.5252 - val_accuracy: 0.7354
# Fold 4, 10 epochs, 142 sec
# MODEL
# make_DNN
# input shape: (1000, 4)
# FIT
# Epoch 1/10
# 2172/2172 [==============================] - 11s 5ms/step - loss: 0.5962 - accuracy: 0.6801 - val_loss: 0.4575 - val_accuracy: 0.7848
# Epoch 2/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.4631 - accuracy: 0.7844 - val_loss: 0.4874 - val_accuracy: 0.7667
# Epoch 3/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.4172 - accuracy: 0.8117 - val_loss: 0.3863 - val_accuracy: 0.8287
# Epoch 4/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.4024 - accuracy: 0.8209 - val_loss: 0.3981 - val_accuracy: 0.8225
# Epoch 5/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.3987 - accuracy: 0.8222 - val_loss: 0.4522 - val_accuracy: 0.7836
# Epoch 6/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.4123 - accuracy: 0.8131 - val_loss: 0.4005 - val_accuracy: 0.8197
# Epoch 7/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.4155 - accuracy: 0.8092 - val_loss: 0.3796 - val_accuracy: 0.8313
# Epoch 8/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.4335 - accuracy: 0.8029 - val_loss: 0.4239 - val_accuracy: 0.8057
# Epoch 9/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.4398 - accuracy: 0.7968 - val_loss: 0.4109 - val_accuracy: 0.8191
# Epoch 10/10
# 2172/2172 [==============================] - 10s 5ms/step - loss: 0.4539 - accuracy: 0.7924 - val_loss: 0.4094 - val_accuracy: 0.8178
# Fold 5, 10 epochs, 142 sec
# 2021-06-01 20:23:22 UTC
