# %% [markdown]
# # Wen CNN
#
# Simulate the CNN approach of Wen et al. 2019.
#
# Notebook 101 ran to completion on PC. Now run more epochs on CoLab.

# %%
import time
def show_time():
    t = time.time()
    print(time.strftime('%Y-%m-%d %H:%M:%S %Z', time.localtime(t)))
show_time()
# Out:
# 2021-07-30 17:25:47 UTC

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D
from keras.layers import Dense,Embedding,Dropout
from keras.layers import Flatten,TimeDistributed
from keras.losses import BinaryCrossentropy
from keras.callbacks import ModelCheckpoint
from keras.models import load_model

# %%
import sys
IN_COLAB = False
try:
    from google.colab import drive
    IN_COLAB = True
except:
    pass
if IN_COLAB:
    print("On Google CoLab, mount cloud-local file, get our code from GitHub.")
    PATH='/content/drive/'
    #drive.mount(PATH,force_remount=True)  # hardly ever need this
    drive.mount(PATH)    # Google will require login credentials
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/RNA_describe.py')
    with open('RNA_describe.py', 'w') as f:
        f.write(r.text)  
    from RNA_describe import ORF_counter
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/GenCodeTools.py')
    with open('GenCodeTools.py', 'w') as f:
        f.write(r.text)  
    from GenCodeTools import GenCodeLoader
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/KmerTools.py')
    with open('KmerTools.py', 'w') as f:
        f.write(r.text)  
    from KmerTools import KmerTools
else:
        print("CoLab not working. On my PC, use relative paths.")
        DATAPATH='data/'  # must end in "/"
        sys.path.append("..") # append parent dir in order to use sibling dirs
        from SimTools.RNA_describe import ORF_counter
        from SimTools.GenCodeTools import GenCodeLoader
        from SimTools.KmerTools import KmerTools
BESTMODELPATH=DATAPATH+"BestModel-121"  # saved on cloud instance and lost after logout
LASTMODELPATH=DATAPATH+"LastModel-121"  # saved on Google Drive but requires login
# Out:
# On Google CoLab, mount cloud-local file, get our code from GitHub.
# Mounted at /content/drive/

# %% [markdown]
# ## Data Load

# %%
PC_TRAINS=8000
NC_TRAINS=8000
PC_TESTS=2000
NC_TESTS=2000   
PC_LENS=(200,4000)
NC_LENS=(200,4000)   # Wen used 3500 for hyperparameter, 3000 for train
PC_FILENAME='gencode.v26.pc_transcripts.fa.gz'
NC_FILENAME='gencode.v26.lncRNA_transcripts.fa.gz'
PC_FULLPATH=DATAPATH+PC_FILENAME
NC_FULLPATH=DATAPATH+NC_FILENAME
MAX_K = 3 
# With K={1,2,3}, num K-mers is 4^3 + 4^2 + 4^1 = 84.
# Wen specified 17x20 which is impossible.
# The factors of 84 are 1, 2, 3, 4, 6, 7, 12, 14, 21, 28, 42 and 84.
FRQ_CNT=84
ROWS=7
COLS=FRQ_CNT//ROWS
SHAPE2D = (ROWS,COLS,1)
EPOCHS=100 # 1000 # 200
SPLITS=5
FOLDS=5   # make this 5 for serious testing
show_time()
# Out:
# 2021-07-30 17:26:13 UTC

# %%
loader=GenCodeLoader()
loader.set_label(1)
loader.set_check_utr(True)
pcdf=loader.load_file(PC_FULLPATH)
print("PC seqs loaded:",len(pcdf))
loader.set_label(0)
loader.set_check_utr(False)
ncdf=loader.load_file(NC_FULLPATH)
print("NC seqs loaded:",len(ncdf))
show_time()
# Out:
# PC seqs loaded: 60604
# NC seqs loaded: 27720
# 2021-07-30 17:26:20 UTC

# %%
def dataframe_length_filter(df,low_high):
    (low,high)=low_high
    # The pandas query language is strange, 
    # but this is MUCH faster than loop & drop.
    return df[ (df['seqlen']>=low) & (df['seqlen']<=high) ]
def dataframe_extract_sequence(df):
    return df['sequence'].tolist()

pc_all = dataframe_extract_sequence(
    dataframe_length_filter(pcdf,PC_LENS))
nc_all = dataframe_extract_sequence(
    dataframe_length_filter(ncdf,NC_LENS))

show_time()
print("PC seqs pass filter:",len(pc_all))
print("NC seqs pass filter:",len(nc_all))
# Garbage collection to reduce RAM footprint
pcdf=None
ncdf=None
# Out:
# 2021-07-30 17:26:20 UTC
# PC seqs pass filter: 49180
# NC seqs pass filter: 26850

# %% [markdown]
# ## Data Prep

# %%
pc_train=pc_all[:PC_TRAINS] 
nc_train=nc_all[:NC_TRAINS]
print("PC train, NC train:",len(pc_train),len(nc_train))
pc_test=pc_all[PC_TRAINS:PC_TRAINS+PC_TESTS] 
nc_test=nc_all[NC_TRAINS:NC_TRAINS+PC_TESTS]
print("PC test, NC test:",len(pc_test),len(nc_test))
# Garbage collection
pc_all=None
nc_all=None
# Out:
# PC train, NC train: 8000 8000
# PC test, NC test: 2000 2000

# %%
def prepare_x_and_y(seqs1,seqs0):
    len1=len(seqs1)
    len0=len(seqs0)
    total=len1+len0
    L1=np.ones(len1,dtype=np.int8)
    L0=np.zeros(len0,dtype=np.int8)
    S1 = np.asarray(seqs1)
    S0 = np.asarray(seqs0)
    all_labels = np.concatenate((L1,L0))
    all_seqs = np.concatenate((S1,S0))  
    # interleave (uses less RAM than shuffle)
    for i in range(0,len0):
        all_labels[i*2] = L0[i]
        all_seqs[i*2] = S0[i]
        all_labels[i*2+1] = L1[i]
        all_seqs[i*2+1] = S1[i]
    return all_seqs,all_labels  # use this to test unshuffled
    X,y = shuffle(all_seqs,all_labels) # sklearn.utils.shuffle 
    return X,y
Xseq,y=prepare_x_and_y(pc_train,nc_train)
#print(Xseq[:3])
#print(y[:3])
show_time()
# Out:
# 2021-07-30 17:26:20 UTC

# %%
def seqs_to_kmer_freqs(seqs,max_K):
    tool = KmerTools()  # from SimTools
    collection = []
    for seq in seqs:
        counts = tool.make_dict_upto_K(max_K)
        # Last param should be True when using Harvester.
        counts = tool.update_count_one_K(counts,max_K,seq,True)
        # Given counts for K=3, Harvester fills in counts for K=1,2.
        counts = tool.harvest_counts_from_K(counts,max_K)
        fdict = tool.count_to_frequency(counts,max_K)
        freqs = list(fdict.values())
        collection.append(freqs)
    return np.asarray(collection)
Xfrq=seqs_to_kmer_freqs(Xseq,MAX_K)
# Garbage collection
Xseq = None
show_time()
# Out:
# 2021-07-30 17:26:31 UTC

# %%
def reshape(frequency_matrix):
    seq_cnt,frq_cnt=Xfrq.shape 
    # CNN inputs require a last dimension = numbers per pixel.
    # For RGB images it is 3.
    # For our frequency matrix it is 1.
    new_matrix = frequency_matrix.reshape(seq_cnt,ROWS,COLS,1)
    return new_matrix

print("Xfrq")
print("Xfrq type",type(Xfrq))
print("Xfrq shape",Xfrq.shape)
Xfrq2D = reshape(Xfrq)
print("Xfrq2D shape",Xfrq2D.shape)
# Out:
# Xfrq
# Xfrq type <class 'numpy.ndarray'>
# Xfrq shape (16000, 84)
# Xfrq2D shape (16000, 7, 12, 1)

# %% [markdown]
# ## Build and train a neural network

# %%
def make_DNN(shape):
    dt=np.float32
    print("make_DNN")
    print("input shape:",shape)
    WIDTH=(3,3)
    STRIDE=(1,1)
    dnn = Sequential()
    dnn.add(Conv2D(filters=32,kernel_size=WIDTH,strides=STRIDE,activation="relu",padding="same",
            input_shape=shape))
    dnn.add(Conv2D(filters=64,kernel_size=WIDTH,strides=STRIDE,activation="relu",padding="same"))
    dnn.add(MaxPooling2D())
    dnn.add(Flatten())
    dnn.add(Dropout(0.25))
    dnn.add(Dense(128,activation="sigmoid",dtype=dt)) 
    dnn.add(Dropout(0.50))
    dnn.add(Dense(1,activation="sigmoid",dtype=dt))   
    dnn.compile(optimizer='adam',    # adadelta doesn't work as well
                loss=BinaryCrossentropy(from_logits=False),
                metrics=['accuracy'])   # add to default metrics=loss
    dnn.build(input_shape=shape) 
    return dnn
model = make_DNN(SHAPE2D)
print(model.summary())
# Out:
# make_DNN
# input shape: (7, 12, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 7, 12, 32)         320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 7, 12, 64)         18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 3, 6, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1152)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1152)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               147584
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 166,529
# Trainable params: 166,529
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def do_cross_validation(X,y,shape):
    cv_scores = []
    fold=0
    mycallbacks = [ModelCheckpoint(
        filepath=BESTMODELPATH, save_best_only=True, 
        monitor='val_accuracy', mode='max')]   
    # When shuffle=True, the valid indices are a random subset.
    splitter = KFold(n_splits=SPLITS,shuffle=True) 
    model = None
    for train_index,valid_index in splitter.split(X):
        if fold < FOLDS:
            fold += 1
            X_train=X[train_index] # inputs for training
            y_train=y[train_index] # labels for training
            X_valid=X[valid_index] # inputs for validation
            y_valid=y[valid_index] # labels for validation
            print("MODEL")
            # Call constructor on each CV. Else, continually improves the same model.
            model = model = make_DNN(shape)
            print("FIT")  # model.fit() implements learning
            start_time=time.time()
            history=model.fit(X_train, y_train, 
                    epochs=EPOCHS, 
                    verbose=1,  # ascii art while learning
                    callbacks=mycallbacks,   # called at end of each epoch
                    validation_data=(X_valid,y_valid))
            end_time=time.time()
            elapsed_time=(end_time-start_time)                        
            print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
            # print(history.history.keys())  # all these keys will be shown in figure
            pd.DataFrame(history.history).plot(figsize=(8,5))
            plt.grid(True)
            plt.gca().set_ylim(0,1) # any losses > 1 will be off the scale
            plt.show()
    return model  # parameters at end of training

# %%
show_time()
last_model = do_cross_validation(Xfrq2D,y,SHAPE2D)
last_model.save(LASTMODELPATH)
# Out:
# 2021-07-30 17:26:35 UTC
# MODEL
# make_DNN
# input shape: (7, 12, 1)
# FIT
# Epoch 1/100
# 400/400 [==============================] - 30s 5ms/step - loss: 0.7368 - accuracy: 0.5218 - val_loss: 0.6451 - val_accuracy: 0.6187
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/BestModel-121/assets
# Epoch 2/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.6408 - accuracy: 0.6303 - val_loss: 0.6069 - val_accuracy: 0.6872
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/BestModel-121/assets
# Epoch 3/100
# 400/400 [==============================] - 1s 4ms/step - loss: 0.6017 - accuracy: 0.6742 - val_loss: 0.5231 - val_accuracy: 0.7494
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/BestModel-121/assets
# Epoch 4/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.5324 - accuracy: 0.7313 - val_loss: 0.4635 - val_accuracy: 0.7884
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/BestModel-121/assets
# Epoch 5/100
# 400/400 [==============================] - 1s 3ms/step - loss: 0.4671 - accuracy: 0.7831 - val_loss: 0.4050 - val_accuracy: 0.8331
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/BestModel-121/assets
# Epoch 6/100
# 400/400 [==============================] - 1s 4ms/step - loss: 0.4424 - accuracy: 0.7983 - val_loss: 0.3781 - val_accuracy: 0.8375
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/BestModel-121/assets
# Epoch 7/100
# 400/400 [==============================] - 1s 3ms/step - loss: 0.4052 - accuracy: 0.8167 - val_loss: 0.3723 - val_accuracy: 0.8353
# Epoch 8/100
# 400/400 [==============================] - 1s 4ms/step - loss: 0.3899 - accuracy: 0.8281 - val_loss: 0.3530 - val_accuracy: 0.8537
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/BestModel-121/assets
# Epoch 9/100
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3892 - accuracy: 0.8347 - val_loss: 0.3687 - val_accuracy: 0.8334
# Epoch 10/100
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3724 - accuracy: 0.8355 - val_loss: 0.3449 - val_accuracy: 0.8587
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/BestModel-121/assets
# Epoch 11/100
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3618 - accuracy: 0.8420 - val_loss: 0.3398 - val_accuracy: 0.8500
# Epoch 12/100
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3615 - accuracy: 0.8440 - val_loss: 0.3465 - val_accuracy: 0.8441
# Epoch 13/100
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3517 - accuracy: 0.8484 - val_loss: 0.3194 - val_accuracy: 0.8659
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/BestModel-121/assets
# Epoch 14/100
# 400/400 [==============================] - 1s 4ms/step - loss: 0.3427 - accuracy: 0.8503 - val_loss: 0.3358 - val_accuracy: 0.8578
# Epoch 15/100
# 400/400 [==============================] - 1s 4ms/step - loss: 0.3352 - accuracy: 0.8552 - val_loss: 0.3259 - val_accuracy: 0.8656
# Epoch 16/100
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3418 - accuracy: 0.8549 - val_loss: 0.3334 - val_accuracy: 0.8466
# Epoch 17/100
# 400/400 [==============================] - 1s 4ms/step - loss: 0.3340 - accuracy: 0.8500 - val_loss: 0.3403 - val_accuracy: 0.8469
# Epoch 18/100
# 400/400 [==============================] - 1s 4ms/step - loss: 0.3240 - accuracy: 0.8574 - val_loss: 0.3066 - val_accuracy: 0.8700
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/BestModel-121/assets
# Epoch 19/100
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3220 - accuracy: 0.8622 - val_loss: 0.3059 - val_accuracy: 0.8750
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/BestModel-121/assets
# Epoch 20/100
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3203 - accuracy: 0.8595 - val_loss: 0.3237 - val_accuracy: 0.8537
# Epoch 21/100
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3195 - accuracy: 0.8678 - val_loss: 0.3180 - val_accuracy: 0.8587
# Epoch 22/100
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3217 - accuracy: 0.8620 - val_loss: 0.3058 - val_accuracy: 0.8681
# Epoch 23/100
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3113 - accuracy: 0.8656 - val_loss: 0.3011 - val_accuracy: 0.8728
# Epoch 24/100
# 400/400 [==============================] - 1s 3ms/step - loss: 0.
100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2524 - accuracy: 0.8952 - val_loss: 0.2994 - val_accuracy: 0.8778
# Epoch 52/100
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2517 - accuracy: 0.8915 - val_loss: 0.2910 - val_accuracy: 0.8856
# Epoch 53/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2533 - accuracy: 0.8950 - val_loss: 0.2839 - val_accuracy: 0.8803
# Epoch 54/100
# 400/400 [==============================] - 1s 4ms/step - loss: 0.2585 - accuracy: 0.8909 - val_loss: 0.2826 - val_accuracy: 0.8866
# Epoch 55/100
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2558 - accuracy: 0.8953 - val_loss: 0.2992 - val_accuracy: 0.8766
# Epoch 56/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2538 - accuracy: 0.8928 - val_loss: 0.2838 - val_accuracy: 0.8869
# Epoch 57/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2568 - accuracy: 0.8921 - val_loss: 0.2967 - val_accuracy: 0.8744
# Epoch 58/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2538 - accuracy: 0.8932 - val_loss: 0.2804 - val_accuracy: 0.8850
# Epoch 59/100
# 400/400 [==============================] - 1s 4ms/step - loss: 0.2367 - accuracy: 0.8988 - val_loss: 0.2790 - val_accuracy: 0.8863
# Epoch 60/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2426 - accuracy: 0.8989 - val_loss: 0.2868 - val_accuracy: 0.8869
# Epoch 61/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2434 - accuracy: 0.8995 - val_loss: 0.2852 - val_accuracy: 0.8844
# Epoch 62/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2322 - accuracy: 0.9006 - val_loss: 0.2885 - val_accuracy: 0.8803
# Epoch 63/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2459 - accuracy: 0.8987 - val_loss: 0.2988 - val_accuracy: 0.8803
# Epoch 64/100
# 400/400 [==============================] - 1s 4ms/step - loss: 0.2455 - accuracy: 0.8979 - val_loss: 0.2997 - val_accuracy: 0.8772
# Epoch 65/100
# 400/400 [==============================] - 1s 4ms/step - loss: 0.2447 - accuracy: 0.9011 - val_loss: 0.2845 - val_accuracy: 0.8834
# Epoch 66/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2384 - accuracy: 0.9009 - val_loss: 0.2877 - val_accuracy: 0.8838
# Epoch 67/100
# 400/400 [==============================] - 1s 4ms/step - loss: 0.2402 - accuracy: 0.8987 - val_loss: 0.2825 - val_accuracy: 0.8809
# Epoch 68/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2236 - accuracy: 0.9075 - val_loss: 0.2927 - val_accuracy: 0.8828
# Epoch 69/100
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2316 - accuracy: 0.9005 - val_loss: 0.2884 - val_accuracy: 0.8803
# Epoch 70/100
# 400/400 [==============================] - 1s 4ms/step - loss: 0.2218 - accuracy: 0.9064 - val_loss: 0.2854 - val_accuracy: 0.8844
# Epoch 71/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2330 - accuracy: 0.9011 - val_loss: 0.2837 - val_accuracy: 0.8866
# Epoch 72/100
# 400/400 [==============================] - 1s 4ms/step - loss: 0.2300 - accuracy: 0.9049 - val_loss: 0.2847 - val_accuracy: 0.8884
# Epoch 73/100
# 400/400 [==============================] - 1s 4ms/step - loss: 0.2323 - accuracy: 0.9014 - val_loss: 0.2838 - val_accuracy: 0.8853
# Epoch 74/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2308 - accuracy: 0.9036 - val_loss: 0.2867 - val_accuracy: 0.8822
# Epoch 75/100
# 400/400 [==============================] - 1s 4ms/step - loss: 0.2222 - accuracy: 0.9085 - val_loss: 0.2810 - val_accuracy: 0.8859
# Epoch 76/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2297 - accuracy: 0.9027 - val_loss: 0.2845 - val_accuracy: 0.8844
# Epoch 77/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2212 - accuracy: 0.9065 - val_loss: 0.2908 - val_accuracy: 0.8881
# Epoch 78/100
# 400/400 [==============================] - 1s 4ms/step - loss: 0.2260 - accuracy: 0.9023 - val_loss: 0.2820 - val_accuracy: 0.8863
# Epoch 79/100
# 400/400 [==============================] - 1s 4ms/step - loss: 0.2183 - accuracy: 0.9067 - val_loss: 0.2986 - val_accuracy: 0.8838
# Epoch 80/100
# 400/400 [==============================] - 1s 4ms/step - loss: 0.2178 - accuracy: 0.9083 - val_loss: 0.2916 - val_accuracy: 0.8819
# Epoch 81/100
# 400/400 [==============================] - 1s 4ms/step - loss: 0.2198 - accuracy: 0.9097 - val_loss: 0.2910 - val_accuracy: 0.8831
# Epoch 82/100
# 400/400 [==============================] - 1s 4ms/step - loss: 0.2122 - accuracy: 0.9121 - val_loss: 0.2851 - val_accuracy: 0.8828
# Epoch 83/100
# 400/400 [==============================] - 1s 4ms/step - loss: 0.2215 - accuracy: 0.9061 - val_loss: 0.2837 - val_accuracy: 0.8863
# Epoch 84/100
# 400/400 [==============================] - 1s 4ms/step - loss: 0.2111 - accuracy: 0.9111 - val_loss: 0.2829 - val_accuracy: 0.8853
# Epoch 85/100
# 400/400 [==============================] - 1s 4ms/step - loss: 0.2052 - accuracy: 0.9176 - val_loss: 0.2975 - val_accuracy: 0.8822
# Epoch 86/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2102 - accuracy: 0.9126 - val_loss: 0.2895 - val_accuracy: 0.8828
# Epoch 87/100
# 400/400 [==============================] - 1s 4ms/step - loss: 0.2056 - accuracy: 0.9163 - val_loss: 0.2841 - val_accuracy: 0.8844
# Epoch 88/100
# 400/400 [==============================] - 1s 4ms/step - loss: 0.2074 - accuracy: 0.9137 - val_loss: 0.2940 - val_accuracy: 0.8866
# Epoch 89/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2040 - accuracy: 0.9176 - val_loss: 0.2891 - val_accuracy: 0.8831
# Epoch 90/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2104 - accuracy: 0.9134 - val_loss: 0.3129 - val_accuracy: 0.8772
# Epoch 91/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.1973 - accuracy: 0.9157 - val_loss: 0.2785 - val_accuracy: 0.8900
# Epoch 92/100
# 400/400 [==============================] - 1s 4ms/step - loss: 0.1946 - accuracy: 0.9195 - val_loss: 0.2899 - val_accuracy: 0.8859
# Epoch 93/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2010 - accuracy: 0.9136 - val_loss: 0.2878 - val_accuracy: 0.8869
# Epoch 94/100
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1835 - accuracy: 0.9195 - val_loss: 0.2895 - val_accuracy: 0.8891
# Epoch 95/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.1938 - accuracy: 0.9196 - val_loss: 0.2868 - val_accuracy: 0.8888
# Epoch 96/100
# 400/400 [==============================] - 1s 4ms/step - loss: 0.1962 - accuracy: 0.9168 - val_loss: 0.3052 - val_accuracy: 0.8866
# Epoch 97/100
# 400/400 [==============================] - 1s 4ms/step - loss: 0.1910 - accuracy: 0.9209 - val_loss: 0.2965 - val_accuracy: 0.8881
# Epoch 98/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.1930 - accuracy: 0.9183 - val_loss: 0.2911 - val_accuracy: 0.8919
# Epoch 99/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.1870 - accuracy: 0.9221 - val_loss: 0.2919 - val_accuracy: 0.8916
# Epoch 100/100
# 400/400 [==============================] - 2s 4ms/step - loss: 0.1862 - accuracy: 0.9225 - val_loss: 0.2995 - val_accuracy: 0.8838
# Fold 5, 100 epochs, 149 sec
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/LastModel-121/assets

# %% [markdown]
# ## Test the neural network

# %%
def show_test_AUC(model,X,y):
    ns_probs = [0 for _ in range(len(y))]
    bm_probs = model.predict(X)
    ns_auc = roc_auc_score(y, ns_probs)
    bm_auc = roc_auc_score(y, bm_probs)
    ns_fpr, ns_tpr, _ = roc_curve(y, ns_probs)
    bm_fpr, bm_tpr, _ = roc_curve(y, bm_probs)
    plt.plot(ns_fpr, ns_tpr, linestyle='--', label='Guess, auc=%.4f'%ns_auc)
    plt.plot(bm_fpr, bm_tpr, marker='.', label='Model, auc=%.4f'%bm_auc)
    plt.title('ROC')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()
    plt.show()
    print("%s: %.2f%%" %('AUC',bm_auc*100.0))
def show_test_accuracy(model,X,y):
    scores = model.evaluate(X, y, verbose=0)
    print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))

# %%
print("Accuracy on test data.")
print("Prepare...")
show_time()
Xseq,y=prepare_x_and_y(pc_test,nc_test)
print("Extract K-mer features...")
show_time()
Xfrq=seqs_to_kmer_freqs(Xseq,MAX_K)
Xfrq2D = reshape(Xfrq)
print("Plot...")
show_time()
show_test_AUC(last_model,Xfrq2D,y)
show_test_accuracy(last_model,Xfrq2D,y)
show_time()
# Out:
# Accuracy on test data.
# Prepare...
# 2021-07-30 17:41:56 UTC
# Extract K-mer features...
# 2021-07-30 17:41:56 UTC
# Plot...
# 2021-07-30 17:41:59 UTC
# AUC: 93.18%
# accuracy: 85.10%
# 2021-07-30 17:42:00 UTC
