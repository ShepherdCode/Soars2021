# %% [markdown]
# # Wen CNN
#
# Simulate the CNN approach of Wen et al. 2019.
#
# Notebook 101 ran to completion on PC. Now run more epochs on CoLab.

# %%
import time
def show_time():
    t = time.time()
    print(time.strftime('%Y-%m-%d %H:%M:%S %Z', time.localtime(t)))
show_time()
# Out:
# 2021-08-12 05:45:44 EDT

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D
from keras.layers import Dense,Embedding,Dropout
from keras.layers import Flatten,TimeDistributed
from keras.losses import BinaryCrossentropy
from keras.callbacks import ModelCheckpoint
from keras.models import load_model

# %%
import sys
IN_COLAB = False
try:
    from google.colab import drive
    IN_COLAB = True
except:
    pass
if IN_COLAB:
    print("On Google CoLab, mount cloud-local file, get our code from GitHub.")
    PATH='/content/drive/'
    #drive.mount(PATH,force_remount=True)  # hardly ever need this
    drive.mount(PATH)    # Google will require login credentials
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/RNA_describe.py')
    with open('RNA_describe.py', 'w') as f:
        f.write(r.text)  
    from RNA_describe import ORF_counter
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/GenCodeTools.py')
    with open('GenCodeTools.py', 'w') as f:
        f.write(r.text)  
    from GenCodeTools import GenCodeLoader
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/KmerTools.py')
    with open('KmerTools.py', 'w') as f:
        f.write(r.text)  
    from KmerTools import KmerTools
else:
        print("CoLab not working. On my PC, use relative paths.")
        DATAPATH='data/'  # must end in "/"
        sys.path.append("..") # append parent dir in order to use sibling dirs
        from SimTools.RNA_describe import ORF_counter
        from SimTools.GenCodeTools import GenCodeLoader
        from SimTools.KmerTools import KmerTools
BESTMODELPATH=DATAPATH+"BestModel-Wen"  # saved on cloud instance and lost after logout
LASTMODELPATH=DATAPATH+"LastModel-Wen"  # saved on Google Drive but requires login
# Out:
# CoLab not working. On my PC, use relative paths.

# %% [markdown]
# ## Data Load

# %%
PC_TRAINS=8000
NC_TRAINS=8000
PC_TESTS=2000
NC_TESTS=2000   
PC_LENS=(200,4000)
NC_LENS=(200,4000)   # Wen used 3500 for hyperparameter, 3000 for train
PC_FILENAME='gencode.v38.pc_transcripts.fa.gz'
NC_FILENAME='gencode.v38.lncRNA_transcripts.fa.gz'
PC_FULLPATH=DATAPATH+PC_FILENAME
NC_FULLPATH=DATAPATH+NC_FILENAME
MAX_K = 3 
# With K={1,2,3}, num K-mers is 4^3 + 4^2 + 4^1 = 84.
# Wen specified 17x20 which is impossible.
# The factors of 84 are 1, 2, 3, 4, 6, 7, 12, 14, 21, 28, 42 and 84.
FRQ_CNT=84
ROWS=7
COLS=FRQ_CNT//ROWS
SHAPE2D = (ROWS,COLS,1)
EPOCHS=100 # 1000 # 200
SPLITS=5
FOLDS=5   # make this 5 for serious testing
show_time()
# Out:
# 2021-08-12 05:46:03 EDT

# %%
loader=GenCodeLoader()
loader.set_label(1)
loader.set_check_utr(True)
pcdf=loader.load_file(PC_FULLPATH)
print("PC seqs loaded:",len(pcdf))
loader.set_label(0)
loader.set_check_utr(False)
ncdf=loader.load_file(NC_FULLPATH)
print("NC seqs loaded:",len(ncdf))
show_time()
# Out:
# PC seqs loaded: 70825
# NC seqs loaded: 48752
# 2021-08-12 05:46:14 EDT

# %%
def dataframe_length_filter(df,low_high):
    (low,high)=low_high
    # The pandas query language is strange, 
    # but this is MUCH faster than loop & drop.
    return df[ (df['seqlen']>=low) & (df['seqlen']<=high) ]
def dataframe_extract_sequence(df):
    return df['sequence'].tolist()

pc_all = dataframe_extract_sequence(
    dataframe_length_filter(pcdf,PC_LENS))
nc_all = dataframe_extract_sequence(
    dataframe_length_filter(ncdf,NC_LENS))

show_time()
print("PC seqs pass filter:",len(pc_all))
print("NC seqs pass filter:",len(nc_all))
# Garbage collection to reduce RAM footprint
pcdf=None
ncdf=None
# Out:
# 2021-08-12 05:46:14 EDT
# PC seqs pass filter: 55381
# NC seqs pass filter: 46919

# %% [markdown]
# ## Data Prep

# %%
pc_train=pc_all[:PC_TRAINS] 
nc_train=nc_all[:NC_TRAINS]
print("PC train, NC train:",len(pc_train),len(nc_train))
pc_test=pc_all[PC_TRAINS:PC_TRAINS+PC_TESTS] 
nc_test=nc_all[NC_TRAINS:NC_TRAINS+PC_TESTS]
print("PC test, NC test:",len(pc_test),len(nc_test))
# Garbage collection
pc_all=None
nc_all=None
# Out:
# PC train, NC train: 8000 8000
# PC test, NC test: 2000 2000

# %%
def prepare_x_and_y(seqs1,seqs0):
    len1=len(seqs1)
    len0=len(seqs0)
    total=len1+len0
    L1=np.ones(len1,dtype=np.int8)
    L0=np.zeros(len0,dtype=np.int8)
    S1 = np.asarray(seqs1)
    S0 = np.asarray(seqs0)
    all_labels = np.concatenate((L1,L0))
    all_seqs = np.concatenate((S1,S0))  
    # interleave (uses less RAM than shuffle)
    for i in range(0,len0):
        all_labels[i*2] = L0[i]
        all_seqs[i*2] = S0[i]
        all_labels[i*2+1] = L1[i]
        all_seqs[i*2+1] = S1[i]
    return all_seqs,all_labels  # use this to test unshuffled
    X,y = shuffle(all_seqs,all_labels) # sklearn.utils.shuffle 
    return X,y
Xseq,y=prepare_x_and_y(pc_train,nc_train)
#print(Xseq[:3])
#print(y[:3])
show_time()
# Out:
# 2021-08-12 05:46:17 EDT

# %%
def seqs_to_kmer_freqs(seqs,max_K):
    tool = KmerTools()  # from SimTools
    collection = []
    for seq in seqs:
        counts = tool.make_dict_upto_K(max_K)
        # Last param should be True when using Harvester.
        counts = tool.update_count_one_K(counts,max_K,seq,True)
        # Given counts for K=3, Harvester fills in counts for K=1,2.
        counts = tool.harvest_counts_from_K(counts,max_K)
        fdict = tool.count_to_frequency(counts,max_K)
        freqs = list(fdict.values())
        collection.append(freqs)
    return np.asarray(collection)
Xfrq=seqs_to_kmer_freqs(Xseq,MAX_K)
# Garbage collection
Xseq = None
show_time()
# Out:
# 2021-08-12 05:46:45 EDT

# %%
def reshape(frequency_matrix):
    seq_cnt,frq_cnt=Xfrq.shape 
    # CNN inputs require a last dimension = numbers per pixel.
    # For RGB images it is 3.
    # For our frequency matrix it is 1.
    new_matrix = frequency_matrix.reshape(seq_cnt,ROWS,COLS,1)
    return new_matrix

print("Xfrq")
print("Xfrq type",type(Xfrq))
print("Xfrq shape",Xfrq.shape)
Xfrq2D = reshape(Xfrq)
print("Xfrq2D shape",Xfrq2D.shape)
# Out:
# Xfrq
# Xfrq type <class 'numpy.ndarray'>
# Xfrq shape (16000, 84)
# Xfrq2D shape (16000, 7, 12, 1)

# %% [markdown]
# ## Build and train a neural network

# %%
def make_DNN(shape):
    dt=np.float32
    print("make_DNN")
    print("input shape:",shape)
    WIDTH=(3,3)
    STRIDE=(1,1)
    dnn = Sequential()
    dnn.add(Conv2D(filters=32,kernel_size=WIDTH,strides=STRIDE,activation="relu",padding="same",
            input_shape=shape))
    dnn.add(Conv2D(filters=64,kernel_size=WIDTH,strides=STRIDE,activation="relu",padding="same"))
    dnn.add(MaxPooling2D())
    dnn.add(Flatten())
    dnn.add(Dropout(0.25))
    dnn.add(Dense(128,activation="sigmoid",dtype=dt)) 
    dnn.add(Dropout(0.50))
    dnn.add(Dense(1,activation="sigmoid",dtype=dt))   
    dnn.compile(optimizer='adam',    # adadelta doesn't work as well
                loss=BinaryCrossentropy(from_logits=False),
                metrics=['accuracy'])   # add to default metrics=loss
    dnn.build(input_shape=shape) 
    return dnn
model = make_DNN(SHAPE2D)
print(model.summary())
# Out:
# make_DNN
# input shape: (7, 12, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 7, 12, 32)         320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 7, 12, 64)         18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 3, 6, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1152)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1152)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               147584
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 166,529
# Trainable params: 166,529
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def do_cross_validation(X,y,shape):
    cv_scores = []
    fold=0
    mycallbacks = [ModelCheckpoint(
        filepath=BESTMODELPATH, save_best_only=True, 
        monitor='val_accuracy', mode='max')]   
    # When shuffle=True, the valid indices are a random subset.
    splitter = KFold(n_splits=SPLITS,shuffle=True) 
    model = None
    for train_index,valid_index in splitter.split(X):
        if fold < FOLDS:
            fold += 1
            X_train=X[train_index] # inputs for training
            y_train=y[train_index] # labels for training
            X_valid=X[valid_index] # inputs for validation
            y_valid=y[valid_index] # labels for validation
            print("MODEL")
            # Call constructor on each CV. Else, continually improves the same model.
            model = model = make_DNN(shape)
            print("FIT")  # model.fit() implements learning
            start_time=time.time()
            history=model.fit(X_train, y_train, 
                    epochs=EPOCHS, 
                    verbose=1,  # ascii art while learning
                    callbacks=mycallbacks,   # called at end of each epoch
                    validation_data=(X_valid,y_valid))
            end_time=time.time()
            elapsed_time=(end_time-start_time)                        
            print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
            # print(history.history.keys())  # all these keys will be shown in figure
            pd.DataFrame(history.history).plot(figsize=(8,5))
            plt.grid(True)
            plt.gca().set_ylim(0,1) # any losses > 1 will be off the scale
            plt.show()
    return model  # parameters at end of training

# %%
show_time()
last_model = do_cross_validation(Xfrq2D,y,SHAPE2D)
last_model.save(LASTMODELPATH)
# Out:
# 2021-08-12 05:46:45 EDT
# MODEL
# make_DNN
# input shape: (7, 12, 1)
# FIT
# Epoch 1/100
# 400/400 [==============================] - 28s 16ms/step - loss: 0.7105 - accuracy: 0.5450 - val_loss: 0.6148 - val_accuracy: 0.6559
# INFO:tensorflow:Assets written to: data/BestModel-Wen/assets
# Epoch 2/100
# 400/400 [==============================] - 6s 15ms/step - loss: 0.6141 - accuracy: 0.6588 - val_loss: 0.5633 - val_accuracy: 0.7200
# INFO:tensorflow:Assets written to: data/BestModel-Wen/assets
# Epoch 3/100
# 400/400 [==============================] - 10s 24ms/step - loss: 0.5715 - accuracy: 0.7061 - val_loss: 0.5361 - val_accuracy: 0.7337
# INFO:tensorflow:Assets written to: data/BestModel-Wen/assets
# Epoch 4/100
# 400/400 [==============================] - 12s 29ms/step - loss: 0.5361 - accuracy: 0.7434 - val_loss: 0.4872 - val_accuracy: 0.7666
# INFO:tensorflow:Assets written to: data/BestModel-Wen/assets
# Epoch 5/100
# 400/400 [==============================] - 9s 23ms/step - loss: 0.4951 - accuracy: 0.7628 - val_loss: 0.4612 - val_accuracy: 0.8031
# INFO:tensorflow:Assets written to: data/BestModel-Wen/assets
# Epoch 6/100
# 400/400 [==============================] - 8s 21ms/step - loss: 0.4640 - accuracy: 0.7841 - val_loss: 0.4507 - val_accuracy: 0.7922
# Epoch 7/100
# 400/400 [==============================] - 8s 21ms/step - loss: 0.4358 - accuracy: 0.8004 - val_loss: 0.4043 - val_accuracy: 0.8275
# INFO:tensorflow:Assets written to: data/BestModel-Wen/assets
# Epoch 8/100
# 400/400 [==============================] - 8s 21ms/step - loss: 0.4177 - accuracy: 0.8160 - val_loss: 0.3831 - val_accuracy: 0.8403
# INFO:tensorflow:Assets written to: data/BestModel-Wen/assets
# Epoch 9/100
# 400/400 [==============================] - 9s 22ms/step - loss: 0.3939 - accuracy: 0.8255 - val_loss: 0.3763 - val_accuracy: 0.8403
# Epoch 10/100
# 400/400 [==============================] - 9s 23ms/step - loss: 0.3888 - accuracy: 0.8270 - val_loss: 0.3676 - val_accuracy: 0.8438
# INFO:tensorflow:Assets written to: data/BestModel-Wen/assets
# Epoch 11/100
# 400/400 [==============================] - 8s 21ms/step - loss: 0.3799 - accuracy: 0.8294 - val_loss: 0.3764 - val_accuracy: 0.8363
# Epoch 12/100
# 400/400 [==============================] - 10s 24ms/step - loss: 0.3683 - accuracy: 0.8414 - val_loss: 0.3621 - val_accuracy: 0.8472
# INFO:tensorflow:Assets written to: data/BestModel-Wen/assets
# Epoch 13/100
# 400/400 [==============================] - 8s 20ms/step - loss: 0.3654 - accuracy: 0.8395 - val_loss: 0.3607 - val_accuracy: 0.8456
# Epoch 14/100
# 400/400 [==============================] - 9s 23ms/step - loss: 0.3650 - accuracy: 0.8396 - val_loss: 0.3503 - val_accuracy: 0.8528
# INFO:tensorflow:Assets written to: data/BestModel-Wen/assets
# Epoch
# INFO:tensorflow:Assets written to: data/BestModel-Wen/assets
# Epoch 72/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2400 - accuracy: 0.9000 - val_loss: 0.2864 - val_accuracy: 0.8838
# Epoch 73/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2428 - accuracy: 0.8983 - val_loss: 0.2819 - val_accuracy: 0.8813
# Epoch 74/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2367 - accuracy: 0.8995 - val_loss: 0.2870 - val_accuracy: 0.8803
# Epoch 75/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2361 - accuracy: 0.8997 - val_loss: 0.2817 - val_accuracy: 0.8859
# Epoch 76/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2265 - accuracy: 0.9038 - val_loss: 0.2798 - val_accuracy: 0.8806
# Epoch 77/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2337 - accuracy: 0.9031 - val_loss: 0.2792 - val_accuracy: 0.8838
# Epoch 78/100
# 400/400 [==============================] - 6s 14ms/step - loss: 0.2322 - accuracy: 0.8994 - val_loss: 0.2849 - val_accuracy: 0.8853
# Epoch 79/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2306 - accuracy: 0.9063 - val_loss: 0.2823 - val_accuracy: 0.8884
# INFO:tensorflow:Assets written to: data/BestModel-Wen/assets
# Epoch 80/100
# 400/400 [==============================] - 6s 14ms/step - loss: 0.2221 - accuracy: 0.9045 - val_loss: 0.2870 - val_accuracy: 0.8869
# Epoch 81/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2404 - accuracy: 0.9008 - val_loss: 0.2831 - val_accuracy: 0.8853
# Epoch 82/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2245 - accuracy: 0.9033 - val_loss: 0.2850 - val_accuracy: 0.8891
# INFO:tensorflow:Assets written to: data/BestModel-Wen/assets
# Epoch 83/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2244 - accuracy: 0.9077 - val_loss: 0.2761 - val_accuracy: 0.8869
# Epoch 84/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2261 - accuracy: 0.9071 - val_loss: 0.2721 - val_accuracy: 0.8850
# Epoch 85/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2156 - accuracy: 0.9106 - val_loss: 0.2756 - val_accuracy: 0.8922
# INFO:tensorflow:Assets written to: data/BestModel-Wen/assets
# Epoch 86/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2098 - accuracy: 0.9118 - val_loss: 0.2861 - val_accuracy: 0.8888
# Epoch 87/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2037 - accuracy: 0.9147 - val_loss: 0.2853 - val_accuracy: 0.8853
# Epoch 88/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2075 - accuracy: 0.9128 - val_loss: 0.2786 - val_accuracy: 0.8897
# Epoch 89/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2130 - accuracy: 0.9119 - val_loss: 0.2760 - val_accuracy: 0.8941
# INFO:tensorflow:Assets written to: data/BestModel-Wen/assets
# Epoch 90/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2045 - accuracy: 0.9139 - val_loss: 0.2766 - val_accuracy: 0.8919
# Epoch 91/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2064 - accuracy: 0.9111 - val_loss: 0.2725 - val_accuracy: 0.8891
# Epoch 92/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.1989 - accuracy: 0.9171 - val_loss: 0.2929 - val_accuracy: 0.8884
# Epoch 93/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2020 - accuracy: 0.9175 - val_loss: 0.2720 - val_accuracy: 0.8906
# Epoch 94/100
# 400/400 [==============================] - 6s 15ms/step - loss: 0.2053 - accuracy: 0.9143 - val_loss: 0.2791 - val_accuracy: 0.8888
# Epoch 95/100
# 400/400 [==============================] - 8s 19ms/step - loss: 0.1991 - accuracy: 0.9161 - val_loss: 0.2722 - val_accuracy: 0.8903
# Epoch 96/100
# 400/400 [==============================] - 8s 21ms/step - loss: 0.1899 - accuracy: 0.9226 - val_loss: 0.2695 - val_accuracy: 0.8947
# INFO:tensorflow:Assets written to: data/BestModel-Wen/assets
# Epoch 97/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.1965 - accuracy: 0.9204 - val_loss: 0.2704 - val_accuracy: 0.8878
# Epoch 98/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.1953 - accuracy: 0.9240 - val_loss: 0.2708 - val_accuracy: 0.8928
# Epoch 99/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.1992 - accuracy: 0.9221 - val_loss: 0.2749 - val_accuracy: 0.8913
# Epoch 100/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.1879 - accuracy: 0.9234 - val_loss: 0.2757 - val_accuracy: 0.8922
# Fold 1, 100 epochs, 675 sec
# MODEL
# make_DNN
# input shape: (7, 12, 1)
# FIT
# Epoch 1/100
# 400/400 [==============================] - 6s 13ms/step - loss: 0.7126 - accuracy: 0.5262 - val_loss: 0.6217 - val_accuracy: 0.6441
# Epoch 2/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0
100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2549 - accuracy: 0.8967 - val_loss: 0.2840 - val_accuracy: 0.8841
# Epoch 64/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2566 - accuracy: 0.8899 - val_loss: 0.3041 - val_accuracy: 0.8756
# Epoch 65/100
# 400/400 [==============================] - 5s 11ms/step - loss: 0.2593 - accuracy: 0.8904 - val_loss: 0.2915 - val_accuracy: 0.8847
# Epoch 66/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2598 - accuracy: 0.8891 - val_loss: 0.2853 - val_accuracy: 0.8891
# Epoch 67/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2503 - accuracy: 0.8925 - val_loss: 0.2860 - val_accuracy: 0.8872
# Epoch 68/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2444 - accuracy: 0.8978 - val_loss: 0.2898 - val_accuracy: 0.8850
# Epoch 69/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2499 - accuracy: 0.8915 - val_loss: 0.2833 - val_accuracy: 0.8888
# Epoch 70/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2431 - accuracy: 0.8998 - val_loss: 0.2804 - val_accuracy: 0.8894
# Epoch 71/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2424 - accuracy: 0.8971 - val_loss: 0.2837 - val_accuracy: 0.8875
# Epoch 72/100
# 400/400 [==============================] - 5s 11ms/step - loss: 0.2428 - accuracy: 0.8970 - val_loss: 0.2817 - val_accuracy: 0.8900
# Epoch 73/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2392 - accuracy: 0.8999 - val_loss: 0.2781 - val_accuracy: 0.8922
# Epoch 74/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2382 - accuracy: 0.8956 - val_loss: 0.2832 - val_accuracy: 0.8888
# Epoch 75/100
# 400/400 [==============================] - 5s 11ms/step - loss: 0.2470 - accuracy: 0.8980 - val_loss: 0.2765 - val_accuracy: 0.8928
# Epoch 76/100
# 400/400 [==============================] - 5s 11ms/step - loss: 0.2376 - accuracy: 0.9008 - val_loss: 0.2903 - val_accuracy: 0.8850
# Epoch 77/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2366 - accuracy: 0.9044 - val_loss: 0.2832 - val_accuracy: 0.8891
# Epoch 78/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2367 - accuracy: 0.8992 - val_loss: 0.2834 - val_accuracy: 0.8903
# Epoch 79/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2300 - accuracy: 0.9039 - val_loss: 0.2804 - val_accuracy: 0.8944
# Epoch 80/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2228 - accuracy: 0.9052 - val_loss: 0.2761 - val_accuracy: 0.8928
# Epoch 81/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2340 - accuracy: 0.8960 - val_loss: 0.2795 - val_accuracy: 0.8931
# Epoch 82/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2260 - accuracy: 0.9059 - val_loss: 0.2845 - val_accuracy: 0.8900
# Epoch 83/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2236 - accuracy: 0.9012 - val_loss: 0.2829 - val_accuracy: 0.8934
# Epoch 84/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2230 - accuracy: 0.9081 - val_loss: 0.2783 - val_accuracy: 0.8947
# Epoch 85/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2245 - accuracy: 0.9041 - val_loss: 0.2758 - val_accuracy: 0.8978
# INFO:tensorflow:Assets written to: data/BestModel-Wen/assets
# Epoch 86/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2229 - accuracy: 0.9041 - val_loss: 0.2764 - val_accuracy: 0.8997
# INFO:tensorflow:Assets written to: data/BestModel-Wen/assets
# Epoch 87/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2258 - accuracy: 0.9056 - val_loss: 0.2797 - val_accuracy: 0.8931
# Epoch 88/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2188 - accuracy: 0.9120 - val_loss: 0.2792 - val_accuracy: 0.8938
# Epoch 89/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2144 - accuracy: 0.9114 - val_loss: 0.2980 - val_accuracy: 0.8822
# Epoch 90/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2184 - accuracy: 0.9140 - val_loss: 0.2730 - val_accuracy: 0.9013
# INFO:tensorflow:Assets written to: data/BestModel-Wen/assets
# Epoch 91/100
# 400/400 [==============================] - 6s 15ms/step - loss: 0.2020 - accuracy: 0.9155 - val_loss: 0.2838 - val_accuracy: 0.8981
# Epoch 92/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2089 - accuracy: 0.9131 - val_loss: 0.2787 - val_accuracy: 0.8950
# Epoch 93/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2051 - accuracy: 0.9157 - val_loss: 0.2789 - val_accuracy: 0.8984
# Epoch 94/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.
100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.3240 - accuracy: 0.8622 - val_loss: 0.3098 - val_accuracy: 0.8700
# Epoch 26/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.3252 - accuracy: 0.8543 - val_loss: 0.3095 - val_accuracy: 0.8625
# Epoch 27/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.3289 - accuracy: 0.8567 - val_loss: 0.3207 - val_accuracy: 0.8581
# Epoch 28/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.3278 - accuracy: 0.8586 - val_loss: 0.3073 - val_accuracy: 0.8678
# Epoch 29/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.3175 - accuracy: 0.8608 - val_loss: 0.3037 - val_accuracy: 0.8700
# Epoch 30/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.3083 - accuracy: 0.8614 - val_loss: 0.2997 - val_accuracy: 0.8753
# Epoch 31/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.3169 - accuracy: 0.8609 - val_loss: 0.3004 - val_accuracy: 0.8741
# Epoch 32/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.3008 - accuracy: 0.8731 - val_loss: 0.3006 - val_accuracy: 0.8741
# Epoch 33/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.3126 - accuracy: 0.8641 - val_loss: 0.3193 - val_accuracy: 0.8653
# Epoch 34/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.3058 - accuracy: 0.8698 - val_loss: 0.2990 - val_accuracy: 0.8716
# Epoch 35/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2959 - accuracy: 0.8710 - val_loss: 0.3081 - val_accuracy: 0.8681
# Epoch 36/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.3018 - accuracy: 0.8725 - val_loss: 0.3065 - val_accuracy: 0.8712
# Epoch 37/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2992 - accuracy: 0.8742 - val_loss: 0.2908 - val_accuracy: 0.8750
# Epoch 38/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.3010 - accuracy: 0.8722 - val_loss: 0.2927 - val_accuracy: 0.8794
# Epoch 39/100
# 400/400 [==============================] - 7s 17ms/step - loss: 0.2974 - accuracy: 0.8732 - val_loss: 0.2933 - val_accuracy: 0.8775
# Epoch 40/100
# 400/400 [==============================] - 7s 18ms/step - loss: 0.3080 - accuracy: 0.8660 - val_loss: 0.2873 - val_accuracy: 0.8803
# Epoch 41/100
# 400/400 [==============================] - 6s 15ms/step - loss: 0.2976 - accuracy: 0.8746 - val_loss: 0.2897 - val_accuracy: 0.8803
# Epoch 42/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2894 - accuracy: 0.8760 - val_loss: 0.2887 - val_accuracy: 0.8769
# Epoch 43/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2932 - accuracy: 0.8739 - val_loss: 0.2943 - val_accuracy: 0.8791
# Epoch 44/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2887 - accuracy: 0.8802 - val_loss: 0.2836 - val_accuracy: 0.8781
# Epoch 45/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2905 - accuracy: 0.8751 - val_loss: 0.2826 - val_accuracy: 0.8822
# Epoch 46/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2841 - accuracy: 0.8812 - val_loss: 0.2873 - val_accuracy: 0.8784
# Epoch 47/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2828 - accuracy: 0.8799 - val_loss: 0.2835 - val_accuracy: 0.8800
# Epoch 48/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2716 - accuracy: 0.8841 - val_loss: 0.2944 - val_accuracy: 0.8734
# Epoch 49/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2843 - accuracy: 0.8793 - val_loss: 0.2987 - val_accuracy: 0.8709
# Epoch 50/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2788 - accuracy: 0.8814 - val_loss: 0.2920 - val_accuracy: 0.8750
# Epoch 51/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2853 - accuracy: 0.8795 - val_loss: 0.2791 - val_accuracy: 0.8809
# Epoch 52/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2748 - accuracy: 0.8781 - val_loss: 0.2778 - val_accuracy: 0.8803
# Epoch 53/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2708 - accuracy: 0.8861 - val_loss: 0.2757 - val_accuracy: 0.8825
# Epoch 54/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2735 - accuracy: 0.8845 - val_loss: 0.2812 - val_accuracy: 0.8825
# Epoch 55/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2646 - accuracy: 0.8878 - val_loss: 0.2728 - val_accuracy: 0.8863
# Epoch 56/100
# 400/400 [==============================] - 6s 14ms/step - loss: 0.2669 - accuracy: 0.8870 - val_loss: 0.2866 - val_accuracy: 0.8791
# Epoch 57/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2645 - accuracy: 0.8867 - val_loss: 0.2793 - val_accuracy: 0.8816
# Epoch 58/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2642 - accuracy: 0.8868 - val_loss: 0.2700 - val_accuracy: 0.8853
# Epoch 59/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2574 - accuracy: 0.8923 - val_loss: 0.2796 - val_accuracy: 0.8809
# Epoch 60/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2590 - accuracy: 0.8897 - val_loss: 0.2704 - val_accuracy: 0.8888
# Epoch 61/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2554 - accuracy: 0.8897 - val_loss: 0.2742 - val_accuracy: 0.8841
# Epoch 62/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2604 - accuracy: 0.8896 - val_loss: 0.2738 - val_accuracy: 0.8819
# Epoch 63/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2575 - accuracy: 0.8962 - val_loss: 0.2776 - val_accuracy: 0.8834
# Epoch 64/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2620 - accuracy: 0.8870 - val_loss: 0.2700 - val_accuracy: 0.8888
# Epoch 65/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2482 - accuracy: 0.8971 - val_loss: 0.2672 - val_accuracy: 0.8816
# Epoch 66/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2524 - accuracy: 0.8947 - val_loss: 0.2684 - val_accuracy: 0.8872
# Epoch 67/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2504 - accuracy: 0.8962 - val_loss: 0.2634 - val_accuracy: 0.8866
# Epoch 68/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2494 - accuracy: 0.8978 - val_loss: 0.2731 - val_accuracy: 0.8891
# Epoch 69/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2506 - accuracy: 0.8977 - val_loss: 0.2751 - val_accuracy: 0.8856
# Epoch 70/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2426 - accuracy: 0.8973 - val_loss: 0.2703 - val_accuracy: 0.8900
# Epoch 71/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2394 - accuracy: 0.8989 - val_loss: 0.2714 - val_accuracy: 0.8863
# Epoch 72/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2404 - accuracy: 0.9030 - val_loss: 0.2686 - val_accuracy: 0.8847
# Epoch 73/100
# 400/400 [==============================] - 6s 14ms/step - loss: 0.2397 - accuracy: 0.8988 - val_loss: 0.2699 - val_accuracy: 0.8866
# Epoch 74/100
# 400/400 [==============================] - 6s 16ms/step - loss: 0.2429 - accuracy: 0.8955 - val_loss: 0.2643 - val_accuracy: 0.8888
# Epoch 75/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2473 - accuracy: 0.8930 - val_loss: 0.2684 - val_accuracy: 0.8872
# Epoch 76/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2441 - accuracy: 0.8958 - val_loss: 0.2717 - val_accuracy: 0.8869
# Epoch 77/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2419 - accuracy: 0.8985 - val_loss: 0.2672 - val_accuracy: 0.8869
# Epoch 78/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2313 - accuracy: 0.9039 - val_loss: 0.2610 - val_accuracy: 0.8903
# Epoch 79/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2311 - accuracy: 0.9034 - val_loss: 0.2634 - val_accuracy: 0.8919
# Epoch 80/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2361 - accuracy: 0.9006 - val_loss: 0.2700 - val_accuracy: 0.8881
# Epoch 81/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2268 - accuracy: 0.9092 - val_loss: 0.2619 - val_accuracy: 0.8922
# Epoch 82/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2150 - accuracy: 0.9111 - val_loss: 0.2678 - val_accuracy: 0.8866
# Epoch 83/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2223 - accuracy: 0.9037 - val_loss: 0.2689 - val_accuracy: 0.8938
# Epoch 84/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2163 - accuracy: 0.9090 - val_loss: 0.2595 - val_accuracy: 0.8928
# Epoch 85/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2210 - accuracy: 0.9080 - val_loss: 0.2577 - val_accuracy: 0.8925
# Epoch 86/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2082 - accuracy: 0.9139 - val_loss: 0.2624 - val_accuracy: 0.8938
# Epoch 87/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2112 - accuracy: 0.9133 - val_loss: 0.2737 - val_accuracy: 0.8897
# Epoch 88/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2197 - accuracy: 0.9074 - val_loss: 0.2697 - val_accuracy: 0.8903
# Epoch 89/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2109 - accuracy: 0.9106 - val_loss: 0.2601 - val_accuracy: 0.8956
# Epoch 90/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2170 - accuracy: 0.9124 - val_loss: 0.2641 - val_accuracy: 0.8953
# Epoch 91/100
# 400/400 [==============================] - 6s 15ms/step - loss: 0.2138 - accuracy: 0.9132 - val_loss: 0.2590 - val_accuracy: 0.8928
# Epoch 92/100
# 400/400 [==============================] - 7s 18ms/step - loss: 0.2157 - accuracy: 0.9117 - val_loss: 0.2578 - val_accuracy: 0.8928
# Epoch 93/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2053 - accuracy: 0.9142 - val_loss: 0.2576 - val_accuracy: 0.8944
# Epoch 94/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2033 - accuracy: 0.9161 - val_loss: 0.2654 - val_accuracy: 0.8925
# Epoch 95/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2059 - accuracy: 0.9137 - val_loss: 0.2571 - val_accuracy: 0.8966
# Epoch 96/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2074 - accuracy: 0.9157 - val_loss: 0.2653 - val_accuracy: 0.8931
# Epoch 97/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2111 - accuracy: 0.9171 - val_loss: 0.2577 - val_accuracy: 0.8975
# Epoch 98/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.1964 - accuracy: 0.9200 - val_loss: 0.2578 - val_accuracy: 0.8984
# Epoch 99/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2003 - accuracy: 0.9215 - val_loss: 0.2549 - val_accuracy: 0.8997
# Epoch 100/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.1977 - accuracy: 0.9186 - val_loss: 0.2655 - val_accuracy: 0.8953
# Fold 3, 100 epochs, 503 sec
# MODEL
# make_DNN
# input shape: (7, 12, 1)
# FIT
# Epoch 1/100
# 400/400 [==============================] - 6s 13ms/step - loss: 0.7115 - accuracy: 0.5432 - val_loss: 0.6247 - val_accuracy: 0.6566
# Epoch 2/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.6196 - accuracy: 0.6609 - val_loss: 0.5595 - val_accuracy: 0.7191
# Epoch 3/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.5563 - accuracy: 0.7170 - val_loss: 0.5097 - val_accuracy: 0.7516
# Epoch 4/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.5168 - accuracy: 0.7474 - val_loss: 0.4785 - val_accuracy: 0.7731
# Epoch 5/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.4738 - accuracy: 0.7805 - val_loss: 0.4220 - val_accuracy: 0.8213
# Epoch 6/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.4358 - accuracy: 0.8032 - val_loss: 0.4116 - val_accuracy: 0.8134
# Epoch 7/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.4092 - accuracy: 0.8170 - val_loss: 0.3862 - val_accuracy: 0.8325
# Epoch 8/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.3942 - accuracy: 0.8251 - val_loss: 0.3757 - val_accuracy: 0.8400
# Epoch 9/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.3848 - accuracy: 0.8294 - val_loss: 0.3646 - val_accuracy: 0.8419
# Epoch 10/100
# 400/400 [==============================] - 6s 15ms/step - loss: 0.3768 - accuracy: 0.8304 - val_loss: 0.3725 - val_accuracy: 0.8338
# Epoch 11/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.3745 - accuracy: 0.8354 - val_loss: 0.3523 - val_accuracy: 0.8478
# Epoch 12/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.3662 - accuracy: 0.8362 - val_loss: 0.3564 - val_accuracy: 0.8428
# Epoch 13/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.3527 - accuracy: 0.8484 - val_loss: 0.3483 - val_accuracy: 0.8503
# Epoch 14/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.3570 - accuracy: 0.8497 - val_loss: 0.3490 - val_accuracy: 0.8491
# Epoch 15/100
# 400/400 [==============================] - 5s 14ms/step - loss: 0.3463 - accuracy: 0.8546 - val_loss: 0.3527 - val_accuracy: 0.8428
# Epoch 16/100
# ...
# Epoch 92/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2000 - accuracy: 0.9215 - val_loss: 0.2836 - val_accuracy: 0.8859
# Epoch 93/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.1911 - accuracy: 0.9222 - val_loss: 0.2884 - val_accuracy: 0.8863
# Epoch 94/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.1900 - accuracy: 0.9207 - val_loss: 0.2891 - val_accuracy: 0.8906
# Epoch 95/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.1983 - accuracy: 0.9202 - val_loss: 0.2814 - val_accuracy: 0.8891
# Epoch 96/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.1873 - accuracy: 0.9215 - val_loss: 0.2895 - val_accuracy: 0.8869
# Epoch 97/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.1849 - accuracy: 0.9249 - val_loss: 0.2951 - val_accuracy: 0.8859
# Epoch 98/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.1796 - accuracy: 0.9278 - val_loss: 0.2838 - val_accuracy: 0.8903
# Epoch 99/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.1879 - accuracy: 0.9246 - val_loss: 0.2895 - val_accuracy: 0.8900
# Epoch 100/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.1852 - accuracy: 0.9247 - val_loss: 0.2797 - val_accuracy: 0.8891
# Fold 4, 100 epochs, 520 sec
# MODEL
# make_DNN
# input shape: (7, 12, 1)
# FIT
# Epoch 1/100
# 400/400 [==============================] - 6s 13ms/step - loss: 0.7205 - accuracy: 0.5295 - val_loss: 0.6202 - val_accuracy: 0.6438
# Epoch 2/100
# 400/400 [==============================] - 4s 11ms/step - loss: 0.6274 - accuracy: 0.6486 - val_loss: 0.5869 - val_accuracy: 0.6837
# Epoch 3/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.5711 - accuracy: 0.7070 - val_loss: 0.5127 - val_accuracy: 0.7634
# Epoch 4/100
# 400/400 [==============================] - 7s 17ms/step - loss: 0.5374 - accuracy: 0.7404 - val_loss: 0.4664 - val_accuracy: 0.7909
# Epoch 5/100
# 400/400 [==============================] - 7s 18ms/step - loss: 0.4821 - accuracy: 0.7745 - val_loss: 0.4274 - val_accuracy: 0.8206
# Epoch 6/100
# 400/400 [==============================] - 5s 11ms/step - loss: 0.4480 - accuracy: 0.7971 - val_loss: 0.4072 - val_accuracy: 0.8297
# Epoch 7/100
# 400/400 [==============================] - 5s 11ms/step - loss: 0.4248 - accuracy: 0.8057 - val_loss: 0.3827 - val_accuracy: 0.8338
# Epoch 8/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.4011 - accuracy: 0.8226 - val_loss: 0.3748 - val_accuracy: 0.8397
# Epoch 9/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.3945 - accuracy: 0.8270 - val_loss: 0.3649 - val_accuracy: 0.8406
# Epoch 10/100
# 400/400 [==============================] - 5s 11ms/step - loss: 0.3796 - accuracy: 0.8334 - val_loss: 0.3641 - val_accuracy: 0.8391
# Epoch 11/100
# 400/400 [==============================] - 5s 11ms/step - loss: 0.3736 - accuracy: 0.8380 - val_loss: 0.3530 - val_accuracy: 0.8484
# Epoch 12/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.3658 - accuracy: 0.8426 - val_loss: 0.3546 - val_accuracy: 0.8447
# Epoch 13/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.3576 - accuracy: 0.8408 - val_loss: 0.3493 - val_accuracy: 0.8462
# Epoch 14/100
# 400/400 [==============================] - 5s 11ms/step - loss: 0.3659 - accuracy: 0.8398 - val_loss: 0.3598 - val_accuracy: 0.8422
# Epoch 15/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.3504 - accuracy: 0.8475 - val_loss: 0.3429 - val_accuracy: 0.8503
# Epoch 16/100
# 400/400 [==============================] - 5s 11ms/step - loss: 0.3462 - accuracy: 0.8520 - val_loss: 0.3381 - val_accuracy: 0.8525
# Epoch 17/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.3535 - accuracy: 0.8478 - val_loss: 0.3420 - val_accuracy: 0.8469
# Epoch 18/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.3524 - accuracy: 0.8433 - val_loss: 0.3324 - val_accuracy: 0.8550
# Epoch 19/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.3358 - accuracy: 0.8596 - val_loss: 0.3356 - val_accuracy: 0.8497
# Epoch 20/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.3388 - accuracy: 0.8475 - val_loss: 0.3340 - val_accuracy: 0.8509
# Epoch 21/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.3291 - accuracy: 0.8632 - val_loss: 0.3351 - val_accuracy: 0.8547
# Epoch 22/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.3259 - accuracy: 0.8588 - val_loss: 0.3302 - val_accuracy: 0.8541
# Epoch 23/100
# 400/400 [==============================] - 5s 11ms/step - loss: 0.3337 - accuracy: 0.8548 - val_loss: 0.3279 - val_accuracy: 0.8606
# Epoch 24/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.3219 - accuracy: 0.8608 - val_loss: 0.3266 - val_accuracy: 0.8556
# Epoch 25/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.3206 - accuracy: 0.8599 - val_loss: 0.3172 - val_accuracy: 0.8581
# Epoch 26/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.3165 - accuracy: 0.8661 - val_loss: 0.3140 - val_accuracy: 0.8616
# Epoch 27/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.3163 - accuracy: 0.8615 - val_loss: 0.3215 - val_accuracy: 0.8581
# Epoch 28/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.3084 - accuracy: 0.8696 - val_loss: 0.3118 - val_accuracy: 0.8612
# Epoch 29/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.3050 - accuracy: 0.8679 - val_loss: 0.3221 - val_accuracy: 0.8591
# Epoch 30/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.3088 - accuracy: 0.8679 - val_loss: 0.3164 - val_accuracy: 0.8569
# Epoch 31/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.3031 - accuracy: 0.8715 - val_loss: 0.3084 - val_accuracy: 0.8631
# Epoch 32/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.3096 - accuracy: 0.8657 - val_loss: 0.3071 - val_accuracy: 0.8644
# Epoch 33/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2943 - accuracy: 0.8730 - val_loss: 0.3081 - val_accuracy: 0.8647
# Epoch 34/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.3050 - accuracy: 0.8692 - val_loss: 0.3043 - val_accuracy: 0.8656
# Epoch 35/100
# 400/400 [==============================] - 5s 11ms/step - loss: 0.2976 - accuracy: 0.8715 - val_loss: 0.3097 - val_accuracy: 0.8647
# Epoch 36/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2937 - accuracy: 0.8753 - val_loss: 0.3226 - val_accuracy: 0.8572
# Epoch 37/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2959 - accuracy: 0.8741 - val_loss: 0.3153 - val_accuracy: 0.8622
# Epoch 38/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2995 - accuracy: 0.8692 - val_loss: 0.3091 - val_accuracy: 0.8659
# Epoch 39/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2937 - accuracy: 0.8739 - val_loss: 0.3201 - val_accuracy: 0.8597
# Epoch 40/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2826 - accuracy: 0.8754 - val_loss: 0.3004 - val_accuracy: 0.8706
# Epoch 41/100
# 400/400 [==============================] - 6s 14ms/step - loss: 0.2786 - accuracy: 0.8809 - val_loss: 0.3003 - val_accuracy: 0.8675
# Epoch 42/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2805 - accuracy: 0.8822 - val_loss: 0.3148 - val_accuracy: 0.8591
# Epoch 43/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2895 - accuracy: 0.8756 - val_loss: 0.2999 - val_accuracy: 0.8678
# Epoch 44/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2828 - accuracy: 0.8775 - val_loss: 0.3032 - val_accuracy: 0.8712
# Epoch 45/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2802 - accuracy: 0.8819 - val_loss: 0.3047 - val_accuracy: 0.8656
# Epoch 46/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2796 - accuracy: 0.8803 - val_loss: 0.3018 - val_accuracy: 0.8681
# Epoch 47/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2700 - accuracy: 0.8855 - val_loss: 0.2977 - val_accuracy: 0.8687
# Epoch 48/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2808 - accuracy: 0.8782 - val_loss: 0.2919 - val_accuracy: 0.8706
# Epoch 49/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2691 - accuracy: 0.8883 - val_loss: 0.3035 - val_accuracy: 0.8691
# Epoch 50/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2721 - accuracy: 0.8827 - val_loss: 0.2877 - val_accuracy: 0.8750
# Epoch 51/100
# 400/400 [==============================] - 6s 14ms/step - loss: 0.2685 - accuracy: 0.8873 - val_loss: 0.2969 - val_accuracy: 0.8703
# Epoch 52/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2607 - accuracy: 0.8871 - val_loss: 0.2898 - val_accuracy: 0.8737
# Epoch 53/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2623 - accuracy: 0.8867 - val_loss: 0.2960 - val_accuracy: 0.8737
# Epoch 54/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2683 - accuracy: 0.8855 - val_loss: 0.2869 - val_accuracy: 0.8797
# Epoch 55/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2607 - accuracy: 0.8921 - val_loss: 0.2860 - val_accuracy: 0.8750
# Epoch 56/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2571 - accuracy: 0.8914 - val_loss: 0.3022 - val_accuracy: 0.8703
# Epoch 57/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2583 - accuracy: 0.8904 - val_loss: 0.2964 - val_accuracy: 0.8669
# Epoch 58/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2558 - accuracy: 0.8935 - val_loss: 0.2929 - val_accuracy: 0.8703
# Epoch 59/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2571 - accuracy: 0.8917 - val_loss: 0.2877 - val_accuracy: 0.8813
# Epoch 60/100
# 400/400 [==============================] - 5s 11ms/step - loss: 0.2506 - accuracy: 0.8922 - val_loss: 0.3028 - val_accuracy: 0.8687
# Epoch 61/100
# 400/400 [==============================] - 6s 15ms/step - loss: 0.2602 - accuracy: 0.8912 - val_loss: 0.2843 - val_accuracy: 0.8838
# Epoch 62/100
# 400/400 [==============================] - 7s 17ms/step - loss: 0.2485 - accuracy: 0.8936 - val_loss: 0.2954 - val_accuracy: 0.8763
# Epoch 63/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2544 - accuracy: 0.8914 - val_loss: 0.2788 - val_accuracy: 0.8831
# Epoch 64/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2518 - accuracy: 0.8973 - val_loss: 0.2768 - val_accuracy: 0.8844
# Epoch 65/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2381 - accuracy: 0.9007 - val_loss: 0.2786 - val_accuracy: 0.8869
# Epoch 66/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2404 - accuracy: 0.8976 - val_loss: 0.2871 - val_accuracy: 0.8794
# Epoch 67/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2370 - accuracy: 0.9006 - val_loss: 0.2868 - val_accuracy: 0.8825
# Epoch 68/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2341 - accuracy: 0.9049 - val_loss: 0.2909 - val_accuracy: 0.8863
# Epoch 69/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2411 - accuracy: 0.8949 - val_loss: 0.2864 - val_accuracy: 0.8872
# Epoch 70/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2427 - accuracy: 0.9005 - val_loss: 0.2758 - val_accuracy: 0.8903
# Epoch 71/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2287 - accuracy: 0.9029 - val_loss: 0.2764 - val_accuracy: 0.8875
# Epoch 72/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2424 - accuracy: 0.8996 - val_loss: 0.2866 - val_accuracy: 0.8859
# Epoch 73/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2267 - accuracy: 0.9056 - val_loss: 0.2796 - val_accuracy: 0.8916
# Epoch 74/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2295 - accuracy: 0.9056 - val_loss: 0.2799 - val_accuracy: 0.8875
# Epoch 75/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2355 - accuracy: 0.9010 - val_loss: 0.2748 - val_accuracy: 0.8900
# Epoch 76/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2256 - accuracy: 0.9065 - val_loss: 0.2783 - val_accuracy: 0.8922
# Epoch 77/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2244 - accuracy: 0.9035 - val_loss: 0.2759 - val_accuracy: 0.8894
# Epoch 78/100
# 400/400 [==============================] - 6s 14ms/step - loss: 0.2170 - accuracy: 0.9094 - val_loss: 0.2760 - val_accuracy: 0.8903
# Epoch 79/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2184 - accuracy: 0.9063 - val_loss: 0.2788 - val_accuracy: 0.8928
# Epoch 80/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2175 - accuracy: 0.9065 - val_loss: 0.2772 - val_accuracy: 0.8956
# Epoch 81/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2133 - accuracy: 0.9095 - val_loss: 0.2725 - val_accuracy: 0.8953
# Epoch 82/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2167 - accuracy: 0.9098 - val_loss: 0.2720 - val_accuracy: 0.8916
# Epoch 83/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2148 - accuracy: 0.9076 - val_loss: 0.2754 - val_accuracy: 0.8938
# Epoch 84/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2096 - accuracy: 0.9116 - val_loss: 0.2739 - val_accuracy: 0.8903
# Epoch 85/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2105 - accuracy: 0.9097 - val_loss: 0.2755 - val_accuracy: 0.8894
# Epoch 86/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2085 - accuracy: 0.9109 - val_loss: 0.2730 - val_accuracy: 0.8925
# Epoch 87/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2048 - accuracy: 0.9177 - val_loss: 0.2755 - val_accuracy: 0.8922
# Epoch 88/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2061 - accuracy: 0.9145 - val_loss: 0.2655 - val_accuracy: 0.8944
# Epoch 89/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.2077 - accuracy: 0.9154 - val_loss: 0.2678 - val_accuracy: 0.8984
# Epoch 90/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2004 - accuracy: 0.9139 - val_loss: 0.2783 - val_accuracy: 0.8956
# Epoch 91/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.2025 - accuracy: 0.9150 - val_loss: 0.2713 - val_accuracy: 0.8963
# Epoch 92/100
# 400/400 [==============================] - 6s 14ms/step - loss: 0.2018 - accuracy: 0.9168 - val_loss: 0.2688 - val_accuracy: 0.8981
# Epoch 93/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.1938 - accuracy: 0.9196 - val_loss: 0.2688 - val_accuracy: 0.8984
# Epoch 94/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.1964 - accuracy: 0.9191 - val_loss: 0.2760 - val_accuracy: 0.8969
# Epoch 95/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.1955 - accuracy: 0.9214 - val_loss: 0.2721 - val_accuracy: 0.8947
# Epoch 96/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.1868 - accuracy: 0.9235 - val_loss: 0.2793 - val_accuracy: 0.8919
# Epoch 97/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.1858 - accuracy: 0.9252 - val_loss: 0.2737 - val_accuracy: 0.8956
# Epoch 98/100
# 400/400 [==============================] - 5s 13ms/step - loss: 0.1859 - accuracy: 0.9213 - val_loss: 0.2762 - val_accuracy: 0.8959
# Epoch 99/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.1822 - accuracy: 0.9222 - val_loss: 0.2732 - val_accuracy: 0.8969
# Epoch 100/100
# 400/400 [==============================] - 5s 12ms/step - loss: 0.1830 - accuracy: 0.9231 - val_loss: 0.2711 - val_accuracy: 0.8972
# Fold 5, 100 epochs, 497 sec
# INFO:tensorflow:Assets written to: data/LastModel-Wen/assets

# %% [markdown]
# ## Test the neural network

# %%
def show_test_AUC(model,X,y):
    ns_probs = [0 for _ in range(len(y))]
    bm_probs = model.predict(X)
    ns_auc = roc_auc_score(y, ns_probs)
    bm_auc = roc_auc_score(y, bm_probs)
    ns_fpr, ns_tpr, _ = roc_curve(y, ns_probs)
    bm_fpr, bm_tpr, _ = roc_curve(y, bm_probs)
    plt.plot(ns_fpr, ns_tpr, linestyle='--', label='Guess, auc=%.4f'%ns_auc)
    plt.plot(bm_fpr, bm_tpr, marker='.', label='Model, auc=%.4f'%bm_auc)
    plt.title('ROC')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()
    plt.show()
    print("%s: %.2f%%" %('AUC',bm_auc*100.0))
def show_test_accuracy(model,X,y):
    scores = model.evaluate(X, y, verbose=0)
    print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))

# %%
print("Accuracy on test data.")
print("Prepare...")
show_time()
Xseq,y=prepare_x_and_y(pc_test,nc_test)
print("Extract K-mer features...")
show_time()
Xfrq=seqs_to_kmer_freqs(Xseq,MAX_K)
Xfrq2D = reshape(Xfrq)
print("Plot...")
show_time()
show_test_AUC(last_model,Xfrq2D,y)
show_test_accuracy(last_model,Xfrq2D,y)
show_time()
# Out:
# Accuracy on test data.
# Prepare...
# 2021-08-12 06:31:43 EDT
# Extract K-mer features...
# 2021-08-12 06:31:43 EDT
# Plot...
# 2021-08-12 06:31:47 EDT
# AUC: 93.72%
# accuracy: 87.25%
# 2021-08-12 06:31:49 EDT
