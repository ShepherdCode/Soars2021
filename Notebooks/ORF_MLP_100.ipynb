# %% [markdown]
# # ORF recognition by MLP
#
# Use variable number of bases between START and STOP. Thus, ncRNA will have its STOP out-of-frame or too close to the START, and pcRNA will have its STOP in-frame and far from the START.

# %%
import time 
t = time.time()
time.strftime('%Y-%m-%d %H:%M:%S %Z', time.localtime(t))
# Out:
# '2021-06-17 15:36:57 EDT'

# %%
PC_SEQUENCES=32000   # how many protein-coding sequences
NC_SEQUENCES=32000   # how many non-coding sequences
PC_TESTS=1000
NC_TESTS=1000
RNA_LEN=36            # how long is each sequence
CDS_LEN=18            # min CDS len to be coding
ALPHABET=4          # how many different letters are possible
INPUT_SHAPE_2D = (RNA_LEN,ALPHABET,1) # Conv2D needs 3D inputs
INPUT_SHAPE = (RNA_LEN,ALPHABET) # Conv1D needs 2D inputs
INPUT_SHAPE = (None,RNA_LEN,ALPHABET) # MLP inputs
FILTERS = 16   # how many different patterns the model looks for
NEURONS = 16
DROP_RATE = 0.4
WIDTH = 3   # how wide each pattern is, in bases
STRIDE_2D = (1,1)  # For Conv2D how far in each direction
STRIDE = 1 # For Conv1D, how far between pattern matches, in bases
EPOCHS=100  # how many times to train on all the data
SPLITS=3  # SPLITS=3 means train on 2/3 and validate on 1/3 
FOLDS=3  # train the model this many times (range 1 to SPLITS)

# %%
import sys
try:
    from google.colab import drive
    IN_COLAB = True
    print("On Google CoLab, mount cloud-local file, get our code from GitHub.")
    PATH='/content/drive/'
    #drive.mount(PATH,force_remount=True)  # hardly ever need this
    #drive.mount(PATH)    # Google will require login credentials
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/RNA_gen.py')
    with open('RNA_gen.py', 'w') as f:
        f.write(r.text)  
    from RNA_gen import *
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/RNA_describe.py')
    with open('RNA_describe.py', 'w') as f:
        f.write(r.text)  
    from RNA_describe import ORF_counter
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/RNA_prep.py')
    with open('RNA_prep.py', 'w') as f:
        f.write(r.text)  
    from RNA_prep import *
except:
    print("CoLab not working. On my PC, use relative paths.")
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"
    sys.path.append("..") # append parent dir in order to use sibling dirs
    from SimTools.RNA_gen import *
    from SimTools.RNA_describe import ORF_counter
    from SimTools.RNA_prep import *

MODELPATH="BestModel"  # saved on cloud instance and lost after logout
#MODELPATH=DATAPATH+MODELPATH  # saved on Google Drive but requires login

if not assert_imported_RNA_gen():
    print("ERROR: Cannot use RNA_gen.")
if not assert_imported_RNA_prep():
    print("ERROR: Cannot use RNA_prep.")
# Out:
# CoLab not working. On my PC, use relative paths.

# %%
from os import listdir
import csv
from zipfile import ZipFile

import numpy as np
import pandas as pd
from scipy import stats  # mode

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

from keras.models import Sequential
from keras.layers import Dense,Embedding,Dropout
from keras.layers import Conv1D,Conv2D
from keras.layers import Flatten,MaxPooling1D,MaxPooling2D
from keras.losses import BinaryCrossentropy
# tf.keras.losses.BinaryCrossentropy

import matplotlib.pyplot as plt
from matplotlib import colors
mycmap = colors.ListedColormap(['red','blue'])  # list color for label 0 then 1
np.set_printoptions(precision=2)

# %%
import random
def partition_random_sequences(goal_per_class):
    pc_seqs=[]
    nc_seqs=[]
    oc = ORF_counter()
    trials = 0
    pc_cnt = 0
    nc_cnt = 0
    bases=['A','C','G','T']
    while pc_cnt<goal_per_class or nc_cnt<goal_per_class:
        trials += 1        
        between_bases = random.randint(0,RNA_LEN-6) 
        utr5_bases = (RNA_LEN - (between_bases + 6)) // 2
        utr3_bases = RNA_LEN - (utr5_bases + (between_bases+6))
        one_seq  = "".join(random.choices(bases,k=utr5_bases)) 
        one_seq += 'ATG'    
        one_seq += "".join(random.choices(bases,k=between_bases)) 
        random_stop = random.choice(['TAA','TAG','TGA']) # random frame
        one_seq += random_stop
        one_seq += "".join(random.choices(bases,k=utr3_bases))  
        if len(one_seq) != RNA_LEN:
            print("WRONG LENGTH:",len(one_seq),utr5_bases,between_bases,utr3_bases)
        oc.set_sequence(one_seq)
        cds_len = oc.get_max_cds_len() + 3
        if cds_len >= CDS_LEN and pc_cnt<goal_per_class:
            pc_cnt += 1
            pc_seqs.append(one_seq)
        elif cds_len < CDS_LEN and nc_cnt<goal_per_class:
            nc_cnt += 1
            nc_seqs.append(one_seq)
    print ("It took %d trials to reach %d per class."%(trials,goal_per_class))
    return pc_seqs,nc_seqs
pc_all,nc_all=partition_random_sequences(10)  # just testing
pc_all,nc_all=partition_random_sequences(PC_SEQUENCES+PC_TESTS)
print("Use",len(pc_all),"PC seqs")
print("Use",len(nc_all),"NC seqs")
# Out:
# It took 28 trials to reach 10 per class.
# It took 92875 trials to reach 33000 per class.
# Use 33000 PC seqs
# Use 33000 NC seqs

# %%
# Describe the sequences
def describe_sequences(list_of_seq):
    oc = ORF_counter()
    num_seq = len(list_of_seq)
    rna_lens = np.zeros(num_seq)
    orf_lens = np.zeros(num_seq)
    for i in range(0,num_seq):
        rna_len = len(list_of_seq[i])
        rna_lens[i] = rna_len
        oc.set_sequence(list_of_seq[i])
        orf_len = oc.get_max_orf_len()
        orf_lens[i] = orf_len
    print ("Average RNA length:",rna_lens.mean())
    print ("Average ORF length:",orf_lens.mean())
    
print("Simulated sequences prior to adjustment:")
print("PC seqs")
describe_sequences(pc_all)
print("NC seqs")
describe_sequences(nc_all)
# Out:
# Simulated sequences prior to adjustment:
# PC seqs
# Average RNA length: 36.0
# Average ORF length: 19.98190909090909
# NC seqs
# Average RNA length: 36.0
# Average ORF length: 2.0045454545454544

# %%
pc_train=pc_all[:PC_SEQUENCES]
nc_train=nc_all[:NC_SEQUENCES]
pc_test=pc_all[PC_SEQUENCES:]
nc_test=nc_all[NC_SEQUENCES:]

# %%
# Use code from our SimTools library.
X,y = prepare_inputs_len_x_alphabet(pc_train,nc_train,ALPHABET) # shuffles
print("Data ready.")
# Out:
# Data ready.

# %%
def make_DNN():
    print("make_DNN")
    print("input shape:",INPUT_SHAPE)
    dnn = Sequential()
    #dnn.add(Embedding(input_dim=INPUT_SHAPE,output_dim=INPUT_SHAPE)) 
    #dnn.add(Conv1D(filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,padding="same",
    #        input_shape=INPUT_SHAPE))
    #dnn.add(Conv1D(filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,padding="same"))
    #dnn.add(MaxPooling1D())
    #dnn.add(Conv1D(filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,padding="same"))
    #dnn.add(Conv1D(filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,padding="same"))
    #dnn.add(MaxPooling1D())
    #dnn.add(Flatten())
    dnn.add(Dense(NEURONS,activation="sigmoid",dtype=np.float32))   
    dnn.add(Dense(NEURONS,activation="sigmoid",dtype=np.float32))   
    dnn.add(Dense(NEURONS,activation="sigmoid",dtype=np.float32))   
    dnn.add(Dropout(DROP_RATE))
    dnn.add(Dense(1,activation="sigmoid",dtype=np.float32))   
    dnn.compile(optimizer='adam',
                loss=BinaryCrossentropy(from_logits=False),
                metrics=['accuracy'])   # add to default metrics=loss
    dnn.build(input_shape=INPUT_SHAPE)
    #ln_rate = tf.keras.optimizers.Adam(learning_rate = LN_RATE)
    #bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    #model.compile(loss=bc, optimizer=ln_rate, metrics=["accuracy"])
    return dnn
model = make_DNN()
print(model.summary())
# Out:
# make_DNN
# input shape: (None, 36, 4)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 36, 16)            80
# _________________________________________________________________
# dense_1 (Dense)              (None, 36, 16)            272
# _________________________________________________________________
# dense_2 (Dense)              (None, 36, 16)            272
# _________________________________________________________________
# dropout (Dropout)            (None, 36, 16)            0
# _________________________________________________________________
# dense_3 (Dense)              (None, 36, 1)             17
# =================================================================
# Total params: 641
# Trainable params: 641
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from keras.callbacks import ModelCheckpoint
def do_cross_validation(X,y):
    cv_scores = []
    fold=0
    mycallbacks = [ModelCheckpoint(
        filepath=MODELPATH, save_best_only=True, 
        monitor='val_accuracy', mode='max')]   
    splitter = KFold(n_splits=SPLITS)  # this does not shuffle
    for train_index,valid_index in splitter.split(X):
        if fold < FOLDS:
            fold += 1
            X_train=X[train_index] # inputs for training
            y_train=y[train_index] # labels for training
            X_valid=X[valid_index] # inputs for validation
            y_valid=y[valid_index] # labels for validation
            print("MODEL")
            # Call constructor on each CV. Else, continually improves the same model.
            model = model = make_DNN()
            print("FIT")  # model.fit() implements learning
            start_time=time.time()
            history=model.fit(X_train, y_train, 
                    epochs=EPOCHS, 
                    verbose=1,  # ascii art while learning
                    callbacks=mycallbacks,   # called at end of each epoch
                    validation_data=(X_valid,y_valid))
            end_time=time.time()
            elapsed_time=(end_time-start_time)                        
            print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
            # print(history.history.keys())  # all these keys will be shown in figure
            pd.DataFrame(history.history).plot(figsize=(8,5))
            plt.grid(True)
            plt.gca().set_ylim(0,1) # any losses > 1 will be off the scale
            plt.show()

# %%
do_cross_validation(X,y)
# Out:
# MODEL
# make_DNN
# input shape: (None, 36, 4)
# FIT
# Epoch 1/100
# 1334/1334 [==============================] - 7s 4ms/step - loss: 0.7242 - accuracy: 0.5020 - val_loss: 0.6931 - val_accuracy: 0.5040
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 2/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6941 - accuracy: 0.5001 - val_loss: 0.6934 - val_accuracy: 0.4960
# Epoch 3/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6934 - accuracy: 0.5010 - val_loss: 0.6931 - val_accuracy: 0.5040
# Epoch 4/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6933 - accuracy: 0.4996 - val_loss: 0.6933 - val_accuracy: 0.4960
# Epoch 5/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5020 - val_loss: 0.6932 - val_accuracy: 0.4960
# Epoch 6/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5027 - val_loss: 0.6931 - val_accuracy: 0.5040
# Epoch 7/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.4995 - val_loss: 0.6932 - val_accuracy: 0.4960
# Epoch 8/100
# 1334/1334 [==============================] - 5s 3ms/step - loss: 0.6931 - accuracy: 0.5032 - val_loss: 0.6933 - val_accuracy: 0.4960
# Epoch 9/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.4988 - val_loss: 0.6932 - val_accuracy: 0.4960
# Epoch 10/100
# 1334/1334 [==============================] - 5s 3ms/step - loss: 0.6932 - accuracy: 0.4980 - val_loss: 0.6931 - val_accuracy: 0.5040
# Epoch 11/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.4989 - val_loss: 0.6931 - val_accuracy: 0.5040
# Epoch 12/100
# 1334/1334 [==============================] - 5s 3ms/step - loss: 0.6932 - accuracy: 0.5014 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 13/100
# 1334/1334 [==============================] - 5s 3ms/step - loss: 0.6932 - accuracy: 0.5002 - val_loss: 0.6932 - val_accuracy: 0.4960
# Epoch 14/100
# 1334/1334 [==============================] - 5s 3ms/step - loss: 0.6932 - accuracy: 0.4967 - val_loss: 0.6934 - val_accuracy: 0.4960
# Epoch 15/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.5021 - val_loss: 0.6931 - val_accuracy: 0.5040
# Epoch 16/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.4985 - val_loss: 0.6932 - val_accuracy: 0.4960
# Epoch 17/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.4990 - val_loss: 0.6932 - val_accuracy: 0.4960
# Epoch 18/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6931 - accuracy: 0.5039 - val_loss: 0.6931 - val_accuracy: 0.5040
# Epoch 19/100
# 1334/1334 [==============================] - 5s 3ms/step - loss: 0.6931 - accuracy: 0.5041 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 20/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 21/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5032 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 22/100
# 1334/1334 [==============================] - 5s 3ms/step - loss: 0.6932 - accuracy: 0.4996 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 23/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5043 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 24/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.4999 - val_loss: 0.6935 - val_accuracy: 0.4960
# Epoch 25/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6933 - accuracy: 0.4991 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 26/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5012 - val_loss: 0.6934 - val_accuracy: 0.4960
# Epoch 27/100
# 1334/1334 [==============================] - 6s 4ms/step - loss: 0.6931 - accuracy: 0.5034 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 28/100
# 1334/1334 [==============================] - 6s 5ms/step - loss: 0.6931 - accuracy: 0.5018 - val_loss: 0.6933 - val_accuracy: 0.4960
# Epoch 29/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5027 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 30/100
# 1334/1334 [==============================] - 6s 5ms/step - loss: 0.6931 - accuracy: 0.5047 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 31/100
# 1334/1334 [==============================] - 9s 7ms/step - loss: 0.6931 - accuracy: 0.5062 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 32/100
# 1334/1334 [==============================] - 9s 6ms/step - loss: 0.6931 - accuracy: 0.5047 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 33/100
# 1334/1334 [==============================] - 7s 5ms/step - loss: 0.6931 - accuracy: 0.5046 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 34/100
# 1334/1334 [==============================] - 7s 6ms/step - loss: 0.6931 - accuracy: 0.5054 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 35/100
# 1334/1334 [==============================] - 9s 6ms/step - loss: 0.6931 - accuracy: 0.5030 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 36/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5024 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 37/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5047 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 38/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5044 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 39/100
# 1334/1334 [==============================] - 7s 5ms/step - loss: 0.6932 - accuracy: 0.4987 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 40/100
# 1334/1334 [==============================] - 6s 4ms/step - loss: 0.6932 - accuracy: 0.5005 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 41/100
# 1334/1334 [==============================] - 6s 4ms/step - loss: 0.6931 - accuracy: 0.5021 - val_loss: 0.6933 - val_accuracy: 0.4960
# Epoch 42/100
# 1334/1334 [==============================] - 6s 5ms/step - loss: 0.6932 - accuracy: 0.4999 - val_loss: 0.6933 - val_accuracy: 0.5009
# Epoch 43/100
# 1334/1334 [==============================] - 6s 4ms/step - loss: 0.6931 - accuracy: 0.5037 - val_loss: 0.6931 - val_accuracy: 0.5041
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 44/100
# 1334/1334 [==============================] - 6s 5ms/step - loss: 0.6932 - accuracy: 0.5003 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 45/100
# 1334/1334 [==============================] - 7s 5ms/step - loss: 0.6932 - accuracy: 0.5028 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 46/100
# 1334/1334 [==============================] - 6s 4ms/step - loss: 0.6931 - accuracy: 0.5048 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 47/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5053 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 48/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.5023 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 49/100
# 1334/1334 [==============================] - 6s 5ms/step - loss: 0.6931 - accuracy: 0.5035 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 50/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5003 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 51/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5044 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 52/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5052 - val_loss: 0.6931 - val_accuracy: 0.5040
# Epoch 53/100
# 1334/1334 [==============================] - 6s 4ms/step - loss: 0.6931 - accuracy: 0.5017 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 54/100
# 1334/1334 [==============================] - 5s 3ms/step - loss: 0.6931 - accuracy: 0.5032 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 55/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5073 - val_loss: 0.6931 - val_accuracy: 0.5040
# Epoch 56/100
# 1334/1334 [==============================] - 6s 5ms/step - loss: 0.6932 - accuracy: 0.5013 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 57/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 58/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6931 - accuracy: 0.5025 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 59/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6931 - accuracy: 0.5045 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 60/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.5003 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 61/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6931 - accuracy: 0.5060 - val_loss: 0.6931 - val_accuracy: 0.5040
# Epoch 62/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.5020 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 63/100
# 1334/1334 [==============================] - 5s 3ms/step - loss: 0.6931 - accuracy: 0.5081 - val_loss: 0.6931 - val_accuracy: 0.5041
# Epoch 64/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.5049 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 65/100
# 1334/1334 [==============================] - 6s 4ms/step - loss: 0.6931 - accuracy: 0.5054 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 66/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6931 - accuracy: 0.5061 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 67/100
# 1334/1334 [==============================] - 7s 5ms/step - loss: 0.6931 - accuracy: 0.5036 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 68/100
# 1334/1334 [==============================] - 6s 5ms/step - loss: 0.6931 - accuracy: 0.5041 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 69/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5039 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 70/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6931 - accuracy: 0.5049 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 71/100
# 1334/1334 [==============================] - 5s 3ms/step - loss: 0.6931 - accuracy: 0.5053 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 72/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5020 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 73/100
# 1334/1334 [==============================] - 5s 3ms/step - loss: 0.6931 - accuracy: 0.5041 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 74/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5062 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 75/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5037 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 76/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5033 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 77/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5048 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 78/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5030 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 79/100
# 1334/1334 [==============================] - 5s 3ms/step - loss: 0.6931 - accuracy: 0.5037 - val_loss: 0.6933 - val_accuracy: 0.5009
# Epoch 80/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5051 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 81/100
# 1334/1334 [==============================] - 6s 5ms/step - loss: 0.6931 - accuracy: 0.5034 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 82/100
# 1334/1334 [==============================] - 5s 3ms/step - loss: 0.6931 - accuracy: 0.5016 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 83/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5040 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 84/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5064 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 85/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.5039 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 86/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5034 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 87/100
# 1334/1334 [==============================] - 6s 5ms/step - loss: 0.6931 - accuracy: 0.5056 - val_loss: 0.6931 - val_accuracy: 0.5040
# Epoch 88/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6931 - accuracy: 0.5002 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 89/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5056 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 90/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5024 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 91/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6931 - accuracy: 0.5040 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 92/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.5020 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 93/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5029 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 94/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.5036 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 95/100
# 1334/1334 [==============================] - 6s 4ms/step - loss: 0.6931 - accuracy: 0.5053 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 96/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6931 - accuracy: 0.5017 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 97/100
# 1334/1334 [==============================] - 5s 3ms/step - loss: 0.6931 - accuracy: 0.5063 - val_loss: 0.6931 - val_accuracy: 0.5009
# Epoch 98/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6931 - accuracy: 0.4993 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 99/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6931 - accuracy: 0.5057 - val_loss: 0.6932 - val_accuracy: 0.5009
# Epoch 100/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6931 - accuracy: 0.5058 - val_loss: 0.6932 - val_accuracy: 0.5009
# Fold 1, 100 epochs, 519 sec
# MODEL
# make_DNN
# input shape: (None, 36, 4)
# FIT
# Epoch 1/100
# 1334/1334 [==============================] - 6s 4ms/step - loss: 0.7065 - accuracy: 0.5006 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 2/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6936 - accuracy: 0.5028 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 3/100
# 1334/1334 [==============================] - 6s 5ms/step - loss: 0.6934 - accuracy: 0.5003 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 4/100
# 1334/1334 [==============================] - 8s 6ms/step - loss: 0.6933 - accuracy: 0.4977 - val_loss: 0.6935 - val_accuracy: 0.4948
# Epoch 5/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6933 - accuracy: 0.5001 - val_loss: 0.6934 - val_accuracy: 0.4948
# Epoch 6/100
# 1334/1334 [==============================] - 5s 3ms/step - loss: 0.6932 - accuracy: 0.4987 - val_loss: 0.6933 - val_accuracy: 0.4948
# Epoch 7/100
# 1334/1334 [==============================] - 5s 3ms/step - loss: 0.6932 - accuracy: 0.4987 - val_loss: 0.6935 - val_accuracy: 0.4948
# Epoch 8/100
# 1334/1334 [==============================] - 6s 4ms/step - loss: 0.6932 - accuracy: 0.5013 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 9/100
# 1334/1334 [==============================] - 6s 4ms/step - loss: 0.6931 - accuracy: 0.5065 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 10/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5004 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 11/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5005 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 12/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.4980 - val_loss: 0.6933 - val_accuracy: 0.4948
# Epoch 13/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.4987 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 14/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.4968 - val_loss: 0.6933 - val_accuracy: 0.4948
# Epoch 15/100
# 1334/1334 [==============================] - 6s 4ms/step - loss: 0.6932 - accuracy: 0.5025 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 16/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6931 - accuracy: 0.5037 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 17/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5005 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 18/100
# 1334/1334 [==============================] - 5s 3ms/step - loss: 0.6932 - accuracy: 0.4988 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 19/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.4981 - val_loss: 0.6935 - val_accuracy: 0.4948
# Epoch 20/100
# 1334/1334 [==============================] - 5s 3ms/step - loss: 0.6931 - accuracy: 0.5058 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 21/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5044 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 22/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5039 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 23/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.4918 - val_loss: 0.6934 - val_accuracy: 0.4948
# Epoch 24/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6930 - accuracy: 0.5085 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 25/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.4991 - val_loss: 0.6934 - val_accuracy: 0.4948
# Epoch 26/100
# 1334/1334 [==============================] - 6s 4ms/step - loss: 0.6932 - accuracy: 0.5036 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 27/100
# 1334/1334 [==============================] - 7s 5ms/step - loss: 0.6932 - accuracy: 0.5024 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 28/100
# 1334/1334 [==============================] - 6s 4ms/step - loss: 0.6932 - accuracy: 0.4994 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 29/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.4995 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 30/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5007 - val_loss: 0.6931 - val_accuracy: 0.5052
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 31/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5009 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 32/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.5020 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 33/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.4981 - val_loss: 0.6933 - val_accuracy: 0.4948
# Epoch 34/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.4987 - val_loss: 0.6933 - val_accuracy: 0.4948
# Epoch 35/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.5013 - val_loss: 0.6933 - val_accuracy: 0.4948
# Epoch 36/100
# 1334/1334 [==============================] - 6s 4ms/step - loss: 0.6932 - accuracy: 0.5008 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 37/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.4983 - val_loss: 0.6933 - val_accuracy: 0.4948
# Epoch 38/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5020 - val_loss: 0.6933 - val_accuracy: 0.4948
# Epoch 39/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6931 - accuracy: 0.5047 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 40/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.5012 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 41/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.4994 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 42/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.4956 - val_loss: 0.6933 - val_accuracy: 0.4948
# Epoch 43/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.5023 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 44/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6931 - accuracy: 0.5035 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 45/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.5027 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 46/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.4988 - val_loss: 0.6933 - val_accuracy: 0.4948
# Epoch 47/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6931 - accuracy: 0.5028 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 48/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.5024 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 49/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.4937 - val_loss: 0.6933 - val_accuracy: 0.4948
# Epoch 50/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.5007 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 51/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.5034 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 52/100
# 1334/1334 [==============================] - 6s 4ms/step - loss: 0.6932 - accuracy: 0.4990 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 53/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.4956 - val_loss: 0.6933 - val_accuracy: 0.4948
# Epoch 54/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.5005 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 55/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.5021 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 56/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.5003 - val_loss: 0.6934 - val_accuracy: 0.4948
# Epoch 57/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6933 - accuracy: 0.4930 - val_loss: 0.6935 - val_accuracy: 0.4948
# Epoch 58/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6930 - accuracy: 0.5076 - val_loss: 0.6931 - val_accuracy: 0.5052
# Epoch 59/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.5010 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 60/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6931 - accuracy: 0.5020 - val_loss: 0.6931 - val_accuracy: 0.5072
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 61/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.5022 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 62/100
# 1334/1334 [==============================] - 5s 3ms/step - loss: 0.6932 - accuracy: 0.4995 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 63/100
# 1334/1334 [==============================] - 5s 3ms/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 64/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6931 - accuracy: 0.5027 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 65/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5006 - val_loss: 0.6933 - val_accuracy: 0.4948
# Epoch 66/100
# 1334/1334 [==============================] - 6s 4ms/step - loss: 0.6931 - accuracy: 0.5060 - val_loss: 0.6931 - val_accuracy: 0.5072
# Epoch 67/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5017 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 68/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6931 - accuracy: 0.5021 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 69/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6931 - accuracy: 0.5020 - val_loss: 0.6933 - val_accuracy: 0.4948
# Epoch 70/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6931 - accuracy: 0.5035 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 71/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5027 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 72/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5009 - val_loss: 0.6933 - val_accuracy: 0.4948
# Epoch 73/100
# 1334/1334 [==============================] - 6s 4ms/step - loss: 0.6931 - accuracy: 0.5033 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 74/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5017 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 75/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.4998 - val_loss: 0.6934 - val_accuracy: 0.4948
# Epoch 76/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5015 - val_loss: 0.6933 - val_accuracy: 0.4948
# Epoch 77/100
# 1334/1334 [==============================] - 6s 4ms/step - loss: 0.6932 - accuracy: 0.5018 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 78/100
# 1334/1334 [==============================] - 7s 5ms/step - loss: 0.6932 - accuracy: 0.4996 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 79/100
# 1334/1334 [==============================] - 7s 5ms/step - loss: 0.6932 - accuracy: 0.4995 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 80/100
# 1334/1334 [==============================] - 6s 4ms/step - loss: 0.6931 - accuracy: 0.5030 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 81/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5012 - val_loss: 0.6934 - val_accuracy: 0.4948
# Epoch 82/100
# 1334/1334 [==============================] - 5s 3ms/step - loss: 0.6932 - accuracy: 0.5016 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 83/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5026 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 84/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.4991 - val_loss: 0.6933 - val_accuracy: 0.4948
# Epoch 85/100
# 1334/1334 [==============================] - 5s 3ms/step - loss: 0.6932 - accuracy: 0.5025 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 86/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5023 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 87/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5029 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 88/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5008 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 89/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5064 - val_loss: 0.6931 - val_accuracy: 0.5072
# Epoch 90/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5018 - val_loss: 0.6931 - val_accuracy: 0.5072
# Epoch 91/100
# 1334/1334 [==============================] - 5s 3ms/step - loss: 0.6932 - accuracy: 0.5014 - val_loss: 0.6933 - val_accuracy: 0.4948
# Epoch 92/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5035 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 93/100
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.6932 - accuracy: 0.4998 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 94/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5007 - val_loss: 0.6931 - val_accuracy: 0.5035
# Epoch 95/100
# 1334/1334 [==============================] - 5s 3ms/step - loss: 0.6931 - accuracy: 0.5021 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 96/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5017 - val_loss: 0.6932 - val_accuracy: 0.4948
# Epoch 97/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5041 - val_loss: 0.6931 - val_accuracy: 0.5035
# Epoch 98/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5010 - val_loss: 0.6933 - val_accuracy: 0.4948
# Epoch 99/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5018 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 100/100
# 1334/1334 [==============================] - 5s 3ms/step - loss: 0.6932 - accuracy: 0.5012 - val_loss: 0.6932 - val_accuracy: 0.4948
# Fold 2, 100 epochs, 485 sec
# MODEL
# make_DNN
# input shape: (None, 36, 4)
# FIT
# Epoch 1/100
# 1334/1334 [==============================] - 6s 4ms/step - loss: 0.7047 - accuracy: 0.5010 - val_loss: 0.6932 - val_accuracy: 0.5012
# Epoch 2/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6938 - accuracy: 0.4990 - val_loss: 0.6932 - val_accuracy: 0.5012
# Epoch 3/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6933 - accuracy: 0.5015 - val_loss: 0.6932 - val_accuracy: 0.4988
# Epoch 4/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6933 - accuracy: 0.4973 - val_loss: 0.6932 - val_accuracy: 0.4988
# Epoch 5/100
# 1334/1334 [==============================] - 5s 3ms/step - loss: 0.6931 - accuracy: 0.5053 - val_loss: 0.6931 - val_accuracy: 0.5012
# Epoch 6/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.4989 - val_loss: 0.6931 - val_accuracy: 0.5012
# Epoch 7/100
# 1334/1334 [==============================] - 5s 3ms/step - loss: 0.6932 - accuracy: 0.4963 - val_loss: 0.6932 - val_accuracy: 0.4988
# Epoch 8/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.4984 - val_loss: 0.6932 - val_accuracy: 0.4988
# Epoch 9/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6931 - val_accuracy: 0.5012
# Epoch 10/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.4995 - val_loss: 0.6932 - val_accuracy: 0.4988
# Epoch 11/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.4977 - val_loss: 0.6931 - val_accuracy: 0.5012
# Epoch 12/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.4992 - val_loss: 0.6932 - val_accuracy: 0.5012
# Epoch 13/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.4989 - val_loss: 0.6931 - val_accuracy: 0.4988
# Epoch 14/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.4984 - val_loss: 0.6932 - val_accuracy: 0.4988
# Epoch 15/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5039 - val_loss: 0.6931 - val_accuracy: 0.5012
# Epoch 16/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.4971 - val_loss: 0.6932 - val_accuracy: 0.4988
# Epoch 17/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.4966 - val_loss: 0.6931 - val_accuracy: 0.5012
# Epoch 18/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5021 - val_loss: 0.6931 - val_accuracy: 0.5012
# Epoch 19/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5049 - val_loss: 0.6931 - val_accuracy: 0.4988
# Epoch 20/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5010 - val_loss: 0.6932 - val_accuracy: 0.4988
# Epoch 21/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.4957 - val_loss: 0.6932 - val_accuracy: 0.4988
# Epoch 22/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.4980 - val_loss: 0.6931 - val_accuracy: 0.5012
# Epoch 23/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.4979 - val_loss: 0.6932 - val_accuracy: 0.4988
# Epoch 24/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5015 - val_loss: 0.6931 - val_accuracy: 0.5012
# Epoch 25/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5001 - val_loss: 0.6931 - val_accuracy: 0.5012
# Epoch 26/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5034 - val_loss: 0.6932 - val_accuracy: 0.4988
# Epoch 27/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5021 - val_loss: 0.6932 - val_accuracy: 0.4988
# Epoch 28/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5012 - val_loss: 0.6931 - val_accuracy: 0.5012
# Epoch 29/100
# 1334/1334 [==============================] - 5s 3ms/step - loss: 0.6932 - accuracy: 0.4996 - val_loss: 0.6931 - val_accuracy: 0.5012
# Epoch 30/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.4952 - val_loss: 0.6932 - val_accuracy: 0.4988
# Epoch 31/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.4955 - val_loss: 0.6932 - val_accuracy: 0.4988
# Epoch 32/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.4930 - val_loss: 0.6932 - val_accuracy: 0.4988
# Epoch 33/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.4961 - val_loss: 0.6931 - val_accuracy: 0.5012
# Epoch 34/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5043 - val_loss: 0.6932 - val_accuracy: 0.4988
# Epoch 35/100
# 1334/1334 [==============================] - 6s 5ms/step - loss: 0.6932 - accuracy: 0.5014 - val_loss: 0.6932 - val_accuracy: 0.4988
# Epoch 36/100
# 1334/1334 [==============================] - 7s 5ms/step - loss: 0.6932 - accuracy: 0.4954 - val_loss: 0.6933 - val_accuracy: 0.4988
# Epoch 37/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5032 - val_loss: 0.6932 - val_accuracy: 0.4988
# Epoch 38/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5028 - val_loss: 0.6932 - val_accuracy: 0.4988
# Epoch 39/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5032 - val_loss: 0.6932 - val_accuracy: 0.4988
# Epoch 40/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6932 - accuracy: 0.5012 - val_loss: 0.6931 - val_accuracy: 0.5012
# Epoch 41/100
# 1334/1334 [==============================] - 5s 4ms/step - loss: 0.6931 - accuracy: 0.5056 - val_loss: 0.6932 - val_accuracy: 0.4988
# Epoch 42/100
# 1334/1334 [==============================] - 7s 5ms/step - loss: 0.6932 - accuracy: 0.5007 - val_loss: 0.6931 - val_accuracy: 0.5026
# Epoch 43/100
# 1334/1334 [==============================] - 8s 6ms/step - loss: 0.6932 - accuracy: 0.4997 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 44/100
# 1334/1334 [==============================] - 7s 5ms/step - loss: 0.6932 - accuracy: 0.4978 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 45/100
# 1334/1334 [==============================] - 9s 7ms/step - loss: 0.6931 - accuracy: 0.5013 - val_loss: 0.6931 - val_accuracy: 0.5012
# Epoch 46/100
# 1334/1334 [==============================] - 9s 7ms/step - loss: 0.6932 - accuracy: 0.5005 - val_loss: 0.6932 - val_accuracy: 0.4988
# Epoch 47/100
# 1334/1334 [==============================] - 16s 12ms/step - loss: 0.6932 - accuracy: 0.5001 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 48/100
# 1334/1334 [==============================] - 38s 29ms/step - loss: 0.6932 - accuracy: 0.5031 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 49/100
# 1334/1334 [==============================] - 32s 24ms/step - loss: 0.6932 - accuracy: 0.5058 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 50/100
# 1334/1334 [==============================] - 38s 29ms/step - loss: 0.6932 - accuracy: 0.5006 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 51/100
# 1334/1334 [==============================] - 28s 21ms/step - loss: 0.6932 - accuracy: 0.5002 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 52/100
# 1334/1334 [==============================] - 22s 16ms/step - loss: 0.6932 - accuracy: 0.5037 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 53/100
# 1334/1334 [==============================] - 25s 18ms/step - loss: 0.6931 - accuracy: 0.5019 - val_loss: 0.6932 - val_accuracy: 0.5022
# Epoch 54/100
# 1334/1334 [==============================] - 24s 18ms/step - loss: 0.6931 - accuracy: 0.5025 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 55/100
# 1334/1334 [==============================] - 25s 18ms/step - loss: 0.6932 - accuracy: 0.4976 - val_loss: 0.6932 - val_accuracy: 0.5022
# Epoch 56/100
# 1334/1334 [==============================] - 23s 17ms/step - loss: 0.6932 - accuracy: 0.5005 - val_loss: 0.6932 - val_accuracy: 0.5022
# Epoch 57/100
# 1334/1334 [==============================] - 22s 17ms/step - loss: 0.6931 - accuracy: 0.5049 - val_loss: 0.6932 - val_accuracy: 0.5012
# Epoch 58/100
# 1334/1334 [==============================] - 17s 13ms/step - loss: 0.6931 - accuracy: 0.4976 - val_loss: 0.6932 - val_accuracy: 0.5022
# Epoch 59/100
# 1334/1334 [==============================] - 28s 21ms/step - loss: 0.6931 - accuracy: 0.5027 - val_loss: 0.6932 - val_accuracy: 0.5022
# Epoch 60/100
# 1334/1334 [==============================] - 30s 22ms/step - loss: 0.6931 - accuracy: 0.5019 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 61/100
# 1334/1334 [==============================] - 15s 11ms/step - loss: 0.6932 - accuracy: 0.5036 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 62/100
# 1334/1334 [==============================] - 13s 10ms/step - loss: 0.6931 - accuracy: 0.5033 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 63/100
# 1334/1334 [==============================] - 13s 9ms/step - loss: 0.6932 - accuracy: 0.5005 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 64/100
# 1334/1334 [==============================] - 13s 9ms/step - loss: 0.6931 - accuracy: 0.5017 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 65/100
# 1334/1334 [==============================] - 12s 9ms/step - loss: 0.6932 - accuracy: 0.5036 - val_loss: 0.6932 - val_accuracy: 0.5022
# Epoch 66/100
# 1334/1334 [==============================] - 14s 11ms/step - loss: 0.6931 - accuracy: 0.5044 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 67/100
# 1334/1334 [==============================] - 13s 10ms/step - loss: 0.6931 - accuracy: 0.5012 - val_loss: 0.6932 - val_accuracy: 0.5022
# Epoch 68/100
# 1334/1334 [==============================] - 12s 9ms/step - loss: 0.6931 - accuracy: 0.5046 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 69/100
# 1334/1334 [==============================] - 14s 10ms/step - loss: 0.6931 - accuracy: 0.4990 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 70/100
# 1334/1334 [==============================] - 12s 9ms/step - loss: 0.6932 - accuracy: 0.5018 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 71/100
# 1334/1334 [==============================] - 11s 8ms/step - loss: 0.6931 - accuracy: 0.5019 - val_loss: 0.6932 - val_accuracy: 0.5022
# Epoch 72/100
# 1334/1334 [==============================] - 12s 9ms/step - loss: 0.6932 - accuracy: 0.4990 - val_loss: 0.6932 - val_accuracy: 0.5022
# Epoch 73/100
# 1334/1334 [==============================] - 11s 8ms/step - loss: 0.6932 - accuracy: 0.5017 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 74/100
# 1334/1334 [==============================] - 11s 8ms/step - loss: 0.6931 - accuracy: 0.5030 - val_loss: 0.6932 - val_accuracy: 0.5022
# Epoch 75/100
# 1334/1334 [==============================] - 12s 9ms/step - loss: 0.6932 - accuracy: 0.5034 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 76/100
# 1334/1334 [==============================] - 12s 9ms/step - loss: 0.6932 - accuracy: 0.5024 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 77/100
# 1334/1334 [==============================] - 12s 9ms/step - loss: 0.6931 - accuracy: 0.5042 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 78/100
# 1334/1334 [==============================] - 13s 10ms/step - loss: 0.6932 - accuracy: 0.5016 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 79/100
# 1334/1334 [==============================] - 12s 9ms/step - loss: 0.6932 - accuracy: 0.5022 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 80/100
# 1334/1334 [==============================] - 12s 9ms/step - loss: 0.6932 - accuracy: 0.5007 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 81/100
# 1334/1334 [==============================] - 14s 10ms/step - loss: 0.6931 - accuracy: 0.5026 - val_loss: 0.6931 - val_accuracy: 0.5012
# Epoch 82/100
# 1334/1334 [==============================] - 12s 9ms/step - loss: 0.6931 - accuracy: 0.5019 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 83/100
# 1334/1334 [==============================] - 20s 15ms/step - loss: 0.6931 - accuracy: 0.4997 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 84/100
# 1334/1334 [==============================] - 15s 12ms/step - loss: 0.6932 - accuracy: 0.5018 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 85/100
# 1334/1334 [==============================] - 8s 6ms/step - loss: 0.6931 - accuracy: 0.5029 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 86/100
# 1334/1334 [==============================] - 8s 6ms/step - loss: 0.6932 - accuracy: 0.5040 - val_loss: 0.6931 - val_accuracy: 0.5012
# Epoch 87/100
# 1334/1334 [==============================] - 9s 7ms/step - loss: 0.6931 - accuracy: 0.5026 - val_loss: 0.6931 - val_accuracy: 0.5012
# Epoch 88/100
# 1334/1334 [==============================] - 9s 7ms/step - loss: 0.6932 - accuracy: 0.5005 - val_loss: 0.6931 - val_accuracy: 0.5012
# Epoch 89/100
# 1334/1334 [==============================] - 9s 7ms/step - loss: 0.6931 - accuracy: 0.5036 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 90/100
# 1334/1334 [==============================] - 9s 7ms/step - loss: 0.6932 - accuracy: 0.5032 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 91/100
# 1334/1334 [==============================] - 9s 7ms/step - loss: 0.6931 - accuracy: 0.5024 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 92/100
# 1334/1334 [==============================] - 9s 7ms/step - loss: 0.6931 - accuracy: 0.5018 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 93/100
# 1334/1334 [==============================] - 9s 7ms/step - loss: 0.6932 - accuracy: 0.5026 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 94/100
# 1334/1334 [==============================] - 9s 7ms/step - loss: 0.6931 - accuracy: 0.5015 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 95/100
# 1334/1334 [==============================] - 10s 8ms/step - loss: 0.6931 - accuracy: 0.4992 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 96/100
# 1334/1334 [==============================] - 9s 7ms/step - loss: 0.6931 - accuracy: 0.5031 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 97/100
# 1334/1334 [==============================] - 9s 7ms/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5022
# Epoch 98/100
# 1334/1334 [==============================] - 9s 7ms/step - loss: 0.6932 - accuracy: 0.5028 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 99/100
# 1334/1334 [==============================] - 9s 7ms/step - loss: 0.6931 - accuracy: 0.5042 - val_loss: 0.6931 - val_accuracy: 0.5022
# Epoch 100/100
# 1334/1334 [==============================] - 9s 7ms/step - loss: 0.6931 - accuracy: 0.4970 - val_loss: 0.6932 - val_accuracy: 0.5022
# Fold 3, 100 epochs, 1072 sec

# %%
from keras.models import load_model
X,y = prepare_inputs_len_x_alphabet(pc_test,nc_test,ALPHABET)
best_model=load_model(MODELPATH)
scores = best_model.evaluate(X, y, verbose=0)
print("The best model parameters were saved during cross-validation.")
print("Best was defined as maximum validation accuracy at end of any epoch.")
print("Now re-load the best model and test it on previously unseen data.")
print("Test on",len(pc_test),"PC seqs")
print("Test on",len(nc_test),"NC seqs")
print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))
# Out:
# The best model parameters were saved during cross-validation.
# Best was defined as maximum validation accuracy at end of any epoch.
# Now re-load the best model and test it on previously unseen data.
# Test on 1000 PC seqs
# Test on 1000 NC seqs
# accuracy: 50.21%

# %%
# This code worked on CNN but not on MLP
if False:
    from sklearn.metrics import roc_curve
    from sklearn.metrics import roc_auc_score
    ns_probs = [0 for _ in range(len(y))]
    bm_probs = best_model.predict(X)
    # bm_probs = np.reshape(bm_probs,(2000,36))
    print(type(ns_probs))
    print(type(bm_probs))
    print(bm_probs.shape)

# %%
if False:
    ns_auc = roc_auc_score(y, ns_probs)
    bm_auc = roc_auc_score(y, bm_probs)
    ns_fpr, ns_tpr, _ = roc_curve(y, ns_probs)
    bm_fpr, bm_tpr, _ = roc_curve(y, bm_probs)
    plt.plot(ns_fpr, ns_tpr, linestyle='--', label='Guess, auc=%.4f'%ns_auc)
    plt.plot(bm_fpr, bm_tpr, marker='.', label='Model, auc=%.4f'%bm_auc)
    plt.title('ROC')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()
    plt.show()
    print("%s: %.2f%%" %('AUC',bm_auc*100.0))

# %%
t = time.time()
time.strftime('%Y-%m-%d %H:%M:%S %Z', time.localtime(t))
# Out:
# '2021-06-17 16:11:56 EDT'
