# %% [markdown]
# # MLP GenCode
# Based on MLP_GenCode 104, tyr to reimplement Wen et al 2019.

# %%
import time
def show_time():
    t = time.time()
    print(time.strftime('%Y-%m-%d %H:%M:%S %Z', time.localtime(t)))
show_time()
# Out:
# 2021-07-14 16:24:09 UTC

# %%
PC_TRAINS=8000
NC_TRAINS=8000
PC_TESTS=2000
NC_TESTS=2000   # Wen et al 2019 used 8000 and 2000 of each class
PC_LENS=(200,4000)
NC_LENS=(250,3000)    # Wen et al 2019 used 250-3500 for lncRNA only
MAX_K = 3
INPUT_SHAPE=(None,84)  # 4^3 + 4^2 + 4^1
NEURONS=128
EPOCHS=50
SPLITS=5
FOLDS=5   # make this 5 for serious testing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

from keras.models import Sequential
from keras.layers import Dense,Embedding,Dropout
from keras.layers import Flatten,TimeDistributed
from keras.losses import BinaryCrossentropy
from keras.callbacks import ModelCheckpoint

# %%
import sys
IN_COLAB = False
try:
    from google.colab import drive
    IN_COLAB = True
except:
    pass
if IN_COLAB:
    print("On Google CoLab, mount cloud-local file, get our code from GitHub.")
    PATH='/content/drive/'
    #drive.mount(PATH,force_remount=True)  # hardly ever need this
    drive.mount(PATH)    # Google will require login credentials
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/GenCodeTools.py')
    with open('GenCodeTools.py', 'w') as f:
        f.write(r.text)  
    from GenCodeTools import GenCodeLoader
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/KmerTools.py')
    with open('KmerTools.py', 'w') as f:
        f.write(r.text)  
    from KmerTools import KmerTools
else:
        print("CoLab not working. On my PC, use relative paths.")
        DATAPATH='data/'  # must end in "/"
        sys.path.append("..") # append parent dir in order to use sibling dirs
        from SimTools.GenCodeTools import GenCodeLoader
        from SimTools.KmerTools import KmerTools
MODELPATH="BestModel"  # saved on cloud instance and lost after logout
#MODELPATH=DATAPATH+MODELPATH  # saved on Google Drive but requires login
# Out:
# On Google CoLab, mount cloud-local file, get our code from GitHub.
# Mounted at /content/drive/

# %% [markdown]
# ## Data Load
# Restrict mRNA to those transcripts with a recognized ORF.

# %%
PC_FILENAME='gencode.v26.pc_transcripts.fa.gz'
NC_FILENAME='gencode.v26.lncRNA_transcripts.fa.gz'
PC_FULLPATH=DATAPATH+PC_FILENAME
NC_FULLPATH=DATAPATH+NC_FILENAME

# %%
loader=GenCodeLoader()
loader.set_label(1)
loader.set_check_utr(False)
pcdf=loader.load_file(PC_FULLPATH)
print("PC seqs loaded:",len(pcdf))
loader.set_label(0)
loader.set_check_utr(False)
ncdf=loader.load_file(NC_FULLPATH)
print("NC seqs loaded:",len(ncdf))
show_time()
# Out:
# PC seqs loaded: 95146
# NC seqs loaded: 27720
# 2021-07-14 16:24:39 UTC

# %% [markdown]
# ## Data Prep

# %%
def dataframe_length_filter(df,low_high):
    (low,high)=low_high
    # The pandas query language is strange, 
    # but this is MUCH faster than loop & drop.
    return df[ (df['seqlen']>=low) & (df['seqlen']<=high) ]
def dataframe_shuffle(df):
    # The ignore_index option is new in Pandas 1.3. 
    # The default (False) replicates the old behavior: shuffle the index too.
    # The new option seems more logical th
    # After shuffling, df.iloc[0] has index == 0.
    # return df.sample(frac=1,ignore_index=True)
    return df.sample(frac=1)  # Use this till CoLab upgrades Pandas
def dataframe_extract_sequence(df):
    return df['sequence'].tolist()

pc_all = dataframe_extract_sequence(
    dataframe_shuffle(
    dataframe_length_filter(pcdf,PC_LENS)))
nc_all = dataframe_extract_sequence(
    dataframe_shuffle(
    dataframe_length_filter(ncdf,NC_LENS)))

show_time()
print("PC seqs pass filter:",len(pc_all))
print("NC seqs pass filter:",len(nc_all))
# Garbage collection to reduce RAM footprint
pcdf=None
ncdf=None
# Out:
# 2021-07-14 16:24:39 UTC
# PC seqs pass filter: 82256
# NC seqs pass filter: 25755

# %%
# Any portion of a shuffled list is a random selection
pc_train=pc_all[:PC_TRAINS] 
nc_train=nc_all[:NC_TRAINS]
pc_test=pc_all[PC_TRAINS:PC_TRAINS+PC_TESTS] 
nc_test=nc_all[NC_TRAINS:NC_TRAINS+PC_TESTS]
print("PC train, NC train:",len(pc_train),len(nc_train))
print("PC test, NC test:",len(pc_test),len(nc_test))
# Garbage collection
pc_all=None
nc_all=None
# Out:
# PC train, NC train: 8000 8000
# PC test, NC test: 2000 2000

# %%
def prepare_x_and_y(seqs1,seqs0):
    len1=len(seqs1)
    len0=len(seqs0)
    labels1=np.ones(len1,dtype=np.int8)
    labels0=np.zeros(len0,dtype=np.int8)
    all_labels = np.concatenate((labels1,labels0))
    seqs1 = np.asarray(seqs1)
    seqs0 = np.asarray(seqs0)
    all_seqs = np.concatenate((seqs1,seqs0),axis=0)
    # return all_seqs,all_labels  # test unshuffled
    tandem=(all_seqs,all_labels)
    X,y = shuffle(tandem) # sklearn.utils.shuffle
    return X,y
Xseq,y=prepare_x_and_y(pc_train,nc_train)
#print(pc_train[0])
#print(Xseq[0],y[0])
show_time()
# Out:
# 2021-07-14 16:24:39 UTC

# %%
def seqs_to_kmer_freqs(seqs,max_K):
    tool = KmerTools()  # from SimTools
    empty = tool.make_dict_upto_K(max_K)
    collection = []
    for seq in seqs:
        counts = empty
        # Last param should be True when using Harvester.
        counts = tool.update_count_one_K(counts,max_K,seq,True)
        # Given counts for K=3, Harvester fills in counts for K=1,2.
        counts = tool.harvest_counts_from_K(counts,max_K)
        fdict = tool.count_to_frequency(counts,max_K)
        freqs = list(fdict.values())
        collection.append(freqs)
    return np.asarray(collection)
Xfrq=seqs_to_kmer_freqs(Xseq,MAX_K)
show_time()
print("X shape",np.shape(Xfrq))
print(type(Xfrq),"of",type(Xfrq[0]),"of",type(Xfrq[0][0]))
print("y shape",np.shape(y))
# Out:
# 2021-07-14 16:24:50 UTC
# X shape (16000, 84)
# <class 'numpy.ndarray'> of <class 'numpy.ndarray'> of <class 'numpy.float64'>
# y shape (16000,)

# %% [markdown]
# ## Neural network

# %%
def make_DNN():
    dt=np.float32
    print("make_DNN")
    print("input shape:",INPUT_SHAPE)
    dnn = Sequential()
    dnn.add(Dense(NEURONS,activation="sigmoid",dtype=dt))
    dnn.add(Dense(NEURONS,activation="sigmoid",dtype=dt)) 
    #dnn.add(Dropout(DROP_RATE))
    dnn.add(Dense(1,activation="sigmoid",dtype=dt))   
    dnn.compile(optimizer='adam',
                loss=BinaryCrossentropy(from_logits=False),
                metrics=['accuracy'])   # add to default metrics=loss
    dnn.build(input_shape=INPUT_SHAPE) 
    return dnn
model = make_DNN()
print(model.summary())
# Out:
# make_DNN
# input shape: (None, 84)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               10880
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 27,521
# Trainable params: 27,521
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def do_cross_validation(X,y):
    cv_scores = []
    fold=0
    mycallbacks = [ModelCheckpoint(
        filepath=MODELPATH, save_best_only=True, 
        monitor='val_accuracy', mode='max')]   
    splitter = KFold(n_splits=SPLITS)  # this does not shuffle
    for train_index,valid_index in splitter.split(X):
        if fold < FOLDS:
            fold += 1
            X_train=X[train_index] # inputs for training
            y_train=y[train_index] # labels for training
            X_valid=X[valid_index] # inputs for validation
            y_valid=y[valid_index] # labels for validation
            print("MODEL")
            # Call constructor on each CV. Else, continually improves the same model.
            model = model = make_DNN()
            print("FIT")  # model.fit() implements learning
            start_time=time.time()
            history=model.fit(X_train, y_train, 
                    epochs=EPOCHS, 
                    verbose=1,  # ascii art while learning
                    callbacks=mycallbacks,   # called at end of each epoch
                    validation_data=(X_valid,y_valid))
            end_time=time.time()
            elapsed_time=(end_time-start_time)                        
            print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
            # print(history.history.keys())  # all these keys will be shown in figure
            pd.DataFrame(history.history).plot(figsize=(8,5))
            plt.grid(True)
            plt.gca().set_ylim(0,1) # any losses > 1 will be off the scale
            plt.show()

# %%
do_cross_validation(Xfrq,y)
# Out:
# MODEL
# make_DNN
# input shape: (None, 84)
# FIT
# Epoch 1/50
# 400/400 [==============================] - 17s 4ms/step - loss: 0.6736 - accuracy: 0.6124 - val_loss: 0.8419 - val_accuracy: 0.0000e+00
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 2/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6661 - accuracy: 0.6265 - val_loss: 0.9604 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6638 - accuracy: 0.6238 - val_loss: 0.8258 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6661 - accuracy: 0.6274 - val_loss: 0.8193 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6658 - accuracy: 0.6251 - val_loss: 0.9317 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6641 - accuracy: 0.6247 - val_loss: 0.9260 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6643 - accuracy: 0.6238 - val_loss: 0.9035 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6638 - accuracy: 0.6219 - val_loss: 0.9921 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6624 - accuracy: 0.6225 - val_loss: 1.0023 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6604 - accuracy: 0.6250 - val_loss: 0.9000 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6579 - accuracy: 0.6301 - val_loss: 1.2018 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6620 - accuracy: 0.6228 - val_loss: 0.9739 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6554 - accuracy: 0.6256 - val_loss: 0.9667 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6543 - accuracy: 0.6208 - val_loss: 0.8971 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6483 - accuracy: 0.6218 - val_loss: 0.9344 - val_accuracy: 0.0016
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 16/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6354 - accuracy: 0.6243 - val_loss: 1.0206 - val_accuracy: 0.0028
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 17/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6264 - accuracy: 0.6312 - val_loss: 0.8142 - val_accuracy: 0.0172
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 18/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.5964 - accuracy: 0.6540 - val_loss: 0.4916 - val_accuracy: 0.9991
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 19/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.5810 - accuracy: 0.7008 - val_loss: 0.5867 - val_accuracy: 0.9897
# Epoch 20/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.5438 - accuracy: 0.7189 - val_loss: 0.5527 - val_accuracy: 0.9903
# Epoch 21/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.5063 - accuracy: 0.7587 - val_loss: 0.5390 - val_accuracy: 0.9894
# Epoch 22/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.4703 - accuracy: 0.8120 - val_loss: 0.4422 - val_accuracy: 0.9912
# Epoch 23/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.4329 - accuracy: 0.8571 - val_loss: 0.3557 - val_accuracy: 0.9937
# Epoch 24/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3959 - accuracy: 0.8845 - val_loss: 0.4423 - val_accuracy: 0.9894
# Epoch 25/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3766 - accuracy: 0.8869 - val_loss: 0.2128 - val_accuracy: 0.9972
# Epoch 26/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3515 - accuracy: 0.8936 - val_loss: 0.2834 - val_accuracy: 0.9919
# Epoch 27/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3255 - accuracy: 0.9175 - val_loss: 0.2548 - val_accuracy: 0.9919
# Epoch 28/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3167 - accuracy: 0.9184 - val_loss: 0.4460 - val_accuracy: 0.9156
# Epoch 29/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3007 - accuracy: 0.9094 - val_loss: 0.1657 - val_accuracy: 0.9937
# Epoch 30/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2874 - accuracy: 0.9183 - val_loss: 0.1761 - val_accuracy: 0.9934
# Epoch 31/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2756 - accuracy: 0.9218 - val_loss: 0.2787 - val_accuracy: 0.9897
# Epoch 32/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2656 - accuracy: 0.9237 - val_loss: 0.1441 - val_accuracy: 0.9934
# Epoch 33/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2590 - accuracy: 0.9202 - val_loss: 0.3489 - val_accuracy: 0.9544
# Epoch 34/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2515 - accuracy: 0.9282 - val_loss: 0.2277 - val_accuracy: 0.9897
# Epoch 35/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2491 - accuracy: 0.9236 - val_loss: 0.1629 - val_accuracy: 0.9909
# Epoch 36/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2365 - accuracy: 0.9264 - val_loss: 0.1684 - val_accuracy: 0.9906
# Epoch 37/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2229 - accuracy: 0.9332 - val_loss: 0.2831 - val_accuracy: 0.9722
# Epoch 38/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2358 - accuracy: 0.9233 - val_loss: 0.1418 - val_accuracy: 0.9909
# Epoch 39/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2176 - accuracy: 0.9355 - val_loss: 0.1873 - val_accuracy: 0.9897
# Epoch 40/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2179 - accuracy: 0.9302 - val_loss: 0.1612 - val_accuracy: 0.9903
# Epoch 41/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2156 - accuracy: 0.9342 - val_loss: 0.1301 - val_accuracy: 0.9906
# Epoch 42/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2147 - accuracy: 0.9344 - val_loss: 0.1179 - val_accuracy: 0.9909
# Epoch 43/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2102 - accuracy: 0.9323 - val_loss: 0.1645 - val_accuracy: 0.9897
# Epoch 44/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2065 - accuracy: 0.9353 - val_loss: 0.1560 - val_accuracy: 0.9897
# Epoch 45/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2017 - accuracy: 0.9394 - val_loss: 0.1582 - val_accuracy: 0.9897
# Epoch 46/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1928 - accuracy: 0.9396 - val_loss: 0.0679 - val_accuracy: 0.9934
# Epoch 47/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1984 - accuracy: 0.9334 - val_loss: 0.1073 - val_accuracy: 0.9906
# Epoch 48/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1943 - accuracy: 0.9317 - val_loss: 0.1625 - val_accuracy: 0.9897
# Epoch 49/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1920 - accuracy: 0.9393 - val_loss: 0.2890 - val_accuracy: 0.9212
# Epoch 50/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1930 - accuracy: 0.9365 - val_loss: 0.0815 - val_accuracy: 0.9912
# Fold 1, 50 epochs, 96 sec
# MODEL
# make_DNN
# input shape: (None, 84)
# FIT
# Epoch 1/50
# 400/400 [==============================] - 2s 4ms/step - loss: 0.6638 - accuracy: 0.6237 - val_loss: 1.1493 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6685 - accuracy: 0.6244 - val_loss: 0.9261 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6643 - accuracy: 0.6248 - val_loss: 1.1374 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6595 - accuracy: 0.6331 - val_loss: 0.8681 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6668 - accuracy: 0.6197 - val_loss: 0.9286 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6603 - accuracy: 0.6297 - val_loss: 0.9603 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6626 - accuracy: 0.6246 - val_loss: 0.8921 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6609 - accuracy: 0.6295 - val_loss: 0.8953 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6605 - accuracy: 0.6248 - val_loss: 0.9408 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6608 - accuracy: 0.6219 - val_loss: 0.9507 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6561 - accuracy: 0.6261 - val_loss: 0.8726 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6537 - accuracy: 0.6216 - val_loss: 0.9955 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6500 - accuracy: 0.6193 - val_loss: 0.8952 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6399 - accuracy: 0.6202 - val_loss: 0.8664 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6189 - accuracy: 0.6435 - val_loss: 1.0725 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.5922 - accuracy: 0.6817 - val_loss: 0.8892 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.5587 - accuracy: 0.6953 - val_loss: 0.5690 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 18/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.5177 - accuracy: 0.7604 - val_loss: 0.8533 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.4745 - accuracy: 0.8117 - val_loss: 0.6631 - val_accuracy: 0.7178
# Epoch 20/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.4279 - accuracy: 0.8593 - val_loss: 0.5140 - val_accuracy: 1.0000
# Epoch 21/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3937 - accuracy: 0.8848 - val_loss: 0.5948 - val_accuracy: 1.0000
# Epoch 22/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3570 - accuracy: 0.9150 - val_loss: 0.4076 - val_accuracy: 1.0000
# Epoch 23/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3259 - accuracy: 0.9058 - val_loss: 0.4459 - val_accuracy: 1.0000
# Epoch 24/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3008 - accuracy: 0.9242 - val_loss: 0.4433 - val_accuracy: 1.0000
# Epoch 25/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2865 - accuracy: 0.9244 - val_loss: 0.2955 - val_accuracy: 1.0000
# Epoch 26/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2722 - accuracy: 0.9170 - val_loss: 0.4923 - val_accuracy: 1.0000
# Epoch 27/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2526 - accuracy: 0.9321 - val_loss: 0.4133 - val_accuracy: 1.0000
# Epoch 28/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2449 - accuracy: 0.9292 - val_loss: 0.3373 - val_accuracy: 1.0000
# Epoch 29/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2347 - accuracy: 0.9260 - val_loss: 0.5254 - val_accuracy: 0.9791
# Epoch 30/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2255 - accuracy: 0.9345 - val_loss: 0.2211 - val_accuracy: 1.0000
# Epoch 31/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2125 - accuracy: 0.9361 - val_loss: 0.1985 - val_accuracy: 1.0000
# Epoch 32/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2175 - accuracy: 0.9232 - val_loss: 0.3034 - val_accuracy: 1.0000
# Epoch 33/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2039 - accuracy: 0.9343 - val_loss: 0.1681 - val_accuracy: 1.0000
# Epoch 34/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1975 - accuracy: 0.9362 - val_loss: 0.5752 - val_accuracy: 0.7350
# Epoch 35/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2049 - accuracy: 0.9300 - val_loss: 0.4278 - val_accuracy: 1.0000
# Epoch 36/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1944 - accuracy: 0.9376 - val_loss: 0.6245 - val_accuracy: 0.5584
# Epoch 37/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1930 - accuracy: 0.9334 - val_loss: 0.5361 - val_accuracy: 0.8694
# Epoch 38/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1867 - accuracy: 0.9333 - val_loss: 0.3866 - val_accuracy: 1.0000
# Epoch 39/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1900 - accuracy: 0.9332 - val_loss: 0.1622 - val_accuracy: 1.0000
# Epoch 40/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1777 - accuracy: 0.9444 - val_loss: 0.1064 - val_accuracy: 1.0000
# Epoch 41/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1759 - accuracy: 0.9396 - val_loss: 0.2872 - val_accuracy: 1.0000
# Epoch 42/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1694 - accuracy: 0.9437 - val_loss: 0.1987 - val_accuracy: 1.0000
# Epoch 43/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1729 - accuracy: 0.9389 - val_loss: 0.1445 - val_accuracy: 1.0000
# Epoch 44/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1679 - accuracy: 0.9435 - val_loss: 0.2388 - val_accuracy: 1.0000
# Epoch 45/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1719 - accuracy: 0.9394 - val_loss: 0.2230 - val_accuracy: 1.0000
# Epoch 46/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1679 - accuracy: 0.9415 - val_loss: 0.1836 - val_accuracy: 1.0000
# Epoch 47/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1664 - accuracy: 0.9397 - val_loss: 0.2151 - val_accuracy: 1.0000
# Epoch 48/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1589 - accuracy: 0.9479 - val_loss: 0.3978 - val_accuracy: 0.9912
# Epoch 49/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1694 - accuracy: 0.9386 - val_loss: 0.2145 - val_accuracy: 1.0000
# Epoch 50/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1608 - accuracy: 0.9467 - val_loss: 0.1710 - val_accuracy: 1.0000
# Fold 2, 50 epochs, 82 sec
# MODEL
# make_DNN
# input shape: (None, 84)
# FIT
# Epoch 1/50
# 400/400 [==============================] - 2s 4ms/step - loss: 0.6987 - accuracy: 0.5046 - val_loss: 0.7112 - val_accuracy: 0.5000
# Epoch 2/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6980 - accuracy: 0.5025 - val_loss: 0.7163 - val_accuracy: 0.5000
# Epoch 3/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.7004 - accuracy: 0.4917 - val_loss: 0.6961 - val_accuracy: 0.5000
# Epoch 4/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6955 - accuracy: 0.5095 - val_loss: 0.6940 - val_accuracy: 0.5000
# Epoch 5/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6947 - accuracy: 0.5043 - val_loss: 0.6927 - val_accuracy: 0.5000
# Epoch 6/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6912 - accuracy: 0.5194 - val_loss: 0.6926 - val_accuracy: 0.5000
# Epoch 7/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6904 - accuracy: 0.5334 - val_loss: 0.6946 - val_accuracy: 0.5000
# Epoch 8/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6880 - accuracy: 0.5475 - val_loss: 0.6953 - val_accuracy: 0.5000
# Epoch 9/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6830 - accuracy: 0.5593 - val_loss: 0.6911 - val_accuracy: 0.5000
# Epoch 10/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6728 - accuracy: 0.6238 - val_loss: 0.6961 - val_accuracy: 0.5000
# Epoch 11/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6555 - accuracy: 0.6693 - val_loss: 0.6911 - val_accuracy: 0.5000
# Epoch 12/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6287 - accuracy: 0.7177 - val_loss: 0.7050 - val_accuracy: 0.5000
# Epoch 13/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.5882 - accuracy: 0.7352 - val_loss: 0.6709 - val_accuracy: 0.5000
# Epoch 14/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.5236 - accuracy: 0.8952 - val_loss: 0.6810 - val_accuracy: 0.5000
# Epoch 15/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.4506 - accuracy: 0.9486 - val_loss: 0.6550 - val_accuracy: 0.5000
# Epoch 16/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3779 - accuracy: 0.9540 - val_loss: 0.8310 - val_accuracy: 0.5000
# Epoch 17/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3148 - accuracy: 0.9659 - val_loss: 0.6795 - val_accuracy: 0.5000
# Epoch 18/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2568 - accuracy: 0.9741 - val_loss: 0.6526 - val_accuracy: 0.5325
# Epoch 19/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2130 - accuracy: 0.9788 - val_loss: 0.7152 - val_accuracy: 0.5000
# Epoch 20/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1770 - accuracy: 0.9831 - val_loss: 0.9728 - val_accuracy: 0.5000
# Epoch 21/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1504 - accuracy: 0.9854 - val_loss: 0.7268 - val_accuracy: 0.5000
# Epoch 22/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1322 - accuracy: 0.9871 - val_loss: 0.6783 - val_accuracy: 0.5697
# Epoch 23/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1122 - accuracy: 0.9900 - val_loss: 0.8731 - val_accuracy: 0.5000
# Epoch 24/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1005 - accuracy: 0.9899 - val_loss: 0.6203 - val_accuracy: 0.6522
# Epoch 25/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0908 - accuracy: 0.9925 - val_loss: 0.9861 - val_accuracy: 0.5000
# Epoch 26/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0754 - accuracy: 0.9956 - val_loss: 0.7788 - val_accuracy: 0.5525
# Epoch 27/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0744 - accuracy: 0.9938 - val_loss: 0.7494 - val_accuracy: 0.5856
# Epoch 28/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0639 - accuracy: 0.9960 - val_loss: 0.9936 - val_accuracy: 0.5000
# Epoch 29/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0593 - accuracy: 0.9956 - val_loss: 0.7571 - val_accuracy: 0.6044
# Epoch 30/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0523 - accuracy: 0.9966 - val_loss: 0.9532 - val_accuracy: 0.5184
# Epoch 31/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0506 - accuracy: 0.9963 - val_loss: 1.0704 - val_accuracy: 0.5000
# Epoch 32/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0476 - accuracy: 0.9953 - val_loss: 0.8920 - val_accuracy: 0.5697
# Epoch 33/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0468 - accuracy: 0.9962 - val_loss: 0.8142 - val_accuracy: 0.6147
# Epoch 34/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0470 - accuracy: 0.9963 - val_loss: 1.2771 - val_accuracy: 0.5000
# Epoch 35/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0360 - accuracy: 0.9976 - val_loss: 0.6841 - val_accuracy: 0.6772
# Epoch 36/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0358 - accuracy: 0.9963 - val_loss: 1.3189 - val_accuracy: 0.5000
# Epoch 37/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0366 - accuracy: 0.9956 - val_loss: 0.7288 - val_accuracy: 0.6694
# Epoch 38/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0328 - accuracy: 0.9967 - val_loss: 1.4691 - val_accuracy: 0.5000
# Epoch 39/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0278 - accuracy: 0.9978 - val_loss: 0.8991 - val_accuracy: 0.6197
# Epoch 40/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0292 - accuracy: 0.9978 - val_loss: 0.6451 - val_accuracy: 0.7013
# Epoch 41/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0264 - accuracy: 0.9972 - val_loss: 1.0633 - val_accuracy: 0.5822
# Epoch 42/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0245 - accuracy: 0.9973 - val_loss: 1.0115 - val_accuracy: 0.6031
# Epoch 43/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0352 - accuracy: 0.9954 - val_loss: 1.0913 - val_accuracy: 0.5844
# Epoch 44/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0233 - accuracy: 0.9974 - val_loss: 0.8210 - val_accuracy: 0.6653
# Epoch 45/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0222 - accuracy: 0.9978 - val_loss: 0.9580 - val_accuracy: 0.6328
# Epoch 46/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0211 - accuracy: 0.9977 - val_loss: 0.9862 - val_accuracy: 0.6272
# Epoch 47/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0168 - accuracy: 0.9980 - val_loss: 1.4680 - val_accuracy: 0.5053
# Epoch 48/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0175 - accuracy: 0.9983 - val_loss: 1.6646 - val_accuracy: 0.5000
# Epoch 49/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0180 - accuracy: 0.9972 - val_loss: 1.4960 - val_accuracy: 0.5106
# Epoch 50/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0202 - accuracy: 0.9974 - val_loss: 1.0065 - val_accuracy: 0.6394
# Fold 3, 50 epochs, 82 sec
# MODEL
# make_DNN
# input shape: (None, 84)
# FIT
# Epoch 1/50
# 400/400 [==============================] - 2s 4ms/step - loss: 0.6629 - accuracy: 0.6247 - val_loss: 0.9460 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6689 - accuracy: 0.6085 - val_loss: 0.9607 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6629 - accuracy: 0.6307 - val_loss: 0.9827 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6643 - accuracy: 0.6231 - val_loss: 0.7310 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6634 - accuracy: 0.6247 - val_loss: 1.1077 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6618 - accuracy: 0.6251 - val_loss: 0.9898 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6645 - accuracy: 0.6186 - val_loss: 0.9787 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6573 - accuracy: 0.6290 - val_loss: 1.0039 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6599 - accuracy: 0.6187 - val_loss: 0.9237 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6542 - accuracy: 0.6226 - val_loss: 0.9461 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6461 - accuracy: 0.6291 - val_loss: 1.0982 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6407 - accuracy: 0.6334 - val_loss: 0.9360 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6162 - accuracy: 0.6379 - val_loss: 0.7676 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.5979 - accuracy: 0.6878 - val_loss: 0.9940 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.5607 - accuracy: 0.7392 - val_loss: 1.0149 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.5176 - accuracy: 0.8025 - val_loss: 0.9043 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.4753 - accuracy: 0.8644 - val_loss: 0.9591 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.4286 - accuracy: 0.8760 - val_loss: 0.6687 - val_accuracy: 0.5806
# Epoch 19/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3919 - accuracy: 0.8725 - val_loss: 0.7465 - val_accuracy: 0.4594
# Epoch 20/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3619 - accuracy: 0.8809 - val_loss: 0.5297 - val_accuracy: 0.7738
# Epoch 21/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3372 - accuracy: 0.8791 - val_loss: 0.3998 - val_accuracy: 0.9544
# Epoch 22/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3168 - accuracy: 0.8829 - val_loss: 0.2288 - val_accuracy: 1.0000
# Epoch 23/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3107 - accuracy: 0.8857 - val_loss: 0.2666 - val_accuracy: 1.0000
# Epoch 24/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3049 - accuracy: 0.8752 - val_loss: 0.1746 - val_accuracy: 1.0000
# Epoch 25/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2875 - accuracy: 0.8854 - val_loss: 0.3089 - val_accuracy: 0.9906
# Epoch 26/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2800 - accuracy: 0.8858 - val_loss: 0.5872 - val_accuracy: 0.6478
# Epoch 27/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2769 - accuracy: 0.8835 - val_loss: 0.4020 - val_accuracy: 0.8394
# Epoch 28/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2663 - accuracy: 0.8907 - val_loss: 0.1916 - val_accuracy: 1.0000
# Epoch 29/50
# 400/400 [==============================] - 1s 4ms/step - loss: 0.2717 - accuracy: 0.8850 - val_loss: 0.1706 - val_accuracy: 1.0000
# Epoch 30/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2566 - accuracy: 0.8891 - val_loss: 0.2518 - val_accuracy: 0.9994
# Epoch 31/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2544 - accuracy: 0.8964 - val_loss: 0.3060 - val_accuracy: 0.9075
# Epoch 32/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2535 - accuracy: 0.8933 - val_loss: 0.1589 - val_accuracy: 1.0000
# Epoch 33/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2575 - accuracy: 0.8956 - val_loss: 0.1020 - val_accuracy: 1.0000
# Epoch 34/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2454 - accuracy: 0.8958 - val_loss: 0.0916 - val_accuracy: 1.0000
# Epoch 35/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2477 - accuracy: 0.8977 - val_loss: 0.0831 - val_accuracy: 1.0000
# Epoch 36/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2462 - accuracy: 0.9016 - val_loss: 0.1428 - val_accuracy: 1.0000
# Epoch 37/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2375 - accuracy: 0.9039 - val_loss: 0.0970 - val_accuracy: 1.0000
# Epoch 38/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2313 - accuracy: 0.9077 - val_loss: 0.2365 - val_accuracy: 0.9503
# Epoch 39/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2323 - accuracy: 0.9074 - val_loss: 0.0812 - val_accuracy: 1.0000
# Epoch 40/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2420 - accuracy: 0.9065 - val_loss: 0.1001 - val_accuracy: 1.0000
# Epoch 41/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2297 - accuracy: 0.9100 - val_loss: 0.1934 - val_accuracy: 0.9953
# Epoch 42/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2334 - accuracy: 0.9109 - val_loss: 0.1481 - val_accuracy: 1.0000
# Epoch 43/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2308 - accuracy: 0.9109 - val_loss: 0.0668 - val_accuracy: 1.0000
# Epoch 44/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2268 - accuracy: 0.9127 - val_loss: 0.0707 - val_accuracy: 1.0000
# Epoch 45/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2194 - accuracy: 0.9150 - val_loss: 0.1261 - val_accuracy: 1.0000
# Epoch 46/50
# 400/400 [==============================] - 2s 4ms/step - loss: 0.2287 - accuracy: 0.9129 - val_loss: 0.0891 - val_accuracy: 1.0000
# Epoch 47/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2271 - accuracy: 0.9126 - val_loss: 0.0804 - val_accuracy: 1.0000
# Epoch 48/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2243 - accuracy: 0.9182 - val_loss: 0.2043 - val_accuracy: 0.9453
# Epoch 49/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2278 - accuracy: 0.9122 - val_loss: 0.0522 - val_accuracy: 1.0000
# Epoch 50/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2261 - accuracy: 0.9168 - val_loss: 0.0444 - val_accuracy: 1.0000
# Fold 4, 50 epochs, 82 sec
# MODEL
# make_DNN
# input shape: (None, 84)
# FIT
# Epoch 1/50
# 400/400 [==============================] - 2s 4ms/step - loss: 0.6783 - accuracy: 0.6159 - val_loss: 1.0160 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 400/400 [==============================] - 1s 4ms/step - loss: 0.6646 - accuracy: 0.6222 - val_loss: 0.8568 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 400/400 [==============================] - 1s 4ms/step - loss: 0.6671 - accuracy: 0.6204 - val_loss: 0.9843 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6637 - accuracy: 0.6276 - val_loss: 0.9845 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6632 - accuracy: 0.6266 - val_loss: 1.0446 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 400/400 [==============================] - 1s 4ms/step - loss: 0.6618 - accuracy: 0.6302 - val_loss: 0.8547 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6664 - accuracy: 0.6222 - val_loss: 1.0011 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6581 - accuracy: 0.6341 - val_loss: 0.9480 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 400/400 [==============================] - 1s 4ms/step - loss: 0.6614 - accuracy: 0.6270 - val_loss: 1.0025 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6634 - accuracy: 0.6246 - val_loss: 0.9426 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 400/400 [==============================] - 1s 4ms/step - loss: 0.6615 - accuracy: 0.6261 - val_loss: 0.9702 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 400/400 [==============================] - 1s 4ms/step - loss: 0.6589 - accuracy: 0.6311 - val_loss: 0.9996 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6633 - accuracy: 0.6230 - val_loss: 1.0408 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6616 - accuracy: 0.6254 - val_loss: 0.9374 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 400/400 [==============================] - 1s 4ms/step - loss: 0.6643 - accuracy: 0.6196 - val_loss: 1.0126 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6591 - accuracy: 0.6265 - val_loss: 0.8352 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6592 - accuracy: 0.6287 - val_loss: 0.9502 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6606 - accuracy: 0.6218 - val_loss: 0.8545 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 400/400 [==============================] - 1s 4ms/step - loss: 0.6608 - accuracy: 0.6222 - val_loss: 0.9919 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6564 - accuracy: 0.6263 - val_loss: 0.8643 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6551 - accuracy: 0.6235 - val_loss: 0.8878 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6521 - accuracy: 0.6287 - val_loss: 0.7177 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6497 - accuracy: 0.6237 - val_loss: 0.8855 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6435 - accuracy: 0.6297 - val_loss: 0.8464 - val_accuracy: 0.0000e+00
# Epoch 25/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6390 - accuracy: 0.6448 - val_loss: 0.6480 - val_accuracy: 1.0000
# Epoch 26/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6242 - accuracy: 0.6528 - val_loss: 0.6037 - val_accuracy: 1.0000
# Epoch 27/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6092 - accuracy: 0.6685 - val_loss: 0.5317 - val_accuracy: 1.0000
# Epoch 28/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.5891 - accuracy: 0.6792 - val_loss: 0.5124 - val_accuracy: 1.0000
# Epoch 29/50
# 400/400 [==============================] - 1s 4ms/step - loss: 0.5661 - accuracy: 0.7275 - val_loss: 0.3692 - val_accuracy: 1.0000
# Epoch 30/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.5415 - accuracy: 0.7597 - val_loss: 0.3921 - val_accuracy: 1.0000
# Epoch 31/50
# 400/400 [==============================] - 1s 4ms/step - loss: 0.5268 - accuracy: 0.7884 - val_loss: 0.3105 - val_accuracy: 1.0000
# Epoch 32/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.4987 - accuracy: 0.8185 - val_loss: 0.2066 - val_accuracy: 1.0000
# Epoch 33/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.4758 - accuracy: 0.8378 - val_loss: 0.2642 - val_accuracy: 1.0000
# Epoch 34/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.4585 - accuracy: 0.8453 - val_loss: 0.1556 - val_accuracy: 1.0000
# Epoch 35/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.4268 - accuracy: 0.8610 - val_loss: 0.0887 - val_accuracy: 1.0000
# Epoch 36/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.4090 - accuracy: 0.8697 - val_loss: 0.0711 - val_accuracy: 1.0000
# Epoch 37/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3865 - accuracy: 0.8825 - val_loss: 0.0861 - val_accuracy: 1.0000
# Epoch 38/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3650 - accuracy: 0.8876 - val_loss: 0.0472 - val_accuracy: 1.0000
# Epoch 39/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3483 - accuracy: 0.8917 - val_loss: 0.0320 - val_accuracy: 1.0000
# Epoch 40/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3326 - accuracy: 0.8978 - val_loss: 0.0290 - val_accuracy: 1.0000
# Epoch 41/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3158 - accuracy: 0.9054 - val_loss: 0.0293 - val_accuracy: 1.0000
# Epoch 42/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3043 - accuracy: 0.9058 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 43/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2935 - accuracy: 0.9084 - val_loss: 0.0060 - val_accuracy: 1.0000
# Epoch 44/50
# 400/400 [==============================] - 1s 4ms/step - loss: 0.2926 - accuracy: 0.9092 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 45/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2775 - accuracy: 0.9150 - val_loss: 0.0107 - val_accuracy: 1.0000
# Epoch 46/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2756 - accuracy: 0.9110 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 47/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2636 - accuracy: 0.9172 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 48/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2551 - accuracy: 0.9175 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 49/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2527 - accuracy: 0.9166 - val_loss: 7.0276e-04 - val_accuracy: 1.0000
# Epoch 50/50
# 400/400 [==============================] - 1s 3ms/step - loss: 0.2413 - accuracy: 0.9232 - val_loss: 0.0013 - val_accuracy: 1.0000
# Fold 5, 50 epochs, 68 sec

# %%
# TO DO: run trained model on (pc_test,nc_test)
# and draw the AUC.
# Borrow code from other notebooks.
