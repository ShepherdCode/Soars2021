# %% [markdown]
# # MLP GenCode
# Compared to MLP GenCode 102, what happens using just K=3?

# %%
import time
def show_time():
    t = time.time()
    print(time.strftime('%Y-%m-%d %H:%M:%S %Z', time.localtime(t)))
show_time()
# Out:
# 2021-07-12 14:53:22 UTC

# %%
PC_TRAINS=20000
NC_TRAINS=20000
PC_TESTS=5000
NC_TESTS=5000   # Wen et al 2019 used 8000 and 2000 of each class
PC_LENS=(200,4000)
NC_LENS=(200,4000)    # Wen et al 2019 used 250-3500 for lncRNA only
MAX_K = 3
INPUT_SHAPE=(None,84)  # 4^3 + 4^2 + 4^1
NEURONS=128
EPOCHS=25
SPLITS=5
FOLDS=5   # make this 5 for serious testing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

from keras.models import Sequential
from keras.layers import Dense,Embedding,Dropout
from keras.layers import Flatten,TimeDistributed
from keras.losses import BinaryCrossentropy
from keras.callbacks import ModelCheckpoint

# %%
import sys
IN_COLAB = False
try:
    from google.colab import drive
    IN_COLAB = True
except:
    pass
if IN_COLAB:
    print("On Google CoLab, mount cloud-local file, get our code from GitHub.")
    PATH='/content/drive/'
    #drive.mount(PATH,force_remount=True)  # hardly ever need this
    drive.mount(PATH)    # Google will require login credentials
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/GenCodeTools.py')
    with open('GenCodeTools.py', 'w') as f:
        f.write(r.text)  
    from GenCodeTools import GenCodeLoader
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/KmerTools.py')
    with open('KmerTools.py', 'w') as f:
        f.write(r.text)  
    from KmerTools import KmerTools
else:
        print("CoLab not working. On my PC, use relative paths.")
        DATAPATH='data/'  # must end in "/"
        sys.path.append("..") # append parent dir in order to use sibling dirs
        from SimTools.GenCodeTools import GenCodeLoader
        from SimTools.KmerTools import KmerTools
MODELPATH="BestModel"  # saved on cloud instance and lost after logout
#MODELPATH=DATAPATH+MODELPATH  # saved on Google Drive but requires login
# Out:
# On Google CoLab, mount cloud-local file, get our code from GitHub.
# Mounted at /content/drive/

# %% [markdown]
# ## Data Load
# Restrict mRNA to those transcripts with a recognized ORF.

# %%
PC_FILENAME='gencode.v38.pc_transcripts.fa.gz'
NC_FILENAME='gencode.v38.lncRNA_transcripts.fa.gz'
PC_FULLPATH=DATAPATH+PC_FILENAME
NC_FULLPATH=DATAPATH+NC_FILENAME

# %%
# Full GenCode ver 38 human is 106143 pc + 48752 nc and loads in 7 sec.
# Expect fewer transcripts if special filtering is used.
loader=GenCodeLoader()
loader.set_label(1)
loader.set_check_utr(True)
pcdf=loader.load_file(PC_FULLPATH)
print("PC seqs loaded:",len(pcdf))
loader.set_label(0)
loader.set_check_utr(False)
ncdf=loader.load_file(NC_FULLPATH)
print("NC seqs loaded:",len(ncdf))
show_time()
# Out:
# PC seqs loaded: 70825
# NC seqs loaded: 48752
# 2021-07-12 14:53:51 UTC

# %% [markdown]
# ## Data Prep

# %%
def dataframe_length_filter(df,low_high):
    (low,high)=low_high
    # The pandas query language is strange, 
    # but this is MUCH faster than loop & drop.
    return df[ (df['seqlen']>=low) & (df['seqlen']<=high) ]
def dataframe_shuffle(df):
    # The ignore_index option is new in Pandas 1.3. 
    # The default (False) replicates the old behavior: shuffle the index too.
    # The new option seems more logical th
    # After shuffling, df.iloc[0] has index == 0.
    # return df.sample(frac=1,ignore_index=True)
    return df.sample(frac=1)  # Use this till CoLab upgrades Pandas
def dataframe_extract_sequence(df):
    return df['sequence'].tolist()

pc_all = dataframe_extract_sequence(
    dataframe_shuffle(
    dataframe_length_filter(pcdf,PC_LENS)))
nc_all = dataframe_extract_sequence(
    dataframe_shuffle(
    dataframe_length_filter(ncdf,NC_LENS)))

show_time()
print("PC seqs pass filter:",len(pc_all))
print("NC seqs pass filter:",len(nc_all))
# Garbage collection to reduce RAM footprint
pcdf=None
ncdf=None
# Out:
# 2021-07-12 14:53:51 UTC
# PC seqs pass filter: 55381
# NC seqs pass filter: 46919

# %%
# Any portion of a shuffled list is a random selection
pc_train=pc_all[:PC_TRAINS] 
nc_train=nc_all[:NC_TRAINS]
pc_test=pc_all[PC_TRAINS:PC_TRAINS+PC_TESTS] 
nc_test=nc_all[NC_TRAINS:NC_TRAINS+PC_TESTS]
print("PC train, NC train:",len(pc_train),len(nc_train))
print("PC test, NC test:",len(pc_test),len(nc_test))
# Garbage collection
pc_all=None
nc_all=None
# Out:
# PC train, NC train: 20000 20000
# PC test, NC test: 5000 5000

# %%
def prepare_x_and_y(seqs1,seqs0):
    len1=len(seqs1)
    len0=len(seqs0)
    labels1=np.ones(len1,dtype=np.int8)
    labels0=np.zeros(len0,dtype=np.int8)
    all_labels = np.concatenate((labels1,labels0))
    seqs1 = np.asarray(seqs1)
    seqs0 = np.asarray(seqs0)
    all_seqs = np.concatenate((seqs1,seqs0),axis=0)
    # return all_seqs,all_labels  # test unshuffled
    tandem=(all_seqs,all_labels)
    X,y = shuffle(tandem) # sklearn.utils.shuffle
    return X,y
Xseq,y=prepare_x_and_y(pc_train,nc_train)
#print(pc_train[0])
#print(Xseq[0],y[0])
show_time()
# Out:
# 2021-07-12 14:53:52 UTC

# %%
def seqs_to_kmer_freqs(seqs,max_K):
    tool = KmerTools()  # from SimTools
    empty = tool.make_dict_upto_K(max_K)
    collection = []
    for seq in seqs:
        counts = empty
        # Last param should be True when using Harvester.
        counts = tool.update_count_one_K(counts,max_K,seq,False)
        # Given counts for K=3, Harvester fills in counts for K=1,2.
        #counts = tool.harvest_counts_from_K(counts,max_K)
        fdict = tool.count_to_frequency(counts,max_K)
        freqs = list(fdict.values())
        collection.append(freqs)
    return np.asarray(collection)
Xfrq=seqs_to_kmer_freqs(Xseq,MAX_K)
show_time()
print("X shape",np.shape(Xfrq))
print(type(Xfrq),"of",type(Xfrq[0]),"of",type(Xfrq[0][0]))
print("y shape",np.shape(y))
# Out:
# 2021-07-12 14:54:17 UTC
# X shape (40000, 84)
# <class 'numpy.ndarray'> of <class 'numpy.ndarray'> of <class 'numpy.float64'>
# y shape (40000,)

# %% [markdown]
# ## Neural network

# %%
def make_DNN():
    dt=np.float32
    print("make_DNN")
    print("input shape:",INPUT_SHAPE)
    dnn = Sequential()
    dnn.add(Dense(NEURONS,activation="sigmoid",dtype=dt))
    dnn.add(Dense(NEURONS,activation="sigmoid",dtype=dt)) 
    #dnn.add(Dropout(DROP_RATE))
    dnn.add(Dense(1,activation="sigmoid",dtype=dt))   
    dnn.compile(optimizer='adam',
                loss=BinaryCrossentropy(from_logits=False),
                metrics=['accuracy'])   # add to default metrics=loss
    dnn.build(input_shape=INPUT_SHAPE) 
    return dnn
model = make_DNN()
print(model.summary())
# Out:
# make_DNN
# input shape: (None, 84)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               10880
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 27,521
# Trainable params: 27,521
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def do_cross_validation(X,y):
    cv_scores = []
    fold=0
    mycallbacks = [ModelCheckpoint(
        filepath=MODELPATH, save_best_only=True, 
        monitor='val_accuracy', mode='max')]   
    splitter = KFold(n_splits=SPLITS)  # this does not shuffle
    for train_index,valid_index in splitter.split(X):
        if fold < FOLDS:
            fold += 1
            X_train=X[train_index] # inputs for training
            y_train=y[train_index] # labels for training
            X_valid=X[valid_index] # inputs for validation
            y_valid=y[valid_index] # labels for validation
            print("MODEL")
            # Call constructor on each CV. Else, continually improves the same model.
            model = model = make_DNN()
            print("FIT")  # model.fit() implements learning
            start_time=time.time()
            history=model.fit(X_train, y_train, 
                    epochs=EPOCHS, 
                    verbose=1,  # ascii art while learning
                    callbacks=mycallbacks,   # called at end of each epoch
                    validation_data=(X_valid,y_valid))
            end_time=time.time()
            elapsed_time=(end_time-start_time)                        
            print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
            # print(history.history.keys())  # all these keys will be shown in figure
            pd.DataFrame(history.history).plot(figsize=(8,5))
            plt.grid(True)
            plt.gca().set_ylim(0,1) # any losses > 1 will be off the scale
            plt.show()

# %%
do_cross_validation(Xfrq,y)
# Out:
# MODEL
# make_DNN
# input shape: (None, 84)
# FIT
# Epoch 1/25
# 1000/1000 [==============================] - 15s 3ms/step - loss: 0.6643 - accuracy: 0.6276 - val_loss: 0.8073 - val_accuracy: 0.0000e+00
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 2/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6647 - accuracy: 0.6245 - val_loss: 1.0278 - val_accuracy: 0.0000e+00
# Epoch 3/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6611 - accuracy: 0.6266 - val_loss: 0.9131 - val_accuracy: 0.0000e+00
# Epoch 4/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6594 - accuracy: 0.6234 - val_loss: 0.9689 - val_accuracy: 0.0000e+00
# Epoch 5/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6508 - accuracy: 0.6250 - val_loss: 0.8755 - val_accuracy: 5.0000e-04
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 6/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6107 - accuracy: 0.6479 - val_loss: 0.9337 - val_accuracy: 0.0036
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 7/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.5183 - accuracy: 0.7565 - val_loss: 0.4273 - val_accuracy: 0.9836
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 8/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.4046 - accuracy: 0.8841 - val_loss: 0.9962 - val_accuracy: 0.0081
# Epoch 9/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.3265 - accuracy: 0.9134 - val_loss: 0.3579 - val_accuracy: 0.9423
# Epoch 10/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2834 - accuracy: 0.9228 - val_loss: 0.3533 - val_accuracy: 0.9335
# Epoch 11/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2447 - accuracy: 0.9290 - val_loss: 0.5411 - val_accuracy: 0.9244
# Epoch 12/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2214 - accuracy: 0.9347 - val_loss: 0.6032 - val_accuracy: 0.9229
# Epoch 13/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2106 - accuracy: 0.9340 - val_loss: 0.4456 - val_accuracy: 0.9260
# Epoch 14/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1945 - accuracy: 0.9372 - val_loss: 0.7313 - val_accuracy: 0.8087
# Epoch 15/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1837 - accuracy: 0.9412 - val_loss: 0.5356 - val_accuracy: 0.9243
# Epoch 16/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1827 - accuracy: 0.9415 - val_loss: 0.4146 - val_accuracy: 0.9261
# Epoch 17/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1673 - accuracy: 0.9460 - val_loss: 0.4464 - val_accuracy: 0.9251
# Epoch 18/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1641 - accuracy: 0.9468 - val_loss: 0.4470 - val_accuracy: 0.9251
# Epoch 19/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1634 - accuracy: 0.9475 - val_loss: 0.4736 - val_accuracy: 0.9247
# Epoch 20/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1531 - accuracy: 0.9496 - val_loss: 0.3311 - val_accuracy: 0.9276
# Epoch 21/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1543 - accuracy: 0.9488 - val_loss: 0.2804 - val_accuracy: 0.9299
# Epoch 22/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1499 - accuracy: 0.9525 - val_loss: 0.3435 - val_accuracy: 0.9270
# Epoch 23/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1492 - accuracy: 0.9519 - val_loss: 0.6647 - val_accuracy: 0.9189
# Epoch 24/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1445 - accuracy: 0.9527 - val_loss: 0.6031 - val_accuracy: 0.9234
# Epoch 25/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1391 - accuracy: 0.9551 - val_loss: 0.4677 - val_accuracy: 0.9247
# Fold 1, 25 epochs, 93 sec
# MODEL
# make_DNN
# input shape: (None, 84)
# FIT
# Epoch 1/25
# 1000/1000 [==============================] - 3s 2ms/step - loss: 0.6671 - accuracy: 0.6260 - val_loss: 0.8920 - val_accuracy: 0.0000e+00
# Epoch 2/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6642 - accuracy: 0.6243 - val_loss: 0.9812 - val_accuracy: 0.0000e+00
# Epoch 3/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6628 - accuracy: 0.6244 - val_loss: 0.8743 - val_accuracy: 0.0000e+00
# Epoch 4/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6614 - accuracy: 0.6241 - val_loss: 0.9818 - val_accuracy: 0.0000e+00
# Epoch 5/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6531 - accuracy: 0.6259 - val_loss: 0.7894 - val_accuracy: 0.0000e+00
# Epoch 6/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6243 - accuracy: 0.6376 - val_loss: 0.9601 - val_accuracy: 0.0000e+00
# Epoch 7/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.5544 - accuracy: 0.6985 - val_loss: 0.5445 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 8/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.4505 - accuracy: 0.8328 - val_loss: 0.3524 - val_accuracy: 1.0000
# Epoch 9/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.3765 - accuracy: 0.8787 - val_loss: 0.3282 - val_accuracy: 1.0000
# Epoch 10/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.3188 - accuracy: 0.8998 - val_loss: 0.1922 - val_accuracy: 1.0000
# Epoch 11/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2847 - accuracy: 0.9071 - val_loss: 0.3075 - val_accuracy: 1.0000
# Epoch 12/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2642 - accuracy: 0.9085 - val_loss: 0.1848 - val_accuracy: 1.0000
# Epoch 13/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2597 - accuracy: 0.9067 - val_loss: 0.4534 - val_accuracy: 1.0000
# Epoch 14/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2429 - accuracy: 0.9157 - val_loss: 0.1164 - val_accuracy: 1.0000
# Epoch 15/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2396 - accuracy: 0.9124 - val_loss: 0.1017 - val_accuracy: 1.0000
# Epoch 16/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2277 - accuracy: 0.9184 - val_loss: 0.1471 - val_accuracy: 1.0000
# Epoch 17/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2250 - accuracy: 0.9185 - val_loss: 0.1418 - val_accuracy: 1.0000
# Epoch 18/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2220 - accuracy: 0.9222 - val_loss: 0.3055 - val_accuracy: 1.0000
# Epoch 19/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2272 - accuracy: 0.9173 - val_loss: 0.3892 - val_accuracy: 1.0000
# Epoch 20/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2214 - accuracy: 0.9214 - val_loss: 0.3401 - val_accuracy: 1.0000
# Epoch 21/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2135 - accuracy: 0.9229 - val_loss: 0.1705 - val_accuracy: 1.0000
# Epoch 22/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2139 - accuracy: 0.9214 - val_loss: 0.2195 - val_accuracy: 1.0000
# Epoch 23/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2117 - accuracy: 0.9219 - val_loss: 0.1553 - val_accuracy: 1.0000
# Epoch 24/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2057 - accuracy: 0.9237 - val_loss: 0.1860 - val_accuracy: 1.0000
# Epoch 25/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2081 - accuracy: 0.9245 - val_loss: 0.2153 - val_accuracy: 1.0000
# Fold 2, 25 epochs, 82 sec
# MODEL
# make_DNN
# input shape: (None, 84)
# FIT
# Epoch 1/25
# 1000/1000 [==============================] - 3s 2ms/step - loss: 0.6983 - accuracy: 0.4933 - val_loss: 0.6959 - val_accuracy: 0.5000
# Epoch 2/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6950 - accuracy: 0.5031 - val_loss: 0.6962 - val_accuracy: 0.5000
# Epoch 3/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6905 - accuracy: 0.5307 - val_loss: 0.6936 - val_accuracy: 0.5000
# Epoch 4/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6780 - accuracy: 0.5819 - val_loss: 0.6859 - val_accuracy: 0.5000
# Epoch 5/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6223 - accuracy: 0.7223 - val_loss: 0.6796 - val_accuracy: 0.5000
# Epoch 6/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.4598 - accuracy: 0.9409 - val_loss: 0.6953 - val_accuracy: 0.5000
# Epoch 7/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2864 - accuracy: 0.9600 - val_loss: 0.7725 - val_accuracy: 0.5000
# Epoch 8/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1795 - accuracy: 0.9730 - val_loss: 0.7608 - val_accuracy: 0.5000
# Epoch 9/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1242 - accuracy: 0.9783 - val_loss: 0.9962 - val_accuracy: 0.5000
# Epoch 10/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0966 - accuracy: 0.9861 - val_loss: 0.8848 - val_accuracy: 0.5200
# Epoch 11/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0775 - accuracy: 0.9889 - val_loss: 0.8806 - val_accuracy: 0.5539
# Epoch 12/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0677 - accuracy: 0.9877 - val_loss: 0.9830 - val_accuracy: 0.5433
# Epoch 13/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0600 - accuracy: 0.9883 - val_loss: 1.1163 - val_accuracy: 0.5200
# Epoch 14/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0555 - accuracy: 0.9900 - val_loss: 1.4583 - val_accuracy: 0.5000
# Epoch 15/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0614 - accuracy: 0.9870 - val_loss: 0.5247 - val_accuracy: 0.7442
# Epoch 16/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0551 - accuracy: 0.9881 - val_loss: 0.9097 - val_accuracy: 0.6230
# Epoch 17/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0530 - accuracy: 0.9881 - val_loss: 1.4075 - val_accuracy: 0.5021
# Epoch 18/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0473 - accuracy: 0.9893 - val_loss: 0.8285 - val_accuracy: 0.6609
# Epoch 19/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0500 - accuracy: 0.9881 - val_loss: 1.0549 - val_accuracy: 0.6037
# Epoch 20/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0447 - accuracy: 0.9902 - val_loss: 1.2079 - val_accuracy: 0.5721
# Epoch 21/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0420 - accuracy: 0.9911 - val_loss: 1.8798 - val_accuracy: 0.5000
# Epoch 22/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0460 - accuracy: 0.9900 - val_loss: 1.4786 - val_accuracy: 0.5222
# Epoch 23/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0412 - accuracy: 0.9916 - val_loss: 1.6690 - val_accuracy: 0.5000
# Epoch 24/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0478 - accuracy: 0.9892 - val_loss: 0.9073 - val_accuracy: 0.6610
# Epoch 25/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0415 - accuracy: 0.9902 - val_loss: 0.5330 - val_accuracy: 0.7614
# Fold 3, 25 epochs, 53 sec
# MODEL
# make_DNN
# input shape: (None, 84)
# FIT
# Epoch 1/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.6628 - accuracy: 0.6305 - val_loss: 1.0181 - val_accuracy: 0.0000e+00
# Epoch 2/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6629 - accuracy: 0.6280 - val_loss: 1.0511 - val_accuracy: 0.0000e+00
# Epoch 3/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6625 - accuracy: 0.6216 - val_loss: 0.8932 - val_accuracy: 0.0000e+00
# Epoch 4/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6565 - accuracy: 0.6221 - val_loss: 0.9274 - val_accuracy: 0.0000e+00
# Epoch 5/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6306 - accuracy: 0.6396 - val_loss: 0.6280 - val_accuracy: 0.9831
# Epoch 6/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.5688 - accuracy: 0.7520 - val_loss: 0.9193 - val_accuracy: 0.0000e+00
# Epoch 7/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.4481 - accuracy: 0.8715 - val_loss: 0.4239 - val_accuracy: 0.9865
# Epoch 8/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.3645 - accuracy: 0.8720 - val_loss: 0.3146 - val_accuracy: 1.0000
# Epoch 9/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.3229 - accuracy: 0.8728 - val_loss: 0.2746 - val_accuracy: 1.0000
# Epoch 10/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2979 - accuracy: 0.8740 - val_loss: 0.3426 - val_accuracy: 0.8972
# Epoch 11/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2825 - accuracy: 0.8802 - val_loss: 0.2519 - val_accuracy: 0.9824
# Epoch 12/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2782 - accuracy: 0.8816 - val_loss: 0.1629 - val_accuracy: 1.0000
# Epoch 13/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2728 - accuracy: 0.8846 - val_loss: 0.1479 - val_accuracy: 1.0000
# Epoch 14/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2622 - accuracy: 0.8872 - val_loss: 0.1419 - val_accuracy: 1.0000
# Epoch 15/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2674 - accuracy: 0.8856 - val_loss: 0.0731 - val_accuracy: 1.0000
# Epoch 16/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2576 - accuracy: 0.8938 - val_loss: 0.1954 - val_accuracy: 0.9764
# Epoch 17/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2620 - accuracy: 0.8925 - val_loss: 0.0835 - val_accuracy: 1.0000
# Epoch 18/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2525 - accuracy: 0.8971 - val_loss: 0.0598 - val_accuracy: 1.0000
# Epoch 19/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2581 - accuracy: 0.8983 - val_loss: 0.0737 - val_accuracy: 1.0000
# Epoch 20/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2529 - accuracy: 0.8986 - val_loss: 0.0431 - val_accuracy: 1.0000
# Epoch 21/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2468 - accuracy: 0.9040 - val_loss: 0.0614 - val_accuracy: 1.0000
# Epoch 22/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2483 - accuracy: 0.9042 - val_loss: 0.0514 - val_accuracy: 1.0000
# Epoch 23/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2421 - accuracy: 0.9072 - val_loss: 0.0146 - val_accuracy: 1.0000
# Epoch 24/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2504 - accuracy: 0.9052 - val_loss: 0.0408 - val_accuracy: 1.0000
# Epoch 25/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2454 - accuracy: 0.9070 - val_loss: 0.0350 - val_accuracy: 1.0000
# Fold 4, 25 epochs, 82 sec
# MODEL
# make_DNN
# input shape: (None, 84)
# FIT
# Epoch 1/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.6735 - accuracy: 0.6165 - val_loss: 0.8491 - val_accuracy: 0.0000e+00
# Epoch 2/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6651 - accuracy: 0.6247 - val_loss: 0.9931 - val_accuracy: 0.0000e+00
# Epoch 3/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.6647 - accuracy: 0.6228 - val_loss: 1.0388 - val_accuracy: 0.0000e+00
# Epoch 4/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.6621 - accuracy: 0.6268 - val_loss: 1.0849 - val_accuracy: 0.0000e+00
# Epoch 5/25
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.6614 - accuracy: 0.6265 - val_loss: 0.8959 - val_accuracy: 0.0000e+00
# Epoch 6/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6599 - accuracy: 0.6269 - val_loss: 0.8541 - val_accuracy: 0.0000e+00
# Epoch 7/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6597 - accuracy: 0.6233 - val_loss: 0.9866 - val_accuracy: 0.0000e+00
# Epoch 8/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6511 - accuracy: 0.6298 - val_loss: 0.8489 - val_accuracy: 0.0000e+00
# Epoch 9/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.6321 - accuracy: 0.6377 - val_loss: 0.5895 - val_accuracy: 1.0000
# Epoch 10/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.5943 - accuracy: 0.6890 - val_loss: 0.4065 - val_accuracy: 1.0000
# Epoch 11/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.5435 - accuracy: 0.7661 - val_loss: 0.2658 - val_accuracy: 1.0000
# Epoch 12/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.4848 - accuracy: 0.8218 - val_loss: 0.1529 - val_accuracy: 1.0000
# Epoch 13/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.4207 - accuracy: 0.8608 - val_loss: 0.0865 - val_accuracy: 1.0000
# Epoch 14/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.3728 - accuracy: 0.8750 - val_loss: 0.0391 - val_accuracy: 1.0000
# Epoch 15/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.3407 - accuracy: 0.8861 - val_loss: 0.0100 - val_accuracy: 1.0000
# Epoch 16/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.3080 - accuracy: 0.8940 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 17/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2945 - accuracy: 0.8958 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 18/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2806 - accuracy: 0.9037 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 19/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2681 - accuracy: 0.9038 - val_loss: 8.2429e-04 - val_accuracy: 1.0000
# Epoch 20/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2633 - accuracy: 0.9046 - val_loss: 8.1696e-04 - val_accuracy: 1.0000
# Epoch 21/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2610 - accuracy: 0.9111 - val_loss: 4.2873e-04 - val_accuracy: 1.0000
# Epoch 22/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2511 - accuracy: 0.9095 - val_loss: 5.2125e-04 - val_accuracy: 1.0000
# Epoch 23/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2490 - accuracy: 0.9093 - val_loss: 8.7724e-05 - val_accuracy: 1.0000
# Epoch 24/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2469 - accuracy: 0.9135 - val_loss: 1.3822e-04 - val_accuracy: 1.0000
# Epoch 25/25
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.2475 - accuracy: 0.9131 - val_loss: 2.5924e-05 - val_accuracy: 1.0000
# Fold 5, 25 epochs, 57 sec

# %%
# TO DO: run trained model on (pc_test,nc_test)
# and draw the AUC.
# Borrow code from other notebooks.
