# %% [markdown]
# # ORF recognition by CNN
# Reproduce the experiment by Keagen & John.
#
# TO DO: Is there any base composition bias in ORF vs random?
#
# TO DO: Grid search. See [Brownlee](https://machinelearningmastery.com/grid-search-hyperparameters-deep-learning-models-python-keras/)

# %%
PC_SEQUENCES=2000   # how many protein-coding sequences
NC_SEQUENCES=2000   # how many non-coding sequences
PC_TESTS=1000
NC_TESTS=1000
BASES=1000            # how long is each sequence
ALPHABET=4          # how many different letters are possible
INPUT_SHAPE_2D = (BASES,ALPHABET,1) # Conv2D needs 3D inputs
INPUT_SHAPE = (BASES,ALPHABET) # Conv1D needs 2D inputs
FILTERS = 8   # how many different patterns the model looks for
WIDTH = 3   # how wide each pattern is, in bases
STRIDE_2D = (1,1)  # For Conv2D how far in each direction
STRIDE = 1 # For Conv1D, how far between pattern matches, in bases
EPOCHS=50  # how many times to train on all the data
SPLITS=5  # SPLITS=3 means train on 2/3 and validate on 1/3 
FOLDS=5  # train the model this many times (range 1 to SPLITS)

# %%
import sys
try:
    from google.colab import drive
    IN_COLAB = True
    print("On Google CoLab, mount cloud-local file, get our code from GitHub.")
    PATH='/content/drive/'
    #drive.mount(PATH,force_remount=True)  # hardly ever need this
    #drive.mount(PATH)    # Google will require login credentials
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/RNA_gen.py')
    with open('RNA_gen.py', 'w') as f:
        f.write(r.text)  
    from RNA_gen import *
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/RNA_describe.py')
    with open('RNA_describe.py', 'w') as f:
        f.write(r.text)  
    from RNA_describe import *
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/Soars2021/master/SimTools/RNA_prep.py')
    with open('RNA_prep.py', 'w') as f:
        f.write(r.text)  
    from RNA_prep import *
except:
    print("CoLab not working. On my PC, use relative paths.")
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"
    sys.path.append("..") # append parent dir in order to use sibling dirs
    from SimTools.RNA_gen import *
    from SimTools.RNA_describe import *
    from SimTools.RNA_prep import *

MODELPATH="BestModel"  # saved on cloud instance and lost after logout
#MODELPATH=DATAPATH+MODELPATH  # saved on Google Drive but requires login

if not assert_imported_RNA_gen():
    print("ERROR: Cannot use RNA_gen.")
if not assert_imported_RNA_prep():
    print("ERROR: Cannot use RNA_prep.")
# Out:
# CoLab not working. On my PC, use relative paths.

# %%
from os import listdir
import time # datetime
import csv
from zipfile import ZipFile

import numpy as np
import pandas as pd
from scipy import stats  # mode

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

from keras.models import Sequential
from keras.layers import Dense,Embedding
from keras.layers import Conv1D,Conv2D
from keras.layers import Flatten,MaxPooling1D,MaxPooling2D
from keras.losses import BinaryCrossentropy
# tf.keras.losses.BinaryCrossentropy

import matplotlib.pyplot as plt
from matplotlib import colors
mycmap = colors.ListedColormap(['red','blue'])  # list color for label 0 then 1
np.set_printoptions(precision=2)

# %%
t = time.time()
time.strftime('%Y-%m-%d %H:%M:%S %Z', time.localtime(t))
# Out:
# '2021-05-16 15:13:36 EDT'

# %%
# Use code from our SimTools library.
def make_generators(seq_len):
    pcgen = Collection_Generator()  
    pcgen.get_len_oracle().set_mean(seq_len)
    pcgen.set_seq_oracle(Transcript_Oracle())
    ncgen = Collection_Generator()  
    ncgen.get_len_oracle().set_mean(seq_len)
    return pcgen,ncgen

pc_sim,nc_sim = make_generators(BASES)
pc_train = pc_sim.get_sequences(PC_SEQUENCES)
nc_train = nc_sim.get_sequences(NC_SEQUENCES)
print("Train on",len(pc_train),"PC seqs")
print("Train on",len(nc_train),"NC seqs")
# Out:
# Train on 2000 PC seqs
# Train on 2000 NC seqs

# %%
# Use code from our LearnTools library.
X,y = prepare_inputs_len_x_alphabet(pc_train,nc_train,ALPHABET) # shuffles
print("Data ready.")
# Out:
# Data ready.

# %%
def make_DNN():
    print("make_DNN")
    print("input shape:",INPUT_SHAPE)
    dnn = Sequential()
    #dnn.add(Embedding(input_dim=4,output_dim=4)) 
    dnn.add(Conv1D(filters=FILTERS,kernel_size=WIDTH,strides=STRIDE,
                  padding="same",input_shape=INPUT_SHAPE))
    # Data shape: [SAMPLES,BASES,FILTERS]
    #dnn.add(MaxPooling1D())
    dnn.add(Flatten())
    # Data shape: [SAMPLES,BASES*FILTERS]
    dnn.add(Dense(1,activation="sigmoid",dtype=np.float32))   
    dnn.compile(optimizer='adam',
                loss=BinaryCrossentropy(from_logits=False),
                metrics=['accuracy'])   # add to default metrics=loss
    dnn.build(input_shape=INPUT_SHAPE)
    #ln_rate = tf.keras.optimizers.Adam(learning_rate = LN_RATE)
    #bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    #model.compile(loss=bc, optimizer=ln_rate, metrics=["accuracy"])
    return dnn
model = make_DNN()
print(model.summary())
# Out:
# make_DNN
# input shape: (1000, 4)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 1000, 8)           104
# _________________________________________________________________
# flatten (Flatten)            (None, 8000)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 8001
# =================================================================
# Total params: 8,105
# Trainable params: 8,105
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from keras.callbacks import ModelCheckpoint
def do_cross_validation(X,y):
    cv_scores = []
    fold=0
    mycallbacks = [ModelCheckpoint(
        filepath=MODELPATH, save_best_only=True, 
        monitor='val_accuracy', mode='max')]   
    splitter = KFold(n_splits=SPLITS)  # this does not shuffle
    for train_index,valid_index in splitter.split(X):
        if fold < FOLDS:
            fold += 1
            X_train=X[train_index] # inputs for training
            y_train=y[train_index] # labels for training
            X_valid=X[valid_index] # inputs for validation
            y_valid=y[valid_index] # labels for validation
            print("MODEL")
            # Call constructor on each CV. Else, continually improves the same model.
            model = model = make_DNN()
            print("FIT")  # model.fit() implements learning
            start_time=time.time()
            history=model.fit(X_train, y_train, 
                    epochs=EPOCHS, 
                    verbose=1,  # ascii art while learning
                    callbacks=mycallbacks,   # called at end of each epoch
                    validation_data=(X_valid,y_valid))
            end_time=time.time()
            elapsed_time=(end_time-start_time)                        
            print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
            # print(history.history.keys())  # all these keys will be shown in figure
            pd.DataFrame(history.history).plot(figsize=(8,5))
            plt.grid(True)
            plt.gca().set_ylim(0,1) # any losses > 1 will be off the scale
            plt.show()

# %%
do_cross_validation(X,y)
# Out:
# MODEL
# make_DNN
# input shape: (1000, 4)
# FIT
# Epoch 1/50
# 100/100 [==============================] - 3s 20ms/step - loss: 0.7228 - accuracy: 0.5198 - val_loss: 0.7128 - val_accuracy: 0.5387
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 2/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.5078 - accuracy: 0.7997 - val_loss: 0.7443 - val_accuracy: 0.5362
# Epoch 3/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4201 - accuracy: 0.8462 - val_loss: 0.7941 - val_accuracy: 0.5500
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 4/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3433 - accuracy: 0.8894 - val_loss: 0.8553 - val_accuracy: 0.5425
# Epoch 5/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2991 - accuracy: 0.9056 - val_loss: 0.9312 - val_accuracy: 0.5450
# Epoch 6/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2514 - accuracy: 0.9273 - val_loss: 1.0111 - val_accuracy: 0.5400
# Epoch 7/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2153 - accuracy: 0.9456 - val_loss: 1.0943 - val_accuracy: 0.5387
# Epoch 8/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1784 - accuracy: 0.9619 - val_loss: 1.1852 - val_accuracy: 0.5375
# Epoch 9/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.1590 - accuracy: 0.9708 - val_loss: 1.2848 - val_accuracy: 0.5312
# Epoch 10/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1349 - accuracy: 0.9857 - val_loss: 1.3816 - val_accuracy: 0.5325
# Epoch 11/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1151 - accuracy: 0.9926 - val_loss: 1.4817 - val_accuracy: 0.5350
# Epoch 12/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0923 - accuracy: 0.9963 - val_loss: 1.5829 - val_accuracy: 0.5300
# Epoch 13/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0788 - accuracy: 0.9962 - val_loss: 1.6787 - val_accuracy: 0.5312
# Epoch 14/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0673 - accuracy: 0.9993 - val_loss: 1.7743 - val_accuracy: 0.5300
# Epoch 15/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0562 - accuracy: 0.9999 - val_loss: 1.8689 - val_accuracy: 0.5263
# Epoch 16/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0498 - accuracy: 1.0000 - val_loss: 1.9698 - val_accuracy: 0.5362
# Epoch 17/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0409 - accuracy: 1.0000 - val_loss: 2.0508 - val_accuracy: 0.5350
# Epoch 18/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0361 - accuracy: 1.0000 - val_loss: 2.1349 - val_accuracy: 0.5350
# Epoch 19/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0324 - accuracy: 1.0000 - val_loss: 2.2218 - val_accuracy: 0.5300
# Epoch 20/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0284 - accuracy: 1.0000 - val_loss: 2.3058 - val_accuracy: 0.5325
# Epoch 21/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0243 - accuracy: 1.0000 - val_loss: 2.3864 - val_accuracy: 0.5263
# Epoch 22/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0213 - accuracy: 1.0000 - val_loss: 2.4570 - val_accuracy: 0.5288
# Epoch 23/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0193 - accuracy: 1.0000 - val_loss: 2.5335 - val_accuracy: 0.5275
# Epoch 24/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0173 - accuracy: 1.0000 - val_loss: 2.6034 - val_accuracy: 0.5300
# Epoch 25/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0157 - accuracy: 1.0000 - val_loss: 2.6702 - val_accuracy: 0.5312
# Epoch 26/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 2.7420 - val_accuracy: 0.5263
# Epoch 27/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 2.8086 - val_accuracy: 0.5288
# Epoch 28/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 2.8722 - val_accuracy: 0.5263
# Epoch 29/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 2.9326 - val_accuracy: 0.5300
# Epoch 30/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 2.9919 - val_accuracy: 0.5263
# Epoch 31/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 3.0521 - val_accuracy: 0.5288
# Epoch 32/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 3.1089 - val_accuracy: 0.5275
# Epoch 33/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 3.1677 - val_accuracy: 0.5263
# Epoch 34/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 3.2206 - val_accuracy: 0.5250
# Epoch 35/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 3.2790 - val_accuracy: 0.5275
# Epoch 36/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 3.3318 - val_accuracy: 0.5250
# Epoch 37/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 3.3831 - val_accuracy: 0.5312
# Epoch 38/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 3.4361 - val_accuracy: 0.5288
# Epoch 39/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 3.4872 - val_accuracy: 0.5312
# Epoch 40/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 3.5406 - val_accuracy: 0.5325
# Epoch 41/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 3.5892 - val_accuracy: 0.5325
# Epoch 42/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 3.6380 - val_accuracy: 0.5337
# Epoch 43/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 3.6882 - val_accuracy: 0.5325
# Epoch 44/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 3.7343 - val_accuracy: 0.5312
# Epoch 45/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 3.7819 - val_accuracy: 0.5325
# Epoch 46/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 3.8310 - val_accuracy: 0.5325
# Epoch 47/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 3.8756 - val_accuracy: 0.5337
# Epoch 48/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 3.9252 - val_accuracy: 0.5312
# Epoch 49/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 3.9691 - val_accuracy: 0.5362
# Epoch 50/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 4.0151 - val_accuracy: 0.5312
# Fold 1, 50 epochs, 34 sec
# MODEL
# make_DNN
# input shape: (1000, 4)
# FIT
# Epoch 1/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.7443 - accuracy: 0.5289 - val_loss: 0.6935 - val_accuracy: 0.5475
# Epoch 2/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.5549 - accuracy: 0.7426 - val_loss: 0.7096 - val_accuracy: 0.5675
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 3/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.4567 - accuracy: 0.8285 - val_loss: 0.7421 - val_accuracy: 0.5650
# Epoch 4/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3733 - accuracy: 0.8748 - val_loss: 0.7993 - val_accuracy: 0.5700
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 5/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3167 - accuracy: 0.9035 - val_loss: 0.8730 - val_accuracy: 0.5600
# Epoch 6/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2745 - accuracy: 0.9209 - val_loss: 0.9449 - val_accuracy: 0.5738
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 7/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2264 - accuracy: 0.9517 - val_loss: 1.0325 - val_accuracy: 0.5700
# Epoch 8/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.2028 - accuracy: 0.9530 - val_loss: 1.1257 - val_accuracy: 0.5575
# Epoch 9/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.1730 - accuracy: 0.9690 - val_loss: 1.2174 - val_accuracy: 0.5688
# Epoch 10/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1470 - accuracy: 0.9804 - val_loss: 1.3215 - val_accuracy: 0.5663
# Epoch 11/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.1280 - accuracy: 0.9848 - val_loss: 1.4097 - val_accuracy: 0.5650
# Epoch 12/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.1111 - accuracy: 0.9906 - val_loss: 1.5162 - val_accuracy: 0.5650
# Epoch 13/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0941 - accuracy: 0.9947 - val_loss: 1.6179 - val_accuracy: 0.5600
# Epoch 14/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0806 - accuracy: 0.9974 - val_loss: 1.7245 - val_accuracy: 0.5625
# Epoch 15/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0679 - accuracy: 0.9996 - val_loss: 1.8204 - val_accuracy: 0.5638
# Epoch 16/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0587 - accuracy: 0.9994 - val_loss: 1.9116 - val_accuracy: 0.5600
# Epoch 17/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0483 - accuracy: 0.9997 - val_loss: 2.0086 - val_accuracy: 0.5625
# Epoch 18/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0400 - accuracy: 0.9999 - val_loss: 2.0959 - val_accuracy: 0.5575
# Epoch 19/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0373 - accuracy: 1.0000 - val_loss: 2.1836 - val_accuracy: 0.5562
# Epoch 20/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0332 - accuracy: 1.0000 - val_loss: 2.2703 - val_accuracy: 0.5587
# Epoch 21/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0279 - accuracy: 1.0000 - val_loss: 2.3531 - val_accuracy: 0.5612
# Epoch 22/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0244 - accuracy: 1.0000 - val_loss: 2.4312 - val_accuracy: 0.5600
# Epoch 23/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 2.5134 - val_accuracy: 0.5587
# Epoch 24/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 2.5875 - val_accuracy: 0.5625
# Epoch 25/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0170 - accuracy: 1.0000 - val_loss: 2.6593 - val_accuracy: 0.5638
# Epoch 26/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 2.7282 - val_accuracy: 0.5625
# Epoch 27/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 2.7968 - val_accuracy: 0.5650
# Epoch 28/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 2.8625 - val_accuracy: 0.5650
# Epoch 29/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 2.9273 - val_accuracy: 0.5638
# Epoch 30/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 2.9934 - val_accuracy: 0.5650
# Epoch 31/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 3.0554 - val_accuracy: 0.5650
# Epoch 32/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 3.1156 - val_accuracy: 0.5638
# Epoch 33/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 3.1739 - val_accuracy: 0.5638
# Epoch 34/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 3.2347 - val_accuracy: 0.5638
# Epoch 35/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 3.2898 - val_accuracy: 0.5688
# Epoch 36/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 3.3483 - val_accuracy: 0.5650
# Epoch 37/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 3.4056 - val_accuracy: 0.5675
# Epoch 38/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 3.4611 - val_accuracy: 0.5650
# Epoch 39/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 3.5099 - val_accuracy: 0.5675
# Epoch 40/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 3.5667 - val_accuracy: 0.5688
# Epoch 41/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 3.6163 - val_accuracy: 0.5663
# Epoch 42/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 3.6683 - val_accuracy: 0.5675
# Epoch 43/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 3.7210 - val_accuracy: 0.5688
# Epoch 44/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 3.7703 - val_accuracy: 0.5675
# Epoch 45/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 3.8190 - val_accuracy: 0.5688
# Epoch 46/50
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 3.8678 - val_accuracy: 0.5675
# Epoch 47/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 3.9162 - val_accuracy: 0.5688
# Epoch 48/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 3.9660 - val_accuracy: 0.5713
# Epoch 49/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 4.0131 - val_accuracy: 0.5688
# Epoch 50/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 4.0598 - val_accuracy: 0.5700
# Fold 2, 50 epochs, 30 sec
# MODEL
# make_DNN
# input shape: (1000, 4)
# FIT
# Epoch 1/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.7613 - accuracy: 0.5079 - val_loss: 0.6921 - val_accuracy: 0.5612
# Epoch 2/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.5410 - accuracy: 0.7523 - val_loss: 0.7047 - val_accuracy: 0.5925
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 3/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4425 - accuracy: 0.8385 - val_loss: 0.7373 - val_accuracy: 0.6025
# INFO:tensorflow:Assets written to: BestModel/assets
# Epoch 4/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3629 - accuracy: 0.8745 - val_loss: 0.7866 - val_accuracy: 0.5763
# Epoch 5/50
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3114 - accuracy: 0.9072 - val_loss: 0.8432 - val_accuracy: 0.5738
# Epoch 6/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2677 - accuracy: 0.9277 - val_loss: 0.9208 - val_accuracy: 0.5688
# Epoch 7/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2249 - accuracy: 0.9443 - val_loss: 1.0058 - val_accuracy: 0.5700
# Epoch 8/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.1926 - accuracy: 0.9626 - val_loss: 1.0981 - val_accuracy: 0.5688
# Epoch 9/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.1618 - accuracy: 0.9755 - val_loss: 1.1928 - val_accuracy: 0.5638
# Epoch 10/50
# 100/100 [==============================] - 1s 8ms/step - loss: 0.1408 - accuracy: 0.9764 - val_loss: 1.2901 - val_accuracy: 0.5675
# Epoch 11/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.1185 - accuracy: 0.9871 - val_loss: 1.3950 - val_accuracy: 0.5625
# Epoch 12/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0979 - accuracy: 0.9951 - val_loss: 1.4971 - val_accuracy: 0.5612
# Epoch 13/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0866 - accuracy: 0.9965 - val_loss: 1.6020 - val_accuracy: 0.5663
# Epoch 14/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0690 - accuracy: 0.9987 - val_loss: 1.6961 - val_accuracy: 0.5600
# Epoch 15/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0587 - accuracy: 0.9997 - val_loss: 1.7915 - val_accuracy: 0.5562
# Epoch 16/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0512 - accuracy: 1.0000 - val_loss: 1.8880 - val_accuracy: 0.5512
# Epoch 17/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0431 - accuracy: 1.0000 - val_loss: 1.9762 - val_accuracy: 0.5500
# Epoch 18/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0369 - accuracy: 1.0000 - val_loss: 2.0670 - val_accuracy: 0.5537
# Epoch 19/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0320 - accuracy: 1.0000 - val_loss: 2.1474 - val_accuracy: 0.5562
# Epoch 20/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0271 - accuracy: 1.0000 - val_loss: 2.2297 - val_accuracy: 0.5525
# Epoch 21/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0244 - accuracy: 1.0000 - val_loss: 2.3079 - val_accuracy: 0.5537
# Epoch 22/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0214 - accuracy: 1.0000 - val_loss: 2.3794 - val_accuracy: 0.5512
# Epoch 23/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0190 - accuracy: 1.0000 - val_loss: 2.4552 - val_accuracy: 0.5550
# Epoch 24/50
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0165 - accuracy: 1.0000 - val_loss: 2.5288 - val_accuracy: 0.5525
# Epoch 25/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 2.5982 - val_accuracy: 0.5525
# Epoch 26/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 2.6611 - val_accuracy: 0.5512
# Epoch 27/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 2.7248 - val_accuracy: 0.5537
# Epoch 28/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 2.7894 - val_accuracy: 0.5525
# Epoch 29/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 2.8522 - val_accuracy: 0.5512
# Epoch 30/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 2.9095 - val_accuracy: 0.5487
# Epoch 31/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 2.9720 - val_accuracy: 0.5500
# Epoch 32/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 3.0252 - val_accuracy: 0.5512
# Epoch 33/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 3.0832 - val_accuracy: 0.5487
# Epoch 34/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 3.1399 - val_accuracy: 0.5475
# Epoch 35/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 3.1914 - val_accuracy: 0.5512
# Epoch 36/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 3.2459 - val_accuracy: 0.5512
# Epoch 37/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 3.2965 - val_accuracy: 0.5525
# Epoch 38/50
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 3.3507 - val_accuracy: 0.5500
# Epoch 39/50
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 3.4045 - val_accuracy: 0.5475
# Epoch 40/50
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 3.4546 - val_accuracy: 0.5475
# Epoch 41/50
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 3.5068 - val_accuracy: 0.5450
# Epoch 42/50
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 3.5535 - val_accuracy: 0.5462
# Epoch 43/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 3.6006 - val_accuracy: 0.5450
# Epoch 44/50
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 3.6496 - val_accuracy: 0.5475
# Epoch 45/50
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 3.6934 - val_accuracy: 0.5475
# Epoch 46/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 3.7411 - val_accuracy: 0.5487
# Epoch 47/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 3.7865 - val_accuracy: 0.5487
# Epoch 48/50
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 3.8348 - val_accuracy: 0.5487
# Epoch 49/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 3.8769 - val_accuracy: 0.5475
# Epoch 50/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 3.9211 - val_accuracy: 0.5512
# Fold 3, 50 epochs, 35 sec
# MODEL
# make_DNN
# input shape: (1000, 4)
# FIT
# Epoch 1/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.7335 - accuracy: 0.5094 - val_loss: 0.7001 - val_accuracy: 0.5238
# Epoch 2/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5217 - accuracy: 0.7800 - val_loss: 0.7167 - val_accuracy: 0.5450
# Epoch 3/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4241 - accuracy: 0.8472 - val_loss: 0.7627 - val_accuracy: 0.5525
# Epoch 4/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3428 - accuracy: 0.8920 - val_loss: 0.8202 - val_accuracy: 0.5688
# Epoch 5/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3016 - accuracy: 0.9055 - val_loss: 0.8968 - val_accuracy: 0.5600
# Epoch 6/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2470 - accuracy: 0.9368 - val_loss: 0.9831 - val_accuracy: 0.5562
# Epoch 7/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2155 - accuracy: 0.9454 - val_loss: 1.0749 - val_accuracy: 0.5638
# Epoch 8/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1747 - accuracy: 0.9713 - val_loss: 1.1691 - val_accuracy: 0.5838
# Epoch 9/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1531 - accuracy: 0.9748 - val_loss: 1.2726 - val_accuracy: 0.5750
# Epoch 10/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1301 - accuracy: 0.9848 - val_loss: 1.3787 - val_accuracy: 0.5663
# Epoch 11/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1099 - accuracy: 0.9896 - val_loss: 1.4712 - val_accuracy: 0.5738
# Epoch 12/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0908 - accuracy: 0.9948 - val_loss: 1.5887 - val_accuracy: 0.5688
# Epoch 13/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0789 - accuracy: 0.9960 - val_loss: 1.6914 - val_accuracy: 0.5688
# Epoch 14/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0660 - accuracy: 0.9990 - val_loss: 1.7870 - val_accuracy: 0.5700
# Epoch 15/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0551 - accuracy: 0.9993 - val_loss: 1.8844 - val_accuracy: 0.5738
# Epoch 16/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0489 - accuracy: 0.9999 - val_loss: 1.9933 - val_accuracy: 0.5663
# Epoch 17/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0413 - accuracy: 1.0000 - val_loss: 2.0821 - val_accuracy: 0.5675
# Epoch 18/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0348 - accuracy: 1.0000 - val_loss: 2.1733 - val_accuracy: 0.5650
# Epoch 19/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0308 - accuracy: 1.0000 - val_loss: 2.2632 - val_accuracy: 0.5700
# Epoch 20/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0269 - accuracy: 1.0000 - val_loss: 2.3402 - val_accuracy: 0.5713
# Epoch 21/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0235 - accuracy: 1.0000 - val_loss: 2.4239 - val_accuracy: 0.5675
# Epoch 22/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0214 - accuracy: 1.0000 - val_loss: 2.5099 - val_accuracy: 0.5650
# Epoch 23/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0185 - accuracy: 1.0000 - val_loss: 2.5877 - val_accuracy: 0.5650
# Epoch 24/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0161 - accuracy: 1.0000 - val_loss: 2.6573 - val_accuracy: 0.5638
# Epoch 25/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 2.7249 - val_accuracy: 0.5638
# Epoch 26/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 2.7940 - val_accuracy: 0.5625
# Epoch 27/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 2.8637 - val_accuracy: 0.5663
# Epoch 28/50
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 2.9317 - val_accuracy: 0.5638
# Epoch 29/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 2.9966 - val_accuracy: 0.5638
# Epoch 30/50
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 3.0598 - val_accuracy: 0.5650
# Epoch 31/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 3.1198 - val_accuracy: 0.5675
# Epoch 32/50
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 3.1789 - val_accuracy: 0.5638
# Epoch 33/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 3.2413 - val_accuracy: 0.5650
# Epoch 34/50
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 3.2971 - val_accuracy: 0.5688
# Epoch 35/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 3.3493 - val_accuracy: 0.5688
# Epoch 36/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 3.4100 - val_accuracy: 0.5675
# Epoch 37/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 3.4630 - val_accuracy: 0.5675
# Epoch 38/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 3.5187 - val_accuracy: 0.5675
# Epoch 39/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 3.5702 - val_accuracy: 0.5675
# Epoch 40/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 3.6250 - val_accuracy: 0.5688
# Epoch 41/50
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 3.6769 - val_accuracy: 0.5688
# Epoch 42/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 3.7276 - val_accuracy: 0.5663
# Epoch 43/50
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 3.7775 - val_accuracy: 0.5688
# Epoch 44/50
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 3.8267 - val_accuracy: 0.5675
# Epoch 45/50
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 3.8785 - val_accuracy: 0.5675
# Epoch 46/50
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 3.9257 - val_accuracy: 0.5675
# Epoch 47/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 3.9745 - val_accuracy: 0.5675
# Epoch 48/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 4.0221 - val_accuracy: 0.5675
# Epoch 49/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 4.0697 - val_accuracy: 0.5675
# Epoch 50/50
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 4.1199 - val_accuracy: 0.5675
# Fold 4, 50 epochs, 34 sec
# MODEL
# make_DNN
# input shape: (1000, 4)
# FIT
# Epoch 1/50
# 100/100 [==============================] - 1s 9ms/step - loss: 0.7247 - accuracy: 0.5203 - val_loss: 0.7099 - val_accuracy: 0.5462
# Epoch 2/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5643 - accuracy: 0.7014 - val_loss: 0.7143 - val_accuracy: 0.5800
# Epoch 3/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4508 - accuracy: 0.8246 - val_loss: 0.7577 - val_accuracy: 0.5775
# Epoch 4/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3650 - accuracy: 0.8755 - val_loss: 0.8184 - val_accuracy: 0.5738
# Epoch 5/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3108 - accuracy: 0.9141 - val_loss: 0.8915 - val_accuracy: 0.5625
# Epoch 6/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2781 - accuracy: 0.9149 - val_loss: 0.9773 - val_accuracy: 0.5825
# Epoch 7/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2358 - accuracy: 0.9416 - val_loss: 1.0650 - val_accuracy: 0.5725
# Epoch 8/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1966 - accuracy: 0.9569 - val_loss: 1.1572 - val_accuracy: 0.5688
# Epoch 9/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1742 - accuracy: 0.9664 - val_loss: 1.2558 - val_accuracy: 0.5688
# Epoch 10/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1472 - accuracy: 0.9794 - val_loss: 1.3568 - val_accuracy: 0.5650
# Epoch 11/50
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1209 - accuracy: 0.9849 - val_loss: 1.4690 - val_accuracy: 0.5675
# Epoch 12/50
# 100/100 [==============================] - 1s 10ms/step - loss: 0.1039 - accuracy: 0.9908 - val_loss: 1.5698 - val_accuracy: 0.5587
# Epoch 13/50
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0883 - accuracy: 0.9931 - val_loss: 1.6738 - val_accuracy: 0.5525
# Epoch 14/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0738 - accuracy: 0.9984 - val_loss: 1.7807 - val_accuracy: 0.5575
# Epoch 15/50
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0644 - accuracy: 0.9988 - val_loss: 1.8868 - val_accuracy: 0.5525
# Epoch 16/50
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0552 - accuracy: 0.9999 - val_loss: 1.9827 - val_accuracy: 0.5487
# Epoch 17/50
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0471 - accuracy: 0.9998 - val_loss: 2.0773 - val_accuracy: 0.5525
# Epoch 18/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0407 - accuracy: 1.0000 - val_loss: 2.1680 - val_accuracy: 0.5450
# Epoch 19/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0344 - accuracy: 1.0000 - val_loss: 2.2628 - val_accuracy: 0.5450
# Epoch 20/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0306 - accuracy: 0.9999 - val_loss: 2.3476 - val_accuracy: 0.5475
# Epoch 21/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0274 - accuracy: 1.0000 - val_loss: 2.4317 - val_accuracy: 0.5475
# Epoch 22/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0220 - accuracy: 1.0000 - val_loss: 2.5159 - val_accuracy: 0.5500
# Epoch 23/50
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0211 - accuracy: 1.0000 - val_loss: 2.5913 - val_accuracy: 0.5462
# Epoch 24/50
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0179 - accuracy: 1.0000 - val_loss: 2.6729 - val_accuracy: 0.5487
# Epoch 25/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 2.7445 - val_accuracy: 0.5462
# Epoch 26/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 2.8168 - val_accuracy: 0.5512
# Epoch 27/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 2.8829 - val_accuracy: 0.5475
# Epoch 28/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 2.9526 - val_accuracy: 0.5500
# Epoch 29/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 3.0181 - val_accuracy: 0.5500
# Epoch 30/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 3.0828 - val_accuracy: 0.5475
# Epoch 31/50
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 3.1496 - val_accuracy: 0.5437
# Epoch 32/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 3.2085 - val_accuracy: 0.5487
# Epoch 33/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 3.2666 - val_accuracy: 0.5487
# Epoch 34/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 3.3268 - val_accuracy: 0.5475
# Epoch 35/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 3.3915 - val_accuracy: 0.5450
# Epoch 36/50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 3.4462 - val_accuracy: 0.5487
# Epoch 37/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 3.4989 - val_accuracy: 0.5487
# Epoch 38/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 3.5574 - val_accuracy: 0.5525
# Epoch 39/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 3.6101 - val_accuracy: 0.5487
# Epoch 40/50
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 3.6643 - val_accuracy: 0.5500
# Epoch 41/50
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 3.7182 - val_accuracy: 0.5500
# Epoch 42/50
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 3.7711 - val_accuracy: 0.5475
# Epoch 43/50
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 3.8242 - val_accuracy: 0.5475
# Epoch 44/50
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 3.8766 - val_accuracy: 0.5487
# Epoch 45/50
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 3.9253 - val_accuracy: 0.5475
# Epoch 46/50
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 3.9768 - val_accuracy: 0.5487
# Epoch 47/50
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 4.0244 - val_accuracy: 0.5487
# Epoch 48/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 4.0759 - val_accuracy: 0.5462
# Epoch 49/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 4.1240 - val_accuracy: 0.5462
# Epoch 50/50
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 4.1722 - val_accuracy: 0.5487
# Fold 5, 50 epochs, 38 sec

# %%
from keras.models import load_model
pc_test = pc_sim.get_sequences(PC_TESTS)
nc_test = nc_sim.get_sequences(NC_TESTS)
X,y = prepare_inputs_len_x_alphabet(pc_test,nc_test,ALPHABET)
best_model=load_model(MODELPATH)
scores = best_model.evaluate(X, y, verbose=0)
print("The best model parameters were saved during cross-validation.")
print("Best was defined as maximum validation accuracy at end of any epoch.")
print("Now re-load the best model and test it on previously unseen data.")
print("Test on",len(pc_test),"PC seqs")
print("Test on",len(nc_test),"NC seqs")
print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))
# Out:
# The best model parameters were saved during cross-validation.
# Best was defined as maximum validation accuracy at end of any epoch.
# Now re-load the best model and test it on previously unseen data.
# Test on 1000 PC seqs
# Test on 1000 NC seqs
# accuracy: 59.90%

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
ns_probs = [0 for _ in range(len(y))]
bm_probs = best_model.predict(X)
ns_auc = roc_auc_score(y, ns_probs)
bm_auc = roc_auc_score(y, bm_probs)
ns_fpr, ns_tpr, _ = roc_curve(y, ns_probs)
bm_fpr, bm_tpr, _ = roc_curve(y, bm_probs)
plt.plot(ns_fpr, ns_tpr, linestyle='--', label='Guess, auc=%.4f'%ns_auc)
plt.plot(bm_fpr, bm_tpr, marker='.', label='Model, auc=%.4f'%bm_auc)
plt.title('ROC')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()
print("%s: %.2f%%" %('AUC',bm_auc))
# Out:
# AUC: 0.63%
